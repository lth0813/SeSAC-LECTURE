# %%
import pandas as pd

# %%
realty = pd.read_csv("서울시 부동산 실거래가 정보(2022~2025).csv", encoding="cp949")
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_3096\2780434804.py:1: DtypeWarning: Columns (7,8) have mixed types. Specify dtype option on import or set low_memory=False.
#   realty = pd.read_csv("서울시 부동산 실거래가 정보(2022~2025).csv", encoding="cp949")

# %%
parking = pd.read_csv("서울시 시영주차장 실시간 주차대수 정보.csv", encoding="cp949")

# %%
realty.head()
# Out:
#    접수연도  자치구코드 자치구명  법정동코드 법정동명  지번구분 지번구분명      본번    부번           건물명  ...  \
# 0  2025  11320  도봉구  10600  방학동   1.0    대지   638.0  10.0  한신빌라(638-10)  ...
# 1  2025  11380  은평구  10800  역촌동   NaN   NaN     NaN   NaN           NaN  ...
# 2  2025  11500  강서구  10200  등촌동   1.0    대지   628.0  13.0        현대프린스텔  ...
# 3  2025  11620  관악구  10200  신림동   1.0    대지  1639.0  51.0         푸리마타운  ...
# 4  2025  11530  구로구  10600  고척동   1.0    대지   339.0   0.0      고척파크푸르지오  ...
#
#    물건금액(만원)  건물면적(㎡)  토지면적(㎡)    층  권리구분 취소일    건축년도   건물용도  신고구분  \
# 0     14800    37.66    16.00  4.0   NaN NaN  1994.0  연립다세대  중개거래
# 1     39620    74.08   182.00  NaN   NaN NaN  1972.0  단독다가구   직거래
# 2     10300    26.16    35.71  6.0   NaN NaN  1999.0   오피스텔  중개거래
# 3     12700    18.70    26.16  8.0   NaN NaN  2014.0   오피스텔  중개거래
# 4     84000    59.89     0.00  9.0   NaN NaN  2009.0    아파트  중개거래
#
#   신고한 개업공인중개사 시군구명
# 0           서울 도봉구
# 1              NaN
# 2           서울 강서구
# 3           서울 관악구
# ...

# %%
parking.head()
# Out:
#     주차장코드             주차장명              주소 주차장 종류 주차장 종류명  운영구분    운영구분명  \
# 0  171721     세종로 공영주차장(시)    종로구 세종로 80-1     NW  노외 주차장     1  시간제 주차장
# 1  171730   종묘주차장 공영주차장(시)     종로구 훈정동 2-0     NW  노외 주차장     1  시간제 주차장
# 2  171900   훈련원공원 공영주차장(시)   중구 을지로5가 40-3     NW  노외 주차장     1  시간제 주차장
# 3  172051    한강진역 공영주차장(시)  용산구 한남동 728-27     NW  노외 주차장     1  시간제 주차장
# 4  172065  용산주차빌딩 공영주차장(시)  용산구 한강로2가 12-9     NW  노외 주차장     1  시간제 주차장
#
#            전화번호  주차현황 정보 제공여부                  주차현황 정보 제공여부명  ...  \
# 0  02-2290-6566             1  현재~20분이내 연계데이터 존재(현재 주차대수 표현)  ...
# 1  02-2290-6166             1  현재~20분이내 연계데이터 존재(현재 주차대수 표현)  ...
# 2  02-3405-4597             1  현재~20분이내 연계데이터 존재(현재 주차대수 표현)  ...
# 3   02-795-6406             1  현재~20분이내 연계데이터 존재(현재 주차대수 표현)  ...
# 4  02-2290-6014             1  현재~20분이내 연계데이터 존재(현재 주차대수 표현)  ...
#
#    버스 기본 주차 시간(분 단위)  버스 추가 단위 요금 버스 추가 단위 시간(분 단위)  일 최대 요금 주차장 위치 좌표 위도  \
# ...

# %%
realty.columns
# Out:
# Index(['접수연도', '자치구코드', '자치구명', '법정동코드', '법정동명', '지번구분', '지번구분명', '본번', '부번',
#        '건물명', '계약일', '물건금액(만원)', '건물면적(㎡)', '토지면적(㎡)', '층', '권리구분', '취소일',
#        '건축년도', '건물용도', '신고구분', '신고한 개업공인중개사 시군구명'],
#       dtype='object')

# %%
parking.columns
# Out:
# Index(['주차장코드', '주차장명', '주소', '주차장 종류', '주차장 종류명', '운영구분', '운영구분명', '전화번호',
#        '주차현황 정보 제공여부', '주차현황 정보 제공여부명', '총 주차면', '현재 주차 차량수',
#        '현재 주차 차량수 업데이트시간', '유무료구분', '유무료구분명', '야간무료개방여부', '야간무료개방여부명',
#        '평일 운영 시작시각(HHMM)', '평일 운영 종료시각(HHMM)', '주말 운영 시작시각(HHMM)',
#        '주말 운영 종료시각(HHMM)', '공휴일 운영 시작시각(HHMM)', '공휴일 운영 종료시각(HHMM)',
#        '토요일 유,무료 구분', '토요일 유,무료 구분명', '공휴일 유,무료 구분', '공휴일 유,무료 구분명',
#        '월 정기권 금액', '노상 주차장 관리그룹번호', '기본 주차 요금', '기본 주차 시간(분 단위)', '추가 단위 요금',
#        '추가 단위 시간(분 단위)', '버스 기본 주차 요금', '버스 기본 주차 시간(분 단위)', '버스 추가 단위 요금',
#        '버스 추가 단위 시간(분 단위)', '일 최대 요금', '주차장 위치 좌표 위도', '주차장 위치 좌표 경도',
#        '공유 주차장 관리업체명', '공유 주차장 여부', '공유 주차장 관리업체 링크', '공유 주차장 기타사항'],
#       dtype='object')
