# %%
import numpy as np
import pandas as pd
import matplotlib as mpl
import matplotlib.pyplot as plt
import seaborn as sns

# %%
mpl.rcParams['axes.unicode_minus'] = False
plt.rc('font', family='Malgun Gothic')

# %%
cctv = pd.read_csv("seoulCCTV.csv")
pop = pd.read_excel("seoulPopulation.xlsx")

# %%
x = cctv.sort_values("소계",ascending=True).reset_index(drop=True)["소계"]
y = cctv.sort_values("소계",ascending=True)["기관명"]

# %%
plt.figure()
plt.title("구별 CCTV 수")
plt.grid(True)
plt.ylabel("구별")
plt.xlim(0, 3000)
plt.xticks(range(0, 3000, 500))
plt.margins(0.01)
plt.barh(y, x, height=0.5)
# Out:
# <BarContainer object of 25 artists>

# %%
# 필요한 데이터만 추출
pop.rename(columns={"자치구":"기관명"},inplace=True)
pop2 = pop[['기관명','인구']][3:].reset_index(drop=True)
pop2
# Out:
#      기관명      인구
# 0    종로구  162820
# 1     중구  133240
# 2    용산구  244203
# 3    성동구  311244
# 4    광진구  372164
# 5   동대문구  369496
# 6    중랑구  414503
# 7    성북구  461260
# 8    강북구  330192
# 9    도봉구  348646
# 10   노원구  569384
# 11   은평구  494388
# 12  서대문구  327163
# 13   마포구  389649
# 14   양천구  479978
# 15   강서구  603772
# 16   구로구  447874
# 17   금천구  255082
# 18  영등포구  402985
# 19   동작구  412520
# 20   관악구  525515
# 21   서초구  450310
# 22   강남구  570500
# 23   송파구  667483
# 24   강동구  453233

# %%
# 데이터 2개 병합하기
data = cctv.merge(pop2,on="기관명")

# %%
# 불필요한 열 삭제
data.drop(data.iloc[:,2:6], axis=1, inplace=True)

# %%
# 두 번째 그래프를 그리기 위해 CCTV비율 컬럼 생성
data["CCTV비율"] = data["소계"] / data["인구"] * 100

# %%
x2 = data.sort_values(by="CCTV비율")["CCTV비율"]
y2 = data.sort_values(by="CCTV비율")["기관명"]

# %%
# 그래프를 그리기 위해 to_numeric() 사용하여 데이터 타입 변환
data["인구"] = pd.to_numeric(data["인구"])
data["CCTV비율"] = pd.to_numeric(data["CCTV비율"])

# %%
data.dtypes
# Out:
# 기관명        object
# 소계          int64
# 인구          int64
# CCTV비율    float64
# dtype: object

# %%
plt.figure()
plt.title("구별 CCTV 비율")
plt.grid(True)
plt.ylabel("구별")
plt.xlim(0, 0.7)
plt.xticks(np.arange(0,0.7,0.1))
plt.yticks(fontsize=8)
plt.margins(0.01)
plt.barh(y2, x2, height=0.5)
# Out:
# <BarContainer object of 25 artists>

# %%
# lmplot을 사용하여 회귀선 그리기
sns.lmplot(data=data, 
           x="인구", 
           y="소계", 
           height=5, 
           palette="viridis", 
           scatter_kws={"s": 20}, 
           ci=None, 
           line_kws={"linestyle": "dashed", "color": "green"})
plt.grid(True)

# %%
# lmplot으로는 colorbar를 표현할 수 없어서 회귀선을 직접 그리고 오차도 추가하기
fp1 = np.polyfit(data["인구"], data["소계"], 1)
f1 = np.poly1d(fp1)
fx = np.linspace(100000, 700000, 100)
data["오차"] = np.abs(data["소계"] - f1(data["인구"]))
data
# Out:
#      기관명    소계      인구    CCTV비율           오차
# 0    강남구  2780  570500  0.487292  1388.055355
# 1    강동구   773  453233  0.170552   465.422892
# 2    강북구   748  330192  0.226535   329.342026
# 3    강서구   884  603772  0.146413   551.503155
# 4    관악구  1496  525515  0.284673   162.948104
# 5    광진구   707  372164  0.189970   425.290264
# 6    구로구  1561  447874  0.348536   329.592918
# 7    금천구  1015  255082  0.397911    35.989293
# 8    노원구  1265  569384  0.222170   125.483618
# 9    도봉구   485  348646  0.139110   616.501341
# 10  동대문구  1294  369496  0.350207   165.202586
# 11   동작구  1091  412520  0.264472    94.122892
# 12   마포구   574  389649  0.147312   581.180999
# 13  서대문구   962  327163  0.294043   111.376568
# 14   서초구  1930  450310  0.428594   695.403794
# 15   성동구  1062  311244  0.341211     9.464016
# 16   성북구  1464  461260  0.317391   215.068447
# 17   송파구   618  667483  0.092587   900.911312
# 18   양천구  2034  479978  0.423769   760.563512
# 19  영등포구   904  402985  0.224326   268.640012
# 20   용산구  1624  244203  0.665020   659.231690
# 21   은평구  1873  494388  0.378852   580.698457
# 22   종로구  1002  162820  0.615404   143.775396
# 23    중구   671  133240  0.503603   148.499528
# 24   중랑구   660  414503  0.159227   527.718965

# %%
plt.figure(figsize=(12,10))
plt.scatter(data["인구"], data["소계"], c = data["오차"], s=50)
plt.plot(fx, f1(fx), linestyle = "dashed", color = 'g', lw=3)

plt.xlabel("인구수")
plt.ylabel("인구당비율")

# 각 구 이름을 그래프에 텍스트로 출력하기
for i in range(len(data)):
    plt.text(data["인구"].iloc[i], data["소계"].iloc[i], data["기관명"].iloc[i],
             fontsize=8, color='black', ha='left', va='top')

plt.colorbar()
plt.grid()
plt.show()

# %%
plt.figure(figsize=(12,10))
plt.scatter(data["인구"], data["소계"], c = data["오차"], s=50)
plt.plot(fx, f1(fx), linestyle = "dashed", color = 'g', lw=3)

plt.xlabel("인구수")
plt.ylabel("인구당비율")

#nlargest()를 사용하여 오차가 큰 10개만 text 출력하기
for i in data.nlargest(10,"오차").index:
    plt.text(data["인구"].iloc[i] + 8000, data["소계"].iloc[i], data["기관명"].iloc[i],
             fontsize=8, color='black', ha='left', va='top')
plt.colorbar()
plt.grid()
plt.show()
