# %%
import pandas as pd
import matplotlib as mpl
import matplotlib.pyplot as plt
import warnings

# %%
mpl.rcParams['axes.unicode_minus'] = False
plt.rc('font', family='Malgun Gothic')
warnings.simplefilter(action="ignore", category=FutureWarning)

# %%
# 엑셀 파일을 pandas로 읽기 위해 설치 (필요시 주석 제거하고 셀 실행)
# !pip install xlrd

# %%
# 엑셀 파일은 본인 경로에 맞춰서 설정
data = pd.read_excel("notExercise.xls")

# %%
data.head()
# Out:
#      기간  대분류   분류  운동을 할 충분한 시간이 없어서 함께 운동을 할 사람이 없어서  운동을 할 만한 장소가 없어서  \
# 0  2017  서울시  서울시               49.7              8.1               5.8
# 1  2017   성별   남자               55.2              7.9               5.5
# 2  2017   성별   여자               45.0              8.3               6.0
# 3  2017  연령별  10대               55.7              6.1               5.6
# 4  2017  연령별  20대               54.8              6.9               5.2
#
#    운동을 싫어해서   기타
# 0      34.7  1.7
# 1      29.8  1.6
# 2      38.8  1.8
# 3      32.2  0.3
# 4      32.9  0.1

# %%
tmp_list = []
for item in data["대분류"].unique():
    if not item.endswith("구"):
        tmp_list.append(item)
tmp_list.append("지역소분류")
category = {i + 1: item for i, item in enumerate(tmp_list)}
category
# Out:
# {1: '서울시',
#  2: '성별',
#  3: '연령별',
#  4: '학력별',
#  5: '소득별',
#  6: '혼인상태별',
#  7: '지역대분류',
#  8: '지역소분류'}

# %%
data.loc[data["대분류"].str.endswith("구"),"대분류"] = "지역소분류"

# %%
data.replace("-", 0, inplace=True)

# %%
g_data = data[data["대분류"] == category[2]]
g_data = g_data.iloc[:,2:]
g_data
# Out:
#    분류  운동을 할 충분한 시간이 없어서  함께 운동을 할 사람이 없어서  운동을 할 만한 장소가 없어서  운동을 싫어해서   기타
# 1  남자               55.2               7.9               5.5      29.8  1.6
# 2  여자               45.0               8.3               6.0      38.8  1.8

# %%
plt.figure(figsize=(8,12))
plt.pie(g_data.iloc[:,1],labels=g_data.loc[:,"분류"],autopct='%.1f%%',explode=(0.03,0))
plt.title(g_data.columns[1])
# Out:
# Text(0.5, 1.0, '운동을 할 충분한 시간이 없어서')

# %%
# 함수로 만들기
def choose_category(cate_num):
    g_data = data[data["대분류"] == category[cate_num]]
    g_data = g_data.iloc[:,2:]
    explode_tuple = (0.015,) * (len(g_data.index))
    plt.figure(figsize=(8,12))
    for i in range(1, len(g_data.columns)):
        plt.suptitle(category[cate_num])
        plt.subplot(3,2,i)
        plt.pie(g_data.iloc[:,i],labels=g_data.loc[:,"분류"],autopct='%.1f%%',explode=explode_tuple)
        plt.title(g_data.columns[i])
    plt.show()

# %%
# 함수에 넣을 값 확인하기
category
# Out:
# {1: '서울시',
#  2: '성별',
#  3: '연령별',
#  4: '학력별',
#  5: '소득별',
#  6: '혼인상태별',
#  7: '지역대분류',
#  8: '지역소분류'}

# %%
# 예) 학력별 그래프를 보고 싶다면 4를 입력
# 1번 서울시는 행이 하나 밖에 없어서 의미 X 
# 8번 지역소분류는 행이 많으므로 그래프의 크기를 키우는 것을 추천
choose_category(4)
