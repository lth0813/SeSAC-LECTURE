# %% [markdown]
# ### 포털사이트 크롤링
# - 소스내에서 특정 문자열(data)을 지칭하는 선택자 얻기
#     - 크롬 개발자도구 사용
# - 전체 코드에서 수집하려고 하는 데이터(태그)의 위치를 찾고
#     - 태그를 파싱한 후 필요데이터 추출

# %%
from urllib.request import urlopen # 서버 요청/응답 패키지
import bs4 # 파싱패키지

# %%
# 네이버 사이트의 기본 메뉴 문구 추출
url = 'https://www.naver.com'

# url로 요청후 응답
html = urlopen(url)

# 파서객체 생성 - bs4 객체로 변환
bs_obj = bs4.BeautifulSoup(html, 'html.parser')

# %%
bs_obj
# Out:
#  <!DOCTYPE html>
#  <html class="fzoom" lang="ko"> <head> <meta charset="utf-8"/> <meta content="origin" name="Referrer"/> <meta content="IE=edge" http-equiv="X-UA-Compatible"/> <meta content="width=1190" name="viewport"/> <title>NAVER</title> <meta content="NAVER" name="apple-mobile-web-app-title"> <meta content="index,nofollow" name="robots"> <meta content="네이버 메인에서 다양한 정보와 유용한 컨텐츠를 만나 보세요" name="description"> <meta content="네이버" property="og:title"/> <meta content="https://www.naver.com/" property="og:url"/> <meta content="https://s.pstatic.net/static/www/mobile/edit/2016/0705/mobile_212852414260.png" property="og:image"/> <meta content="네이버 메인에서 다양한 정보와 유용한 컨텐츠를 만나 보세요" property="og:description"> <meta content="summary" name="twitter:card"/> <meta content="" name="twitter:title"/> <meta content="https://www.naver.com/" name="twitter:url"/> <meta content="https://s.pstatic.net/static/www/mobile/edit/2016/0705/mobile_212852414260.png" name="twitter:image"/> <meta content="네이버 메인에서 다양한 정보와 유용한 컨텐츠를 만나 보세요" name="twitter:description"> <meta content="uru5NJKa1Bfr5nv5AdQ26Qat7UrPU_02l-PIZRLzI-g" name="google-site-verification"> <link href="/favicon.ico?1" rel="shortcut icon" type="image/x-icon"/> <link href="https://s.pstatic.net/static/www/nFavicon96.png" rel="apple-touch-icon-precomposed"> <link href="https://s.pstatic.net/static/www/u/2014/0328/mma_204243574.png" rel="apple-touch-icon" sizes="114x114"/> <link href="https://s.pstatic.net/static/www/u/2014/0328/mma_20432863.png" rel="apple-touch-icon"/> <link href="https://ssl.pstatic.net/sstatic/search/pc/css/sp_autocomplete_241121.css" rel="stylesheet"/> <link href="https://www.naver.com/" rel="canonical"/> <link href="https://m.naver.com/" media="only screen and (max-width: 767px)" rel="alternate"/> <script>window.gladsdk=window.gladsdk||{},window.gladsdk.cmd=window.gladsdk.cmd||[],window.ndpsdk=window.ndpsdk||{},window.ndpsdk.cmd=window.ndpsdk.cmd||[],window.ndpsdk.polyfill=window.ndpsdk.polyfill||{cmd:[]};var g_ssc="navertop.v5";window.nsc=g_ssc,window.nmain=window.nmain||{},window.nmain.jsOrigin="www"</script> <script>window.ntm=window.ntm||[]</script> <script async="" src="https://ssl.pstatic.net/tveta/libs/ndpsdk/prod/ndp-loader.js"></script> <script async="" src="https://ssl.pstatic.net/tveta/libs/glad/prod/gfp-core.js"></script> <script defer="defer" src="https://ssl.pstatic.net/tveta/libs/assets/js/pc/main/min/pc.veta.core.min.js"></script> <script>
# window["EAGER-DATA"] = window["EAGER-DATA"] || {};
# window["EAGER-DATA"]["PC-FEED-WRAPPER"] = {"@type":"BLOCK","blocks":[{"@type":"BLOCK","blocks":[{"@type":"PC-FEED-BLOCK","blocks":[{"@type":"PC-FEED-BLOCK","materials":[{"@type":"MATERIAL-PC-FEED","title":"얼굴에 주름 잘 생기는 사람, 어떤 특징 있을까","url":"https://post.naver.com/viewer/postView.naver?volumeNo=45964497&memberNo=3551273","image":{"url":"https://s.pstatic.net/dthumb.phinf/?src=%22https%3A%2F%2Fs.pstatic.net%2Fstatic%2Fwww%2Fmobile%2Fedit%2F20250116_1095%2Fupload_1737001507517fY9D8.jpg%22&type=f504_292&service=navermain"},"source":{"name":"하이닥","service":"POST","image":{"url":"https://s.pstatic.net/post.phinf/MjAyMTAxMjFfMTE5/MDAxNjExMTk2ODEyMDgx.AG1ECb4e7m-A0onWyebWePJEr0gcGMLQtkafPeqqYJYg.t3HtYNGHaxxNUOnV-Q1mnjCVCHcr6oYlYH8B3Wno5kkg.PNG/post_7533287607858319333.png?type=f120_120"}},"showLiveBadge":false,"_id":"654ad80598c6dbca70ba6cec"},{"@type":"MATERIAL-PC-FEED","title":"⬇️잠들기 1분 전 뱃살 녹이는 초간단 운동⬇️","url":"https://tv.naver.com/h/68118280","image":{"url":"https://s.pstatic.net/dthumb.phinf/?src=%22https%3A%2F%2Fs.pstatic.net%2Fstatic%2Fwww%2Fmobile%2Fedit%2F20250116_1095%2Fupload_1737001754562cEysd.jpg%22&type=f504_292&service=navermain"},"video":{"playTime":"00:16"},"showLiveBadge":false,"_id":"654ad80598c6dbca70ba6ced"},{"@type":"MATERIAL-PC-FEED","title":"저혈압, 수분 섭취가 중요하다고? ","url":"https://blog.naver.com/PostView.naver?blogId=schmcseoul&logNo=223724076836&proxyReferer=&noTrackingCode=true","image":{"url":"https://s.pstatic.net/dthumb.phinf/?src=%22https%3A%2F%2Fs.pstatic.net%2Fstatic%2Fwww%2Fmobile%2Fedit%2F20250116_1095%2Fupload_1737005362078etd7d.jpg%22&type=f504_292&service=navermain"},"source":{"name":"순천향대 서울병원","service":"BLOG","image":{"url":"http://blogpfthumb.phinf.naver.net/MjAyMjEyMDhfMTY4/MDAxNjcwNDgwMTc5OTE3.8zhUC4sL_VYiI-a_2MK_tuPhJvqIrGgUzjDAKUyAHjQg.BiVwsdZg6z5RPsMVxIYhiDBzNt7cu2JGwdG4bL_FCMMg.PNG.schmcseoul/2022_%EC%88%9C%EC%B2%9C%ED%96%A5%EB%8C%80%ED%95%99%EA%B5%90_%EB%B8%94%EB%A1%9C%EA%B7%B8%ED%94%84%EB%A1%9C%ED%95%84.png/2022_%25EC%2588%259C%25EC%25B2%259C%25ED%2596%25A5%25EB%258C%2580%25ED%2595%2599%25EA%25B5%2590_%25EB%25B8%2594%25EB%25A1%259C%25EA%25B7%25B8%25ED%2594%2584%25EB%25A1%259C%25ED%2595%2584.png?type=s1"}},"showLiveBadge":false,"_id":"654ad80598c6dbca70ba6
</svg> </span> <span class="blind">검색</span> </button> </fieldset> </form> <div class="search_box"> <button aria-pressed="false" class="btn_keyboard" id="ke_kbd_btn" type="button"> <span class="keybord_text"> <span class="blind">입력도구</span> </span> </button> <div id="_nx_kbd" style="display:none"></div> <button class="btn_arrow" data-atcmp-element="" id="nautocomplete" type="button"> <span class="blind">자동완성/최근검색어펼치기</span> </button> </div> <div class="layer_atcmp" id="autoFrame" style="display:none"></div> </div> </div> </div> <div id="search-right-first"></div> <div id="search-right-second"></div> <div aria-label="주요 서비스" class="shortcut_area" id="shortcutArea" role="navigation"></div> <div class="menu_area" id="topAsideArea"></div> <div class="pay_area" id="topPayArea"></div> <div class="talk_area" id="topTalkArea"></div> <div class="notify_area" id="topNotiArea"></div> <div class="shopping_area" id="topShoppingArea"></div> </div> </div> <div id="container" role="main"> <div id="root"></div> </div> <div id="footer" role="contentinfo"></div> </div> <script> window['EAGER-DATA'] = window['EAGER-DATA'] || {};
#         window['EAGER-DATA']['GV'] = {
#             svt: '20250122120521',  }; </script> <script>!function(){function t(t){var e=document.getElementById("search_area"),n=document.getElementById("search-btn");if(!t)return e&&e.removeAttribute("style"),void(n&&n.setAttribute("style","fill: #03c75a"));e&&e.setAttribute("style","border-color: "+t),n&&n.setAttribute("class","ico_btn_search type_color"),n&&n.setAttribute("style","fill: "+t)}var e=window["EAGER-DATA"]["CAS-MINICONTENT-PC-SPECIAL-LOGO"];if(!e||!e.items||e.items.length>0==!1)return void t();var n=Math.floor(Math.random()*e.items.length),i=e.items[n];e.items=[i],t(i&&i.content&&i.content.input&&i.content.input.color);const l=document.getElementById("search");l&&l.classList.add("type_special_logo_full"),window.addEventListener("header-sticky-state-change",(function(){var t;(t=document.getElementById("header"))&&t.classList.contains("ani_fixed")?l&&l.classList.remove("type_special_logo_full"):l&&l.classList.add("type_special_logo_full")}));var o=i&&i.content&&i.content.input&&i.content.input.placeholder;if(o){var s=document.getElementById("query");s&&o&&s.setAttribute("title",o),s&&o&&s.setAttribute("placeholder",o)}}()</script> </body> </html>

# %%
test_menu = bs_obj.find('div',{'id':'wrap'})
test_menu
# Out:
# <div id="wrap"> <div id="header" role="banner"> <div class="header_inner" id="topSearchWrap"> <div class="search_special_bg" id="special-logo"></div> <div class="ad_area" id="timeboard-ex" style="min-width:1340px"> </div> <div class="search_area" id="search_area" style="border-color:#fff"> <div class="search_group"> <div class="search_group_inner" id="search"> <h1 class="search_logo" id="special-input-logo"></h1> <form action="https://search.naver.com/search.naver" id="sform" method="get" name="search" role="search"> <fieldset> <legend class="blind">검색</legend> <input name="where" type="hidden" value="nexearch"/> <input id="sm" name="sm" type="hidden" value="top_hty"/> <input id="fbm" name="fbm" type="hidden" value="0"/> <input disabled="disabled" id="acr" name="acr" type="hidden" value=""/> <input disabled="disabled" id="acq" name="acq" type="hidden" value=""/> <input disabled="disabled" id="qdt" name="qdt" type="hidden" value=""/> <input id="ie" name="ie" type="hidden" value="utf8"/> <input disabled="disabled" id="acir" name="acir" type="hidden" value=""/> <input disabled="disabled" id="os" name="os" type="hidden" value=""/> <input disabled="disabled" id="bid" name="bid" type="hidden" value=""/> <input disabled="disabled" id="pkid" name="pkid" type="hidden" value=""/> <input disabled="disabled" id="eid" name="eid" type="hidden" value=""/> <input disabled="disabled" id="mra" name="mra" type="hidden" value=""/> <div class="search_input_box"> <input autocomplete="off" class="search_input" data-atcmp-element="" id="query" maxlength="255" name="query" placeholder="검색어를 입력해 주세요." title="검색어를 입력해 주세요." type="search"/> </div> <button class="btn_search" onclick='window.ntm.push({event:"nclick",el:this,click_area:"sch.action"})' type="submit"> <span class="ico_btn_search_svg"> <svg id="search-btn" viewbox="0 0 50 50" xmlns="http://www.w3.org/2000/svg"> <path d="M22.13.5c11.378 0 20.632 9.256 20.632 20.63 0 4.699-1.566 9.155-4.439 12.782l10.164 10.165a2.41 2.41 0 0 1-1.706 4.115 2.412 2.412 0 0 1-1.706-.705L33.31 35.719a2.41 2.41 0 0 1 0-3.41 15.71 15.71 0 0 0 4.628-11.178c0-8.718-7.09-15.808-15.807-15.808-8.718 0-15.808 7.09-15.808 15.808 0 7.15 4.817 13.43 11.714 15.273a2.41 2.41 0 0 1 1.705 2.954 2.41 2.41 0 0 1-2.95 1.705C7.788 38.658 1.5 30.46 1.5 21.131 1.5 9.756 10.756.5 22.13.5zm4.716 34.746a3.483 3.483 0 1 1 0 6.966 3.483 3.483 0 0 1 0-6.966z"></path> </svg> </span> <span class="blind">검색</span> </button> </fieldset> </form> <div class="search_box"> <button aria-pressed="false" class="btn_keyboard" id="ke_kbd_btn" type="button"> <span class="keybord_text"> <span class="blind">입력도구</span> </span> </button> <div id="_nx_kbd" style="display:none"></div> <button class="btn_arrow" data-atcmp-element="" id="nautocomplete" type="button"> <span class="blind">자동완성/최근검색어펼치기</span> </button> </div> <div class="layer_atcmp" id="autoFrame" style="display:none"></div> </div> </div> </div> <div id="search-right-first"></div> <div id="search-right-second"></div> <div aria-label="주요 서비스" class="shortcut_area" id="shortcutArea" role="navigation"></div> <div class="menu_area" id="topAsideArea"></div> <div class="pay_area" id="topPayArea"></div> <div class="talk_area" id="topTalkArea"></div> <div class="notify_area" id="topNotiArea"></div> <div class="shopping_area" id="topShoppingArea"></div> </div> </div> <div id="container" role="main"> <div id="root"></div> </div> <div id="footer" role="contentinfo"></div> </div>

# %% [markdown]
# ### 수집한 데이터를 csv로 저장
# 1. 항목별로 list에 저장
# 2. 항목들을 dict로 구성
# 3. dict를 데이터프레임으로 생성
# 4. 데이터프레임을 csv로 저장

# %% [markdown]
# ## 네이버 뉴스 크롤링
# #### 네이버 뉴스는 네이버 정책에 따라 모든 언론사들의 뉴스가 랜덤하게 배치됨
# - 단, 로그인 후 구독을 추가하면 구독한 언론사들의 뉴스가 나옴
# - 헤드라인 뉴스는 표면적으로는 제공되지 않는다

# %%
# 네이버 뉴스 크롤링
# url은 기본 url 부터 사용
url = 'https://news.naver.com'
html = urlopen(url)

# %%
# html #<http.client.HTTPResponse at 0x1b6fa0cd0d0>
# html_text = html.read() # 바이너리 문자열로 반환
# # html_text

# %%
# bs4 객체 생성
bs_obj = bs4.BeautifulSoup(html, 'html.parser')

# %%
print(bs_obj.prettify())
# Out:
# <!DOCTYPE html>
# <html lang="ko">
#  <head>
#   <title id="browserTitleArea">
#    네이버 뉴스
#   </title>
#   <script>
#    function isMobileDevice() {
# 		return /^.*(iPhone|iPod|iPad|Android).*/.test(navigator.userAgent);
# 	}
#   </script>
#   <script>
#    (function () {
# 		try {
# 			if (isMobileDevice() && isAbleApplyPrefersColorScheme()) {
#
# 				document.querySelector("html").classList.add("DARK_THEME");
# 			}
# 		} catch(e) {}
#
# 		function isAbleApplyPrefersColorScheme() {
#
# 			if (window.matchMedia("(prefers-color-scheme)").matches === false) {
# 				return false;
# 			}
#
# 			var userAgent = navigator.userAgent;
#
# 			if (userAgent.indexOf("NAVER") > -1) {
#
# 				if (/.*NAVER\([a-zA-Z]*;\s[a-zA-Z]*;\s([0-9]*);/.test(userAgent)) {
# 					return Number(RegExp.$1) >= 1000;
# 				}
# 			} else {
#
# 				return document.cookie.indexOf("NSCS=1") > -1;
# 			}
#
# 			return false;
# 		}
# 	})();
#   </script>
#   <script>
#    var g_ssc = 'news.v3_media' || null;
# 		var bSupportedIntersectionObserver = "IntersectionObserver" in window;
#   </script>
#   <meta charset="utf-8"/>
#   <meta content="width=device-width,initial-scale=1.0,maximum-scale=1.0,minimum-scale=1.0,user-scalable=no,target-densitydpi=medium-dpi" name="viewport">
#    <link href="https://ssl.pstatic.net/static.news/mnews/resources/20250117_004017/css/generated/newshome.css" rel="stylesheet" type="text/css"/>
#    <link href="https://mimgnews.pstatic.net/image/news/m/2023/favicon/favicon.ico" rel="shortcut icon" type="image/x-icon"/>
#    <script>
#     (function(){
# 		var userAgent = navigator.userAgent;
# 		var result = [];
#
# 		if(userAgent.indexOf('Android') > -1){
# 			result = [
# 				'<link rel="apple-touch-icon-precomposed" sizes="72x72" href="https://ssl.pstatic.net/static.news/image/news/m/2018/favicon/06/android_legacy_hdpi_72X72.png" />',
# 				'<link rel="apple-touch-icon-precomposed" sizes="96x96" href="https://ssl.pstatic.net/static.news/image/news/m/2018/favicon/06/android_legacy_xhdpi_96x96.png" />',
# 				'<link rel="apple-touch-icon-precomposed" sizes="144x144" href="https://ssl.pstatic.net/static.news/image/news/m/2018/favicon/06/android_legacy_xxhpdi_144x144.png" />',
# 				'<link rel="apple-touch-icon-precomposed" sizes="192x192" href="https://ssl.pstatic.net/static.news/image/news/m/2018/favicon/06/android_legacy_xxxhpdi_192x192.png" />'
# 			];
# 		}else if(userAgent.indexOf('iPhone') > -1){
# 			result = [
# 				'<link rel="apple-touch-icon-precomposed" sizes="120X120" href="https://ssl.pstatic.net/static.news/image/news/m/2018/favicon/06/iOS_iPhone_2x_120X120.png" />',
# 				'<link rel="apple-touch-icon-precomposed" sizes="180x180" href="https://ssl.pstatic.net/static.news/image/news/m/2018/favicon/06/iOS_iPhone_3x_180X180.png" />'
# 			];
# 		}else if(userAgent.indexOf('iPad') > -1){
# 			result = [
# 				'<link rel="apple-touch-icon-precomposed" sizes="167x167" href="https://ssl.pstatic.net/static.news/image/news/m/2018/favicon/06/iOS_iPadPro_2x_167X167.png" />',
# 				'<link rel="apple-touch-icon-precomposed" sizes="152x152" href="https://ssl.pstatic.net/static.news/image/news/m/2018/favicon/06/iOS_iPad_2x_152X152.png" />'
# 			];
# 		}
# 		document.write(result.join('\n'));
# 	})();
#    </script>
#    <script src="https://ssl.pstatic.net/static.news/mnews/resources/20250117_004017/js/generated/statistics_jquery.js" type="text/javascript">
#    </script>
#    <script>
#     document.documentElement.setAttribute('data-useragent',navigator.userAgent);
#    </script>
#    <script>
#     document.documentElement.setAttribute('data-useragent', navigator.userAgent);
#
#
# function showNoImage(elImg, type) {
#     switch (type) {
#
#         case "remove":
#             try {
#                 elImg.parentNode.removeChild(elImg);
#             } catch(e) {}
#             break;
#
#
#         case "removeParent":
#             try {
#                 elImg.parentNode.outerHTML = '';
#             } catch(e) {}
#             break;
#
#
#         case "alt":
#             elImg.outerHTML = ('<span class="noimage_text {imgClassName}">' + (elImg.alt || "") + '</span>')
#
#                 .replace('{imgClassName}', elImg.className);
#             break;
#
#
# 		case "class" :
# 			var outerHTMLSource = Number(elImg.getAttribute("height")) > 0?
#
# 				'<span class="noimage_wrap {imgClassName}" style="height:' + elImg.getAttribute("height") + 'px;"><span class="noimage"></span></span>':
# 				'<span class="noimage_wrap {imgClassName}"><span class="noimage"></span></span>';
# 			elImg.outerHTML = outerHTMLSource.replace('{imgClassName}', elImg.className);
# 			break;
#
#         case "pressname" :
#             var pressname = elImg.getAttribute("data-pressname");
#             elImg.outerHTML = '<span class="cjs_broadcast_noimg"><span class="noimg_text">' + pressname + '</span></span>';
#             break;
#
#         case "noHeight":
#
#             elImg.outerHTML = '<span class="noimage_wrap"><span class="noimage"></span></span>';
#             break;
#
#
#         default:
#
#             elImg.outerHTML = Number(elImg.getAttribute("height")) > 0?
#
#                 '<span class="noimage_wrap" style="height:' + elImg.getAttribute("height") + 'px;"><span class="noimage"></span></span>':
#                 '<span class="noimage_wrap"><span class="noimage"></span></span>';
#     }
# }
#
#
# function doAfterLoadEnd(callback, callbackOnPersisted) {
#     var eventName = "onpageshow" in window ? "pageshow" : "load";
#
#     callback = callback || function(){};
#     callbackOnPersisted = callbackOnPersisted || function(){};
#
#     window.addEventListener(eventName, function(e) {
#         try{
#             if(Boolean(e.persisted)){
#                 callbackOnPersisted();
#                 return;
#             }
#         }catch(e){}
#
#         callback();
#     });
# }
#    </script>
#    <meta content="네이버 뉴스" property="og:title"/>
#    <meta content="website" property="og:type"/>
#    <meta content="https://news.naver.com/main/home.naver" property="og:url"/>
#    <meta content="https://ssl.pstatic.net/static.news/image/news/ogtag/navernews_800x420_20221201.png" property="og:image"/>
#    <meta content="정치, 경제, 사회, 생활/문화, 세계, IT/과학 등 언론사별, 분야별 뉴스 기사 제공" property="og:description"/>
#    <meta content="네이버" property="og:article:author"/>
#    <meta content="summary" name="twitter:card"/>
#    <meta content="네이버 뉴스" name="twitter:title"/>
#    <meta content="네이버 뉴스" name="twitter:site"/>
#    <meta content="네이버 뉴스" name="twitter:creator"/>
#    <meta content="https://ssl.pstatic.net/static.news/image/news/ogtag/navernews_800x420_20221201.png" name="twitter:image"/>
#    <meta content="정치, 경제, 사회, 생활/문화, 세계, IT/과학 등 언론사별, 분야별 뉴스 기사 제공" name="twitter:description"/>
#    <script>
#     (function () {
#         var isUnderIE10 = navigator.appName === "Microsoft Internet Explorer";
#         if (!isUnderIE10) {
#             var script = document.createElement("script");
#             script.async = true;
#             script.src = "https://ssl.pstatic.net/tveta/libs/glad/prod/gfp-core.js";
#             document.head.appendChild(script);
#         }
#     })();
#
#
#     window.gladsdk = window.gladsdk || { cmd: [] };
#     window.gladsdk.cmd.push(function () {
#
#         window.gladsdk.setGlobalConfig({
#             enablePersistAd: true
#         });
#
#
#         var adUnits = [];
#
#         adUnits.push({
#             adUnitId: "p_news_sidebox",
#             adSlotElementId: "glad_ad_sidebox",
#             customParam: {
#                 calp: "home"
#             }
#         });
#
#         for (let i = 0; i < adUnits.length; i++) {
#             window.gladsdk.defineAdSlot(adUnits[i]);
#         }
#
#
#         var htmlClass = document.querySelector("html").getAttribute("class");
#         if (htmlClass && htmlClass.indexOf("DARK_THEME") > -1) {
#             window.gladsdk.setHostMeta("theme", "system");
#         }
#     });
#    </script>
#   </meta>
#  </head>
#  <body class="as_mp_layout body_main">
#   <div class="u_skip">
#    <a href="#ct">
#     본문 바로가기
#    </a>
#   </div>
#   <!-- Menu 구분  -->
#   <section class="news_header">
#    <header class="nh_header" role="banner">
#     <div class="Ngnb">
#      <div class="Ngnb_inner">
#       <div class="Ngnb_both">
#        <div class="Ngnb_left">
#         <span class="Ngnb_logo">
#          <a class="Nlogo_link" href="https://www.naver.com" onclick="nclk(event,'gnb.naver','','');">
#           <span class="Nicon_logo">
#            NAVER
#           </span>
#          </a>
#         </span>
#         <div class="Ngnb_service">
#          <h1 class="Nservice_item">
#           <a href="https://news.naver.com" onclick="nclk(event,'gnb.news','','');">
#            <span class="Nicon_service">
#             뉴스
#            </span>
#           </a>
#          </h1>
#          <span class="Nservice_subitem">
#           <a href="https://entertain.naver.com/home" onclick="nclk(event,'gnb.enter','','');">
#            <span class="Nicon_family Nicon_entertain">
#             엔터
#            </span>
#           </a>
#          </span>
#          <span class="Nservice_subitem">
#           <a href="https://sports.news.naver.com/index" onclick="nclk(event,'gnb.sports','','');">
#            <span class="Nicon_family Nicon_sports">
#             스포츠
#            </span>
#           </a>
#          </span>
#          <span class="Nservice_subitem">
#           <a href="https://weather.naver.com/" onclick="nclk(event,'gnb.weather','','');">
#            <span class="Nicon_family Nicon_weather">
#             날씨
#            </span>
#           </a>
#          </span>
#          <span class="Nservice_subitem">
#           <a href="https://contents.premium.naver.com/" onclick="nclk(event,'gnb.premium','','');">
#            <span class="Nicon_family Nicon_premium">
#             프리미엄
#            </span>
#           </a>
#          </span>
#         </div>
#        </div>
#        <div class="Ngnb_right">
#         <div class="Ngnb_group">
#          <div class="gnb_dark_type2" id="gnb">
#          </div>
#         </div>
#         <div class="Ngnb_search is_hidden _search_content">
#         </div>
#         <div class="Ngnb_tool">
#          <a class="Ntool_button _search_content_toggle_btn" href="javascript:;" onclick="nclk(event,'gnb.sch','','');">
#           <span class="Nicon_search">
#            검색
#           </span>
#          </a>
#         </div>
#        </div>
#       </div>
#      </div>
#     </div>
#     <div class="Nlnb _float_lnb">
#      <div class="Nlnb_inner">
#       <div class="Nlnb_both">
#        <div class="Nlnb_left _lnb_scroll">
#         <div class="Nlnb_menu Ntype_scroll">
#          <div class="Nlnb_menu_inner _scroll">
#           <ul class="Nlnb_menu_list" role="menu">
#            <li class="Nlist_item is_active">
#             <a aria-selected="true" class="Nitem_link" href="https://news.naver.com/?viewType=pc" onclick="nclk(event,'lnb.pcmedia','','');" role="menuitem">
#              <span class="Nitem_link_menu">
#               언론사별
#              </span>
#             </a>
#            </li>
#            <li class="Nlist_item">
#             <a aria-selected="false" class="Nitem_link" href="https://news.naver.com/section/100" onclick="nclk(event,'lnb.pol','','');" role="menuitem">
#              <span class="Nitem_link_menu">
#               정치
#              </span>
#             </a>
#            </li>
#            <li class="Nlist_item">
#             <a aria-selected="false" class="Nitem_link" href="https://news.naver.com/section/101" onclick="nclk(event,'lnb.eco','','');" role="menuitem">
#              <span class="Nitem_link_menu">
#               경제
#              </span>
#             </a>
#            </li>
#            <li class="Nlist_item">
#             <a aria-selected="false" class="Nitem_link" href="https://news.naver.com/section/102" onclick="nclk(event,'lnb.soc','','');" role="menuitem">
#              <span class="Nitem_link_menu">
#               사회
#              </span>
#             </a>
#            </li>
#            <li class="Nlist_item">
#             <a aria-selected="false" class="Nitem_link" href="https://news.naver.com/section/103" onclick="nclk(event,'lnb.lif','','');" role="menuitem">
#              <span class="Nitem_link_menu">
#               생활/문화
#              </span>
#             </a>
#            </li>
#            <li class="Nlist_item">
#             <a aria-selected="false" class="Nitem_link" href="https://news.naver.com/section/105" onclick="nclk(event,'lnb.sci','','');" role="menuitem">
#              <span class="Nitem_link_menu">
#               IT/과학
#              </span>
#             </a>
#            </li>
#            <li class="Nlist_item">
#             <a aria-selected="false" class="Nitem_link" href="https://news.naver.com/section/104" onclick="nclk(event,'lnb.wor','','');" role="menuitem">
#              <span class="Nitem_link_menu">
#               세계
#              </span>
#             </a>
#            </li>
#            <li class="Nlist_item _isNew">
#             <a aria-selected="false" class="Nitem_link" href="https://news.naver.com/main/ranking/popularDay.naver" onclick="nclk(event,'lnb.rank','','');" role="menuitem">
#              <span class="Nitem_link_menu">
#               랭킹
#              </span>
#             </a>
#            </li>
#            <li class="Nlist_item _isNew">
#             <a aria-selected="false" class="Nitem_link" href="https://news.naver.com/newspaper/home?viewType=pc" onclick="nclk(event,'lnb.paper','','');" role="menuitem">
#              <span class="Nitem_link_menu">
#               신문보기
#              </span>
#             </a>
#            </li>
#            <li class="Nlist_item">
#             <a aria-selected="false" class="Nitem_link" href="https://news.naver.com/opinion/home" onclick="nclk(event,'lnb.opi','','');" role="menuitem">
#              <span class="Nitem_link_menu">
#               오피니언
#              </span>
#             </a>
#            </li>
#            <li class="Nlist_item">
#             <a aria-selected="false" class="Nitem_link" href="https://news.naver.com/main/tv/index.naver?mid=tvh" onclick="nclk(event,'lnb.tv','','');" role="menuitem">
#              <span class="Nitem_link_menu">
#               TV
#              </span>
#             </a>
#            </li>
#            <li class="Nlist_item">
#             <a aria-selected="false" class="Nitem_link" href="https://news.naver.com/factcheck/main" onclick="nclk(event,'lnb.fact','','');" role="menuitem">
#              <span class="Nitem_link_menu">
#               팩트체크
#              </span>
#             </a>
#            </li>
#            <li class="Nlist_item">
#             <a aria-selected="false" class="Nitem_link" href="https://media.naver.com/algorithm" onclick="nclk(event,'lnb.algo','','');" role="menuitem">
#              <span class="Nitem_link_menu">
#               알고리즘 안내
#              </span>
#             </a>
#            </li>
#            <li class="Nlist_item _isNew">
#             <a aria-selected="false" class="Nitem_link" href="https://news.naver.com/main/ombudsman/errorArticleList.naver?mid=omb" onclick="nclk(event,'lnb.correct','','');" role="menuitem">
#              <span class="Nitem_link_menu">
#               정정보도 모음
#              </span>
#             </a>
#            </li>
#           </ul>
#          </div>
#         </div>
#        </div>
#       </div>
#      </div>
#     </div>
#    </header>
#   </section>
#   <hr/>
#   <div class="main_wrap" id="ct" role="main">
#    <div class="main_container">
#     <section class="main_content">
#      <h3 class="blind">
#       콘텐츠
#      </h3>
#      <div class="main_sublnb">
#       <div class="main_sublnb_date">
#        <strong>
#         1
#        </strong>
#        .
#        <strong>
#         22
#        </strong>
#        <span>
#         (수)
#        </span>
#       </div>
#       <ul class="main_sublnb_menu">
#        <li class="main_sublnb_item">
#         <a class="main_sublnb_link" href="https://news.naver.com/main/officeList.naver " onclick="nclk(event, 'slb.allmedia', '', '')">
#          전체 언론사
#         </a>
#        </li>
#        <li class="main_sublnb_item">
#         <a class="main_sublnb_link" href="https://newsstand.naver.com/" onclick="nclk(event, 'slb.newsstand', '', '')" target="_blank">
#          뉴스스탠드
#         </a>
#        </li>
#        <li class="main_sublnb_item">
#         <a class="main_sublnb_link" href="https://newslibrary.naver.com/search/searchByDate.naver" onclick="nclk(event, 'slb.library', '', '')" target="_blank">
#          라이브러리
#         </a>
#        </li>
#       </ul>
#      </div>
#      <div class="main_brick">
#       <!-- BRICK HOUSE -->
#       <div class="grid1_wrap brick-house _brick_gid_wrapper">
#        <div class="brick-vowel _brick_column">
#         <div class="main_brick_item _press_main_status_wrapper">
#          <div class="comp_journal_subscribe">
#           <div class="cjs_title_wrap">
#            <h3 class="cjs_edit_title">
#             <span class="cjs_main">
#              언론사편집
#             </span>
#             <a class="cjs_subscribe_a" href="#feedJournalistCard" onclick="nclk(event, 'home.editassetting1', '', '')">
#              <span class="subs_text">
#               기자
#              </span>
#             </a>
#             <a class="cjs_subscribe_a" href="#feedSeriesCard" onclick="nclk(event, 'home.editassetting2', '', '')">
#              <span class="subs_text">
#               연재
#              </span>
#             </a>
#            </h3>
#            <a class="cjs_more_link" href="https://media.naver.com/channel/settings" onclick="nclk(event, 'home.editsetting', '', '')">
#             구독설정
#             <span class="ico_more">
#             </span>
#            </a>
#           </div>
#           <div class="cjs_news_flash_wrap cjs_nf_close _newsflash_wrapper">
#            <div class="cjs_nf_title">
#             <span class="ico_newsflash">
#              속보
#             </span>
#            </div>
#            <div class="cjs_nf_list _item_list">
#             <a class="cjs_nf_a _item _cds_link _newsflash_link" href="https://n.news.naver.com/article/032/0003347049" onclick="nclk(event, 'home.newsflash', '', '')">
#              <div class="cn_title_area">
#               <h4 class="cn_title">
#                대통령경호처, 공수처 관저 압색에 “영부인도 경호 대상” 불응 시사
#               </h4>
#               <div class="cn_snippet">
#                <div class="cn_journal_wrap">
#                 <div class="cn_thumb">
#                  <img alt="" height="10" loading="lazy" onerror="showNoImage(this)" src="https://mimgnews.pstatic.net/image/upload/office_logo/032/2022/12/05/logo_032_56_20221205150153.png?type=nf20_20" width="10"/>
#                 </div>
#                 <div class="cn_name">
#                  경향신문
#                 </div>
#                </div>
#               </div>
#              </div>
#             </a>
#             <a class="cjs_nf_a _item _cds_link _newsflash_link" href="https://n.news.naver.com/article/050/0000085527" onclick="nclk(event, 'home.newsflash', '', '')">
#              <div class="cn_title_area">
#               <h4 class="cn_title">
#                '서부지법' 난동부린 시위대 56명 구속…"도주우려"
#               </h4>
#               <div class="cn_snippet">
#                <div class="cn_journal_wrap">
#                 <div class="cn_thumb">
#                  <img alt="" height="10" loading="lazy" onerror="showNoImage(this)" src="https://mimgnews.pstatic.net/image/upload/office_logo/050/2021/07/15/logo_050_56_20210715110055.jpg?type=nf20_20" width="10"/>
#                 </div>
#                 <div class="cn_name">
#                  한경비즈니스
#                 </div>
#                </div>
#                <div class="cn_state">
#                 내용작성전
#                </div>
#               </div>
#              </div>
#             </a>
#             <a class="cjs_nf_a _item _cds_link _newsflash_link" href="https://n.news.naver.com/article/243/0000071684" onclick="nclk(event, 'home.newsflash', '', '')">
#              <div class="cn_title_area">
#               <h4 class="cn_title">
#                법원, '서부지법 난동' 58명 중 56명 구속영장 발부
#               </h4>
#               <div class="cn_snippet">
#                <div class="cn_journal_wrap">
#                 <div class="cn_thumb">
#                  <img alt="" height="10" loading="lazy" onerror="showNoImage(this)" src="https://mimgnews.pstatic.net/image/upload/office_logo/243/2023/01/12/logo_243_56_20230112142411.png?type=nf20_20" width="10"/>
#                 </div>
#                 <div class="cn_name">
#                  이코노미스트
#                 </div>
#                </div>
#                <div class="cn_state">
#                 내용작성전
#                </div>
#               </div>
#              </div>
#             </a>
#             <a class="cjs_nf_a _item _cds_link _newsflash_link" href="https://n.news.naver.com/article/001/0015174453" onclick="nclk(event, 'home.newsflash', '', '')">
#              <div class="cn_title_area">
#               <h4 class="cn_title">
#                '서부지법 집단난동' 시위대 58명 중 56명 구속…"도주우려"
#               </h4>
#               <div class="cn_snippet">
#                <div class="cn_journal_wrap">
#                 <div class="cn_thumb">
#                  <img alt="" height="10" loading="lazy" onerror="showNoImage(this)" src="https://mimgnews.pstatic.net/image/upload/office_logo/001/2020/08/11/logo_001_56_20200811154916.png?type=nf20_20" width="10"/>
#                 </div>
#                 <div class="cn_name">
#                  연합뉴스
#                 </div>
#                </div>
#               </div>
#              </div>
#             </a>
#             <a class="cjs_nf_a _item _cds_link _newsflash_link" href="https://n.news.naver.com/article/656/0000119231" onclick="nclk(event, 'home.newsflash', '', '')">
#              <div class="cn_title_area">
#               <h4 class="cn_title">
#                공수처, 대통령실·관저 압수수색… 비화폰 확보할까
#               </h4>
#               <div class="cn_snippet">
#                <div class="cn_journal_wrap">
#                 <div class="cn_thumb">
#                  <img alt="" height="10" loading="lazy" onerror="showNoImage(this)" src="https://mimgnews.pstatic.net/image/upload/office_logo/656/2022/01/19/logo_656_56_20220119134936.png?type=nf20_20" width="10"/>
#                 </div>
#                 <div class="cn_name">
#                  대전일보
#                 </div>
#                </div>
#               </div>
#              </div>
#             </a>
#             <a class="cjs_nf_a _item _cds_link _newsflash_link" href="https://n.news.naver.com/article/666/0000062711" onclick="nclk(event, 'home.newsflash', '', '')">
#              <div class="cn_title_area">
#               <h4 class="cn_title">
#                공수처, 대통령실·관저 압수수색…비화폰 확보 시도
#               </h4>
#               <div class="cn_snippet">
#                <div class="cn_journal_wrap">
#                 <div class="cn_thumb">
#                  <img alt="" height="10" loading="lazy" onerror="showNoImage(this)" src="https://mimgnews.pstatic.net/image/upload/office_logo/666/2023/01/03/logo_666_56_20230103174615.png?type=nf20_20" width="10"/>
#                 </div>
#                 <div class="cn_name">
#                  경기일보
#                 </div>
#                </div>
#               </div>
#              </div>
#             </a>
#             <a class="cjs_nf_a _item _cds_link _newsflash_link" href="https://n.news.naver.com/article/028/0002727883" onclick="nclk(event, 'home.newsflash', '', '')">
#              <div class="cn_title_area">
#               <h4 class="cn_title">
#                ‘서부지법 난동’ 56명 구속영장 발부…“도주 우려”
#               </h4>
#               <div class="cn_snippet">
#                <div class="cn_journal_wrap">
#                 <div class="cn_thumb">
#                  <img alt="" height="10" loading="lazy" onerror="showNoImage(this)" src="https://mimgnews.pstatic.net/image/upload/office_logo/028/2024/06/18/logo_028_56_20240618172517.png?type=nf20_20" width="10"/>
#                 </div>
#                 <div class="cn_name">
#                  한겨레
#                 </div>
#                </div>
#               </div>
#              </div>
#             </a>
#             <a class="cjs_nf_a _item _cds_link _newsflash_link" href="https://n.news.naver.com/article/016/0002419518" onclick="nclk(event, 'home.newsflash', '', '')">
#              <div class="cn_title_area">
#               <h4 class="cn_title">
#                공수처, 대통령실·관저 압수수색中
#               </h4>
#               <div class="cn_snippet">
#                <div class="cn_journal_wrap">
#                 <div class="cn_thumb">
#                  <img alt="" height="10" loading="lazy" onerror="showNoImage(this)" src="https://mimgnews.pstatic.net/image/upload/office_logo/016/2020/11/03/logo_016_56_20201103113832.jpg?type=nf20_20" width="10"/>
#                 </div>
#                 <div class="cn_name">
#                  헤럴드경제
#                 </div>
#                </div>
#                <div class="cn_state">
#                 내용작성전
#                </div>
#               </div>
#              </div>
#             </a>
#             <a class="cjs_nf_a _item _cds_link _newsflash_link" href="https://n.news.naver.com/article/029/0002931243" onclick="nclk(event, 'home.newsflash', '', '')">
#              <div class="cn_title_area">
#               <h4 class="cn_title">
#                이재명 "한미동맹 노력"…나경원 "미국을 `점령군`이라더니, 결의안에 尹성과 베껴"
#               </h4>
#               <div class="cn_snippet">
#                <div class="cn_journal_wrap">
#                 <div class="cn_thumb">
#                  <img alt="" height="10" loading="lazy" onerror="showNoImage(this)" src="https://mimgnews.pstatic.net/image/upload/office_logo/029/2022/09/01/logo_029_56_20220901154918.jpg?type=nf20_20" width="10"/>
#                 </div>
#                 <div class="cn_name">
#                  디지털타임스
#                 </div>
#                </div>
#               </div>
#              </div>
#             </a>
#             <a class="cjs_nf_a _item _cds_link _newsflash_link" href="https://n.news.naver.com/article/658/0000095168" onclick="nclk(event, 'home.newsflash', '', '')">
#              <div class="cn_title_area">
#               <h4 class="cn_title">
#                공수처 “대통령실·관저 압수수색 진행 중”
#               </h4>
#               <div class="cn_snippet">
#                <div class="cn_journal_wrap">
#                 <div class="cn_thumb">
#                  <img alt="" height="10" loading="lazy" onerror="showNoImage(this)" src="https://mimgnews.pstatic.net/image/upload/office_logo/658/2022/01/20/logo_658_56_20220120164828.png?type=nf20_20" width="10"/>
#                 </div>
#                 <div class="cn_name">
#                  국제신문
#                 </div>
#                </div>
#                <div class="cn_state">
#                 내용작성전
#                </div>
#               </div>
#              </div>
#             </a>
#             <a class="cjs_nf_a _item _cds_link _newsflash_link" href="https://n.news.naver.com/article/081/0003512970" onclick="nclk(event, 'home.newsflash', '', '')">
#              <div class="cn_title_area">
#               <h4 class="cn_title">
#                공수처, 대통령실·관저 압수수색 진행중…비화폰 확보 시도
#               </h4>
#               <div class="cn_snippet">
#                <div class="cn_journal_wrap">
#                 <div class="cn_thumb">
#                  <img alt="" height="10" loading="lazy" onerror="showNoImage(this)" src="https://mimgnews.pstatic.net/image/upload/office_logo/081/2022/01/05/logo_081_56_20220105195830.png?type=nf20_20" width="10"/>
#                 </div>
#                 <div class="cn_name">
#                  서울신문
#                 </div>
#                </div>
#               </div>
#              </div>
#             </a>
#             <button class="cjs_nf_btn_open is_close _toggle_btn" type="button">
#              <span class="blind">
#               속보 닫기
#              </span>
#             </button>
#            </div>
#           </div>
#          </div>
#         </div>
#         <div class="main_brick_item _channel_main_news_card_wrapper">
#          <div class="comp_news_feed comp_news_none">
#           <div class="cnf_journal_area">
#            <a class="cnf_journal" href="https://media.naver.com/press/214" onclick="nclk(event, 'home.editnfmedia', '', '')">
#             <div class="cnf_journal_thumb">
#              <img alt="" data-src="https://mimgnews.pstatic.net/image/upload/office_logo/214/2020/06/30/logo_214_56_20200630111130.png?type=nf36_36" height="18" loading="lazy" onerror="showNoImage(this)" width="18">
#              </img>
#             </div>
#             <em class="cnf_journal_name">
#              MBC
#             </em>
#             <span class="cnf_journal_sub">
#              01월 22일 11:36
#             </span>
#            </a>
#            <button class="cnf_btn_subscription _subscribe_btn" data-office_id="214" data-office_name="MBC" onclick="nclk(event, 'home.editnfset', '', '')">
#             <span class="blind">
#              구독
#             </span>
#            </button>
#           </div>
#           <a class="cnf_news_area _cds_link _editn_link" href="https://n.news.naver.com/article/214/0001401610" onclick="nclk(event, 'home.editnfimg', '', '')">
#            <div class="cnf_news_thumb">
#             <img alt="" data-src="https://mimgnews.pstatic.net/image/origin/214/2025/01/22/1401610.jpg?type=nf168_108&amp;ut=20250122115908" height="54" loading="lazy" onerror="showNoImage(this)" width="80"/>
#            </div>
#            <strong class="cnf_news_title">
#             [속보] 공수처, 대통령실·관저 압수수색‥윤석열 '비화폰' 서버 확보 시도
#            </strong>
#           </a>
#           <ul class="cnf_news_list">
#            <li class="cnf_news_item">
#             <a class="cnf_news _cds_link _editn_link" href="https://n.news.naver.com/article/214/0001401585" onclick="nclk(event, 'home.editnfimg', '', '')">
#              "대통령 측, 사법부 존중하라"‥공수처장, 출근길에 '직격탄' [현장영상]
#             </a>
#            </li>
#            <li class="cnf_news_item">
#             <a class="cnf_news _cds_link _editn_link" href="https://n.news.naver.com/article/214/0001401587" onclick="nclk(event, 'home.editnfimg', '', '')">
#              윤상현 "대한민국 지키겠다는 것이 죄라면 제명하라"
#             </a>
#            </li>
#            <li class="cnf_news_item">
#             <a class="cnf_news _cds_link _editn_link" href="https://n.news.naver.com/article/214/0001401484" onclick="nclk(event, 'home.editnfimg', '', '')">
#              '尹 지지' 2030 일어섰다?‥'특정 교회 신자 많아'
#             </a>
#            </li>
#           </ul>
#          </div>
#         </div>
#         <div class="main_brick_item _channel_main_news_card_wrapper">
#          <div class="comp_news_feed comp_news_none">
#           <div class="cnf_journal_area">
#            <a class="cnf_journal" href="https://media.naver.com/press/660" onclick="nclk(event, 'home.editnfmedia', '', '')">
#             <div class="cnf_journal_thumb">
#              <img alt="" data-src="https://mimgnews.pstatic.net/image/upload/office_logo/660/2022/01/19/logo_660_56_20220119141745.png?type=nf36_36" height="18" loading="lazy" onerror="showNoImage(this)" width="18">
#              </img>
#             </div>
#             <em class="cnf_journal_name">
#              kbc광주방송
#             </em>
#             <span class="cnf_journal_sub">
#              01월 22일 11:07
#             </span>
#            </a>
#            <button class="cnf_btn_subscription _subscribe_btn" data-office_id="660" data-office_name="kbc광주방송" onclick="nclk(event, 'home.editnfset', '', '')">
#             <span class="blind">
#              구독
#             </span>
#            </button>
#           </div>
#           <a class="cnf_news_area _cds_link _editn_link" href="https://n.news.naver.com/article/660/0000077889" onclick="nclk(event, 'home.editnfimg', '', '')">
#            <div class="cnf_news_thumb">
#             <img alt="" data-src="https://mimgnews.pstatic.net/image/origin/660/2025/01/22/77889.jpg?type=nf168_108&amp;ut=20250122105418" height="54" loading="lazy" onerror="showNoImage(this)" width="80"/>
#            </div>
#            <strong class="cnf_news_title">
#             '제명 위기' 윤상현 "대한민국 지키는 게 죄라면 제명하라"
#            </strong>
#           </a>
#           <ul class="cnf_news_list">
#            <li class="cnf_news_item">
#             <a class="cnf_news _cds_link _editn_link" href="https://n.news.naver.com/article/660/0000077873" onclick="nclk(event, 'home.editnfimg', '', '')">
#              경북 한 펜션서 30대 여성과 남성 숨진 채 발견..경찰 수사
#             </a>
#            </li>
#            <li class="cnf_news_item">
#             <a class="cnf_news _cds_link _editn_link" href="https://n.news.naver.com/article/660/0000077861" onclick="nclk(event, 'home.editnfimg', '', '')">
#              튀르키예 스키 리조트 호텔 화재.."최소 66명 사망"
#             </a>
#            </li>
#            <li class="cnf_news_item">
#             <a class="cnf_news _cds_link _editn_link" href="https://n.news.naver.com/article/660/0000077854" onclick="nclk(event, 'home.editnfimg', '', '')">
#              무안국제공항 로컬라이저 조성 당시 한국공항공사 사장 숨진 채 발견
#             </a>
#            </li>
#           </ul>
#          </div>
#         </div>
#         <div class="main_brick_item _channel_main_news_card_wrapper">
#          <div class="comp_news_feed comp_news_none">
#           <div class="cnf_journal_area">
#            <a class="cnf_journal" href="https://media.naver.com/press/032" onclick="nclk(event, 'home.editnfmedia', '', '')">
#             <div class="cnf_journal_thumb">
#              <img alt="" data-src="https://mimgnews.pstatic.net/image/upload/office_logo/032/2022/12/05/logo_032_56_20221205150153.png?type=nf36_36" height="18" loading="lazy" onerror="showNoImage(this)" width="18">
#              </img>
#             </div>
#             <em class="cnf_journal_name">
#              경향신문
#             </em>
#             <span class="cnf_journal_sub">
#              01월 22일 11:38
#             </span>
#            </a>
#            <button class="cnf_btn_subscription _subscribe_btn" data-office_id="032" data-office_name="경향신문" onclick="nclk(event, 'home.editnfset', '', '')">
#             <span class="blind">
#              구독
#             </span>
#            </button>
#           </div>
#           <a class="cnf_news_area _cds_link _editn_link" href="https://n.news.naver.com/article/032/0003347040" onclick="nclk(event, 'home.editnfimg', '', '')">
#            <div class="cnf_news_thumb">
#             <img alt="" data-src="https://mimgnews.pstatic.net/image/origin/032/2025/01/22/3347040.jpg?type=nf168_108&amp;ut=20250122114111" height="54" loading="lazy" onerror="showNoImage(this)" width="80"/>
#            </div>
#            <strong class="cnf_news_title">
#             [속보]공수처, 대통령실·관저 압수수색…윤석열 ‘비화폰’ 서버 확보 시도
#            </strong>
#           </a>
#           <ul class="cnf_news_list">
#            <li class="cnf_news_item">
#             <a class="cnf_news _cds_link _editn_link" href="https://n.news.naver.com/article/032/0003347015" onclick="nclk(event, 'home.editnfimg', '', '')">
#              [속보]공수처 “구치소 내 조사실 마련···윤석열 강제구인 등 대면조사에 최선”
#             </a>
#            </li>
#            <li class="cnf_news_item">
#             <a class="cnf_news _cds_link _editn_link" href="https://n.news.naver.com/article/032/0003347025" onclick="nclk(event, 'home.editnfimg', '', '')">
#              이재명 “흑묘·백묘? 쥐만 잘 잡으면 돼”···‘탈이념’ ‘탈진영’ 언급
#             </a>
#            </li>
#            <li class="cnf_news_item">
#             <a class="cnf_news _cds_link _editn_link" href="https://n.news.naver.com/article/032/0003347026" onclick="nclk(event, 'home.editnfimg', '', '')">
#              [속보] 김성훈 경호차장, 김건희 황제경호 의혹에 “확인 못 해준다”
#             </a>
#            </li>
#           </ul>
#          </div>
#         </div>
#         <div class="main_brick_item _channel_main_news_card_wrapper">
#          <div class="comp_news_feed comp_news_none">
#           <div class="cnf_journal_area">
#            <a class="cnf_journal" href="https://media.naver.com/press/020" onclick="nclk(event, 'home.editnfmedia', '', '')">
#             <div class="cnf_journal_thumb">
#              <img alt="" data-src="https://mimgnews.pstatic.net/image/upload/office_logo/020/2020/09/17/logo_020_56_20200917112548.jpg?type=nf36_36" height="18" loading="lazy" onerror="showNoImage(this)" width="18">
#              </img>
#             </div>
#             <em class="cnf_journal_name">
#              동아일보
#             </em>
#             <span class="cnf_journal_sub">
#              01월 22일 11:58
#             </span>
#            </a>
#            <button class="cnf_btn_subscription _subscribe_btn" data-office_id="020" data-office_name="동아일보" onclick="nclk(event, 'home.editnfset', '', '')">
#             <span class="blind">
#              구독
#             </span>
#            </button>
#           </div>
#           <a class="cnf_news_area _cds_link _editn_link" href="https://n.news.naver.com/article/020/0003611513" onclick="nclk(event, 'home.editnfimg', '', '')">
#            <div class="cnf_news_thumb">
#             <img alt="" data-src="https://mimgnews.pstatic.net/image/origin/020/2025/01/22/3611513.jpg?type=nf168_108&amp;ut=20250122110912" height="54" loading="lazy" onerror="showNoImage(this)" width="80"/>
#            </div>
#            <strong class="cnf_news_title">
#             [단독]공수처, 대통령실 ‘尹 비화폰 서버 확보’ 압수수색 시도
#            </strong>
#           </a>
#           <ul class="cnf_news_list">
#            <li class="cnf_news_item">
#             <a class="cnf_news _cds_link _editn_link" href="https://n.news.naver.com/article/020/0003611505" onclick="nclk(event, 'home.editnfimg', '', '')">
#              공수처, 서울구치소 도착…尹 강제구인 3차 시도
#             </a>
#            </li>
#            <li class="cnf_news_item">
#             <a class="cnf_news _cds_link _editn_link" href="https://n.news.naver.com/article/020/0003611509" onclick="nclk(event, 'home.editnfimg', '', '')">
#              [단독]초유의 대통령 ‘출정 경호’…호송차 구치소 ‘내부정문’ 통과뒤 경호처 차량경호
#             </a>
#            </li>
#            <li class="cnf_news_item">
#             <a class="cnf_news _cds_link _editn_link" href="https://n.news.naver.com/article/020/0003611522" onclick="nclk(event, 'home.editnfimg', '', '')">
#              [속보]법원, ‘서부지법 폭력난입’ 58명중 56명 구속
#             </a>
#            </li>
#           </ul>
#          </div>
#         </div>
#         <div class="main_brick_item _channel_main_news_card_wrapper">
#          <div class="comp_news_feed comp_news_none">
#           <div class="cnf_journal_area">
#            <a class="cnf_journal" href="https://media.naver.com/press/018" onclick="nclk(event, 'home.editnfmedia', '', '')">
#             <div class="cnf_journal_thumb">
#              <img alt="" data-src="https://mimgnews.pstatic.net/image/upload/office_logo/018/2018/07/18/logo_018_56_20180718152418.png?type=nf36_36" height="18" loading="lazy" onerror="showNoImage(this)" width="18">
#              </img>
#             </div>
#             <em class="cnf_journal_name">
#              이데일리
#             </em>
#             <span class="cnf_journal_sub">
#              01월 22일 11:55
#             </span>
#            </a>
#            <button class="cnf_btn_subscription _subscribe_btn" data-office_id="018" data-office_name="이데일리" onclick="nclk(event, 'home.editnfset', '', '')">
#             <span class="blind">
#              구독
#             </span>
#            </button>
#           </div>
#           <a class="cnf_news_area _cds_link _editn_link" href="https://n.news.naver.com/article/018/0005929541" onclick="nclk(event, 'home.editnfimg', '', '')">
#            <div class="cnf_news_thumb">
#             <img alt="" data-src="https://mimgnews.pstatic.net/image/origin/018/2025/01/22/5929541.jpg?type=nf168_108&amp;ut=20250122062215" height="54" loading="lazy" onerror="showNoImage(this)" width="80"/>
#            </div>
#            <strong class="cnf_news_title">
#             "이러다 진짜 문 닫겠어요" 임시공휴일에 우는 소상공인
#            </strong>
#           </a>
#           <ul class="cnf_news_list">
#            <li class="cnf_news_item">
#             <a class="cnf_news _cds_link _editn_link" href="https://n.news.naver.com/article/018/0005929841" onclick="nclk(event, 'home.editnfimg', '', '')">
#              尹, 선관위 강제수사 불가능하다더니…野 “재임 중 165회 이뤄져”
#             </a>
#            </li>
#            <li class="cnf_news_item">
#             <a class="cnf_news _cds_link _editn_link" href="https://n.news.naver.com/article/018/0005929804" onclick="nclk(event, 'home.editnfimg', '', '')">
#              "전광훈 목사님 천사미소"..판사실 침입 전도사 체포
#             </a>
#            </li>
#            <li class="cnf_news_item">
#             <a class="cnf_news _cds_link _editn_link" href="https://n.news.naver.com/article/018/0005929816" onclick="nclk(event, 'home.editnfimg', '', '')">
#              생포된 북한군 “한국어로 된 ‘사랑 영화’ 틀어달라”
#             </a>
#            </li>
#           </ul>
#          </div>
#         </div>
#         <div class="main_brick_item _channel_main_news_card_wrapper">
#          <div class="comp_news_feed comp_news_none">
#           <div class="cnf_journal_area">
#            <a class="cnf_journal" href="https://media.naver.com/press/028" onclick="nclk(event, 'home.editnfmedia', '', '')">
#             <div class="cnf_journal_thumb">
#              <img alt="" data-src="https://mimgnews.pstatic.net/image/upload/office_logo/028/2024/06/18/logo_028_56_20240618172517.png?type=nf36_36" height="18" loading="lazy" onerror="showNoImage(this)" width="18">
#              </img>
#             </div>
#             <em class="cnf_journal_name">
#              한겨레
#             </em>
#             <span class="cnf_journal_sub">
#              01월 22일 11:49
#             </span>
#            </a>
#            <button class="cnf_btn_subscription _subscribe_btn" data-office_id="028" data-office_name="한겨레" onclick="nclk(event, 'home.editnfset', '', '')">
#             <span class="blind">
#              구독
#             </span>
#            </button>
#           </div>
#           <a class="cnf_news_area _cds_link _editn_link" href="https://n.news.naver.com/article/028/0002727883" onclick="nclk(event, 'home.editnfimg', '', '')">
#            <div class="cnf_news_thumb">
#             <img alt="" data-src="https://mimgnews.pstatic.net/image/origin/028/2025/01/22/2727883.jpg?type=nf168_108&amp;ut=20250122115811" height="54" loading="lazy" onerror="showNoImage(this)" width="80"/>
#            </div>
#            <strong class="cnf_news_title">
#             [속보] ‘서부지법 난동’ 56명 구속영장 발부…“도주 우려”
#            </strong>
#           </a>
#           <ul class="cnf_news_list">
#            <li class="cnf_news_item">
#             <a class="cnf_news _cds_link _editn_link" href="https://n.news.naver.com/article/028/0002727869" onclick="nclk(event, 'home.editnfimg', '', '')">
#              [속보] 이상민 “증언하지 않겠다”…언론사 단전·단수  질의 답 거부
#             </a>
#            </li>
#            <li class="cnf_news_item">
#             <a class="cnf_news _cds_link _editn_link" href="https://n.news.naver.com/article/028/0002727885" onclick="nclk(event, 'home.editnfimg', '', '')">
#              선관위 압수수색 30차례…윤석열 “강제수사 불가능해 계엄” 거짓말
#             </a>
#            </li>
#            <li class="cnf_news_item">
#             <a class="cnf_news _cds_link _editn_link" href="https://n.news.naver.com/article/028/0002727871" onclick="nclk(event, 'home.editnfimg', '', '')">
#              홍준표 “차기 대선 후보인 내가 쪽팔리게 떨면서 줄까지 서야 하나”
#             </a>
#            </li>
#           </ul>
#          </div>
#         </div>
#         <div class="main_brick_item _channel_main_news_card_wrapper">
#          <div class="comp_news_feed comp_news_none">
#           <div class="cnf_journal_area">
#            <a class="cnf_journal" href="https://media.naver.com/press/050" onclick="nclk(event, 'home.editnfmedia', '', '')">
#             <div class="cnf_journal_thumb">
#              <img alt="" data-src="https://mimgnews.pstatic.net/image/upload/office_logo/050/2021/07/15/logo_050_56_20210715110055.jpg?type=nf36_36" height="18" loading="lazy" onerror="showNoImage(this)" width="18">
#              </img>
#             </div>
#             <em class="cnf_journal_name">
#              한경비즈니스
#             </em>
#             <span class="cnf_journal_sub">
#              01월 22일 09:46
#             </span>
#            </a>
#            <button class="cnf_btn_subscription _subscribe_btn" data-office_id="050" data-office_name="한경비즈니스" onclick="nclk(event, 'home.editnfset', '', '')">
#             <span class="blind">
#              구독
#             </span>
#            </button>
#           </div>
#           <a class="cnf_news_area _cds_link _editn_link" href="https://n.news.naver.com/article/050/0000085507" onclick="nclk(event, 'home.editnfimg', '', '')">
#            <div class="cnf_news_thumb">
#             <img alt="" data-src="https://mimgnews.pstatic.net/image/origin/050/2025/01/22/85507.jpg?type=nf168_108&amp;ut=20250122091511" height="54" loading="lazy" onerror="showNoImage(this)" width="80"/>
#            </div>
#            <strong class="cnf_news_title">
#             “미워도 다시 한번”…고액자산가, 코스피와 삼성전자 담았다 [2025 부자 투자 노트①]
#            </strong>
#           </a>
#           <ul class="cnf_news_list">
#            <li class="cnf_news_item">
#             <a class="cnf_news _cds_link _editn_link" href="https://n.news.naver.com/article/050/0000085504" onclick="nclk(event, 'home.editnfimg', '', '')">
#              머스크, 틱톡까지 인수하나?
#             </a>
#            </li>
#            <li class="cnf_news_item">
#             <a class="cnf_news _cds_link _editn_link" href="https://n.news.naver.com/article/050/0000085502" onclick="nclk(event, 'home.editnfimg', '', '')">
#              트럼프 "다음달 1일부터 중국에 10% 관세 부과 방안 논의중"
#             </a>
#            </li>
#            <li class="cnf_news_item">
#             <a class="cnf_news _cds_link _editn_link" href="https://n.news.naver.com/article/050/0000085514" onclick="nclk(event, 'home.editnfimg', '', '')">
#              대명소노 “티웨이 품는다”...글로벌 리딩기업 도약 선포
#             </a>
#            </li>
#           </ul>
#          </div>
#         </div>
#         <div class="main_brick_item _channel_main_news_card_wrapper">
#          <div class="comp_news_feed comp_news_none">
#           <div class="cnf_journal_area">
#            <a class="cnf_journal" href="https://media.naver.com/press/655" onclick="nclk(event, 'home.editnfmedia', '', '')">
#             <div class="cnf_journal_thumb">
#              <img alt="" data-src="https://mimgnews.pstatic.net/image/upload/office_logo/655/2022/01/20/logo_655_56_20220120164501.png?type=nf36_36" height="18" loading="lazy" onerror="showNoImage(this)" width="18">
#              </img>
#             </div>
#             <em class="cnf_journal_name">
#              CJB청주방송
#             </em>
#             <span class="cnf_journal_sub">
#              01월 22일 11:50
#             </span>
#            </a>
#            <button class="cnf_btn_subscription _subscribe_btn" data-office_id="655" data-office_name="CJB청주방송" onclick="nclk(event, 'home.editnfset', '', '')">
#             <span class="blind">
#              구독
#             </span>
#            </button>
#           </div>
#           <a class="cnf_news_area _cds_link _editn_link" href="https://n.news.naver.com/article/655/0000023148" onclick="nclk(event, 'home.editnfimg', '', '')">
#            <div class="cnf_news_thumb">
#             <img alt="" data-src="https://mimgnews.pstatic.net/image/origin/655/2025/01/22/23148.jpg?type=nf168_108&amp;ut=20250122114913" height="54" loading="lazy" onerror="showNoImage(this)" width="80"/>
#            </div>
#            <strong class="cnf_news_title">
#             '내란 혐의' 김용현·조지호 나란히 보석 신청...이유는?
#            </strong>
#           </a>
#           <ul class="cnf_news_list">
#            <li class="cnf_news_item">
#             <a class="cnf_news _cds_link _editn_link" href="https://n.news.naver.com/article/655/0000023143" onclick="nclk(event, 'home.editnfimg', '', '')">
#              나경원 "민주 '한미동맹 지지 결의안'...尹 격상시킨 성과 베껴"
#             </a>
#            </li>
#            <li class="cnf_news_item">
#             <a class="cnf_news _cds_link _editn_link" href="https://n.news.naver.com/article/655/0000023146" onclick="nclk(event, 'home.editnfimg', '', '')">
#              다가오는 설, 무려 134만 명 해외여행 떠난다
#             </a>
#            </li>
#            <li class="cnf_news_item">
#             <a class="cnf_news _cds_link _editn_link" href="https://n.news.naver.com/article/655/0000023142" onclick="nclk(event, 'home.editnfimg', '', '')">
#              [속보] 공수처장 "오늘 다시 尹 강제구인 시도 할 것"
#             </a>
#            </li>
#           </ul>
#          </div>
#         </div>
#         <div class="main_brick_item _channel_main_news_card_wrapper">
#          <div class="comp_news_feed comp_news_none">
#           <div class="cnf_journal_area">
#            <a class="cnf_journal" href="https://media.naver.com/press/081" onclick="nclk(event, 'home.editnfmedia', '', '')">
#             <div class="cnf_journal_thumb">
#              <img alt="" data-src="https://mimgnews.pstatic.net/image/upload/office_logo/081/2022/01/05/logo_081_56_20220105195830.png?type=nf36_36" height="18" loading="lazy" onerror="showNoImage(this)" width="18">
#              </img>
#             </div>
#             <em class="cnf_journal_name">
# ...
#          <div class="comp_correction_banner">
#           <div class="ccb_banner_wrap">
#            <a class="ccb_link_banner" href="/main/ombudsman/errorArticleList.naver?mid=omb" onclick="nclk(event, 'home.editmodbanner', '', '')" target="_blank">
#             <picture>
#              <source media="(max-width: 320px)" srcset="https://ssl.pstatic.net/static.news/image/news/m/2024/07/29/ccb_correction_banner_320.png"/>
#              <img alt="고침, 정정, 반론 추후 보도 모음. 언론사의 정정 반론 추후 보도 기사를 모았습니다." class="light_type" loading="lazy" src="https://ssl.pstatic.net/static.news/image/news/m/2024/07/29/ccb_correction_banner.png" width="100%"/>
#             </picture>
#             <picture>
#              <source media="(max-width: 320px)" srcset="https://ssl.pstatic.net/static.news/image/news/m/2024/07/29/ccb_correction_banner_320_dark.png"/>
#              <img alt="고침, 정정, 반론 추후 보도 모음. 언론사의 정정 반론 추후 보도 기사를 모았습니다." class="dark_type" loading="lazy" src="https://ssl.pstatic.net/static.news/image/news/m/2024/07/29/ccb_correction_banner_dark.png" width="100%"/>
#             </picture>
#            </a>
#           </div>
#          </div>
#         </div>
#        </div>
#        <div class="brick-vowel _brick_column">
#        </div>
#        <div class="brick-vowel _brick_column">
#        </div>
#       </div>
#      </div>
#     </section>
#     <section class="main_aside _aside_wrapper">
#      <div class="main_aside_inner _aside_content">
#       <h3 class="blind">
#        구독
#       </h3>
#       <div class="_aside">
#       </div>
#       <script>
#        doAfterLoadEnd(loadAside);
#
#
# function loadAside() {
#     var forcePcVersion = "";
#
#     if (isMobileDevice() && !forcePcVersion) {
#         return;
#     }
#     var iframe = append();
#     var asideFixed;
#
#     window.addEventListener('message', function(event) {
#         var data = event.data;
#
#         if (event.origin !== "https://news.naver.com") {
#             return;
#         }
#
#         if (data.type === "setIframeSize" && data.height) {
#             iframe.style.height = data.height + 'px';
#             iframe.style.visibility = "";
#
#             try {
#                 asideFixed.deactivate(); // event 중복 적용되지 않게
#             } catch(e) {}
#
#             asideFixed = AsideFixed({
#                 "wrapper" : document.querySelector("._aside_wrapper")
#
#             });
#         }
#     });
#
#
#     function append() {
#         var iframe = document.createElement('iframe');
#
#         iframe.title = "구독 및 추천 채널";
#         iframe.width = "100%";
#         iframe.height = "0";
#         iframe.style.visibility = "hidden";
#         iframe.setAttribute("frameborder", "no");
#         iframe.setAttribute("scrolling", "no");
#         iframe.src = "https://news.naver.com/aside?oid=";
#
#         document.querySelector("._aside").appendChild(iframe);
#
#         return iframe;
#     }
# }
#       </script>
#      </div>
#     </section>
#     <div class="layer_toast" style="display: none">
#     </div>
#     <div class="layer_toast_journal_subscribe _subscribe_toast_layer" style="display: none">
#      <button class="lt_btn_set _subscribe_toast_btn" onclick="nclk(event, 'home.edittallchk', '', '')" type="button">
#      </button>
#     </div>
#    </div>
#   </div>
#   <!-- //ct -->
#   <hr/>
#   <div class="mp_footer">
#    <div class="f_maininfo">
#     <div class="f_maininfoinner">
#      <a class="r_pg_top _go_top" href="javascript:topPage();" id="goTop" onclick="nclk(event, 'fot.pctop', '', '');">
#       맨위로
#      </a>
#      <footer role="contentinfo">
#       <p class="u_cr">
#        <span class="u_ftm _footer_login">
#         <span class="u_cri u_cri_v1">
#          <a class="u_cra" data-mpurl='{"m":"https://m.naver.com/services.html","p":"https://www.naver.com/more.html"}' href="https://m.naver.com/services.html" onclick="nclk(event,'fot.serviceall','','');">
#           전체서비스
#          </a>
#         </span>
#        </span>
#        <span class="u_ftm">
#         <span class="u_cri u_cri_v1">
#          <a class="u_cra" data-mpurl='{"m":"https://m.news.naver.com/ombudsman/index","p":"https://news.naver.com/main/ombudsman/index.naver"}' href="https://m.news.naver.com/ombudsman/index" onclick="nclk(event,'fot.guide','','');">
#           서비스안내
#          </a>
#         </span>
#         <span class="u_cri u_cri_v1">
#          <a class="u_cra" data-mpurl='{"m":"https://help.naver.com/alias/news/news_001.naver","p":"https://help.naver.com/alias/news/news_001.naver"}' href="https://help.naver.com/alias/news/news_001.naver" onclick="nclk(event,'fot.report','','');">
#           오류신고
#          </a>
#         </span>
#         <span class="u_cri u_cri_v1">
#          <a class="u_cra" data-mpurl='{"m":"https://help.naver.com/alias/news/news_007.naver","p":"https://help.naver.com/alias/news/news_007.naver"}' href="https://help.naver.com/alias/news/news_007.naver" onclick="nclk(event,'fot.help','','');">
#           고객센터
#          </a>
#         </span>
#        </span>
#        <span class="cr_rule">
#         <span class="cr_rulea">
#          청소년 보호 책임자 : 이정규
#         </span>
#        </span>
#        <span class="u_presscopy">
#         각 언론사가 직접 콘텐츠를 편집합니다.
#        </span>
#        <span class="u_copyright">
#         이 콘텐츠의 저작권은 저작권자 또는 제공처에 있으며, 이를 무단 이용하는 경우 저작권법 등에 따라 법적 책임을 질 수 있습니다.
#        </span>
#        <span class="u_naverlogo">
#         <a class="u_naverlogo_a" data-mpurl='{"m":"https://www.navercorp.com/","p":"https://www.navercorp.com/"}' href="https://www.navercorp.com/" id="nhnLink" onclick="nclk(event,'fot.navercorp','','');">
#          NAVER
#         </a>
#        </span>
#       </p>
#      </footer>
#     </div>
#    </div>
#   </div>
#   <script src="https://ssl.pstatic.net/static.news/mnews/resources/20250117_004017/js/generated/news.mobile.js" type="text/javascript">
#   </script>
#   <script src="https://ssl.pstatic.net/static.news/mnews/resources/20250117_004017/js/generated/pressmain.dependency.js" type="text/javascript">
#   </script>
#   <script type="text/javascript">
#    var config = {
#         "neloCollectorUrl": "https://kr-col-ext.nelo.navercorp.com/_store",
#         "projectName": "P638fcb_news-mobile-front",
#         "host": "real"
#     }
#
#     try{
#         neloSender.init(config);
#     }catch(e){}
#   </script>
#   <script type="text/javascript">
#    /**
#  * 이 파일은 모바일 뉴스 서비스 전체 페이지에 적용되는 스크립트로써,
#  * 코드 추가 시 Front-End 성능 관점에서 주의를 요합니다.
#  */
# jQuery(window).on('load', function(){
#     setTimeout(onload, 10);
#
#     function onload(){
#         var oLnb = new news.Lnb('._lnb_scroll');
#         new news.ImageLazyLoader().load("img[data-src]");
#         new news.MoveTopButton("._go_top");
#
#
#         new news.HistoryManager().init("naver_mobile_news_history", "");
#
#         // iframe lazy-loading
#         (function(){
#             try {
#                 Array.prototype.slice.apply(document.querySelectorAll('iframe[data-src]'))
#                     .forEach(function(iframeEl) {
#                         var originSrc = iframeEl.getAttribute('data-src');
#                         if(originSrc) {
#                             iframeEl.setAttribute('src', originSrc);
#                         }
#                     });
#             }catch(e) {}
#         })();
#
#         if(typeof init === "function"){
#             init();
#         }
#
#         var cookie = news.Cookie.getInstance();
#         var isShownNewLnb = cookie.getItem("isShownNewLnb");
#         if(isShownNewLnb == null) {
#             isShownNewLnb = "Y";
#             cookie.setItem("isShownNewLnb", isShownNewLnb, 3650, "", "/");
#             $("._isNew").addClass("is_new");
#         }
#
#         {
#             var footerLogin = jQuery(document).find('._footer_login');
#             if(footerLogin <= 0) {
#                 return;
#             }
#
#             // 디바이스에 따라 로그인, 로그아웃 URL 분기
#             var loginUrl = "https://nid.naver.com/nidlogin.login";
#             var logoutUrl = "https://nid.naver.com/nidlogin.logout?";
#             if (news.Util.getAgentInfo().bMobileOrTablet) {
#                 loginUrl = "https://nid.naver.com/nidlogin.login?svctype=262144";
#                 logoutUrl = "https://nid.naver.com/nidlogin.logout?svctype=262144&";
#             }
#
#             if(news.LoginAssistor.isLoginUser()) {
#                 footerLogin.prepend('<span class="u_cri u_cri_v1"><a href="javascript:news.Util.logout(\''+logoutUrl+'url=\'+encodeURIComponent(location.href));" class="u_cra" id="news_logout" onclick="nclk(event,\'fot.logout\',\'\',\'\');" >로그아웃</a></span>')
#             }else {
#                 footerLogin.prepend('<span class="u_cri u_cri_v1"><a href="'+loginUrl+'" class="u_cra" id="news_login" onclick="nclk(event,\'fot.login\',\'\',\'\');" >로그인</a></span>')
#             }
#         }
#     }
# });
#   </script>
#   <script id="feedRefreshButtonTemplate" type="text/x-handlebars-template">
#    {{buttonText}}
#     <span class="paging">
#         <span class="blind">현재</span>{{currentPage}}
#         <em class="total"> / <span class="blind">전체</span>{{totalPage}}</em>
#     </span>
#   </script>
#   <script type="text/javascript">
#    try {
#         FeedCard($('._journalist_feed_card_wrapper'), 'journalist', 'https://m.news.naver.com');
#         FeedCard($('._series_feed_card_wrapper'), 'series', 'https://m.news.naver.com');
#     } catch (e) {
#         neloSender.sendErrorToNelo("[PC 언론사별] FeedCard 스크립트 오류 " + e);
#     }
#
#     try {
#         BrickGridForEditByPress($("._brick_gid_wrapper"));
#     } catch (e) {
#         neloSender.sendErrorToNelo("[PC 언론사별] BrickGridForEditByPress 스크립트 오류 " + e);
#     }
#
#     try {
#         PressMainStatusCard($('._press_main_status_wrapper'));
#     } catch (e) {
#         neloSender.sendErrorToNelo("[PC 언론사별] PressMainStatusCard 스크립트 오류 " + e);
#     }
#
#     try {
#         NewsFlashCard($('._newsflash_wrapper'));
#     } catch (e) {
#         neloSender.sendErrorToNelo("[PC 언론사별] NewsFlashCard 스크립트 오류 " + e);
#     }
#
#     try {
#
#
#         window.gladsdk.cmd.push(function () {
#             var adSlot = window.gladsdk.findAdSlot("glad_ad_sidebox");
#             adSlot.setCustomParam("calp", 'home');
#             window.gladsdk.displayAd(adSlot);
#
#
#             window.gladsdk.addEventListener(window.gladsdk.event.ERROR, function (ad, error) {
#                 $("._card_ad").hide();
#             });
#         });
#     } catch (e) {
#         neloSender.sendErrorToNelo("[PC 언론사별] 광고 호출 스크립트 오류 " + e);
#     }
#
#     try {
#         $('._channel_news_card_wrapper').each(function () {
#             var wrapper = $(this);
#             ChannelNewsCard(wrapper, 'https://m.news.naver.com');
#         });
#     } catch (e) {
#         neloSender.sendErrorToNelo("[PC 언론사별] ChannelNewsCard 스크립트 오류" + e);
#     }
#
#     try {
#         ChannelMainNewsCard($('._channel_main_news_card_wrapper'), 'https://m.news.naver.com');
#     } catch (e) {
#         neloSender.sendErrorToNelo("[PC 언론사별] ChannelMainNewsCard 스크립트 오류 " + e);
#     }
#
#     try {
#         SubscribeBannerShortCard($('._short_subscribe_banner_card_wrapper'), 'https://m.news.naver.com');
#         SubscribeBannerLongCard($('._long_subscribe_banner_card_wrapper'), 'https://m.news.naver.com');
#     } catch (e) {
#         neloSender.sendErrorToNelo("[PC 언론사별] SubscribeBannerCard 스크립트 오류 " + e);
#     }
#
#     try {
#         WeeklySpecialReportCard($('._weekly_special_report_card_wrapper'));
#     } catch (e) {
#         neloSender.sendErrorToNelo("[PC 언론사별] WeeklySpecialReportCard 스크립트 오류 " + e);
#     }
#
#     try {
#         $('._horizontal_card_wrapper').each(function () {
#             var wrapper = $(this);
#             HorizontalTypeCard(wrapper, 'https://m.news.naver.com');
#         });
#     } catch (e) {
#         neloSender.sendErrorToNelo("[PC 언론사별] HorizontalTypeCard 스크립트 오류 " + e);
#     }
#
#     try {
#         SpecialReportCard($('._special_report_card_wrapper'), 'https://m.news.naver.com');
#     } catch (e) {
#         neloSender.sendErrorToNelo("[PC 언론사별] SpecialReportCard 스크립트 오류 " + e);
#     }
#
#     ArticleLinkParamsAppender('news_media_pc');
#
#     // Impression
#     try {
#         news.Impression.getInstance().init();
#     } catch (e) {
#         neloSender.sendErrorToNelo("[PC 언론사별] Impression init 스크립트 오류 " + e);
#     }
#
#     new news.ImageLazyLoader().load("img[data-src]");
#   </script>
#   <script>
#    var gnb_service = 'news';
#     var gnb_logout = encodeURIComponent(location.href);
#     var gnb_template = 'gnb_utf8';
#     var gnb_brightness = 3;
#     var gnb_item_hide_option= 128;
#
#     doAfterLoadEnd(function () {
#         try {
#             GlobalMPUrlManager.init();
#         } catch (e) {}
#     });
#
#     doAfterLoadEnd(function() {
#         if (!document.querySelector('#gnb') || isMobileDevice() === true) {
#             return;
#         }
#
#         var gnb_src = "https://ssl.pstatic.net/static.gn/templates/gnb_utf8?2025012212";
#
#         // GnbHelper를 이용하여 GNB Layer를 닫을 수 있도록 지원한다.
#         if (window.jindo) {
#             jindo.LazyLoading.load(
#                 gnb_src,
#                 function() {
#                     try {
#                         getGNB();
#                     } catch(e) {}
#                 },
#                 'utf-8'
#             );
#
#             jindo.$Fn(function (oEvent) {
#
#                 GnbHelper.attachClick(oEvent.$value().target);
#             }).attach(document, 'click');
#         } else if (window.jQuery) {
#             new news.JsLoader().
#                 load(
#                     [gnb_src],
#                     function() {
#                         try {
#                             getGNB();
#                         } catch(e) {}
#                     }
#                 );
#
#             $(document).on("click", function(event) {
#                 GnbHelper.attachClick(event.target);
#             });
#         }
#     });
#   </script>
#   <script>
#    doAfterLoadEnd(function() {
#         if (!document.querySelector('.news_header')){
#             return;
#         }
#
#         try {
#             GnbFloatingManager.init();
#         } catch (e) { }
#     });
#   </script>
#   <script>
#    doAfterLoadEnd(function() {
#     try {
#         new SearchAutoComplete({
#             content: document.querySelector("._search_content"),
#             contentToggleBtn: document.querySelector("._search_content_toggle_btn"),
#             isMobile: isMobileDevice(),
#             nClickType: "newsM"
#         });
#     } catch(e) {}
# });
#   </script>
#   <!-- LCS -->
#   <script type="text/javascript">
#    function initMa(){
#     var data = {
#         "service": "news",
#         "baseInfo": {
#             "category": (function(){
#
#                 var result = "언론사별(신규)";
#
#                 if(result !== ""){
#                     return result;
#                 }
#                 try{
#
#                     return document.querySelector('meta[property="og:title"]')
#                         .getAttribute('content')
#                         .replace(/[\s]*:+[\s]*네이버[\s]*뉴스/, '');
#                 }catch(e){
#                     return "";
#                 }
#             })()
#         },
#         "extraInfo": {}
#     };
#
#
#
#     try{
#         ma.init({
#             api: "https://ma.news.naver.com/l",
#             data: data
#         });
#     }catch(e){}
# }
#   </script>
#   <script type="text/javascript">
#    window.ntm_news = window.ntm_news || [];
#
#     doAfterLoadEnd(function () {
#         var ntmUrl = "https://ntm.pstatic.net/scripts/ntm_b7032129a433.js";
#
#
#
#
#
#         ntmInit(ntmUrl);
#     });
#   </script>
#   <script type="text/javascript">
#    // NLog pageview 전송
#     var eventType = "onpageshow" in window ? "pageshow" : "load";
#     jQuery(window).on(eventType, function() {
#         var sti = "";
#         var gdid = "";
#
#
#
#
#
#
#                 if (isMobileDevice()) {
#                     // mobile
#
#                         sti = "m_news";
#
#                 } else {
#                     // pc
#
#                 }
#
#
#
#         // ma 전송
#         try {
#             initMa();
#         } catch (e) {
#         }
#
#         ntmCustomPageViewSend({
#             sti: sti,
#             gdid: gdid
#         });
#     });
#   </script>
#   <!-- //LCS -->
#   <div id="videoWrap">
#   </div>
#  </body>
# </html>

# %%
news_title = bs_obj.findAll('strong',{'class':'cnf_news_title'})
news_title2 = bs_obj.findAll('a',{'class':'cnf_news'})
news_titles = news_title + news_title2

# news_titles = bs_obj.findAll('strong', {'class': 'cnf_news_title'}) + bs_obj.findAll('a', {'class': 'cnf_news _cds_link _editn_link'})

# CSS 선택자 사용
# news_titles = bs_obj.select('strong.cnf_news_title, a.cnf_news')

# %%
len(news_titles)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[71], line 1
# ----> 1 len(news_titles)
#
# TypeError: object of type 'NoneType' has no len()

# %%
news_titles
# Out:
# [<strong class="cnf_news_title">공수처장 “대통령, 사법부 존중해야...오늘 중 최대한 강제구인”</strong>,
#  <strong class="cnf_news_title">내란 국조특위, 尹 '동행명령장' 발부…與 "망신주기"[종합]</strong>,
#  <strong class="cnf_news_title">개신교 단체 "폭력 조장 전광훈, 당장 출교·제명하라"</strong>,
#  <strong class="cnf_news_title">[속보] 공수처, 대통령실·관저 압수수색… 비화폰 확보할까</strong>,
#  <strong class="cnf_news_title">[단독]국방부, 경호처 국방장관 공관 ‘무단사용’ 알고도 뒤늦게 철수시켜</strong>,
#  <strong class="cnf_news_title">알프스에서 '용아장성'을 만나다 [인스브루크 트레킹]</strong>,
#  <strong class="cnf_news_title">[속보] ‘서부지법 난동’ 56명 구속영장 발부…“도주 우려”</strong>,
#  <strong class="cnf_news_title">[속보] 공수처, 대통령실·관저 압수수색…비화폰 등 확보 시도</strong>,
#  <strong class="cnf_news_title">[단독] 4년 만에 늑장 논란…현대차증권, '부실 무역펀드' 배상 나섰다</strong>,
#  <strong class="cnf_news_title">[속보] 공수처, 대통령실ㆍ관저 압수수색…비화폰 등 확보 시도</strong>,
#  <strong class="cnf_news_title">공수처, 강제구인·방문조사 추가 시도…대통령실·관저 압수수색</strong>,
#  <strong class="cnf_news_title">버스 중앙차로서 역방향으로 걷던 70대, 광역버스에 치여 숨져… 운전자 입건</strong>,
#  <strong class="cnf_news_title">'억' 소리 나는 연봉 받는다…몸값 치솟는 IT 인재 누구</strong>,
#  <strong class="cnf_news_title">'서부지법 집단난동' 시위대 58명 중 56명 구속…"도주우려"</strong>,
#  <strong class="cnf_news_title">[2024년 귀속 연말정산] ⑫끝 없는 배움의 삶.. 연말정산으로 교육비 부담 덜기</strong>,
#  <strong class="cnf_news_title">[속보]공수처, 대통령실·관저 압수수색中</strong>,
#  <strong class="cnf_news_title">홍준표 "대선 후보 자격으로 초청⋯벌벌 떨면서 군중 집회 참석할 필요 있나"</strong>,
#  <strong class="cnf_news_title">홍진경, ‘고소한 김’ 만드는 비결 공개… ‘이것’ 활용하면 된다는데?</strong>,
#  <strong class="cnf_news_title">[어바웃 G] 창업자 장남 홀딩스 지분 매각…경영권 '선긋기' I 녹십자 ①</strong>,
#  <strong class="cnf_news_title">[속보] 이재명 "한미동맹 노력"…나경원 "미군은 '점령군'이라더니"</strong>,
#  <strong class="cnf_news_title">윤석열 대통령 헌재 첫 출석… "국회·언론이 '초 갑'"</strong>,
#  <strong class="cnf_news_title">'제명 위기' 윤상현 "대한민국 지키는 게 죄라면 제명하라"</strong>,
#  <strong class="cnf_news_title">트럼프, 취임 첫날 의회 폭도 사면·기후협정 탈퇴 결정…뒤로 가는 미국[트럼프 2기 개막]</strong>,
#  <strong class="cnf_news_title">“미워도 다시 한번”…고액자산가, 코스피와 삼성전자 담았다 [2025 부자 투자 노트①]</strong>,
#  <strong class="cnf_news_title">"HPC도 우리꺼"…차세대 메모리 '출격 준비' 마친 SK하이닉스 [소부장반차장]</strong>,
#  <strong class="cnf_news_title">BYD 국내 첫 진출에 긴장하는 자동차업계</strong>,
#  <strong class="cnf_news_title">굳이 마이크 앞에 선 공수처장…"대통령과 숨바꼭질 유감"</strong>,
#  <strong class="cnf_news_title">힘받는 비트코인, 10만6000달러 육박… 가상자산TF 출범 영향</strong>,
#  <strong class="cnf_news_title">[단독] “방검복 샀습니다”...신변위협 문자 쇄도에, 민주당 의원들 전우조까지 돌린다는데</strong>,
#  <strong class="cnf_news_title">감염병 급증 왜?...질병청장 "코로나19로 억제됐다가 폭발"</strong>,
#  <strong class="cnf_news_title">[속보] 이재명 "한미동맹 노력"…나경원 "미국을 `점령군`이라더니, 결의안에 尹성과 베껴"</strong>,
#  <strong class="cnf_news_title">[단독]공수처, 대통령실 ‘尹 비화폰 서버 확보’ 압수수색 시도</strong>,
#  <strong class="cnf_news_title">최상목 권한대행 3개 법안에 또 거부권</strong>,
#  <strong class="cnf_news_title">공수처, 서울구치소 도착…尹 강제구인·현장조사 시도</strong>,
#  <strong class="cnf_news_title">Trump's 'nuclear power' comments cloud U.S. stance on North Korea's status</strong>,
#  <strong class="cnf_news_title">수도권 지하철 요금 150원 인상...시점은 3월 유력</strong>,
#  <strong class="cnf_news_title">[윤석열의 해석 개헌] 7. 윤석열은 헌법을 살해하려 한다</strong>,
#  <strong class="cnf_news_title">차량 훔쳐 운전한 중학생 2명 불구속 입건</strong>,
#  <strong class="cnf_news_title">[속보]공수처, 대통령실·관저 압수수색…윤석열 ‘비화폰’ 서버 확보 시도</strong>,
#  <strong class="cnf_news_title">[속보] 공수처, 尹 3번째 강제구인.. 서울구치소에 조사실 마련</strong>,
#  <strong class="cnf_news_title">[속보] 공수처, '구치소 수감' 윤석열 대통령 조사 3차 시도</strong>,
#  <strong class="cnf_news_title">김상욱 “내란수괴 최소 무기징역…尹 앞뒤 안 맞는 거짓말”</strong>,
#  <strong class="cnf_news_title">미국, 중국 견제 때문에라도 韓日에 무리한 요구 어렵다</strong>,
#  <strong class="cnf_news_title">이 많은 내란범들을 보라 [쿠데타의 재구성]</strong>,
#  <strong class="cnf_news_title">코스피, 추가 상승폭 확대 '타진'…기관, '낌새' 챘나</strong>,
#  <strong class="cnf_news_title">[단독] 민주, 文정부 장관 가세한 특위 줄가동…‘조기 대선 모드’</strong>,
#  <strong class="cnf_news_title">"2000만원 내릴게요" 다급해진 집주인들?…마용성도 호가 낮춘다</strong>,
#  <strong class="cnf_news_title">"이러다 진짜 문 닫겠어요" 임시공휴일에 우는 소상공인</strong>,
#  <strong class="cnf_news_title">[단독] 공수처, 대통령실·관저 압수수색…비화폰·회의록 확보 시도</strong>,
#  <strong class="cnf_news_title">‘받아쓰기 언론’ 기계적 균형, 민주주의 훼손한다</strong>,
#  <strong class="cnf_news_title">김병환 "가계부채 관리하되 지방은행엔 여유 줄것…대출금리는 내려야"</strong>,
#  <strong class="cnf_news_title">'서부지법 난동' 시위대 무더기 구속… 56명 구속·2명 기각</strong>,
#  <strong class="cnf_news_title">'서부지법 난동' 58명 중 56명 구속…"도주 우려"</strong>,
#  <strong class="cnf_news_title">공수처, 대통령실·관저 압수수색 영장 집행 중</strong>,
#  <strong class="cnf_news_title">삼성 ‘갤럭시 S25’ 공개 D-2...국내 가격 동결할 듯</strong>,
#  <strong class="cnf_news_title">공수처, 대통령실·관저 압수수색 시도…구치소에선 조사 재시도</strong>,
#  <strong class="cnf_news_title">[속보]공수처장 "법 테두리 내 불복 절차 따르면 돼"…오늘 尹 3차 강제구인 시도</strong>,
#  <strong class="cnf_news_title">무안공항 '로컬라이저 개량' 당시 공항공사 사장 숨진 채 발견</strong>,
#  <strong class="cnf_news_title">“과일 싸고 맛 좋은데”…불황 속 설 선물 구색맞추기 분주</strong>,
#  <strong class="cnf_news_title">뇌혈관 장벽 재현한 3D 모델…알츠하이머 연구 진전 기대</strong>,
#  <strong class="cnf_news_title">누락되는 전쟁범죄, 강간 피해와 에코사이드</strong>,
#  <strong class="cnf_news_title">공허했던 尹의 변명… 동아일보 "거짓과 모르쇠" 조선일보 "무책임"</strong>,
#  <strong class="cnf_news_title">베일 벗은 한국식 밸류업 정책, '일본처럼' 효과 낼까 [마켓톡톡]</strong>,
#  <strong class="cnf_news_title">[단독] 김건희 母 최은순, 사위 '尹 체포' 이튿날 스크린골프</strong>,
#  <strong class="cnf_news_title">Yoon denies issuing order to remove lawmakers</strong>,
#  <strong class="cnf_news_title">공수처, 대통령실·관저 압수수색…비화폰 서버 등 확보 시도</strong>,
#  <strong class="cnf_news_title">[속보] 공수처, 대통령실·관저 압수수색‥윤석열 '비화폰' 서버 확보 시도</strong>,
#  <strong class="cnf_news_title">공수처, 대통령실·관저 압수수색 시도 중</strong>,
#  <strong class="cnf_news_title">[속보] 공수처, 대통령실·관저 압수수색…비화폰 확보 시도</strong>,
#  <strong class="cnf_news_title">이준석 "부정선거 1대1 토론하자" vs 황교안 "아예 다 같이 붙자"</strong>,
#  <strong class="cnf_news_title">[속보]공수처, 대통령실·관저 압수수색…비화폰 확보 시도</strong>,
#  <strong class="cnf_news_title">'성난 팔 근육' 이지현, "번쩍 든 게 뭐지?"…짧고 굵게 전신 운동 된다?</strong>,
#  <strong class="cnf_news_title">'내란 혐의' 김용현·조지호 나란히 보석 신청...이유는?</strong>,
#  <strong class="cnf_news_title">[속보]'서부지법 불법사태' 56명 구속…2명 영장 기각</strong>,
#  <strong class="cnf_news_title">'인간 키세스' 짤 주인공이 말하는 "평범한 사람들의 힘"</strong>,
#  <strong class="cnf_news_title">26년 얼굴 없는 선행 '노고록 아저씨'.. 올 설 명절도 깜짝 선물</strong>,
#  <strong class="cnf_news_title">내란 국조특위, 尹대통령 등 7명 동행명령장 발부</strong>,
#  <strong class="cnf_news_title">'서부지법 난동' 58명 중 56명 구속…"도주 우려"</strong>,
#  <strong class="cnf_news_title">애플, 4분기 중국 아이폰 판매량 18.2% ↓… “역대 최대 감소”</strong>,
#  <strong class="cnf_news_title">유승민 "내가 후보 돼야 이재명 이겨" … 조기 대선시 출마 시사</strong>,
#  <strong class="cnf_news_title">"탄핵심판은 계속 출석"...지지층 결집 의도했나</strong>,
#  <strong class="cnf_news_title">경찰, '판사 살인예고' 등 3명 검거…흉악범죄 예고 55건 수사</strong>,
#  <a class="cnf_news _cds_link _editn_link" href="https://n.news.naver.com/article/023/0003884015" onclick="nclk(event, 'home.editnfimg', '', '')">성과급 1450% 준다는데…SK하이닉스 노조 거절, 왜?</a>,
#  <a class="cnf_news _cds_link _editn_link" href="https://n.news.naver.com/article/023/0003883999" onclick="nclk(event, 'home.editnfimg', '', '')">생포된 북한군 “사랑 영화 틀어달라…한국말 나오는 걸로”</a>,
#  <a class="cnf_news _cds_link _editn_link" href="https://n.news.naver.com/article/023/0003883976" onclick="nclk(event, 'home.editnfimg', '', '')">하루 7잔 마시던 커피 끊었더니… 60세 백지연 ‘이것’ 싹 사라졌다</a>,
#  <a class="cnf_news _cds_link _editn_link" href="https://n.news.naver.com/article/031/0000903278" onclick="nclk(event, 'home.editnfimg', '', '')">1월 소비심리 계엄 기저효과 반등⋯"쇼크 회복은 아직"</a>,
#  <a class="cnf_news _cds_link _editn_link" href="https://n.news.naver.com/article
</a>,
#  <a class="cnf_news _cds_link _editn_link" href="https://n.news.naver.com/article/366/0001048926" onclick="nclk(event, 'home.editnfimg', '', '')">“마지막 기회”... 트럼프 취임 날 멕시코서 ‘이민자 캐러밴’ 출발</a>,
#  <a class="cnf_news _cds_link _editn_link" href="https://n.news.naver.com/article/057/0001868139" onclick="nclk(event, 'home.editnfimg', '', '')">[단독] 유튜버 설 선물 논란에 국민의힘 "이재명도 권영세에 명절 선물, 위반 아니냐" 선관위에 서면 질의</a>,
#  <a class="cnf_news _cds_link _editn_link" href="https://n.news.naver.com/article/057/0001868124" onclick="nclk(event, 'home.editnfimg', '', '')">[단독] '이재명 항소심' 증인 줄줄이 신청…국힘 "허송세월" 탄원서 제출</a>,
#  <a class="cnf_news _cds_link _editn_link" href="https://n.news.naver.com/article/057/0001868135" onclick="nclk(event, 'home.editnfimg', '', '')">오세훈 "정상적인 사람이 하는 합리적 국정운영 보고 싶어, 출마 깊은 고민 중"</a>,
#  <a class="cnf_news _cds_link _editn_link" href="https://n.news.naver.com/article/277/0005536858" onclick="nclk(event, 'home.editnfimg', '', '')">포고령·쪽지·부정선거…3가지에 달린 尹 탄핵심판</a>,
#  <a class="cnf_news _cds_link _editn_link" href="https://n.news.naver.com/article/277/0005536582" onclick="nclk(event, 'home.editnfimg', '', '')">"희귀템 1000만원에 삽니다"…추억 되살리려다 월급 다 털린다</a>,
#  <a class="cnf_news _cds_link _editn_link" href="https://n.news.naver.com/article/277/0005536752" onclick="nclk(event, 'home.editnfimg', '', '')">달려온 딸은 눈물 쏟았다…영하 15도, 내복 바람 어르신에 외투 벗어준 행인</a>,
#  <a class="cnf_news _cds_link _editn_link" href="https://n.news.naver.com/article/021/0002685716" onclick="nclk(event, 'home.editnfimg', '', '')">[단독]제적위기 인제대의대생 수십명 ‘블랙리스트’ 때문에 복학 포기</a>,
#  <a class="cnf_news _cds_link _editn_link" href="https://n.news.naver.com/article/021/0002685642" onclick="nclk(event, 'home.editnfimg', '', '')">계엄 당일 전산장애, 35억원 배상하는 업비트·빗썸…‘역대 최다 금액’</a>,
#  <a class="cnf_news _cds_link _editn_link" href="https://n.news.naver.com/article/021/0002685637" onclick="nclk(event, 'home.editnfimg', '', '')">“다리 영구장애 될수도, 매일 전기고문 당하는듯” 법정서 울먹인 명태균</a>,
#  <a class="cnf_news _cds_link _editn_link" href="https://n.news.naver.com/article/296/0000086038" onclick="nclk(event, 'home.editnfimg', '', '')">“도토리? 외계인?"...유명 ‘이 수술’ 받고 머리통 부풀어, 무슨 일?</a>,
#  <a class="cnf_news _cds_link _editn_link" href="https://n.news.naver.com/article/296/0000086035" onclick="nclk(event, 'home.editnfimg', '', '')">"2년간 85kg 뺐다"...단음료 대신 '이것', 습관만 확 바꿨다 어떻게?</a>,
#  <a class="cnf_news _cds_link _editn_link" href="https://n.news.naver.com/article/296/0000086034" onclick="nclk(event, 'home.editnfimg', '', '')">30시간 동안 발기된 男...병원 실수로 영원히 '못 서게' 돼, 무슨 일?</a>,
#  <a class="cnf_news _cds_link _editn_link" href="https://n.news.naver.com/article/655/0000023143" onclick="nclk(event, 'home.editnfimg', '', '')">나경원 "민주 '한미동맹 지지 결의안'...尹 격상시킨 성과 베껴"</a>,
#  <a class="cnf_news _cds_link _editn_link" href="https://n.news.naver.com/article/655/0000023146" onclick="nclk(event, 'home.editnfimg', '', '')">다가오는 설, 무려 134만 명 해외여행 떠난다</a>,
#  <a class="cnf_news _cds_link _editn_link" href="https://n.news.naver.com/article/655/0000023142" onclick="nclk(event, 'home.editnfimg', '', '')">[속보] 공수처장 "오늘 다시 尹 강제구인 시도 할 것"</a>,
#  <a class="cnf_news _cds_link _editn_link" href="https://n.news.naver.com/article/079/0003984537" onclick="nclk(event, 'home.editnfimg', '', '')">尹 "강제수사 불가능하다"던 선관위, 6년간 181회 압색</a>,
#  <a class="cnf_news _cds_link _editn_link" href="https://n.news.naver.com/article/079/0003984557" onclick="nclk(event, 'home.editnfimg', '', '')">공수처, 사흘 연속 '尹 강제구인' 시도…현장조사 가능성도</a>,
#  <a class="cnf_news _cds_link _editn_link" href="https://n.news.naver.com/article/079/0003984506" onclick="nclk(event, 'home.editnfimg', '', '')">"우크라군, 북한군 시신서 유전정보 수집"</a>,
#  <a class="cnf_news _cds_link _editn_link" href="https://n.news.naver.com/article/047/0002460472" onclick="nclk(event, 'home.editnfimg', '', '')">"헌재재판관 토벌" 조선일보에 실린 섬뜩한 광고</a>,
#  <a class="cnf_news _cds_link _editn_link" href="https://n.news.naver.com/article/047/0002460475" onclick="nclk(event, 'home.editnfimg', '', '')">"승리 위해 뛰겠다" 정의당 배진교·윤소하·추혜선 민주당 입당</a>,
#  <a class="cnf_news _cds_link _editn_link" href="https://n.news.naver.com/article/047/0002460476" onclick="nclk(event, 'home.editnfimg', '', '')">공수처, 서울구치소로... 3차 강제구인 시도 성공할까?</a>,
#  <a class="cnf_news _cds_link _editn_link" href="https://n.news.naver.com/article/661/0000049728" onclick="nclk(event, 'home.editnfimg', '', '')">5분 간격 불법광고물 '자동 경고전화'에 업체 백기</a>,
#  <a class="cnf_news _cds_link _editn_link" href="https://n.news.naver.com/article/661/0000049734" onclick="nclk(event, 'home.editnfimg', '', '')">설 연휴 비상진료체계 가동.. 문 여는 병원·약국 지정</a>,
#  <a class="cnf_news _cds_link _editn_link" href="https://n.news.naver.com/article/661/0000049735" onclick="nclk(event, 'home.editnfimg', '', '')">[제주날씨] 최고 기온 12℃ 평년보다 ↑.. '일교차 10℃  주의'</a>,
#  <a class="cnf_news _cds_link _editn_link" href="https://n.news.naver.com/article/586/0000096004" onclick="nclk(event, 'home.editnfimg', '', '')">개혁신당, 사상 초유 동시 최고위 개최…끝장 대결 불가피</a>,
#  <a class="cnf_news _cds_link _editn_link" href="https://n.news.naver.com/article/586/0000096003" onclick="nclk(event, 'home.editnfimg', '', '')">오세훈 "조기대선 출마, 깊은 고민 중…답하긴 일러"</a>,
#  <a class="cnf_news _cds_link _editn_link" href="https://n.news.naver.com/article/586/0000096001" onclick="nclk(event, 'home.editnfimg', '', '')">검찰, 한덕수 국무총리 피의자 소환 조사</a>,
#  <a class="cnf_news _cds_link _editn_link" href="https://n.news.naver.com/article/011/0004442859" onclick="nclk(event, 'home.editnfimg', '', '')">공수처, '비화폰 확보' 대통령실·관저 압수수색 시도</a>,
#  <a class="cnf_news _cds_link _editn_link" href="https://n.news.naver.com/article/011/0004442754" onclick="nclk(event, 'home.editnfimg', '', '')">"성과급 1450% 준다는데 노조는 거절 왜?"…SK하이닉스 노조 "실적에 비해 낮아"</a>,
#  <a class="cnf_news _cds_link _editn_link" href="https://n.news.naver.com/article/011/0004442813" onclick="nclk(event, 'home.editnfimg', '', '')">"진짜 5000원이라고요?"…없어서 못 사는 다이소 '이 제품' 뭐길래</a>,
#  <a class="cnf_news _cds_link _editn_link" href="https://n.news.naver.com/article/030/0003278309" onclick="nclk(event, 'home.editnfimg', '', '')">트럼프, 머스크 틱톡 인수설에… “그가 원한다면 그럴 것”</a>,
#  <a class="cnf_news _cds_link _editn_link" href="https://n.news.naver.com/article/030/0003278128" onclick="nclk(event, 'home.editnfimg', '', '')">정력에 좋은 굴, “이렇게 먹으면 노로바이러스 걱정없어요” [숏폼]</a>,
#  <a class="cnf_news _cds_link _editn_link" href="https://n.news.naver.com/article/030/0003277977" onclick="nclk(event, 'home.editnfimg', '', '')">내란 특검법, 국무회의 상정 유보…민주당 “원내 6당 동의하고 與만 반대”</a>,
#  <a class="cnf_news _cds_link _editn_link" href="https://n.news.naver.com/article/658/0000095154" onclick="nclk(event, 'home.editnfimg', '', '')">마약 '위장수사' 제도화…'던지기' 수법 적발 위한 영상분석에 AI 활용</a>,
#  <a class="cnf_news _cds_link _editn_link" href="https://n.news.naver.com/article/658/0000095148" onclick="nclk(event, 'home.editnfimg', '', '')">무안공항 '로컬라이저 개량' 당시 공항공사 사장 숨진 채 발견</a>,
#  <a class="cnf_news _cds_link _editn_link" href="https://n.news.naver.com/article/658/0000095140" onclick="nclk(event, 'home.editnfimg', '', '')">'尹탄핵심판' 내일부터 본격 증인신문…김용현 등 8명 예정</a>,
#  <a class="cnf_news _cds_link _editn_link" href="https://n.news.naver.com/article/052/0002144173" onclick="nclk(event, 'home.editnfimg', '', '')">공수처, 강제구인·현장조사 시도...구치소 내 조사실 마련</a>,
#  <a class="cnf_news _cds_link _editn_link" href="https://n.news.naver.com/article/052/0002144179" onclick="nclk(event, 'home.editnfimg', '', '')">'서부지법 폭동' 56명 구속..."도주 우려"</a>,
#  <a class="cnf_news _cds_link _editn_link" href="https://n.news.naver.com/article/052/0002144127" onclick="nclk(event, 'home.editnfimg', '', '')">최상목 "헌재 등 경찰기동대 24시간 배치·주요 법관 신변 보호"</a>,
#  <a class="cnf_news _cds_link _editn_link" href="https://n.news.naver.com/article/654/0000102842" onclick="nclk(event, 'home.editnfimg', '', '')">심야 강릉 도심서 난폭 운전한 10대 폭주족 10명 검거</a>,
#  <a class="cnf_news _cds_link _editn_link" href="https://n.news.naver.com/article/654/0000102832" onclick="nclk(event, 'home.editnfimg', '', '')">인스타그램 '10대 계정' 오늘부터 국내 적용…계정 비공개 전환</a>,
#  <a class="cnf_news _cds_link _editn_link" href="https://n.news.naver.com/article/654/0000102827" onclick="nclk(event, 'home.editnfimg', '', '')">비트코인, 다시 사상 최고가 근접…10만7000달러선</a>]

# %%
for title in news_titles:
    print(title.text)
# “과일 싸고 맛 좋은데”…불황 속 설 선물 구색맞추기 분주
# 틀기만 하면 나오더니...OO·OO 광고 ‘TV 점령’
# 김치 수입량 역대 최고치…가공공장 고사 직전
# 스키·스노우보드 등 겨울스포츠 부상없이 즐기려면?
# 뇌혈관 장벽 재현한 3D 모델…알츠하이머 연구 진전 기대
# "스페이스X 스타십 폭발 큰 충격 아냐…실패 수용하도록 패러다임 바뀌어"
# 건강 모니터링, 약물 전달을 한 번에…'만능 스마트 패치' 개발
# 암세포 증식 82%까지 줄이는 소형 유전자 가위
# 누락되는 전쟁범죄, 강간 피해와 에코사이드
# 작가의 ‘시간’, 구석진 ‘공간’, 노동자의 ‘얼굴’
# ‘안부만 나눠도 힘이 돼’ HIV/AIDS 감염인의 서로돌봄
# ‘한국 시민사회와 연결되고 싶어’ 찾아온 일본 청년여성들
# 공허했던 尹의 변명… 동아일보 "거짓과 모르쇠" 조선일보 "무책임"
# 국회·선관위 침탈영상 공개…헌재 나온 尹, '부정선거' 물러섰다
# 민주당 박선원 의원이 매일 방검복을 입는 이유
# 권영세 유튜버 설 선물에 국힘 내부도 우려 "극단으로 가는 것"
# 베일 벗은 한국식 밸류업 정책, '일본처럼' 효과 낼까 [마켓톡톡]
# 비트코인 언급 없이 '밈코인'만 덜렁, 트럼프의 알 수 없는 속내
# 관세, IRA 폐지... 트럼프 결국 '칼 같은 청구서' 내밀다 [視리즈]
# 신용등급 강등 과정에 들어섰나 : 한국경제 폭력의 도미노
# [단독] 김건희 母 최은순, 사위 '尹 체포' 이튿날 스크린골프
# [단독] 경찰, 서부지법 월담 21명 석방…"주동자만 구속 수사"
# 오동운 "尹, 오늘 강제구인 재시도…조사 회피 의도 있어"
# 환수위, 노소영·노재헌 국세청 고발…"노태우 불법 비자금 상속자들"
# Yoon denies issuing order to remove lawmakers
# Man sentenced for vigilante actions against foreign nationals
# Samsung, SK hynix on edge over ailing Chinese fabs
# Stock market reform plan aims to tighten delisting rules
# 공수처, 대통령실·관저 압수수색…비화폰 서버 등 확보 시도
# 쿠팡, 토해 낼 과징금만 1400억… 공정위 전체 과징금 중 4분의 1
# 징역 22년, 징역 18년 선고받고 복역 중이던 미 의회 폭력사태 주범 두 사람도 석방
# "2030男 결집, 민심 엎었다"...'尹 지지' 청년들은 어디서 왔나
# [속보] 공수처, 대통령실·관저 압수수색‥윤석열 '비화폰' 서버 확보 시도
# "대통령 측, 사법부 존중하라"‥공수처장, 출근길에 '직격탄' [현장영상]
# 윤상현 "대한민국 지키겠다는 것이 죄라면 제명하라"
# '尹 지지' 2030 일어섰다?‥'특정 교회 신자 많아'
# 공수처, 대통령실·관저 압수수색 시도 중
# ‘서부지법 난동’ 관련 58명 중 56명 구속… “도주 우려”
# 최상목 권한대행 “헌법재판관 등 주요 법관에 경호 수준 신변보호… 법치 훼손 안돼”
# “마지막 기회”... 트럼프 취임 날 멕시코서 ‘이민자 캐러밴’ 출발
# [속보] 공수처, 대통령실·관저 압수수색…비화폰 확보 시도
# 애플, 4분기 중국 아이폰 판매량 18.2% ↓… “역대 최대 감소”
# 트럼프, 머스크 틱톡 인수설에… “그가 원한다면 그럴 것”
# 정력에 좋은 굴, “이렇게 먹으면 노로바이러스 걱정없어요” [숏폼]
# 내란 특검법, 국무회의 상정 유보…민주당 “원내 6당 동의하고 與만 반대”
# 유승민 "내가 후보 돼야 이재명 이겨" … 조기 대선시 출마 시사
# 마약 '위장수사' 제도화…'던지기' 수법 적발 위한 영상분석에 AI 활용
# 무안공항 '로컬라이저 개량' 당시 공항공사 사장 숨진 채 발견
# '尹탄핵심판' 내일부터 본격 증인신문…김용현 등 8명 예정
# "탄핵심판은 계속 출석"...지지층 결집 의도했나
# 공수처, 강제구인·현장조사 시도...구치소 내 조사실 마련
# '서부지법 폭동' 56명 구속..."도주 우려"
# 최상목 "헌재 등 경찰기동대 24시간 배치·주요 법관 신변 보호"
# 경찰, '판사 살인예고' 등 3명 검거…흉악범죄 예고 55건 수사
# 심야 강릉 도심서 난폭 운전한 10대 폭주족 10명 검거
# 인스타그램 '10대 계정' 오늘부터 국내 적용…계정 비공개 전환
# 비트코인, 다시 사상 최고가 근접…10만7000달러선

# %% [markdown]
# ### 네이버 뉴스섹션메뉴와 섹션별 url 추출

# %%
from urllib.request import urlopen
import bs4
import pandas as pd

# %%
url = 'https://news.naver.com'

html = urlopen(url)

bs_obj = bs4.BeautifulSoup(html, 'html.parser')

# %%
# 네이버 뉴스 섹션메뉴 태그 확인(개발자도구)
# body > section > header > div.Nlnb._float_lnb > div > div > div.Nlnb_left._lnb_scroll > div > div > ul
# selector가 너무 길어서 유용하지 않아 보임
# 직접 확인한 태그와 클래스 속성 사용
# ul 태그의 class : Nlnb_menu_list
uls = bs_obj.findAll("ul",{"class":"Nlnb_menu_list"})
len(uls) # 원소가 1개이므로
ul = bs_obj.find("ul",{"class":"Nlnb_menu_list"})
ul
# Out:
# <ul class="Nlnb_menu_list" role="menu">
# <li class="Nlist_item is_active"><a aria-selected="true" class="Nitem_link" href="https://news.naver.com/?viewType=pc" onclick="nclk(event,'lnb.pcmedia','','');" role="menuitem"><span class="Nitem_link_menu">언론사별</span></a></li>
# <li class="Nlist_item"><a aria-selected="false" class="Nitem_link" href="https://news.naver.com/section/100" onclick="nclk(event,'lnb.pol','','');" role="menuitem"><span class="Nitem_link_menu">정치</span></a></li>
# <li class="Nlist_item"><a aria-selected="false" class="Nitem_link" href="https://news.naver.com/section/101" onclick="nclk(event,'lnb.eco','','');" role="menuitem"><span class="Nitem_link_menu">경제</span></a></li>
# <li class="Nlist_item"><a aria-selected="false" class="Nitem_link" href="https://news.naver.com/section/102" onclick="nclk(event,'lnb.soc','','');" role="menuitem"><span class="Nitem_link_menu">사회</span></a></li>
# <li class="Nlist_item"><a aria-selected="false" class="Nitem_link" href="https://news.naver.com/section/103" onclick="nclk(event,'lnb.lif','','');" role="menuitem"><span class="Nitem_link_menu">생활/문화</span></a></li>
# <li class="Nlist_item"><a aria-selected="false" class="Nitem_link" href="https://news.naver.com/section/105" onclick="nclk(event,'lnb.sci','','');" role="menuitem"><span class="Nitem_link_menu">IT/과학</span></a></li>
# <li class="Nlist_item"><a aria-selected="false" class="Nitem_link" href="https://news.naver.com/section/104" onclick="nclk(event,'lnb.wor','','');" role="menuitem"><span class="Nitem_link_menu">세계</span></a></li>
# <li class="Nlist_item _isNew"><a aria-selected="false" class="Nitem_link" href="https://news.naver.com/main/ranking/popularDay.naver" onclick="nclk(event,'lnb.rank','','');" role="menuitem"><span class="Nitem_link_menu">랭킹</span></a></li>
# <li class="Nlist_item _isNew"><a aria-selected="false" class="Nitem_link" href="https://news.naver.com/newspaper/home?viewType=pc" onclick="nclk(event,'lnb.paper','','');" role="menuitem"><span class="Nitem_link_menu">신문보기</span></a></li>
# <li class="Nlist_item"><a aria-selected="false" class="Nitem_link" href="https://news.naver.com/opinion/home" onclick="nclk(event,'lnb.opi','','');" role="menuitem"><span class="Nitem_link_menu">오피니언</span></a></li>
# <li class="Nlist_item"><a aria-selected="false" class="Nitem_link" href="https://news.naver.com/main/tv/index.naver?mid=tvh" onclick="nclk(event,'lnb.tv','','');" role="menuitem"><span class="Nitem_link_menu">TV</span></a></li>
# <li class="Nlist_item"><a aria-selected="false" class="Nitem_link" href="https://news.naver.com/factcheck/main" onclick="nclk(event,'lnb.fact','','');" role="menuitem"><span class="Nitem_link_menu">팩트체크</span></a></li>
# <li class="Nlist_item"><a aria-selected="false" class="Nitem_link" href="https://media.naver.com/algorithm" onclick="nclk(event,'lnb.algo','','');" role="menuitem"><span class="Nitem_link_menu">알고리즘 안내</span></a></li>
# <li class="Nlist_item _isNew"><a aria-selected="false" class="Nitem_link" href="https://news.naver.com/main/ombudsman/errorArticleList.naver?mid=omb" onclick="nclk(event,'lnb.correct','','');" role="menuitem"><span class="Nitem_link_menu">정정보도 모음</span></a></li>
# </ul>

# %%
lis = ul.findAll('li')
len(lis)
# Out:
# 14

# %%
for li in lis :
    a_tag = li.find('a')
    print(a_tag.text," : ",a_tag['href'])
# Out:
# 언론사별  :  https://news.naver.com/?viewType=pc
# 정치  :  https://news.naver.com/section/100
# 경제  :  https://news.naver.com/section/101
# 사회  :  https://news.naver.com/section/102
# 생활/문화  :  https://news.naver.com/section/103
# IT/과학  :  https://news.naver.com/section/105
# 세계  :  https://news.naver.com/section/104
# 랭킹  :  https://news.naver.com/main/ranking/popularDay.naver
# 신문보기  :  https://news.naver.com/newspaper/home?viewType=pc
# 오피니언  :  https://news.naver.com/opinion/home
# TV  :  https://news.naver.com/main/tv/index.naver?mid=tvh
# 팩트체크  :  https://news.naver.com/factcheck/main
# 알고리즘 안내  :  https://media.naver.com/algorithm
# 정정보도 모음  :  https://news.naver.com/main/ombudsman/errorArticleList.naver?mid=omb

# %%
# li태그를 이용해서 추출
lis = bs_obj.findAll("li",{"class" : "Nlist_item"})
len(lis)
# Out:
# 14

# %%
for li in lis :
    a_tag = li.find('a')
    print(a_tag.text)
    print(a_tag['href'])
# Out:
# 언론사별
# https://news.naver.com/?viewType=pc
# 정치
# https://news.naver.com/section/100
# 경제
# https://news.naver.com/section/101
# 사회
# https://news.naver.com/section/102
# 생활/문화
# https://news.naver.com/section/103
# IT/과학
# https://news.naver.com/section/105
# 세계
# https://news.naver.com/section/104
# 랭킹
# https://news.naver.com/main/ranking/popularDay.naver
# 신문보기
# https://news.naver.com/newspaper/home?viewType=pc
# 오피니언
# https://news.naver.com/opinion/home
# TV
# https://news.naver.com/main/tv/index.naver?mid=tvh
# 팩트체크
# https://news.naver.com/factcheck/main
# 알고리즘 안내
# https://media.naver.com/algorithm
# 정정보도 모음
# https://news.naver.com/main/ombudsman/errorArticleList.naver?mid=omb

# %%
# 수집 데이터 df로 구성 후 저장
section = []
link = []

# %%
for li in lis :
    a_tag = li.find('a')
    section.append(a_tag.text)
    link.append(a_tag['href'])

# %%
col_dict = {'section':section, "link":link}
news_section_df = pd.DataFrame(col_dict)
news_section_df
# Out:
#     section                                               link
# 0      언론사별                https://news.naver.com/?viewType=pc
# 1        정치                 https://news.naver.com/section/100
# 2        경제                 https://news.naver.com/section/101
# 3        사회                 https://news.naver.com/section/102
# 4     생활/문화                 https://news.naver.com/section/103
# 5     IT/과학                 https://news.naver.com/section/105
# 6        세계                 https://news.naver.com/section/104
# 7        랭킹  https://news.naver.com/main/ranking/popularDay...
# 8      신문보기  https://news.naver.com/newspaper/home?viewType=pc
# 9      오피니언                https://news.naver.com/opinion/home
# 10       TV  https://news.naver.com/main/tv/index.naver?mid...
# 11     팩트체크              https://news.naver.com/factcheck/main
# 12  알고리즘 안내                  https://media.naver.com/algorithm
# 13  정정보도 모음  https://news.naver.com/main/ombudsman/errorArt...

# %%
# news_section_df.to_csv('./navew_news_section.csv', encoding='euc-kr')
news_section_df.to_csv('c:\\Myexam\\navew_news_section.csv', encoding='euc-kr')
