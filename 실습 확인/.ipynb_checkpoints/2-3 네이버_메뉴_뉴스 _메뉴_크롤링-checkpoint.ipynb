# %%
### 포털사이트 크롤링
- 소스내에서 특정 문자열(data)을 지칭하는 선택자 얻기
    - 크롬 개발자도구 사용
- 전체 코드에서 수집하려고 하는 데이터(태그)의 위치를 찾고
    - 태그를 파싱한 후 필요데이터 추출

# %%
from urllib.request import urlopen # 서버 요청/응답 패키지
import bs4 # 파싱패키지

# %%
# 네이버 사이트의 기본 메뉴 문구 추출
url = 'https://www.naver.com'

# url로 요청후 응답
html = urlopen(url)

# 파서객체 생성 - bs4 객체로 변환
bs_obj = bs4.BeautifulSoup(html, 'html.parser')

# %%
bs_obj
# Out:
#  <!DOCTYPE html>
#  <html class="fzoom" lang="ko"> <head> <meta charset="utf-8"/> <meta content="origin" name="Referrer"/> <meta content="IE=edge" http-equiv="X-UA-Compatible"/> <meta content="width=1190" name="viewport"/> <title>NAVER</title> <meta content="NAVER" name="apple-mobile-web-app-title"> <meta content="index,nofollow" name="robots"> <meta content="네이버 메인에서 다양한 정보와 유용한 컨텐츠를 만나 보세요" name="description"> <meta content="네이버" property="og:title"/> <meta content="https://www.naver.com/" property="og:url"/> <meta content="https://s.pstatic.net/static/www/mobile/edit/2016/0705/mobile_212852414260.png" property="og:image"/> <meta content="네이버 메인에서 다양한 정보와 유용한 컨텐츠를 만나 보세요" property="og:description"> <meta content="summary" name="twitter:card"/> <meta content="" name="twitter:title"/> <meta content="https://www.naver.com/" name="twitter:url"/> <meta content="https://s.pstatic.net/static/www/mobile/edit/2016/0705/mobile_212852414260.png" name="twitter:image"/> <meta content="네이버 메인에서 다양한 정보와 유용한 컨텐츠를 만나 보세요" name="twitter:description"> <link href="/favicon.ico?1" rel="shortcut icon" type="image/x-icon"/> <link href="https://s.pstatic.net/static/www/nFavicon96.png" rel="apple-touch-icon-precomposed"> <link href="https://s.pstatic.net/static/www/u/2014/0328/mma_204243574.png" rel="apple-touch-icon" sizes="114x114"/> <link href="https://s.pstatic.net/static/www/u/2014/0328/mma_20432863.png" rel="apple-touch-icon"/> <link href="https://ssl.pstatic.net/sstatic/search/pc/css/sp_autocomplete_231130.css" rel="stylesheet"/> <script>window.gladsdk=window.gladsdk||{},window.gladsdk.cmd=window.gladsdk.cmd||[],window.ndpsdk=window.ndpsdk||{},window.ndpsdk.cmd=window.ndpsdk.cmd||[],window.ndpsdk.polyfill=window.ndpsdk.polyfill||{cmd:[]};var g_ssc="navertop.v5";window.nsc=g_ssc,window.nmain=window.nmain||{},window.nmain.jsOrigin="www"</script> <script async="" src="https://ssl.pstatic.net/tveta/libs/ndpsdk/prod/ndp-loader.js"></script> <script async="" src="https://ssl.pstatic.net/tveta/libs/glad/prod/gfp-core.js"></script> <script defer="defer" src="https://ssl.pstatic.net/tveta/libs/assets/js/pc/main/min/pc.veta.core.min.js"></script> <script>
# window["EAGER-DATA"] = window["EAGER-DATA"] || {};
# window["EAGER-DATA"]["PC-FEED-WRAPPER"] = {"@type":"BLOCK","blocks":[{"@type":"BLOCK","blocks":[{"@type":"PC-FEED-BLOCK","materials":[{"@type":"MATERIAL-PC-FEED","title":"화산귀환","url":"https://comic.naver.com/webtoon/list?titleId=769209","image":{"url":"https://s.pstatic.net/dthumb.phinf/?src=%22https%3A%2F%2Fshared-comic.pstatic.net%2Fthumb%2Fwebtoon%2F769209%2Fthumbnail%2Fthumbnail_IMAG21_3511dcdd-6e33-4171-8839-598d6d266215.jpg%22&type=nf216_280&service=navermain"},"desc":"LICO / 비가","webtoonIcon":{"newest":false,"adult":false,"up":true,"dailyPass":false,"seriesEdition":false},"showLiveBadge":false,"_id":"654ad80598c6dbca70ba6c64"},{"@type":"MATERIAL-PC-FEED","title":"전지적 독자 시점","url":"https://comic.naver.com/webtoon/list?titleId=747269","image":{"url":"https://s.pstatic.net/dthumb.phinf/?src=%22https%3A%2F%2Fshared-comic.pstatic.net%2Fthumb%2Fwebtoon%2F747269%2Fthumbnail%2Fthumbnail_IMAG21_aabd9952-ff45-47a2-a543-33f19a5c6708.jpg%22&type=nf216_280&service=navermain"},"desc":"UMI / 슬리피-C / 싱숑","webtoonIcon":{"newest":false,"adult":false,"up":true,"dailyPass":false,"seriesEdition":false},"showLiveBadge":false,"_id":"654ad80598c6dbca70ba6c65"},{"@type":"MATERIAL-PC-FEED","title":"마음의소리(였던 것)","url":"https://comic.naver.com/webtoon/list?titleId=821793","image":{"url":"https://s.pstatic.net/dthumb.phinf/?src=%22https%3A%2F%2Fshared-comic.pstatic.net%2Fthumb%2Fwebtoon%2F821793%2Fthumbnail%2Fthumbnail_IMAG21_c5c798a7-dadf-487b-9bea-485928755332.jpg%22&type=nf216_280&service=navermain"},"desc":"조석","webtoonIcon":{"newest":false,"adult":false,"up":true,"dailyPass":false,"seriesEdition":false},"showLiveBadge":false,"_id":"654ad80598c6dbca70ba6c66"},{"@type":"MATERIAL-PC-FEED","title":"무직백수 계백순","url":"https://comic.naver.com/webtoon/list?titleId=811721","image":{"url":"https://s.pstatic.net/dthumb.phinf/?src=%22https%3A%2F%2Fshared-comic.pstatic.net%2Fthumb%2Fwebtoon%2F811721%2Fthumbnail%2Fthumbnail_IMAG21_9a2a959a-666b-4156-8e4f-db64dfe319c6.jpg%22&type=nf216_280&service=navermain"},"desc":"지발","webtoonIcon":{"newest":false,"adult":false,"up":true,"dailyPass":false,"seriesEdition":false},"showLiveBadge":false,"_id":"654ad80598c6dbca70ba6c67"},{"@type":"MATERIAL-PC-FEED","title":"백XX","url":"https://comic.naver.com/webtoon/list?titleId=804862","image":{"url":"https://s.pstatic.net/dthumb.phinf/?src=%22https%3A%2F%2Fshared-comic.pstatic.net%2Fthumb%2Fwebtoon%2F804862%2Fthumbnail%2Fthumbnail_IMAG21_f1b2f920-5c10-4155-a547-0c25a7132d8f.jpeg%22&type=nf216_280&service=navermain"},"desc":"박만사, 병장 / 펀치킥","webtoonIcon":{"newest":false,"adult":false,"up":true,"dailyPass":false,"seriesEdition":false},"showLiveBadge":false,"_id":"654ad80598c6dbca70ba6c68"},{"@type":"MATERIAL-PC-FEED","title":"조조코믹스","url":"https://comic.naver.com/webtoon/list?titleId=774862","image":{"url":"https://s.pstatic.net/dthumb.phinf/?src=%22https%3A%2F%2Fshared-comic.pstatic.net%2Fthumb%2Fwebtoon%2F774862%2Fthumbnail%2Fthumbnail_IMAG21_39b7c327-7234-4636-b608-401478abede3.jpg%22&type=nf216_280&service=navermain"},"desc":"이동건","webtoonIcon":{"newest":false,"adult":false,"up":true,"dailyPass":false,"seriesEdition":false},"showLiveBadge":false,"_id":"654ad80598c6dbca70ba6c69"},{"@type":"MATERIAL-PC-FEED","title":"진돌히디만화","url":"https://comic.naver.com/webtoon/list?titleId=822095","image":{"url":"https://s.pstatic.net/dthumb.phinf/?src=%22https%3A%2F%2Fshared-comic.pstatic.net%2Fthumb%2Fwebtoon%2F822095%2Fthumbnail%2Fthumbnail_IMAG21_b43a443d-55bd-4936-a105-200ed7efaef5.jpg%22&type=nf216_280&service=navermain"},"desc":"히디, 진돌 / 진돌","webtoonIcon":{"newest":false,"adult":false,"up":true,"dailyPass":false,"seriesEdition":false},"showLiveBadge":false,"_id":"654ad80598c6dbca70ba
aid":null,"emergency":false,"notCompleted":false,"officeName":"연합뉴스","officeId":"001","officeHomeUrl":null,"officeWeight":0,"officeWeightRate":0.0,"_id":"65692532e9bedeca62543dbb"},{"@type":"MATERIAL-PC-NEWS-ONELINE","gdid":null,"title":"[4·10 총선] \"미래 위해, 자녀 위해 한표\"…일찍부터 유권자 발길","url":"https://news.naver.com/main/list.naver?mode=LPOD&mid=sec&sid1=001&sid2=140&oid=001&isYeonhapFlash=Y&aid=0014622057","aid":null,"emergency":false,"notCompleted":false,"officeName":"연합뉴스","officeId":"001","officeHomeUrl":null,"officeWeight":0,"officeWeightRate":0.0,"_id":"65692532e9bedeca62543dbc"},{"@type":"MATERIAL-PC-NEWS-ONELINE","gdid":null,"title":"[4·10 총선] 모바일신분증 본 선거사무원, 활용 가능한지 꼼꼼히 확인","url":"https://news.naver.com/main/list.naver?mode=LPOD&mid=sec&sid1=001&sid2=140&oid=001&isYeonhapFlash=Y&aid=0014622006","aid":null,"emergency":false,"notCompleted":false,"officeName":"연합뉴스","officeId":"001","officeHomeUrl":null,"officeWeight":0,"officeWeightRate":0.0,"_id":"65692532e9bedeca62543dbd"},{"@type":"MATERIAL-PC-NEWS-ONELINE","gdid":null,"title":"[4·10 총선] 동작갑 투표소에 與 장진영 '8억원 채무 누락' 공고문","url":"https://news.naver.com/main/list.naver?mode=LPOD&mid=sec&sid1=001&sid2=140&oid=001&isYeonhapFlash=Y&aid=0014621965","aid":null,"emergency":false,"notCompleted":false,"officeName":"연합뉴스","officeId":"001","officeHomeUrl":null,"officeWeight":0,"officeWeightRate":0.0,"_id":"65692532e9bedeca62543dbe"},{"@type":"MATERIAL-PC-NEWS-ONELINE","gdid":null,"title":"'전세금 돌려줄게' 속여 점유권 받은 집주인…대법 \"사기 아냐\"","url":"https://news.naver.com/main/list.naver?mode=LPOD&mid=sec&sid1=001&sid2=140&oid=001&isYeonhapFlash=Y&aid=0014621900","aid":null,"emergency":false,"notCompleted":false,"officeName":"연합뉴스","officeId":"001","officeHomeUrl":null,"officeWeight":0,"officeWeightRate":0.0,"_id":"65692532e9bedeca62543dbf"},{"@type":"MATERIAL-PC-NEWS-ONELINE","gdid":null,"title":"공개 감행 vs 무기한 연기…'주연 리스크' 터진 작품들의 선택지","url":"https://news.naver.com/main/list.naver?mode=LPOD&mid=sec&sid1=001&sid2=140&oid=001&isYeonhapFlash=Y&aid=0014621786","aid":null,"emergency":false,"notCompleted":false,"officeName":"연합뉴스","officeId":"001","officeHomeUrl":null,"officeWeight":0,"officeWeightRate":0.0,"_id":"65692532e9bedeca62543dc0"},{"@type":"MATERIAL-PC-NEWS-ONELINE","gdid":null,"title":"\"악성민원 비극 막자\"…공무원 이름 비공개 지자체 확산","url":"https://news.naver.com/main/list.naver?mode=LPOD&mid=sec&sid1=001&sid2=140&oid=001&isYeonhapFlash=Y&aid=0014621766","aid":null,"emergency":false,"notCompleted":false,"officeName":"연합뉴스","officeId":"001","officeHomeUrl":null,"officeWeight":0,"officeWeightRate":0.0,"_id":"6573c24ecaf3d87b7e4d5269"},{"@type":"MATERIAL-PC-NEWS-ONELINE","gdid":null,"title":"알리·테무 저가쇼핑 즐기다가…발암물질에 '화들짝'","url":"https://news.naver.com/main/list.naver?mode=LPOD&mid=sec&sid1=001&sid2=140&oid=001&isYeonhapFlash=Y&aid=0014621703","aid":null,"emergency":false,"notCompleted":false,"officeName":"연합뉴스","officeId":"001","officeHomeUrl":null,"officeWeight":0,"officeWeightRate":0.0,"_id":"660a550699a40d2acc464c48"},{"@type":"MATERIAL-PC-NEWS-ONELINE","gdid":null,"title":"'신의 입자' 존 ...
# window["EAGER-DATA"]["CAS-MINICONTENT-PC-SEARCH-RIGHT"] = {"@type":"MINI-CONTENT-BLOCK","blocks":null,"materials":null,"excludeInPaging":false,"positionForPaging":0,"realtime":false,"items":[],"_id":"6433d8a5a10d300685012682","@type":"MINI-CONTENT-BLOCK","@code":"CAS-MINICONTENT-PC-SEARCH-RIGHT","@template":"NONE","@flowId":"CAS-MINICONTENT","@flowExecutionId":"0cf04e2e-f6db-11ee-9d93-2bd7ee7f124e","@provider":"lambda","@lastModifiedAt":[2024,4,10,1,38,37,73000000]}
# window["EAGER-DATA"]["CAS-MINICONTENT-PC-MEDIA-TAB-EVENT"] = {"@type":"MINI-CONTENT-BLOCK","blocks":null,"materials":null,"excludeInPaging":false,"positionForPaging":0,"realtime":false,"items":[{"content":{"url":"https://news.naver.com/election/nation2024","darkImage":"https://s.pstatic.net/static/www/mobile/edit/20240222_1095/upload_1708585885601gXx80.png","lightImage":"https://s.pstatic.net/static/www/mobile/edit/20240222_1095/upload_1708585880722aZITS.png","altText":"2024 총선","clickCode":"nst.elc2024"},"exposure":true,"@miniContentId":"65d6faabf90934116e0b0de4","@miniContentCode":"PC-MEDIA-TAB-EVENT","@startAt":"2024-03-07 16:00","@endAt":"2024-04-11 23:59","@createdAt":"2024-02-22T16:41:31.32","@updatedAt":"2024-03-07T16:32:55.514"}],"_id":"643687e1a10d300685630556","@type":"MINI-CONTENT-BLOCK","@code":"CAS-MINICONTENT-PC-MEDIA-TAB-EVENT","@template":"NONE","@flowId":"CAS-MINICONTENT","@flowExecutionId":"1417f88e-f6db-11ee-9d93-a1b357a90a04","@provider":"lambda","@lastModifiedAt":[2024,4,10,1,38,49,84000000]}
# window["EAGER-DATA"]["CAS-MINICONTENT-PC-MID-BANNER"] = {"@type":"MINI-CONTENT-BLOCK","blocks":null,"materials":null,"excludeInPaging":false,"positionForPaging":0,"realtime":false,"items":[],"_id":"648ae476a10d300685fbab10","@type":"MINI-CONTENT-BLOCK","@code":"CAS-MINICONTENT-PC-MID-BANNER","@template":"NONE","@flowId":"CAS-MINICONTENT","@flowExecutionId":"095fd53a-f6db-11ee-b0b4-7fbae38f491e","@provider":"lambda","@lastModifiedAt":[2024,4,10,1,38,31,102000000]}
# window["EAGER-DATA"]["CAS-MINICONTENT-PC-TAB-META"] = {"@type":"MINI-CONTENT-BLOCK","blocks":null,"materials":null,"excludeInPaging":false,"positionForPaging":0,"realtime":false,"items":[{"content":{"area":"FEED","tabList":[{"clickCode":"tct.mynr","name":"추천・구독","id":"PC-FEED-RECOMMEND","contingencyEnabled":true,"enabled":true,"useFeedCasEditTemplate":false,"weight":1},{"clickCode":"tct.wtn","name":"자동차","id":"PC-FEED-CARGAME","contingencyEnabled":true,"enabled":true,"useFeedCasEditTemplate":true,"weight":1},{"clickCode":"tct.wtn","name":"웹툰","id":"PC-FEED-WEBTOON","contingencyEnabled":true,"enabled":true,"useFeedCasEditTemplate":true,"weight":1},{"clickCode":"tct.bty","name":"패션뷰티","id":"PC-FEED-BEAUTY","contingencyEnabled":true,"enabled":true,"useFeedCasEditTemplate":false,"weight":1},{"clickCode":"tct.fod","name":"레시피","id":"PC-FEED-RECIPE","contingencyEnabled":true,"enabled":true,"useFeedCasEditTemplate":true,"weight":1},{"clickCode":"tct.lif","name":"리빙","id":"PC-FEED-LIVINGHOME","contingencyEnabled":true,"enabled":true,"useFeedCasEditTemplate":true,"weight":1},{"clickCode":"tct.bok","name":"책방","id":"PC-FEED-CULTURE","contingencyEnabled":true,"enabled":true,"useFeedCasEditTemplate":true,"weight":1},{"clickCode":"tct.lec","name":"지식+","id":"PC-FEED-LECTURE","contingencyEnabled":true,"enabled":true,"useFeedCasEditTemplate":true,"weight":1},{"clickCode":"tct.health","name":"건강","id":"PC-FEED-HEALTH","contingencyEnabled":true,"enabled":true,"useFeedCasEditTemplate":false,"weight":1},{"clickCode":"tct.gameapp","name":"게임","id":"PC-FEED-GAMEAPP","contingencyEnabled":true,"enabled":true,"useFeedCasEditTemplate":false,"weight":1}],"@type":"BLOCK-PC-TAB-META"},"exposure":true,"@miniContentId":"643e64d370a065058f369bac","@miniContentCode":"PC-TAB-META","@startAt":"2023-04-10 00:00","@endAt":"2030-05-30 23:59","@createdAt":"2023-04-18T18:37:23.412","@updatedAt":"2023-11-08T11:34:03.902"},{"content":{"area":"MEDIA","tabList":[{"clickCode":"nst.nsd","name":"뉴스스탠드","id":"PC-MEDIA-NEWSSTAND","contingencyEnabled":true,"enabled":true,"useFeedCasEditTemplate":false,"weight":1},{"clickCode":"nst.nch","name":"언론사편집","id":"PC-MEDIA-NEWS","contingencyEnabled":true,"enabled":true,"useFeedCasEditTemplate":false,"weight":1},{"clickCode":"nst.ent","name":"엔터","id":"PC-MEDIA-ENTER","contingencyEnabled":true,"enabled":true,"useFeedCasEditTemplate":false,"weight":1},{"clickCode":"nst.spo","name":"스포츠","id":"PC-MEDIA-SPORTS","contingencyEnabled":true,"enabled":true,"useFeedCasEditTemplate":false,"weight":1},{"clickCode":"nst.fin","name":"경제","id":"PC-MEDIA-ECONOMIC","contingencyEnabled":true,"enabled":true,"useFeedCasEditTemplate":false,"weight":1}],"@type":"BLOCK-PC-TAB-META"},"exposure":true,"@miniContentId":"643e642c8793487c84743a38","@miniContentCode":"PC-TAB-META","@startAt":"2023-04-11 00:00","@endAt":"2030-05-31 23:59","@createdAt":"2023-04-18T18:34:36.648","@updatedAt":"2023-04-18T18:34:36.648"}],"_id":"643e6299a10d3006853cc04c","@type":"MINI-CONTENT-BLOCK","@code":"CAS-MINICONTENT-PC-TAB-META","@template":"NONE","@flowId":"CAS-MINICONTENT","@flowExecutionId":"167c278b-f6db-11ee-baef-7bbcceaa4723","@provider":"lambda","@lastModifiedAt":[2024,4,10,1,38,53,100000000]}
# </script>
# <script>
# window["ELECTION-DATA"] = window["ELECTION-DATA"] || {};
# window["ELECTION-DATA"] = {"@type":"PC-ELECTION-RESPONSE-BLOCK","blocks":[{"@type":"ELECTION-VOTE-RATE-BLOCK","blocks":null,"materials":null,"excludeInPaging":false,"positionForPaging":0,"realtime":false,"timeCaption":"집계중","voteRate":"11.4","percentTitle":"전국 투표율","widesidoNameShort":null,"app55RateType":"전국 투표율","app55Time":null,"app55Rate":"11.4","_id":null,"@type":"ELECTION-VOTE-RATE-BLOCK","@code":null,"@template":null,"@flowId":null,"@flowExecutionId":null,"@provider":null,"@lastModifiedAt":null},{"@type":"ELECTION-VOTE-RATE-BLOCK","blocks":null,"materials":null,"excludeInPaging":false,"positionForPaging":0,"realtime":false,"timeCaption":"집계중","voteRate":"10.8","percentTitle":"서울 투표율","widesidoNameShort":"서울","app55RateType":null,"app55Time":null,"app55Rate":null,"_id":null,"@type":"ELECTION-VOTE-RATE-BLOCK","@code":null,"@template":null,"@flowId":null,"@flowExecutionId":null,"@provider":null,"@lastModifiedAt":null},{"@type":"ELECTION-VOTE-RATE-BLOCK","blocks":null,"materials":null,"excludeInPaging":false,"positionForPaging":0,"realtime":false,"timeCaption":"집계중","voteRate":"12.5","percentTitle":"부산 투표율","widesidoNameShort":"부산","app55RateType":null,"app55Time":null,"app55Rate":null,"_id":null,"@type":"ELECTION-VOTE-RATE-BLOCK","@code":null,"@template":null,"@flowId":null,"@flowExecutionId":null,"@provider":null,"@lastModifiedAt":null},{"@type":"ELECTION-VOTE-RATE-BLOCK","blocks":null,"materials":null,"excludeInPaging":false,"positionForPaging":0,"realtime":false,"timeCaption":"집계중","voteRate":"12.2","percentTitle":"대구 투표율","widesidoNameShort":"대구","app55RateType":null,"app55Time":null,"app55Rate":null,"_id":null,"@type":"ELECTION-VOTE-RATE-BLOCK","@code":null,"@template":null,"@flowId":null,"@flowExecutionId":null,"@provider":null,"@lastModifiedAt":null},{"@type":
connectionType":"S2S","adProviderType":"IN_NAVER","adProviderName":"NDP_SF","layoutType":"FLUID","creativeType":"BANNER","renderType":"SF","eventTracking":{"ackImpressions":[{"url":"https://siape.veta.naver.com/openrtb/nurl?eu=EU10043565\u0026calp=-\u0026oj=cQgn6aire5OSSR9zJjDNjAl2LrfXYAP5yEeGJklwsfZL%2B4jdMvXGvNWYo%2F2VeS11JL1qM2Pf%2FakR7hD%2Fzt7wKst6sq5tFsok5uj%2BoGrMZWPIBWexIpibH0plqdgUSG%2BUXrQSw%2B%2FX1bbNCF9%2F110BZDp0hCNKO%2BcHo2M9jEOAPSLbaIdXv9YIFqKzdZWOwZvbdMAtSn%2B9Id4vH4MuGzFJiErLLp1Ox71Vg1K%2FFXnNMQA\u0026ac=8947810\u0026src=7024793\u0026evtcd=BID_WIN\u0026x_ti=1505\u0026rk=CZPdhEbXaLvreUc-KiIasA\u0026eltts=NSDuyZLFzec2UOv5jtfVWA%3D%3D\u0026brs=Y\u0026"}],"attached":[],"activeViewImpressions":[],"renderedImpressions":[],"viewableImpressions":[],"clicks":[],"vimp1px":[],"vimp100":[],"vimp100p":[],"admute":[],"advmute":[],"like":[],"unlike":[],"close":[],"bounce":[]},"adInfo":{"placeId":"6436232db28a76002ea3f30c","adomain":["www.brain-study.co.kr"],"cid":"149 ...
# </script> <div id="wrap"> <div id="header" role="banner"> <div class="header_inner" id="topSearchWrap"> <div class="search_special_bg" id="special-logo"></div> <div class="ad_area" id="timeboard-ex" style="min-width:1340px"> </div> <div class="search_area" id="search_area" style="border-color:#fff"> <div class="link_search_special" id="special-input-logo-ex" style="display:none"></div> <div class="search_group"> <div class="search_group_inner" id="search"> <h1 class="search_logo" id="special-input-logo"></h1> <form action="https://search.naver.com/search.naver" id="sform" method="get" name="search" role="search"> <fieldset> <legend class="blind">검색</legend> <input name="where" type="hidden" value="nexearch"/> <input id="sm" name="sm" type="hidden" value="top_hty"/> <input id="fbm" name="fbm" type="hidden" value="0"/> <input disabled="disabled" id="acr" name="acr" type="hidden" value=""/> <input disabled="disabled" id="acq" name="acq" type="hidden" value=""/> <input disabled="disabled" id="qdt" name="qdt" type="hidden" value=""/> <input id="ie" name="ie" type="hidden" value="utf8"/> <input disabled="disabled" id="acir" name="acir" type="hidden" value=""/> <input disabled="disabled" id="os" name="os" type="hidden" value=""/> <input disabled="disabled" id="bid" name="bid" type="hidden" value=""/> <input disabled="disabled" id="pkid" name="pkid" type="hidden" value=""/> <input disabled="disabled" id="eid" name="eid" type="hidden" value=""/> <input disabled="disabled" id="mra" name="mra" type="hidden" value=""/> <div class="search_input_box"> <input autocomplete="off" class="search_input" data-atcmp-element="" id="query" maxlength="255" name="query" placeholder="검색어를 입력해 주세요." title="검색어를 입력해 주세요." type="search"/> </div> <button class="btn_search" onclick='window.nclk_v2(this,"sch.action")' type="submit"> <span class="ico_btn_search_svg"> <svg id="search-btn" viewbox="0 0 50 50" xmlns="http://www.w3.org/2000/svg"> <path d="M22.13.5c11.378 0 20.632 9.256 20.632 20.63 0 4.699-1.566 9.155-4.439 12.782l10.164 10.165a2.41 2.41 0 0 1-1.706 4.115 2.412 2.412 0 0 1-1.706-.705L33.31 35.719a2.41 2.41 0 0 1 0-3.41 15.71 15.71 0 0 0 4.628-11.178c0-8.718-7.09-15.808-15.807-15.808-8.718 0-15.808 7.09-15.808 15.808 0 7.15 4.817 13.43 11.714 15.273a2.41 2.41 0 0 1 1.705 2.954 2.41 2.41 0 0 1-2.95 1.705C7.788 38.658 1.5 30.46 1.5 21.131 1.5 9.756 10.756.5 22.13.5zm4.716 34.746a3.483 3.483 0 1 1 0 6.966 3.483 3.483 0 0 1 0-6.966z"></path> </svg> </span> <span class="blind">검색</span> </button> </fieldset> </form> <div class="search_box"> <button aria-pressed="false" class="btn_keyboard" id="ke_kbd_btn" type="button"> <span class="keybord_text"> <span class="blind">입력도구</span> </span> </button> <div id="_nx_kbd" style="display:none"></div> <button class="btn_arrow" data-atcmp-element="" id="nautocomplete" type="button"> <span class="blind">자동완성/최근검색어펼치기</span> </button> </div> <div class="layer_atcmp" id="autoFrame" style="display:none"> <div class="ly_atcmp" data-atcmp-element=""> <div class="api_atcmp_wrap"> <div class="atcmp_fixer _recent_layer" style="display:none"> <div class="atcmp_header _recent_header"> <strong class="tit">최근 검색어</strong> <div class="option"> <a aria-pressed="false" class="item _delAll" href="#" role="button">전체삭제</a> </div> </div> <div class="atcmp_container"> <ul class="kwd_lst _recent"></ul> <div class="kwd_info kwd_off _offMsg" style="display:none">검색어 저장 기능이 꺼져 있습니다.<br/><span class="kwd_dsc">설정이 초기화 된다면 <a class="kwd_help" data-clk="sly.help" href="https://help.naver.com/alias/search/word/word_35.naver" target="_blank">도움말</a>을 확인해주세요.</span></div> <div class="kwd_info kwd_none _recentNone" style="display:none">최근 검색어 내역이 없습니다.<br/><span class="kwd_dsc">설정이 초기화 된다면 <a class="kwd_help" data-clk="sly.help" href="https://help.naver.com/alias/search/word/word_35.naver" target="_blank">도움말</a>을 확인해주세요.</span></div> </div> <div class="atcmp_footer"> <span class="side_opt_area"> <span class="opt_item"> <a class="close _keywordO ...
#         window['EAGER-DATA']['GV'] = {
#             svt: '20240410104141',  }; </script> <script>!function(){function t(t){var e=document.getElementById("search_area"),n=document.getElementById("search-btn");if(!t)return e&&e.removeAttribute("style"),void(n&&n.setAttribute("style","fill: #03c75a"));e&&e.setAttribute("style","border-color: "+t),n&&n.setAttribute("class","ico_btn_search type_color"),n&&n.setAttribute("style","fill: "+t)}var e=window["EAGER-DATA"]["CAS-MINICONTENT-PC-SPECIAL-LOGO"];if(!e||!e.items||e.items.length>0==!1)return void t();var n=Math.floor(Math.random()*e.items.length),i=e.items[n];e.items=[i],t(i&&i.content&&i.content.input&&i.content.input.color);const l=document.getElementById("search");l&&l.classList.add("type_special_logo_full"),window.addEventListener("header-sticky-state-change",(()=>{var t;(t=document.getElementById("header"))&&t.classList.contains("ani_fixed")?l&&l.classList.remove("type_special_logo_full"):l&&l.classList.add("type_special_logo_full")}));var s=i&&i.content&&i.content.input&&i.content.input.placeholder;if(s){var o=document.getElementById("query");o&&s&&o.setAttribute("title",s),o&&s&&o.setAttribute("placeholder",s)}}()</script> </body> </html>

# %%
test_menu = bs_obj.find('div',{'id':'wrap'})
test_menu
# Out:
# <div id="wrap"> <div id="header" role="banner"> <div class="header_inner" id="topSearchWrap"> <div class="search_special_bg" id="special-logo"></div> <div class="ad_area" id="timeboard-ex" style="min-width:1340px"> </div> <div class="search_area" id="search_area" style="border-color:#fff"> <div class="link_search_special" id="special-input-logo-ex" style="display:none"></div> <div class="search_group"> <div class="search_group_inner" id="search"> <h1 class="search_logo" id="special-input-logo"></h1> <form action="https://search.naver.com/search.naver" id="sform" method="get" name="search" role="search"> <fieldset> <legend class="blind">검색</legend> <input name="where" type="hidden" value="nexearch"/> <input id="sm" name="sm" type="hidden" value="top_hty"/> <input id="fbm" name="fbm" type="hidden" value="0"/> <input disabled="disabled" id="acr" name="acr" type="hidden" value=""/> <input disabled="disabled" id="acq" name="acq" type="hidden" value=""/> <input disabled="disabled" id="qdt" name="qdt" type="hidden" value=""/> <input id="ie" name="ie" type="hidden" value="utf8"/> <input disabled="disabled" id="acir" name="acir" type="hidden" value=""/> <input disabled="disabled" id="os" name="os" type="hidden" value=""/> <input disabled="disabled" id="bid" name="bid" type="hidden" value=""/> <input disabled="disabled" id="pkid" name="pkid" type="hidden" value=""/> <input disabled="disabled" id="eid" name="eid" type="hidden" value=""/> <input disabled="disabled" id="mra" name="mra" type="hidden" value=""/> <div class="search_input_box"> <input autocomplete="off" class="search_input" data-atcmp-element="" id="query" maxlength="255" name="query" placeholder="검색어를 입력해 주세요." title="검색어를 입력해 주세요." type="search"/> </div> <button class="btn_search" onclick='window.nclk_v2(this,"sch.action")' type="submit"> <span class="ico_btn_search_svg"> <svg id="search-btn" viewbox="0 0 50 50" xmlns="http://www.w3.org/2000/svg"> <path d="M22.13.5c11.378 0 20.632 9.256 20.632 20.63 0 4.699-1.566 9.155-4.439 12.782l10.164 10.165a2.41 2.41 0 0 1-1.706 4.115 2.412 2.412 0 0 1-1.706-.705L33.31 35.719a2.41 2.41 0 0 1 0-3.41 15.71 15.71 0 0 0 4.628-11.178c0-8.718-7.09-15.808-15.807-15.808-8.718 0-15.808 7.09-15.808 15.808 0 7.15 4.817 13.43 11.714 15.273a2.41 2.41 0 0 1 1.705 2.954 2.41 2.41 0 0 1-2.95 1.705C7.788 38.658 1.5 30.46 1.5 21.131 1.5 9.756 10.756.5 22.13.5zm4.716 34.746a3.483 3.483 0 1 1 0 6.966 3.483 3.483 0 0 1 0-6.966z"></path> </svg> </span> <span class="blind">검색</span> </button> </fieldset> </form> <div class="search_box"> <button aria-pressed="false" class="btn_keyboard" id="ke_kbd_btn" type="button"> <span class="keybord_text"> <span class="blind">입력도구</span> </span> </button> <div id="_nx_kbd" style="display:none"></div> <button class="btn_arrow" data-atcmp-element="" id="nautocomplete" type="button"> <span class="blind">자동완성/최근검색어펼치기</span> </button> </div> <div class="layer_atcmp" id="autoFrame" style="display:none"> <div class="ly_atcmp" data-atcmp-element=""> <div class="api_atcmp_wrap"> <div class="atcmp_fixer _recent_layer" style="display:none"> <div class="atcmp_header _recent_header"> <strong class="tit">최근 검색어</strong> <div class="option"> <a aria-pressed="false" class="item _delAll" href="#" role="button">전체삭제</a> </div> </div> <div class="atcmp_container"> <ul class="kwd_lst _recent"></ul> <div class="kwd_info kwd_off _offMsg" style="display:none">검색어 저장 기능이 꺼져 있습니다.<br/><span class="kwd_dsc">설정이 초기화 된다면 <a class="kwd_help" data-clk="sly.help" href="https://help.naver.com/alias/search/word/word_35.naver" target="_blank">도움말</a>을 확인해주세요.</span></div> <div class="kwd_info kwd_none _recentNone" style="display:none">최근 검색어 내역이 없습니다.<br/><span class="kwd_dsc">설정이 초기화 된다면 <a class="kwd_help" data-clk="sly.help" href="https://help.naver.com/alias/search/word/word_35.naver" target="_blank">도움말</a>을 확인해주세요.</span></div> </div> <div class="atcmp_footer"> <span class="side_opt_area"> <span class="opt_item"> <a class="close _keywordOnOff" href ...

# %% [markdown]
# ### 수집한 데이터를 csv로 저장
# 1. 항목별로 list에 저장
# 2. 항목들을 dict로 구성
# 3. dict를 데이터프레임으로 생성
# 4. 데이터프레임을 csv로 저장

# %% [markdown]
# ## 네이버 뉴스 크롤링
# #### 네이버 뉴스는 네이버 정책에 따라 모든 언론사들의 뉴스가 랜덤하게 배치됨
# - 단, 로그인 후 구독을 추가하면 구독한 언론사들의 뉴스가 나옴
# - 헤드라인 뉴스는 표면적으로는 제공되지 않는다

# %%
# 네이버 뉴스 크롤링
# url은 기본 url 부터 사용
url = 'https://news.naver.com'
html = urlopen(url)

# %%
# html #<http.client.HTTPResponse at 0x1b6fa0cd0d0>
# html_text = html.read() # 바이너리 문자열로 반환
# # html_text

# %%
# bs4 객체 생성
bs_obj = bs4.BeautifulSoup(html, 'html.parser')

# %%
print(bs_obj.prettify())
# Out:
# <!DOCTYPE html>
# <html lang="ko">
#  <head>
#   <title id="browserTitleArea">
#    네이버 뉴스
#   </title>
#   <script>
#    function isMobileDevice() {
# 		return /^.*(iPhone|iPod|iPad|Android).*/.test(navigator.userAgent);
# 	}
#   </script>
#   <script>
#    (function () {
# 		try {
# 			if (isMobileDevice() && isAbleApplyPrefersColorScheme()) {
#
# 				document.querySelector("html").classList.add("DARK_THEME");
# 			}
# 		} catch(e) {}
#
# 		function isAbleApplyPrefersColorScheme() {
#
# 			if (window.matchMedia("(prefers-color-scheme)").matches === false) {
# 				return false;
# 			}
#
# 			var userAgent = navigator.userAgent;
#
# 			if (userAgent.indexOf("NAVER") > -1) {
#
# 				if (/.*NAVER\([a-zA-Z]*;\s[a-zA-Z]*;\s([0-9]*);/.test(userAgent)) {
# 					return Number(RegExp.$1) >= 1000;
# 				}
# 			} else {
#
# 				return document.cookie.indexOf("NSCS=1") > -1;
# 			}
#
# 			return false;
# 		}
# 	})();
#   </script>
#   <script>
#    var g_ssc = 'news.v3_media' || null;
#   </script>
#   <meta charset="utf-8"/>
#   <meta content="width=device-width,initial-scale=1.0,maximum-scale=1.0,minimum-scale=1.0,user-scalable=no,target-densitydpi=medium-dpi" name="viewport">
#    <link href="https://ssl.pstatic.net/static.news/mnews/resources/20240409_013407/css/generated/newshome.css" rel="stylesheet" type="text/css"/>
#    <link href="https://mimgnews.pstatic.net/image/news/m/2023/favicon/favicon.ico" rel="shortcut icon" type="image/x-icon"/>
#    <script>
#     (function(){
# 		var userAgent = navigator.userAgent;
# 		var result = [];
#
# 		if(userAgent.indexOf('Android') > -1){
# 			result = [
# 				'<link rel="apple-touch-icon-precomposed" sizes="72x72" href="https://ssl.pstatic.net/static.news/image/news/m/2018/favicon/06/android_legacy_hdpi_72X72.png" />',
# 				'<link rel="apple-touch-icon-precomposed" sizes="96x96" href="https://ssl.pstatic.net/static.news/image/news/m/2018/favicon/06/android_legacy_xhdpi_96x96.png" />',
# 				'<link rel="apple-touch-icon-precomposed" sizes="144x144" href="https://ssl.pstatic.net/static.news/image/news/m/2018/favicon/06/android_legacy_xxhpdi_144x144.png" />',
# 				'<link rel="apple-touch-icon-precomposed" sizes="192x192" href="https://ssl.pstatic.net/static.news/image/news/m/2018/favicon/06/android_legacy_xxxhpdi_192x192.png" />'
# 			];
# 		}else if(userAgent.indexOf('iPhone') > -1){
# 			result = [
# 				'<link rel="apple-touch-icon-precomposed" sizes="120X120" href="https://ssl.pstatic.net/static.news/image/news/m/2018/favicon/06/iOS_iPhone_2x_120X120.png" />',
# 				'<link rel="apple-touch-icon-precomposed" sizes="180x180" href="https://ssl.pstatic.net/static.news/image/news/m/2018/favicon/06/iOS_iPhone_3x_180X180.png" />'
# 			];
# 		}else if(userAgent.indexOf('iPad') > -1){
# 			result = [
# 				'<link rel="apple-touch-icon-precomposed" sizes="167x167" href="https://ssl.pstatic.net/static.news/image/news/m/2018/favicon/06/iOS_iPadPro_2x_167X167.png" />',
# 				'<link rel="apple-touch-icon-precomposed" sizes="152x152" href="https://ssl.pstatic.net/static.news/image/news/m/2018/favicon/06/iOS_iPad_2x_152X152.png" />'
# 			];
# 		}
# 		document.write(result.join('\n'));
# 	})();
#    </script>
#    <script src="https://ssl.pstatic.net/static.news/mnews/resources/20240409_013407/js/generated/statistics_jquery.js" type="text/javascript">
#    </script>
#    <script>
#     document.documentElement.setAttribute('data-useragent',navigator.userAgent);
#    </script>
#    <script>
#     document.documentElement.setAttribute('data-useragent', navigator.userAgent);
#
#
# function showNoImage(elImg, type) {
#     switch (type) {
#
#         case "remove":
#             try {
#                 elImg.parentNode.removeChild(elImg);
#             } catch(e) {}
#             break;
#
#
#         case "removeParent":
#             try {
#                 elImg.parentNode.outerHTML = '';
#             } catch(e) {}
#             break;
#
#
#         case "alt":
#             elImg.outerHTML = ('<span class="noimage_text {imgClassName}">' + (elImg.alt || "") + '</span>')
#
#                 .replace('{imgClassName}', elImg.className);
#             break;
#
#
# 		case "class" :
# 			var outerHTMLSource = Number(elImg.getAttribute("height")) > 0?
#
# 				'<span class="noimage_wrap {imgClassName}" style="height:' + elImg.getAttribute("height") + 'px;"><span class="noimage"></span></span>':
# 				'<span class="noimage_wrap {imgClassName}"><span class="noimage"></span></span>';
# 			elImg.outerHTML = outerHTMLSource.replace('{imgClassName}', elImg.className);
# 			break;
#
#         case "pressname" :
#             var pressname = elImg.getAttribute("data-pressname");
#             elImg.outerHTML = '<span class="cjs_broadcast_noimg"><span class="noimg_text">' + pressname + '</span></span>';
#             break;
#
#
#         default:
#
#             elImg.outerHTML = Number(elImg.getAttribute("height")) > 0?
#
#                 '<span class="noimage_wrap" style="height:' + elImg.getAttribute("height") + 'px;"><span class="noimage"></span></span>':
#                 '<span class="noimage_wrap"><span class="noimage"></span></span>';
#     }
# }
#
#
# function doAfterLoadEnd(callback, callbackOnPersisted) {
#     var eventName = "onpageshow" in window ? "pageshow" : "load";
#
#     callback = callback || function(){};
#     callbackOnPersisted = callbackOnPersisted || function(){};
#
#     window.addEventListener(eventName, function(e) {
#         try{
#             if(Boolean(e.persisted)){
#                 callbackOnPersisted();
#                 return;
#             }
#         }catch(e){}
#
#         callback();
#     });
# }
#    </script>
#    <meta content="네이버 뉴스" property="og:title"/>
#    <meta content="website" property="og:type"/>
#    <meta content="https://news.naver.com/main/home.naver" property="og:url"/>
#    <meta content="https://ssl.pstatic.net/static.news/image/news/ogtag/navernews_800x420_20221201.png" property="og:image"/>
#    <meta content="정치, 경제, 사회, 생활/문화, 세계, IT/과학 등 언론사별, 분야별 뉴스 기사 제공" property="og:description"/>
#    <meta content="네이버" property="og:article:author"/>
#    <meta content="summary" name="twitter:card"/>
#    <meta content="네이버 뉴스" name="twitter:title"/>
#    <meta content="네이버 뉴스" name="twitter:site"/>
#    <meta content="네이버 뉴스" name="twitter:creator"/>
#    <meta content="https://ssl.pstatic.net/static.news/image/news/ogtag/navernews_800x420_20221201.png" name="twitter:image"/>
#    <meta content="정치, 경제, 사회, 생활/문화, 세계, IT/과학 등 언론사별, 분야별 뉴스 기사 제공" name="twitter:description"/>
#    <script>
#     (function () {
#         var isUnderIE10 = navigator.appName === "Microsoft Internet Explorer";
#         if (!isUnderIE10) {
#             var script = document.createElement("script");
#             script.async = true;
#             script.src = "https://ssl.pstatic.net/tveta/libs/glad/prod/gfp-core.js";
#             document.head.appendChild(script);
#         }
#     })();
#
#
#     window.gladsdk = window.gladsdk || { cmd: [] };
#     window.gladsdk.cmd.push(function () {
#
#         window.gladsdk.setGlobalConfig({
#             enablePersistAd: true
#         });
#
#
#         var adUnits = [];
#
#         adUnits.push({
#             adUnitId: "p_news_sidebox",
#             adSlotElementId: "glad_ad_sidebox",
#             customParam: {
#                 calp: "home"
#             }
#         });
#
#         for (let i = 0; i < adUnits.length; i++) {
#             window.gladsdk.defineAdSlot(adUnits[i]);
#         }
#
#
#         var htmlClass = document.querySelector("html").getAttribute("class");
#         if (htmlClass && htmlClass.indexOf("DARK_THEME") > -1) {
#             window.gladsdk.setHostMeta("theme", "system");
#         }
#     });
#    </script>
#   </meta>
#  </head>
#  <body class="as_mp_layout">
#   <div class="u_skip">
#    <a href="#ct">
#     본문 바로가기
#    </a>
#   </div>
#   <!-- Menu 구분  -->
#   <section class="news_header">
#    <header class="nh_header" role="banner">
#     <div class="Ngnb">
#      <div class="Ngnb_inner">
#       <div class="Ngnb_both">
#        <div class="Ngnb_left">
#         <span class="Ngnb_logo">
#          <a class="Nlogo_link" href="https://www.naver.com" onclick="nclk(event,'gnb.naver','','');">
#           <span class="Nicon_logo">
#            NAVER
#           </span>
#          </a>
#         </span>
#         <div class="Ngnb_service">
#          <h1 class="Nservice_item">
#           <a href="https://news.naver.com" onclick="nclk(event,'gnb.news','','');">
#            <span class="Nicon_service">
#             뉴스
#            </span>
#           </a>
#          </h1>
#          <span class="Nservice_subitem">
#           <a href="https://entertain.naver.com/home" onclick="nclk(event,'gnb.enter','','');">
#            <span class="Nicon_family Nicon_entertain">
#             연예
#            </span>
#           </a>
#          </span>
#          <span class="Nservice_subitem">
#           <a href="https://sports.news.naver.com/index" onclick="nclk(event,'gnb.sports','','');">
#            <span class="Nicon_family Nicon_sports">
#             스포츠
#            </span>
#           </a>
#          </span>
#          <span class="Nservice_subitem">
#           <a href="https://weather.naver.com/" onclick="nclk(event,'gnb.weather','','');">
#            <span class="Nicon_family Nicon_weather">
#             날씨
#            </span>
#           </a>
#          </span>
#          <span class="Nservice_subitem">
#           <a href="https://contents.premium.naver.com/" onclick="nclk(event,'gnb.premium','','');">
#            <span class="Nicon_family Nicon_premium">
#             프리미엄
#            </span>
#           </a>
#          </span>
#          <span class="Nservice_subitem">
#           <a href="https://news.naver.com/election/nation2024" onclick="nclk(event,'gnb.elc2024','','');">
#            <span class="Nicon_family Nicon_election">
#             총선
#            </span>
#           </a>
#          </span>
#         </div>
#        </div>
#        <div class="Ngnb_right">
#         <div class="Ngnb_group">
#          <div class="gnb_dark_type2" id="gnb">
#          </div>
#         </div>
#         <div class="Ngnb_search is_hidden _search_content">
#         </div>
#         <div class="Ngnb_tool">
#          <a class="Ntool_button _search_content_toggle_btn" href="javascript:;" onclick="nclk(event,'gnb.sch','','');">
#           <span class="Nicon_search">
#            검색
#           </span>
#          </a>
#         </div>
#        </div>
#       </div>
#      </div>
#     </div>
#     <div class="Nlnb _float_lnb">
#      <div class="Nlnb_inner">
#       <div class="Nlnb_both">
#        <div class="Nlnb_left _lnb_scroll">
#         <div class="Nlnb_menu Ntype_scroll">
#          <div class="Nlnb_menu_inner _scroll">
#           <ul class="Nlnb_menu_list" role="menu">
#            <li class="Nlist_item is_active">
#             <a aria-selected="true" class="Nitem_link" href="https://news.naver.com/?viewType=pc" onclick="nclk(event,'lnb.pcmedia','','');" role="menuitem">
#              <span class="Nitem_link_menu">
#               언론사별
#              </span>
#             </a>
#            </li>
#            <li class="Nlist_item">
#             <a aria-selected="false" class="Nitem_link" href="https://news.naver.com/section/100" onclick="nclk(event,'lnb.pol','','');" role="menuitem">
#              <span class="Nitem_link_menu">
#               정치
#              </span>
#             </a>
#            </li>
#            <li class="Nlist_item">
#             <a aria-selected="false" class="Nitem_link" href="https://news.naver.com/section/101" onclick="nclk(event,'lnb.eco','','');" role="menuitem">
#              <span class="Nitem_link_menu">
#               경제
#              </span>
#             </a>
#            </li>
#            <li class="Nlist_item">
#             <a aria-selected="false" class="Nitem_link" href="https://news.naver.com/section/102" onclick="nclk(event,'lnb.soc','','');" role="menuitem">
#              <span class="Nitem_link_menu">
#               사회
#              </span>
#             </a>
#            </li>
#            <li class="Nlist_item">
#             <a aria-selected="false" class="Nitem_link" href="https://news.naver.com/section/103" onclick="nclk(event,'lnb.lif','','');" role="menuitem">
#              <span class="Nitem_link_menu">
#               생활/문화
#              </span>
#             </a>
#            </li>
#            <li class="Nlist_item">
#             <a aria-selected="false" class="Nitem_link" href="https://news.naver.com/section/105" onclick="nclk(event,'lnb.sci','','');" role="menuitem">
#              <span class="Nitem_link_menu">
#               IT/과학
#              </span>
#             </a>
#            </li>
#            <li class="Nlist_item">
#             <a aria-selected="false" class="Nitem_link" href="https://news.naver.com/section/104" onclick="nclk(event,'lnb.wor','','');" role="menuitem">
#              <span class="Nitem_link_menu">
#               세계
#              </span>
#             </a>
#            </li>
#            <li class="Nlist_item _isNew">
#             <a aria-selected="false" class="Nitem_link" href="https://news.naver.com/main/ranking/popularDay.naver" onclick="nclk(event,'lnb.rank','','');" role="menuitem">
#              <span class="Nitem_link_menu">
#               랭킹
#              </span>
#             </a>
#            </li>
#            <li class="Nlist_item _isNew">
#             <a aria-selected="false" class="Nitem_link" href="https://news.naver.com/newspaper/home?viewType=pc" onclick="nclk(event,'lnb.paper','','');" role="menuitem">
#              <span class="Nitem_link_menu">
#               신문보기
#              </span>
#             </a>
#            </li>
#            <li class="Nlist_item">
#             <a aria-selected="false" class="Nitem_link" href="https://news.naver.com/opinion/home" onclick="nclk(event,'lnb.opi','','');" role="menuitem">
#              <span class="Nitem_link_menu">
#               오피니언
#              </span>
#             </a>
#            </li>
#            <li class="Nlist_item">
#             <a aria-selected="false" class="Nitem_link" href="https://news.naver.com/main/tv/index.naver?mid=tvh" onclick="nclk(event,'lnb.tv','','');" role="menuitem">
#              <span class="Nitem_link_menu">
#               TV
#              </span>
#             </a>
#            </li>
#            <li class="Nlist_item">
#             <a aria-selected="false" class="Nitem_link" href="https://news.naver.com/factcheck/main" onclick="nclk(event,'lnb.fact','','');" role="menuitem">
#              <span class="Nitem_link_menu">
#               팩트체크
#              </span>
#             </a>
#            </li>
#            <li class="Nlist_item">
#             <a aria-selected="false" class="Nitem_link" href="https://media.naver.com/algorithm" onclick="nclk(event,'lnb.algo','','');" role="menuitem">
#              <span class="Nitem_link_menu">
#               알고리즘 안내
#              </span>
#             </a>
#            </li>
#            <li class="Nlist_item _isNew">
#             <a aria-selected="false" class="Nitem_link" href="https://news.naver.com/main/ombudsman/errorArticleList.naver?mid=omb" onclick="nclk(event,'lnb.correct','','');" role="menuitem">
#              <span class="Nitem_link_menu">
#               정정보도 모음
#              </span>
#             </a>
#            </li>
#           </ul>
#          </div>
#         </div>
#        </div>
#       </div>
#      </div>
#     </div>
#    </header>
#   </section>
#   <hr/>
#   <div class="main_wrap" id="ct" role="main">
#    <div class="main_container">
#     <section class="main_content">
#      <h3 class="blind">
#       콘텐츠
#      </h3>
#      <div class="main_sublnb">
#       <div class="main_sublnb_date">
#        <strong>
#         4
#        </strong>
#        .
#        <strong>
#         10
#        </strong>
#        <span>
#         (수)
#        </span>
#       </div>
#       <ul class="main_sublnb_menu">
#        <li class="main_sublnb_item">
#         <a class="main_sublnb_link" href="https://news.naver.com/main/officeList.naver " onclick="nclk(event, 'slb.allmedia', '', '')">
#          전체 언론사
#         </a>
#        </li>
#        <li class="main_sublnb_item">
#         <a class="main_sublnb_link" href="https://newsstand.naver.com/" onclick="nclk(event, 'slb.newsstand', '', '')" target="_blank">
#          뉴스스탠드
#         </a>
#        </li>
#        <li class="main_sublnb_item">
#         <a class="main_sublnb_link" href="https://newslibrary.naver.com/search/searchByDate.naver" onclick="nclk(event, 'slb.library', '', '')" target="_blank">
#          라이브러리
#         </a>
#        </li>
#       </ul>
#      </div>
#      <div class="main_brick">
#       <!-- BRICK HOUSE -->
#       <div class="grid1_wrap brick-house _brick_gid_wrapper">
#        <div class="brick-vowel _brick_column">
#         <div class="main_brick_item _press_main_status_wrapper">
#          <div class="comp_journal_subscribe">
#           <div class="cjs_title_wrap">
#            <h3 class="cjs_edit_title">
#             <span class="cjs_main">
#              언론사편집
#             </span>
#             <a class="cjs_subscribe_a" href="#feedJournalistCard" onclick="nclk(event, 'home.editassetting1', '', '')">
#              <span class="subs_text">
#               기자
#              </span>
#             </a>
#             <a class="cjs_subscribe_a" href="#feedSeriesCard" onclick="nclk(event, 'home.editassetting2', '', '')">
#              <span class="subs_text">
#               연재
#              </span>
#             </a>
#            </h3>
#            <a class="cjs_more_link" href="https://media.naver.com/channel/settings" onclick="nclk(event, 'home.editsetting', '', '')">
#             구독설정
#             <span class="ico_more">
#             </span>
#            </a>
#           </div>
#           <div class="cjs_news_flash_wrap cjs_nf_close _newsflash_wrapper">
#            <div class="cjs_nf_title">
#             <span class="ico_newsflash">
#              속보
#             </span>
#            </div>
#            <div class="cjs_nf_list _item_list">
#             <a class="cjs_nf_a _item _cds_link _newsflash_link" href="https://n.news.naver.com/article/659/0000020455" onclick="nclk(event, 'home.newsflash', '', '')">
#              <div class="cn_title_area">
#               <h4 class="cn_title">
#                오전 10시 본투표율 10.4%..지난 총선보다 1.0%p 낮아
#               </h4>
#               <div class="cn_snippet">
#                <div class="cn_journal_wrap">
#                 <div class="cn_thumb">
#                  <img alt="" height="10" loading="lazy" onerror="showNoImage(this)" src="https://mimgnews.pstatic.net/image/upload/office_logo/659/2022/01/19/logo_659_56_20220119141438.png?type=nf20_20" width="10"/>
#                 </div>
#                 <div class="cn_name">
#                  전주MBC
#                 </div>
#                </div>
#                <div class="cn_state">
#                 내용작성전
#                </div>
#               </div>
#              </div>
#             </a>
#             <a class="cjs_nf_a _item _cds_link _newsflash_link" href="https://n.news.naver.com/article/057/0001811349" onclick="nclk(event, 'home.newsflash', '', '')">
#              <div class="cn_title_area">
#               <h4 class="cn_title">
#                22대 총선 투표율 오전 10시 현재 10.4%…지난 총선보다 1%p↓
#               </h4>
#               <div class="cn_snippet">
#                <div class="cn_journal_wrap">
#                 <div class="cn_thumb">
#                  <img alt="" height="10" loading="lazy" onerror="showNoImage(this)" src="https://mimgnews.pstatic.net/image/upload/office_logo/057/2019/11/25/logo_057_56_20191125103925.png?type=nf20_20" width="10"/>
#                 </div>
#                 <div class="cn_name">
#                  MBN
#                 </div>
#                </div>
#                <div class="cn_state">
#                 내용작성전
#                </div>
#               </div>
#              </div>
#             </a>
#             <a class="cjs_nf_a _item _cds_link _newsflash_link" href="https://n.news.naver.com/article/658/0000070948" onclick="nclk(event, 'home.newsflash', '', '')">
#              <div class="cn_title_area">
#               <h4 class="cn_title">
#                총선 투표율 오전 10시 10.4%… 1%p↓
#               </h4>
#               <div class="cn_snippet">
#                <div class="cn_journal_wrap">
#                 <div class="cn_thumb">
#                  <img alt="" height="10" loading="lazy" onerror="showNoImage(this)" src="https://mimgnews.pstatic.net/image/upload/office_logo/658/2022/01/20/logo_658_56_20220120164828.png?type=nf20_20" width="10"/>
#                 </div>
#                 <div class="cn_name">
#                  국제신문
#                 </div>
#                </div>
#               </div>
#              </div>
#             </a>
#             <a class="cjs_nf_a _item _cds_link _newsflash_link" href="https://n.news.naver.com/article/087/0001037218" onclick="nclk(event, 'home.newsflash', '', '')">
#              <div class="cn_title_area">
#               <h4 class="cn_title">
#                4·10총선 투표율 오전 10시 현재 전국 10.4%, 강원 11.5%
#               </h4>
#               <div class="cn_snippet">
#                <div class="cn_journal_wrap">
#                 <div class="cn_thumb">
#                  <img alt="" height="10" loading="lazy" onerror="showNoImage(this)" src="https://mimgnews.pstatic.net/image/upload/office_logo/087/2019/08/22/logo_087_56_20190822110222.png?type=nf20_20" width="10"/>
#                 </div>
#                 <div class="cn_name">
#                  강원일보
#                 </div>
#                </div>
#               </div>
#              </div>
#             </a>
#             <a class="cjs_nf_a _item _cds_link _newsflash_link" href="https://n.news.naver.com/article/014/0005169353" onclick="nclk(event, 'home.newsflash', '', '')">
#              <div class="cn_title_area">
#               <h4 class="cn_title">
#                22대 총선 오전10시 투표율 10.4%...21대 총선보다 1.0%p↓
#               </h4>
#               <div class="cn_snippet">
#                <div class="cn_journal_wrap">
#                 <div class="cn_thumb">
#                  <img alt="" height="10" loading="lazy" onerror="showNoImage(this)" src="https://mimgnews.pstatic.net/image/upload/office_logo/014/2020/12/23/logo_014_56_20201223183322.png?type=nf20_20" width="10"/>
#                 </div>
#                 <div class="cn_name">
#                  파이낸셜뉴스
#                 </div>
#                </div>
#                <div class="cn_state">
#                 내용작성전
#                </div>
#               </div>
#              </div>
#             </a>
#             <button class="cjs_nf_btn_open is_close _toggle_btn" type="button">
#              <span class="blind">
#               속보 닫기
#              </span>
#             </button>
#            </div>
#           </div>
#          </div>
#         </div>
#         <div class="main_brick_item _channel
loading="lazy" onerror="showNoImage(this)" width="100%"/>
#              </div>
#              <div class="cjs_news_tw">
#               <div class="cjs_t">
#                국힘 "딱 한 표 부족하다" 민주 "투표로 정권심판"…격전지 표심 향방은?
#               </div>
#               <p class="cjs_d">
#                4·10 총선을 하루 앞둔 9일 국민의힘과 더불어민주당은 각각 '거야 견제'와 '정권 심판'을 위한 한 표를 호소했다. 국민의힘은 이날 최대 승부처인 수도권에서 집중 유세를 벌이면서 국정 안정과 야당 견제를 위한 투
#               </p>
#              </div>
#             </a>
#            </div>
#            <div class="cjs_info">
#             <button card_type="preview" class="cjs_btn_refresh _refresh_btn" data-max-page="" data-page="0" onclick="nclk(event, 'home.editnfnew', '', '')" size="5" type="button">
#              새로보기
#             </button>
#            </div>
#           </div>
#          </div>
#          <div class="comp_journal_subscribe _preview_card_page" style="display:none">
#           <div class="cjs_channel_card">
#            <div class="cjs_ctitle _item_title">
#             <a class="cjs_ctitle_a" href="https://media.naver.com/press/640" onclick="nclk(event, 'home.editnfmedia', '', '')">
#              <div class="cjs_cmw small">
#               <img data-onshow-src="https://mimgnews.pstatic.net/image/upload/office_logo/640/2020/05/06/logo_640_56_20200506111106.png?type=nf76_76_q90" height="28" loading="lazy" onerror="showNoImage(this)" width="28"/>
#              </div>
#              <div class="cjs_ctw">
#               <h4 class="channel">
#                코리아중앙데일리
#                <span class="datetime">
#                 04월 10일 08:38
#                </span>
#               </h4>
#              </div>
#             </a>
#             <div class="cjs_ctitle_right">
#              <button class="cjs_btn_subscribe _subscribe_btn" data-office_id="640" data-office_name="코리아중앙데일리" onclick="nclk(event, 'home.editnfset', '', '')" type="button">
#               구독
#              </button>
#             </div>
#            </div>
#            <div class="cjs_journal_wrap _item_contents">
#             <a class="cjs_news_a _cds_link _editn_link" href="https://n.news.naver.com/article/640/0000052368" onclick="nclk(event, 'home.editnfimg', '', '')">
#              <div class="cjs_news_mw">
#               <img alt="" data-onshow-src="https://mimgnews.pstatic.net/image/origin/640/2024/04/10/52368.jpg?type=nf264_176&amp;ut=20240410101501" loading="lazy" onerror="showNoImage(this)" width="100%"/>
#              </div>
#              <div class="cjs_news_tw">
#               <div class="cjs_t">
#                Voting for Korea’s parliamentary elections kicks off
#               </div>
#               <p class="cjs_d">
#                Voting kicked off Wednesday morning in Korea to elect the 22nd National Assembly. At stake in this general election are
#               </p>
#              </div>
#             </a>
#            </div>
#            <div class="cjs_ctitle _item_title">
#             <a class="cjs_ctitle_a" href="https://media.naver.com/press/036" onclick="nclk(event, 'home.editnfmedia', '', '')">
#              <div class="cjs_cmw small">
#               <img data-onshow-src="https://mimgnews.pstatic.net/image/upload/office_logo/036/2018/09/20/logo_036_56_20180920152920.png?type=nf76_76_q90" height="28" loading="lazy" onerror="showNoImage(this)" width="28"/>
#              </div>
#              <div class="cjs_ctw">
#               <h4 class="channel">
#                한겨레21
#                <span class="datetime">
#                 04월 10일 08:52
#                </span>
#               </h4>
#              </div>
#             </a>
#             <div class="cjs_ctitle_right">
#              <button class="cjs_btn_subscribe _subscribe_btn" data-office_id="036" data-office_name="한겨레21" onclick="nclk(event, 'home.editnfset', '', '')" type="button">
#               구독
#              </button>
#             </div>
#            </div>
#            <div class="cjs_journal_wrap _item_contents">
#             <a class="cjs_news_a _cds_link _editn_link" href="https://n.news.naver.com/article/036/0000049676" onclick="nclk(event, 'home.editnfimg', '', '')">
#              <div class="cjs_news_mw">
#               <img alt="" data-onshow-src="https://mimgnews.pstatic.net/image/origin/036/2024/04/10/49676.jpg?type=nf264_176&amp;ut=20240410085101" loading="lazy" onerror="showNoImage(this)" width="100%"/>
#              </div>
#              <div class="cjs_news_tw">
#               <div class="cjs_t">
#                ‘어린 악마’로 재탄생한 ‘방치된 아이’
#               </div>
#               <p class="cjs_d">
#                2004년 2월 말, 겨울방학을 마친 중국 대학생들이 속속 각자의 학교로 복귀하고 있었다. 2월23일, 윈난 최고의 명문대학인 쿤밍성 소재 윈난대학도 대부분 복귀를 마친 학생들로 교내가 다시 활기를 띠어가는 중이었다
#               </p>
#              </div>
#             </a>
#            </div>
#            <div class="cjs_ctitle _item_title">
#             <a class="cjs_ctitle_a" href="https://media.naver.com/press/422" onclick="nclk(event, 'home.editnfmedia', '', '')">
#              <div class="cjs_cmw small">
#               <img data-onshow-src="https://mimgnews.pstatic.net/image/upload/office_logo/422/2019/11/29/logo_422_56_20191129165529.jpg?type=nf76_76_q90" height="28" loading="lazy" onerror="showNoImage(this)" width="28"/>
#              </div>
#              <div class="cjs_ctw">
#               <h4 class="channel">
#                연합뉴스TV
#                <span class="datetime">
#                 04월 10일 10:26
#                </span>
#               </h4>
#              </div>
#             </a>
#             <div class="cjs_ctitle_right">
#              <button class="cjs_btn_subscribe _subscribe_btn" data-office_id="422" data-office_name="연합뉴스TV" onclick="nclk(event, 'home.editnfset', '', '')" type="button">
#               구독
#              </button>
#             </div>
#            </div>
#            <div class="cjs_journal_wrap _item_contents">
#             <a class="cjs_news_a _cds_link _editn_link" href="https://n.news.naver.com/article/422/0000654381" onclick="nclk(event, 'home.editnfimg', '', '')">
#              <div class="cjs_news_mw">
#               <img alt="" data-onshow-src="https://mimgnews.pstatic.net/image/origin/422/2024/04/10/654381.jpg?type=nf264_176&amp;ut=20240410084803" loading="lazy" onerror="showNoImage(this)" width="100%"/>
#               <span class="comp_ico_movie">
#                동영상
#               </span>
#               <span class="comp_playtime">
#                <span class="time">
#                 <span class="blind">
#                  재생시간
#                 </span>
#                 02:20
#                </span>
#               </span>
#              </div>
#              <div class="cjs_news_tw">
#               <div class="cjs_t">
#                사전 투표율 최하위 대구…본투표 표심 주목
#               </div>
#               <p class="cjs_d">
#                이번엔 '보수의 심장' 대구로 가보겠습니다. 여당은 대구·경북 지역에서 압승을, 야당은 정권 심판과 독점 구도 타파를 내세워 지지를 호소했습니다. 취재 기자 연결해 이 시각 투표소 분위기 살펴보겠습니다. 정지훈 기자
#               </p>
#              </div>
#             </a>
#            </div>
#            <div class="cjs_ctitle _item_title">
# ...
#              </div>
#              <div class="cjs_age_name">
#               연합뉴스TV
#              </div>
#             </a>
#            </li>
#            <li class="cjs_age_item">
#             <a aria-checked="false" class="cjs_link_age _item" data-office_id="001" href="javascript:;" role="checkbox">
#              <div class="cjs_age_mw">
#               <img alt="" data-onshow-src="https://mimgnews.pstatic.net/image/upload/office_logo/001/2020/08/11/logo_001_56_20200811154916.png" height="54" loading="lazy" onerror="showNoImage(this)" width="54"/>
#              </div>
#              <div class="cjs_age_name">
#               연합뉴스
#              </div>
#             </a>
#            </li>
#            <li class="cjs_age_item">
#             <a aria-checked="false" class="cjs_link_age _item" data-office_id="055" href="javascript:;" role="checkbox">
#              <div class="cjs_age_mw">
#               <img alt="" data-onshow-src="https://mimgnews.pstatic.net/image/upload/office_logo/055/2020/10/07/logo_055_56_20201007141807.jpg" height="54" loading="lazy" onerror="showNoImage(this)" width="54"/>
#              </div>
#              <div class="cjs_age_name">
#               SBS
#              </div>
#             </a>
#            </li>
#            <li class="cjs_age_item">
#             <a aria-checked="false" class="cjs_link_age _item" data-office_id="057" href="javascript:;" role="checkbox">
#              <div class="cjs_age_mw">
#               <img alt="" data-onshow-src="https://mimgnews.pstatic.net/image/upload/office_logo/057/2019/11/25/logo_057_56_20191125103925.png" height="54" loading="lazy" onerror="showNoImage(this)" width="54"/>
#              </div>
#              <div class="cjs_age_name">
#               MBN
#              </div>
#             </a>
#            </li>
#            <li class="cjs_age_item">
#             <a aria-checked="false" class="cjs_link_age _item" data-office_id="437" href="javascript:;" role="checkbox">
#              <div class="cjs_age_mw">
#               <img alt="" data-onshow-src="https://mimgnews.pstatic.net/image/upload/office_logo/437/2023/07/17/logo_437_56_20230717153920.png" height="54" loading="lazy" onerror="showNoImage(this)" width="54"/>
#              </div>
#              <div class="cjs_age_name">
#               JTBC
#              </div>
#             </a>
#            </li>
#            <li class="cjs_age_item">
#             <a aria-checked="false" class="cjs_link_age _item" data-office_id="052" href="javascript:;" role="checkbox">
#              <div class="cjs_age_mw">
#               <img alt="" data-onshow-src="https://mimgnews.pstatic.net/image/upload/office_logo/052/2021/10/01/logo_052_56_20211001183149.png" height="54" loading="lazy" onerror="showNoImage(this)" width="54"/>
#              </div>
#              <div class="cjs_age_name">
#               YTN
#              </div>
#             </a>
#            </li>
#            <li class="cjs_age_item">
#             <a aria-checked="false" class="cjs_link_age _item" data-office_id="374" href="javascript:;" role="checkbox">
#              <div class="cjs_age_mw">
#               <img alt="" data-onshow-src="https://mimgnews.pstatic.net/image/upload/office_logo/374/2020/12/29/logo_374_56_20201229152554.jpg" height="54" loading="lazy" onerror="showNoImage(this)" width="54"/>
#              </div>
#              <div class="cjs_age_name">
#               SBS Biz
#              </div>
#             </a>
#            </li>
#           </ul>
#           <div class="cjs_info">
#            <button class="cjs_btn_refresh _refresh_btn" onclick="nclk(event, 'home.edittnew', '', '')" type="button">
#             새로보기
#            </button>
#           </div>
#          </div>
#         </div>
#        </div>
#        <div class="brick-vowel _brick_column">
#        </div>
#        <div class="brick-vowel _brick_column">
#        </div>
#       </div>
#      </div>
#     </section>
#     <section class="main_aside _aside_wrapper">
#      <div class="main_aside_inner _aside_content">
#       <h3 class="blind">
#        구독
#       </h3>
#       <div class="_aside">
#       </div>
#       <script>
#        doAfterLoadEnd(loadAside);
#
#
# function loadAside() {
#     var forcePcVersion = "";
#
#     if (isMobileDevice() && !forcePcVersion) {
#         return;
#     }
#     var iframe = append();
#     var asideFixed;
#
#     window.addEventListener('message', function(event) {
#         var data = event.data;
#
#         if (event.origin !== "https://news.naver.com") {
#             return;
#         }
#
#         if (data.type === "setIframeSize" && data.height) {
#             iframe.style.height = data.height + 'px';
#             iframe.style.visibility = "";
#
#             try {
#                 asideFixed.deactivate(); // event 중복 적용되지 않게
#             } catch(e) {}
#
#             asideFixed = AsideFixed({
#                 "wrapper" : document.querySelector("._aside_wrapper")
#
#             });
#         }
#     });
#
#
#     function append() {
#         var iframe = document.createElement('iframe');
#
#         iframe.width = "100%";
#         iframe.height = "0";
#         iframe.style.visibility = "hidden";
#         iframe.setAttribute("frameborder", "no");
#         iframe.setAttribute("scrolling", "no");
#         iframe.src = "https://news.naver.com/aside?oid=";
#
#         document.querySelector("._aside").appendChild(iframe);
#
#         return iframe;
#     }
# }
#       </script>
#      </div>
#     </section>
#     <div class="layer_toast" style="display: none">
#     </div>
#     <div class="layer_toast_journal_subscribe _subscribe_toast_layer" style="display: none">
#      <button class="lt_btn_set _subscribe_toast_btn" onclick="nclk(event, 'home.edittallchk', '', '')" type="button">
#      </button>
#     </div>
#    </div>
#   </div>
#   <!-- //ct -->
#   <hr/>
#   <div class="mp_footer">
#    <div class="f_subinfo">
#     <div class="f_subinfoinner">
#      <div class="f_notice">
#       <h5 class="f_notice_badge">
#        공지
#       </h5>
#       <a class="f_notice_link" data-mpurl='{"m":"https://m.news.naver.com/ombudsman/noticeread?notiId=762","p":"https://news.naver.com/main/ombudsman/readView.naver?notiId=762"}' href="https://m.news.naver.com/ombudsman/noticeread?notiId=762" onclick="nclk(event, 'fot.noticetext', '', '');">
#        <p class="f_notice_text">
#         선거 관련 허위 댓글 신고 기능 적용 안내
#        </p>
#       </a>
#      </div>
#     </div>
#    </div>
#    <div class="f_maininfo">
#     <div class="f_maininfoinner">
#      <a class="r_pg_top _go_top" href="javascript:;" id="goTop" onclick="nclk(event, 'fot.pctop', '', '');">
#       맨위로
#      </a>
#      <footer role="contentinfo">
#       <p class="u_ftlkw _footer_login" id="u_ftlkw">
#        <a class="u_ftlk" data-mpurl='{"m":"https://m.naver.com/services.html","p":"https://www.naver.com/more.html"}' href="https://m.naver.com/services.html" onclick="nclk(event,'fot.serviceall','','');">
#         전체서비스
#        </a>
#       </p>
#       <p class="u_cr">
#        <span class="u_ftm">
#         <span class="u_cri u_cri_v1">
#          <a class="u_cra" data-mpurl='{"m":"https://policy.naver.com/policy-mobile/term.html?type=1?type=1","p":"https://policy.naver.com/rules/service.html"}' href="https://policy.naver.com/policy-mobile/term.html?type=1?type=1" onclick="nclk(event,'fot.agreement','','');">
#           이용약관
#          </a>
#         </span>
#         <span class="u_cri u_cri_v1">
#          <a class="u_cra" data-mpurl='{"m":"https://policy.naver.com/policy-mobile/privacy.html","p":"https://policy.naver.com/rules/privacy.html"}' href="https://policy.naver.com/policy-mobile/privacy.html" onclick="nclk(event,'fot.privacy','','');">
#           <strong>
#            개인정보처리방침
#           </strong>
#          </a>
#         </span>
#         <span class="u_cri u_cri_v1">
#          청소년 보호 책임자 : 이정규
#         </span>
#         <span class="u_cri u_cri_v1">
#          <a class="u_cra" data-mpurl='{"m":"https://m.news.naver.com/ombudsman/index","p":"https://news.naver.com/main/ombudsman/index.naver"}' href="https://m.news.naver.com/ombudsman/index" onclick="nclk(event,'fot.guide','','');">
#           서비스안내
#          </a>
#         </span>
#        </span>
#        <span class="u_cri">
#         각 언론사가 직접 콘텐츠를 편집합니다.
#        </span>
#       </p>
#      </footer>
#     </div>
#    </div>
#   </div>
#   <script src="https://ssl.pstatic.net/static.news/mnews/resources/20240409_013407/js/generated/news.mobile.js" type="text/javascript">
#   </script>
#   <script src="https://ssl.pstatic.net/static.news/mnews/resources/20240409_013407/js/generated/pressmain.dependency.js" type="text/javascript">
#   </script>
#   <script type="text/javascript">
#    /**
#  * 이 파일은 모바일 뉴스 서비스 전체 페이지에 적용되는 스크립트로써,
#  * 코드 추가 시 Front-End 성능 관점에서 주의를 요합니다.
#  */
# jQuery(window).on('load', function(){
#     setTimeout(onload, 10);
#
#     function onload(){
#         var oLnb = new news.Lnb('._lnb_scroll');
#         new news.ImageLazyLoader().load("img[data-src]");
#         new news.MoveTopButton("._go_top");
#
#
#         new news.HistoryManager().init("naver_mobile_news_history", "");
#
#         // iframe lazy-loading
#         (function(){
#             try {
#                 Array.prototype.slice.apply(document.querySelectorAll('iframe[data-src]'))
#                     .forEach(function(iframeEl) {
#                         var originSrc = iframeEl.getAttribute('data-src');
#                         if(originSrc) {
#                             iframeEl.setAttribute('src', originSrc);
#                         }
#                     });
#             }catch(e) {}
#         })();
#
#         if(typeof init === "function"){
#             init();
#         }
#
#         var cookie = news.Cookie.getInstance();
#         var isShownNewLnb = cookie.getItem("isShownNewLnb");
#         if(isShownNewLnb == null) {
#             isShownNewLnb = "Y";
#             cookie.setItem("isShownNewLnb", isShownNewLnb, 3650, "", "/");
#             $("._isNew").addClass("is_new");
#         }
#
#         {
#             var footerLogin = jQuery(document).find('._footer_login');
#             if(footerLogin <= 0) {
#                 return;
#             }
#
#             // 디바이스에 따라 로그인, 로그아웃 URL 분기
#             var loginUrl = "https://nid.naver.com/nidlogin.login";
#             var logoutUrl = "https://nid.naver.com/nidlogin.logout?";
#             if (news.Util.getAgentInfo().bMobileOrTablet) {
#                 loginUrl = "https://nid.naver.com/nidlogin.login?svctype=262144";
#                 logoutUrl = "https://nid.naver.com/nidlogin.logout?svctype=262144&";
#             }
#
#             if(news.LoginAssistor.isLoginUser()) {
#                 footerLogin.prepend('<a href="javascript:news.Util.logout(\''+logoutUrl+'url=\'+encodeURIComponent(location.href));" class="u_ftlk" id="news_logout" onclick="nclk(event,\'fot.logout\',\'\',\'\');" >로그아웃</a>')
#             }else {
#                 footerLogin.prepend('<a href="'+loginUrl+'" class="u_ftlk" id="news_login" onclick="nclk(event,\'fot.login\',\'\',\'\');" >로그인</a>')
#             }
#         }
#     }
# });
#   </script>
#   <script id="feedRefreshButtonTemplate" type="text/x-handlebars-template">
#    {{buttonText}}
#     <span class="paging">
#         <span class="blind">현재</span>{{currentPage}}
#         <em class="total"> / <span class="blind">전체</span>{{totalPage}}</em>
#     </span>
#   </script>
#   <script type="text/javascript">
#    FeedCard($('._journalist_feed_card_wrapper'), 'journalist', 'https://m.news.naver.com');
#     FeedCard($('._series_feed_card_wrapper'), 'series', 'https://m.news.naver.com');
#     BrickGridForEditByPress($("._brick_gid_wrapper"));
#     PressMainStatusCard($('._press_main_status_wrapper'));
#     NewsFlashCard($('._newsflash_wrapper'));
#
#
#
#
#     window.gladsdk.cmd.push(function () {
#         var adSlot = window.gladsdk.findAdSlot("glad_ad_sidebox");
#         adSlot.setCustomParam("calp", 'home');
#         window.gladsdk.displayAd(adSlot);
#
#
#         window.gladsdk.addEventListener(window.gladsdk.event.ERROR, function (ad, error) {
#             $("._card_ad").hide();
#         });
#     });
#
#     $('._channel_news_card_wrapper').each(function () {
#         var wrapper = $(this);
#         ChannelNewsCard(wrapper, 'https://m.news.naver.com');
#     })
#
#     ChannelNewsPreviewCard($('._channel_news_preview_wrapper'), 'https://m.news.naver.com');
#     SubscribeBannerShortCard($('._short_subscribe_banner_card_wrapper'), 'https://m.news.naver.com');
#     SubscribeBannerLongCard($('._long_subscribe_banner_card_wrapper'), 'https://m.news.naver.com');
#
#     WeeklySpecialReportCard($('._weekly_special_report_card_wrapper'));
#
#     $('._horizontal_card_wrapper').each(function () {
#         var wrapper = $(this);
#         HorizontalTypeCard(wrapper, 'https://m.news.naver.com');
#     });
#
#     SpecialReportCard($('._special_report_card_wrapper'), 'https://m.news.naver.com');
#
#     ArticleLinkParamsAppender('news_media_pc');
#   </script>
#   <script>
#    var gnb_service = 'news';
#     var gnb_logout = encodeURIComponent(location.href);
#     var gnb_template = 'gnb_utf8';
#     var gnb_brightness = 3;
#     var gnb_item_hide_option= 128;
#
#     doAfterLoadEnd(function () {
#         try {
#             GlobalMPUrlManager.init();
#         } catch (e) {}
#     });
#
#     doAfterLoadEnd(function() {
#         if (!document.querySelector('#gnb') || isMobileDevice() === true) {
#             return;
#         }
#
#         var gnb_src = "https://ssl.pstatic.net/static.gn/templates/gnb_utf8?2024041010";
#
#         // GnbHelper를 이용하여 GNB Layer를 닫을 수 있도록 지원한다.
#         if (window.jindo) {
#             jindo.LazyLoading.load(
#                 gnb_src,
#                 function() {
#                     try {
#                         getGNB();
#                     } catch(e) {}
#                 },
#                 'utf-8'
#             );
#
#             jindo.$Fn(function (oEvent) {
#
#                 GnbHelper.attachClick(oEvent.$value().target);
#             }).attach(document, 'click');
#         } else if (window.jQuery) {
#             new news.JsLoader().
#                 load(
#                     [gnb_src],
#                     function() {
#                         try {
#                             getGNB();
#                         } catch(e) {}
#                     }
#                 );
#
#             $(document).on("click", function(event) {
#                 GnbHelper.attachClick(event.target);
#             });
#         }
#     });
#   </script>
#   <script>
#    doAfterLoadEnd(function() {
#         if (!document.querySelector('.news_header')){
#             return;
#         }
#
#         try {
#             GnbFloatingManager.init();
#         } catch (e) { }
#     });
#   </script>
#   <script>
#    doAfterLoadEnd(function() {
#     try {
#         new SearchAutoComplete({
#             content: document.querySelector("._search_content"),
#             contentToggleBtn: document.querySelector("._search_content_toggle_btn"),
#             isMobile: isMobileDevice(),
#             nClickType: "newsM"
#         });
#     } catch(e) {}
# });
#   </script>
#   <!-- LCS -->
#   <script type="text/javascript">
#    function initMa(){
#     var data = {
#         "service": "news",
#         "baseInfo": {
#             "category": (function(){
#
#                 var result = "언론사별(신규)";
#
#                 if(result !== ""){
#                     return result;
#                 }
#                 try{
#
#                     return document.querySelector('meta[property="og:title"]')
#                         .getAttribute('content')
#                         .replace(/[\s]*:+[\s]*네이버[\s]*뉴스/, '');
#                 }catch(e){
#                     return "";
#                 }
#             })()
#         },
#         "extraInfo": {}
#     };
#
#
#
#     try{
#         ma.init({
#             api: "https://ma.news.naver.com/l",
#             data: data
#         });
#     }catch(e){}
# }
#   </script>
#   <script type="text/javascript">
#    var eventType = "onpageshow" in window ? "pageshow" : "load";
# jQuery(window).on(eventType, function() {
#
#
#
#
#
#     lcs_do();
#
#
#     try {
#         initMa();
#     } catch (e) {
#     }
# });
#   </script>
#   <!-- //LCS -->
#   <div id="videoWrap">
#   </div>
#  </body>
# </html>

# %%
news_title = bs_obj.findAll('div',{'class':'cjs_t'})

# %%
len(news_title)
# Out:
# 82

# %%
news_title
# Out:
# [<div class="cjs_t">어떻게 알았을까…청도 미라, 165cm 키가 큰 1580년생 조선 남성</div>,
#  <div class="cjs_t">“내 한표로 결과 뒤집힐 수도”…이른 아침 권리 행사 나선 시민들</div>,
#  <div class="cjs_t">이명박 “정치가 수준 안 맞아”…권양숙 “투표 많이 참여하길”</div>,
#  <div class="cjs_t">무신사 1조 매출 눈앞...에이블리·카카오스타일 '수익개선' 증명</div>,
#  <div class="cjs_t">제22대 총선 본 투표 시작..이 시각 투표소</div>,
#  <div class="cjs_t">한동훈 “이재명 친위대로 채워진 民 200석, 셀프사면할 것”</div>,
#  <div class="cjs_t">총선 투표율 오전 10시 기준 10.4%…지난 총선보다 1%p↓</div>,
#  <div class="cjs_t">사우디가 돈이 부족하다고? 네옴시티 야망이 주춤한 이유[딥다이브]</div>,
#  <div class="cjs_t">둘 다 성병이라는데… HPV와 HSV는 어떻게 다를까?</div>,
#  <div class="cjs_t">국힘 "딱 한 표 부족하다" 민주 "투표로 정권심판"…격전지 표심 향방은?</div>,
#  <div class="cjs_t">Voting for Korea’s parliamentary elections kicks off</div>,
#  <div class="cjs_t">‘어린 악마’로 재탄생한 ‘방치된 아이’</div>,
#  <div class="cjs_t">사전 투표율 최하위 대구…본투표 표심 주목</div>,
#  <div class="cjs_t">[영상]“서서 죽겠다”던 한동훈, 유세 강행군 끝에 생일날 탈진</div>,
#  <div class="cjs_t">“밥 안 먹고 ‘앞구르기’ 무한반복”…푸바오에 무슨 일이</div>,
#  <div class="cjs_t">전문가들, 민주당 당선 예상자 대폭 늘렸다</div>,
#  <div class="cjs_t">김진태 "대한민국과 강원도 미래 달린 선거, 현명한 선택 바라"</div>,
#  <div class="cjs_t">전 세계 항공기 시장 양대 산맥 '보잉·에어버스'...국내 항공사의 선택은? [Y녹취록]</div>,
#  <div class="cjs_t">[속보]총선 투표율 오전 10시 10.4%… 1%p↓</div>,
#  <div class="cjs_t">남중국해 장악하려는 中… 미국·일본·필리핀 ‘3각 동맹’으로 맞서</div>,
#  <div class="cjs_t">개그맨 김영민 작심 발언 “김대업 ‘거짓말’ 밝혀졌지만…‘노무현 시대’ 와버려”</div>,
#  <div class="cjs_t">10세대 중 4세대는 '나 혼자 산다'…1인 세대 1000만 돌파</div>,
#  <div class="cjs_t">'622조 투입' 반도체 벨트 중심 '용인갑'...같은 듯 다른 '후보자 공약' [소부장반차장]</div>,
#  <div class="cjs_t">"6시 땡" 투표소 열리자마자 '오픈런'.. 총선 결전의 날 열기 후끈</div>,
#  <div class="cjs_t">수검표 도입…내일 새벽 2시쯤 지역구 당선자 윤곽 전망</div>,
#  <div class="cjs_t">박민영 시세 110억 건물 소유…6년새 '40억' 가치 불린 비결은</div>,
#  <div class="cjs_t">파열 위험 높은 ‘취약성 동맥경화’, 스텐트 시술로 예방 가능</div>,
#  <div class="cjs_t">‘편의점 숏컷 폭행’ 가해자, 1심 징역 3년…재판부 "심신미약 인정돼"</div>,
#  <div class="cjs_t">[4·10 총선] 오전 10시 투표율 10.4%…지난 총선보다 1.0%p↓</div>,
#  <div class="cjs_t">"5만원이면 고치는데, 140만원 주고 새 폰 사야 될까요?"</div>,
#  <div class="cjs_t">JTBC 매출 17% 급감… 주요 언론사들, 광고 불황에 경영 악화</div>,
#  <div class="cjs_t">2학년 6반 권순범 학생 누나 김소리씨 [세월호 10년, 100명의 기억-95]</div>,
#  <div class="cjs_t">투표 하고 꽃길 걷자···지역별 봄꽃 명소</div>,
#  <div class="cjs_t">[독자제보명산 태화산] 용인 최고봉과 광주 최고봉이 맞붙었다</div>,
#  <div class="cjs_t">알리·테무 제품에서 발암물질 나오자…"한국인 죽이려고 그러냐"</div>,
#  <div class="cjs_t">[현장] 22대 총선 본투표…내 손으로 만드는 미래</div>,
#  <div class="cjs_t">주차장 된 유럽 항구…中 전기차 재고 '산더미'</div>,
#  <div class="cjs_t">尹이 휠체어 밀었던 美 참전용사 별세…"한국과 연대해 자랑스럽다"</div>,
#  <div class="cjs_t">“낯익은 ‘얼굴’, 실물보다 낫다?” 요즘 20대 빠지더니…일냈다</div>,
#  <div class="cjs_t">시골 마늘밭서 '110억' 와르르…전국 뒤집은 뭉칫돈 정체[뉴스속오늘]</div>,
#  <div class="cjs_t">경기 일산서 만취운전 SUV, 주점 돌진…13명 중경상</div>,
#  <div class="cjs_t">성폭력 피해자가 용서를 이야기할 때</div>,
#  <div class="cjs_t">금값 랠리 속 코스트코 골드바 인기 폭발…"월간 매출 최대 2억달러"</div>,
#  <div class="cjs_t">野 "한 표가 尹정권 심판" vs 與 "한 표로 지켜달라"</div>,
#  <div class="cjs_t">편의점 근무 첫날 970만 원 빼돌린 알바생 구속</div>,
#  <div class="cjs_t">"지적보단 지지를…응원 부족도 스트레스 유발"</div>,
#  <div class="cjs_t">[단독] ‘56조 세수펑크’ 결산 총선 뒤 미루기…한달 전부터 검토 정황</div>,
#  <div class="cjs_t">김건희 여사, 지난 5일 총선 사전투표</div>,
#  <div class="cjs_t">전쟁 같던 최악의 총선, 어느쪽 이기든 끝없는 전쟁 이어진다[박해성의 여의대교]</div>,
#  <div class="cjs_t">보수에 찍힌 YTN 간판프로 끝내 '결방', 담당앵커는 타 부서로</div>,
#  <div class="cjs_t">'하나·우리 싸움인줄 알았는데' 신한은행 기업대출 조용히 가속페달</div>,
#  <div class="cjs_t">김건희 여사 '조용한 투표'에 조국 "패션 자랑하던 분…뭐가 부끄럽나"</div>,
#  <div class="cjs_t">“의료 대란 수습에 5000억원 증발…국민이 의사 봉인가”</div>,
#  <div class="cjs_t">금배지 300개 누가 달까...총선 관전 포인트는?</div>,
#  <div class="cjs_t">해발 1,381m 가리왕산 장애인도 거뜬히 오른다</div>,
#  <div class="cjs_t">이명박 전 대통령, 자택 인근서 투표 "한국 정치가 한국 전체 수준에 안 맞아"</div>,
#  <div class="cjs_t">‘신의 입자’ 예측한 물리학자 피터 힉스 별세</div>,
#  <div class="cjs_t">22대 총선 투표율 10시 기준 10.4%…21대 총선보다 1%p 낮아</div>,
#  <div class="cjs_t">이마트, 명이‧장어 등 원기회복 신선식품 최대 50% 할인</div>,
#  <div class="cjs_t">‘출근 전 투표’부터 19개월 아이와 함께…“국민으로서 권리 행사” [투표현장]</div>,
#  <div class="cjs_t">"우리 아이도 저렇게 컸으면"…운전자 향해 배꼽인사 한 어린이</div>,
#  <div class="cjs_t">“건물주 아닌 연예인이 없네”...박민영 100억대 빌딩 소유, 시세 차익 ‘60억’</div>,
#  <div class="cjs_t">2002년 푸틴 2024년 푸틴 '비극의 오버랩' [전쟁과 문학]</div>,
#  <div class="cjs_t">총선 전날 병원 방문한 尹…“고생 많으십니다” [포착]</div>,
#  <div class="cjs_t">비정한 엄마…美서 달리는 차 밖으로 밀어낸 8개월 아기 숨져</div>,
#  <div class="cjs_t">[Election 2024] 5 races to watch</div>,
#  <div class="cjs_t">투표 포기는 ‘나’ 아닌 ‘남’ 결정대로 사는 것</div>,
#  <div class="cjs_t">투표 마친 이명박 "정치가 한국 수준에 안 맞아"</div>,
#  <div class="cjs_t">하남에 58만명 우르르…다음 로또 줍줍은 과천?</div>,
#  <div class="cjs_t">[선택 2024] 현장연결-대구 투표율 7.5% 경북 7.7% 전국 평균보다 높아···오전 9시 현재</div>,
#  <div class="cjs_t">부산 서구청 차량 돌진 사고…경찰 "급발진 아닌 과실" 결론</div>,
#  <div class="cjs_t">황석영 소설 ‘철도원 삼대’, 부커상 최종후보 올라</div>,
#  <div class="cjs_t">유세현장 기자도 "한동훈이 이상하다"…결국 일정 취소</div>,
#  <div class="cjs_t">조국 "YTN, 조국혁신당이 10번? 분노하지 않을 수 없다"</div>,
#  <div class="cjs_t">'마지막 비상요청' 한동훈 "젖먹던 힘까지 투표 독려에 매진해달라"[2024 총선]</div>,
#  <div class="cjs_t">‘새벽 3시반 기상, 14시간 근무’... 사전투표업무 공무원 숨져</div>,
#  <div class="cjs_t">“대파 들고 가면 안 됩니다”…오늘 ‘총선’ 투표, 주의할 물건은?</div>,
#  <div class="cjs_t">신문·방송 업계, 끝나지 않는 빙하기 찾아왔다</div>,
#  <div class="cjs_t">AI로 만든 60년 전의 나문희…긴 생머리에 댄스까지</div>,
#  <div class="cjs_t">서른 넘어 처음 만난 쌍둥이 자매…직업도 아들 이름도 같아</div>,
#  <div class="cjs_t">[현장에서] 다양성 '최악' 앞둔 22대 국회... 국회의원은 '능력'만 있으면 된다?</div>,
#  <div class="cjs_t">"눈매 달라졌다" 장영란, 25년만에 성형...뭐 했길래?</div>]

# %%
for title in news_title : 
    print(title.text)
# Out:
# 어떻게 알았을까…청도 미라, 165cm 키가 큰 1580년생 조선 남성
# “내 한표로 결과 뒤집힐 수도”…이른 아침 권리 행사 나선 시민들
# 이명박 “정치가 수준 안 맞아”…권양숙 “투표 많이 참여하길”
# 무신사 1조 매출 눈앞...에이블리·카카오스타일 '수익개선' 증명
# 제22대 총선 본 투표 시작..이 시각 투표소
# 한동훈 “이재명 친위대로 채워진 民 200석, 셀프사면할 것”
# 총선 투표율 오전 10시 기준 10.4%…지난 총선보다 1%p↓
# 사우디가 돈이 부족하다고? 네옴시티 야망이 주춤한 이유[딥다이브]
# 둘 다 성병이라는데… HPV와 HSV는 어떻게 다를까?
# 보수에 찍힌 YTN 간판프로 끝내 '결방', 담당앵커는 타 부서로
# '하나·우리 싸움인줄 알았는데' 신한은행 기업대출 조용히 가속페달
# 김건희 여사 '조용한 투표'에 조국 "패션 자랑하던 분…뭐가 부끄럽나"
# “의료 대란 수습에 5000억원 증발…국민이 의사 봉인가”
# 금배지 300개 누가 달까...총선 관전 포인트는?
# 해발 1,381m 가리왕산 장애인도 거뜬히 오른다
# 이명박 전 대통령, 자택 인근서 투표 "한국 정치가 한국 전체 수준에 안 맞아"
# ‘신의 입자’ 예측한 물리학자 피터 힉스 별세
# 22대 총선 투표율 10시 기준 10.4%…21대 총선보다 1%p 낮아
# 이마트, 명이‧장어 등 원기회복 신선식품 최대 50% 할인
# ‘출근 전 투표’부터 19개월 아이와 함께…“국민으로서 권리 행사” [투표현장]
# "우리 아이도 저렇게 컸으면"…운전자 향해 배꼽인사 한 어린이
# “건물주 아닌 연예인이 없네”...박민영 100억대 빌딩 소유, 시세 차익 ‘60억’
# 2002년 푸틴 2024년 푸틴 '비극의 오버랩' [전쟁과 문학]
# 총선 전날 병원 방문한 尹…“고생 많으십니다” [포착]
# 비정한 엄마…美서 달리는 차 밖으로 밀어낸 8개월 아기 숨져
# [Election 2024] 5 races to watch
# 투표 포기는 ‘나’ 아닌 ‘남’ 결정대로 사는 것
# 투표 마친 이명박 "정치가 한국 수준에 안 맞아"
# 하남에 58만명 우르르…다음 로또 줍줍은 과천?
# [선택 2024] 현장연결-대구 투표율 7.5% 경북 7.7% 전국 평균보다 높아···오전 9시 현재
# 부산 서구청 차량 돌진 사고…경찰 "급발진 아닌 과실" 결론
# 황석영 소설 ‘철도원 삼대’, 부커상 최종후보 올라
# 유세현장 기자도 "한동훈이 이상하다"…결국 일정 취소
# 조국 "YTN, 조국혁신당이 10번? 분노하지 않을 수 없다"
# '마지막 비상요청' 한동훈 "젖먹던 힘까지 투표 독려에 매진해달라"[2024 총선]
# ‘새벽 3시반 기상, 14시간 근무’... 사전투표업무 공무원 숨져
# “대파 들고 가면 안 됩니다”…오늘 ‘총선’ 투표, 주의할 물건은?
# 신문·방송 업계, 끝나지 않는 빙하기 찾아왔다
# AI로 만든 60년 전의 나문희…긴 생머리에 댄스까지
# 서른 넘어 처음 만난 쌍둥이 자매…직업도 아들 이름도 같아
# [현장에서] 다양성 '최악' 앞둔 22대 국회... 국회의원은 '능력'만 있으면 된다?
# "눈매 달라졌다" 장영란, 25년만에 성형...뭐 했길래?

# %%
news_dec = bs_obj.findAll('p',{'class':'cjs_d'})

# %%
len(news_dec)
# Out:
# 82

# %%
for dec in news_dec : 
    print(dec.text)
# Out:
# 10년 전 경북 청도군에서 발견된 미라의 주인공이 382년 전 숨진 남성으로 기생충에 감염됐다는 사실이 밝혀졌다. 10일 연합뉴스에 따르면 2014년 10월 경북 청도군. 고성이씨 문중의 한 무덤을 옮기는 과정에서
# 10일 오전 6시 전국 1만4259개 투표소 투표 시작 이른 시각부터 권리 행사 위한 시민 발길 이어져 51.7㎝ 역대 최장 투표 용지…“제대로 찍었나 확인” 아파트 단지·주차장·웨딩홀 등 이색 투표소도 눈길 10일
# 신문·방송업계 호황은 끝났다. 2023년 코로나19가 종식되면서 신문·방송업계에 위기가 찾아왔다. KBS의 영업손실은 644억 원에 달했으며, SBS의 '1조 원 매출'이 무너졌다. 신문사들의 매출도 줄었다. 업계
# 인공지능(AI)으로 배우 나문희(82)씨의 20대 시절 모습이 재현됐다. AI 엔터테인먼트 기술 기업 엠씨에이(MCA)는 한국마사회와 협업으로 ‘AI 나문희’와 함께하는 브랜디드 콘텐츠를 선보였다고 9일 밝혔다. 나
# 서른 살이 넘어 처음 만난 일란성 쌍둥이 자매가 화제를 모으고 있다. 어릴 때 각각 다른 가정에 입양돼 자랐지만 얼굴이 비슷한 것은 물론, 아들 이름과 직업까지 같았다. 네티즌들은 "서로를 찾게 된 것은 행운" "오
# 국회의원의 '능력'이 뭔데? "청년인 게 벼슬인가? 능력도 없는데 청년이라고 공천을 줘야 하나?" 기자가 지난 2월 보도한 <총선 기획 3부작 - 청년 편>에 달린 댓글 중 하나다. 찾아보니 이런 종류의 댓글이 적지
# 방송인 장영란이 눈 성형을 통해 달라진 모습을 공개했다. 8일 유튜브 채널 'A급 장영란'에는 '연예인 최초! 성형 과정 공개한 장영란(수술 이유, 14일 경과)'라는 제목의 영상이 올라왔다. 영상에서 장영란은 "수

# %% [markdown]
# ### 네이버 뉴스섹션메뉴와 섹션별 url 추출

# %%
from urllib.request import urlopen
import bs4
import pandas as pd

# %%
url = 'https://news.naver.com'

html = urlopen(url)

bs_obj = bs4.BeautifulSoup(html, 'html.parser')

# %%
# 네이버 뉴스 섹션메뉴 태그 확인(개발자도구)
# body > section > header > div.Nlnb._float_lnb > div > div > div.Nlnb_left._lnb_scroll > div > div > ul
# selector가 너무 길어서 유용하지 않아 보임
# 직접 확인한 태그와 클래스 속성 사용
# ul 태그의 class : Nlnb_menu_list
uls = bs_obj.findAll("ul",{"class":"Nlnb_menu_list"})
len(uls) # 원소가 1개이므로
ul = bs_obj.find("ul",{"class":"Nlnb_menu_list"})
ul
# Out:
# <ul class="Nlnb_menu_list" role="menu">
# <li class="Nlist_item is_active"><a aria-selected="true" class="Nitem_link" href="https://news.naver.com/?viewType=pc" onclick="nclk(event,'lnb.pcmedia','','');" role="menuitem"><span class="Nitem_link_menu">언론사별</span></a></li>
# <li class="Nlist_item"><a aria-selected="false" class="Nitem_link" href="https://news.naver.com/section/100" onclick="nclk(event,'lnb.pol','','');" role="menuitem"><span class="Nitem_link_menu">정치</span></a></li>
# <li class="Nlist_item"><a aria-selected="false" class="Nitem_link" href="https://news.naver.com/section/101" onclick="nclk(event,'lnb.eco','','');" role="menuitem"><span class="Nitem_link_menu">경제</span></a></li>
# <li class="Nlist_item"><a aria-selected="false" class="Nitem_link" href="https://news.naver.com/section/102" onclick="nclk(event,'lnb.soc','','');" role="menuitem"><span class="Nitem_link_menu">사회</span></a></li>
# <li class="Nlist_item"><a aria-selected="false" class="Nitem_link" href="https://news.naver.com/section/103" onclick="nclk(event,'lnb.lif','','');" role="menuitem"><span class="Nitem_link_menu">생활/문화</span></a></li>
# <li class="Nlist_item"><a aria-selected="false" class="Nitem_link" href="https://news.naver.com/section/105" onclick="nclk(event,'lnb.sci','','');" role="menuitem"><span class="Nitem_link_menu">IT/과학</span></a></li>
# <li class="Nlist_item"><a aria-selected="false" class="Nitem_link" href="https://news.naver.com/section/104" onclick="nclk(event,'lnb.wor','','');" role="menuitem"><span class="Nitem_link_menu">세계</span></a></li>
# <li class="Nlist_item _isNew"><a aria-selected="false" class="Nitem_link" href="https://news.naver.com/main/ranking/popularDay.naver" onclick="nclk(event,'lnb.rank','','');" role="menuitem"><span class="Nitem_link_menu">랭킹</span></a></li>
# <li class="Nlist_item _isNew"><a aria-selected="false" class="Nitem_link" href="https://news.naver.com/newspaper/home?viewType=pc" onclick="nclk(event,'lnb.paper','','');" role="menuitem"><span class="Nitem_link_menu">신문보기</span></a></li>
# <li class="Nlist_item"><a aria-selected="false" class="Nitem_link" href="https://news.naver.com/opinion/home" onclick="nclk(event,'lnb.opi','','');" role="menuitem"><span class="Nitem_link_menu">오피니언</span></a></li>
# <li class="Nlist_item"><a aria-selected="false" class="Nitem_link" href="https://news.naver.com/main/tv/index.naver?mid=tvh" onclick="nclk(event,'lnb.tv','','');" role="menuitem"><span class="Nitem_link_menu">TV</span></a></li>
# <li class="Nlist_item"><a aria-selected="false" class="Nitem_link" href="https://news.naver.com/factcheck/main" onclick="nclk(event,'lnb.fact','','');" role="menuitem"><span class="Nitem_link_menu">팩트체크</span></a></li>
# <li class="Nlist_item"><a aria-selected="false" class="Nitem_link" href="https://media.naver.com/algorithm" onclick="nclk(event,'lnb.algo','','');" role="menuitem"><span class="Nitem_link_menu">알고리즘 안내</span></a></li>
# <li class="Nlist_item _isNew"><a aria-selected="false" class="Nitem_link" href="https://news.naver.com/main/ombudsman/errorArticleList.naver?mid=omb" onclick="nclk(event,'lnb.correct','','');" role="menuitem"><span class="Nitem_link_menu">정정보도 모음</span></a></li>
# </ul>

# %%
lis = ul.findAll('li')
len(lis)
# Out:
# 14

# %%
for li in lis :
    a_tag = li.find('a')
    print(a_tag.text," : ",a_tag['href'])
# Out:
# 언론사별  :  https://news.naver.com/?viewType=pc
# 정치  :  https://news.naver.com/section/100
# 경제  :  https://news.naver.com/section/101
# 사회  :  https://news.naver.com/section/102
# 생활/문화  :  https://news.naver.com/section/103
# IT/과학  :  https://news.naver.com/section/105
# 세계  :  https://news.naver.com/section/104
# 랭킹  :  https://news.naver.com/main/ranking/popularDay.naver
# 신문보기  :  https://news.naver.com/newspaper/home?viewType=pc
# 오피니언  :  https://news.naver.com/opinion/home
# TV  :  https://news.naver.com/main/tv/index.naver?mid=tvh
# 팩트체크  :  https://news.naver.com/factcheck/main
# 알고리즘 안내  :  https://media.naver.com/algorithm
# 정정보도 모음  :  https://news.naver.com/main/ombudsman/errorArticleList.naver?mid=omb

# %%
# li태그를 이용해서 추출
lis = bs_obj.findAll("li",{"class" : "Nlist_item"})
len(lis)
# Out:
# 14

# %%
for li in lis :
    a_tag = li.find('a')
    print(a_tag.text)
    print(a_tag['href'])
# Out:
# 언론사별
# https://news.naver.com/?viewType=pc
# 정치
# https://news.naver.com/section/100
# 경제
# https://news.naver.com/section/101
# 사회
# https://news.naver.com/section/102
# 생활/문화
# https://news.naver.com/section/103
# IT/과학
# https://news.naver.com/section/105
# 세계
# https://news.naver.com/section/104
# 랭킹
# https://news.naver.com/main/ranking/popularDay.naver
# 신문보기
# https://news.naver.com/newspaper/home?viewType=pc
# 오피니언
# https://news.naver.com/opinion/home
# TV
# https://news.naver.com/main/tv/index.naver?mid=tvh
# 팩트체크
# https://news.naver.com/factcheck/main
# 알고리즘 안내
# https://media.naver.com/algorithm
# 정정보도 모음
# https://news.naver.com/main/ombudsman/errorArticleList.naver?mid=omb

# %%
# 수집 데이터 df로 구성 후 저장
section = []
link = []

# %%
for li in lis :
    a_tag = li.find('a')
    section.append(a_tag.text)
    link.append(a_tag['href'])

# %%
col_dict = {'section':section, "link":link}
news_section_df = pd.DataFrame(col_dict)
news_section_df
# Out:
#     section                                               link
# 0      언론사별                https://news.naver.com/?viewType=pc
# 1        정치                 https://news.naver.com/section/100
# 2        경제                 https://news.naver.com/section/101
# 3        사회                 https://news.naver.com/section/102
# 4     생활/문화                 https://news.naver.com/section/103
# 5     IT/과학                 https://news.naver.com/section/105
# 6        세계                 https://news.naver.com/section/104
# 7        랭킹  https://news.naver.com/main/ranking/popularDay...
# 8      신문보기  https://news.naver.com/newspaper/home?viewType=pc
# 9      오피니언                https://news.naver.com/opinion/home
# 10       TV  https://news.naver.com/main/tv/index.naver?mid...
# 11     팩트체크              https://news.naver.com/factcheck/main
# 12  알고리즘 안내                  https://media.naver.com/algorithm
# 13  정정보도 모음  https://news.naver.com/main/ombudsman/errorArt...

# %%
# news_section_df.to_csv('./navew_news_section.csv', encoding='euc-kr')
news_section_df.to_csv('c:\\Myexam\\navew_news_section.csv', encoding='euc-kr')
