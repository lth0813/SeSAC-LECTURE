# %% [markdown]
# ## 2.1.1 유튜브 랭킹 데이터 수집하기

# %%
# 라이브러리 추가하기
from selenium import webdriver 
from bs4 import BeautifulSoup 
import time
import pandas as pd

# %%
from selenium.webdriver.chrome.service import Service as ChromeService
from webdriver_manager.chrome import ChromeDriverManager

# %%
# webdriver로 크롬 브라우저 실행하기
## browser = webdriver.Chrome('C:/Myexam/chromedriver/chromedriver.exe')

driver = webdriver.Chrome(service=ChromeService(ChromeDriverManager().install()))
url = "https://youtube-rank.com/board/bbs/board.php?bo_table=youtube" 
driver.get(url)

# %%
# 페이지 정보 가져오기
html = driver.page_source
soup = BeautifulSoup(html, 'html.parser')

# %%
# BeautifulSoup으로 tr 태그 추출하기
channel_list = soup.select('tr') 
print(len(channel_list), '\n')
print(channel_list[0])
# Out:
# 102
#
# <tr>
# <th class="rank"><a href="/board/bbs/board.php?bo_table=youtube&amp;sop=and&amp;sst=rank&amp;sod=desc&amp;sfl=&amp;stx=&amp;sca=&amp;page=1">순위 <i aria-hidden="true" class="fa fa-sort"></i></a></th>
# <th class="td_img">이미지</th>
# <th class="subject">제목</th>
# <th class="subscriber_cnt"><a href="/board/bbs/board.php?bo_table=youtube&amp;sop=and&amp;sst=subscriber_cnt&amp;sod=desc&amp;sfl=&amp;stx=&amp;sca=&amp;page=1">구독자순 <i aria-hidden="true" class="fa fa-sort"></i></a></th>
# <th class="view_cnt"><a href="/board/bbs/board.php?bo_table=youtube&amp;sop=and&amp;sst=view_cnt&amp;sod=desc&amp;sfl=&amp;stx=&amp;sca=&amp;page=1">View순 <i aria-hidden="true" class="fa fa-sort"></i></a></th>
# <th class="video_cnt"><a href="/board/bbs/board.php?bo_table=youtube&amp;sop=and&amp;sst=video_cnt&amp;sod=desc&amp;sfl=&amp;stx=&amp;sca=&amp;page=1">Video순 <i aria-hidden="true" class="fa fa-sort"></i></a></th>
# <th class="hit"><a href="/board/bbs/board.php?bo_table=youtube&amp;sop=and&amp;sst=wr_hit&amp;sod=desc&amp;sfl=&amp;stx=&amp;sca=&amp;page=1">조회수 <i aria-hidden="true" class="fa fa-sort"></i></a></th>
# </tr>

# %%
# tr 태그 확인하기
channel_list = soup.select('form > table > tbody > tr')
print(len(channel_list))
# Out:
# 100

# %%
# 채널태그출력및태그구조 확인하기
channel = channel_list[0]
print(channel)
# Out:
# <tr class="aos-init aos-animate" data-aos="fade-up" data-aos-duration="800">
# <td class="rank">
#                         1                    </td>
# <td class="td_img">
# <div class="info_img"><a href="https://youtube-rank.com/board/bbs/board.php?bo_table=youtube&amp;wr_id=3203"><img class="lazyload" data-src="https://yt3.ggpht.com/hZDUwjoeQqigphL4A1tkg9c6hVp5yXmbboBR7PYFUSFj5PIJSA483NB5v7b0XVoTN9GCku3tqQ=s88-c-k-c0x00ffffff-no-nd-rj" height="88" src="https://yt3.ggpht.com/hZDUwjoeQqigphL4A1tkg9c6hVp5yXmbboBR7PYFUSFj5PIJSA483NB5v7b0XVoTN9GCku3tqQ=s88-c-k-c0x00ffffff-no-nd-rj" width="88"/></a></div>
# <p class="info_rank">1</p>
# </td>
# <td class="subject">
# <h1>
# <p <a="" class="category" href="https://youtube-rank.com/board/bbs/board.php?bo_table=youtube&amp;sca=%EC%9D%8C%EC%95%85%2F%EB%8C%84%EC%8A%A4%2F%EA%B0%80%EC%88%98">[음악/댄스/가수]
#
#                                 </p>
# <a href="https://youtube-rank.com/board/bbs/board.php?bo_table=youtube&amp;wr_id=3203">
#
# 								BLACKPINK							</a>
# <span>
# <i class="fa fa-comment"></i>
# 								1							</span>
# <i aria-hidden="true" class="fa fa-heart"></i> </h1>
# <h2><span><a href="https://youtube-rank.com/board/bbs/board.php?bo_table=youtube&amp;wr_id=3203">"YG Entertainment" YG 와이지 K-pop BLACKPINK 블랙핑크 블핑 제니 로제 리사 지수 Lisa Jisoo Jennie ...</a></span></h2>
# <h3>
# <i class="fa fa-user"></i>
#                             9210만<i class="fa fa-play"></i>339억0466만                            <i class="fa fa-video-camera"></i>
#                             586                            <i class="fa fa-eye"></i>
#                             31,895                        </h3>
# </td>
# <td class="subscriber_cnt">9210만</td>
# <td class="view_cnt">339억0466만</td>
# <td class="video_cnt">586개</td>
# <td class="hit">
# <strong>31,895</strong>
# <span>HIT</span>
# </td>
# </tr>

# %%
#  카테고리 정보 추출하기
category = channel.select('p.category')[0].text.strip()
print(category)
# Out:
# [음악/댄스/가수]

# %%
#  채널명 찾아오기
title = channel.select('h1 > a')[0].text.strip()
print(title)
# Out:
# BLACKPINK

# %%
#  구독자 수, View 수, 동영상 수 추출하기
subscriber = channel.select('.subscriber_cnt')[0].text
view = channel.select('.view_cnt')[0].text
video = channel.select('.video_cnt')[0].text

print(subscriber)
print(view)
print(video)
# Out:
# 9210만
# 339억0466만
# 586개

# %%
# 반복문으로 채널 정보 추출하기
channel_list = soup.select('tbody > tr') 
for channel in channel_list:
    title = channel.select('h1 > a')[0].text.strip()
    category = channel.select('p.category')[0].text.strip()
    subscriber = channel.select('.subscriber_cnt')[0].text
    view = channel.select('.view_cnt')[0].text
    video = channel.select('.video_cnt')[0].text 
    print(title, category, subscriber, view, video)
# Out:
# BLACKPINK [음악/댄스/가수] 9210만 339억0466만 586개
# BANGTANTV [음악/댄스/가수] 7690만 217억9572만 2,394개
# HYBE LABELS [음악/댄스/가수] 7340만 311억8687만 1,555개
# DaFuq!?Boom! [미분류] 3530만 136억3232만 262개
# SMTOWN [음악/댄스/가수] 3220만 283억2598만 4,262개
# JYP Entertainment [음악/댄스/가수] 2830만 210억8414만 1,927개
# 김프로KIMPRO [BJ/인물/연예인] 2800만 288억9508만 2,186개
# Mark Rober [미분류] 2780만 43억4250만 129개
# Boram Tube Vlog [보람튜브 브이로그] [키즈/어린이] 2650만 110억5288만 223개
# 1MILLION Dance Studio [음악/댄스/가수] 2620만 80억4365만 6,400개
# Alan Becker [해외] 2520만 61억2361만 181개
# 1theK (원더케이) [음악/댄스/가수] 2470만 244억4192만 19,456개
# Mnet K-POP [음악/댄스/가수] 2070만 154억9747만 34,294개
# KBS WORLD TV [TV/방송] 1940만 156억2896만 66,987개
# officialpsy [음악/댄스/가수] 1840만 108억6473만 131개
# Jane ASMR 제인 [음식/요리/레시피] 1780만 74억0754만 2,013개
# JFlaMusic [음악/댄스/가수] 1750만 38억2416만 340개
# 승비니 Seungbini [BJ/인물/연예인] 1640만 121억8541만 397개
# TWICE [음악/댄스/가수] 1640만 54억8330만 1,269개
# GH'S [미분류] 1580만 116억8477만 655개
# Hongyu ASMR 홍유 [음식/요리/레시피] 1550만 53억4293만 682개
# BIGBANG [음악/댄스/가수] 1510만 80억3134만 776개
# Stray Kids [음악/댄스/가수] 1470만 40억4100만 960개
# 서은일상이야기 [키즈/어린이] 1450만 6억0181만 367개
# Boram Tube ToysReview [보람튜브 토이리뷰] [키즈/어린이] 1450만 50억3362만 631개
# BIBO와 장난감 [키즈/어린이] 1300만 32억4652만 197개
# CRAZY GREAPA [미분류] 1250만 103억5484만 902개
# [햄지]Hamzy [음식/요리/레시피] 1200만 42억0019만 734개
# TOMORROW X TOGETHER OFFICIAL [음악/댄스/가수] 1130만 17억6014만 1,823개
# 핑크퐁 (인기 동요・동화) [키즈/어린이] 1130만 72억9923만 3,382개
# 토이몽 TV - ToyMong Tv [키즈/어린이] 1100만 45억4967만 1,392개
# DuDuPopTOY [키즈/어린이] 1100만 49억6481만 2,137개
# Stone Music Entertainment [음악/댄스/가수] 1080만 98억1938만 10,804개
# MBCkpop [TV/방송] 1060만 93억4517만 48,130개
# 쏘영 Ssoyoung [음식/요리/레시피] 1040만 18억3536만 891개
# SEVENTEEN [음악/댄스/가수] 1040만 48억1550만 1,768개
# Larva TUBA [키즈/어린이] 1000만 45억8112만 2,189개
# EXO [음악/댄스/가수] 956만 10억8179만 479개
# M2 [TV/방송] 953만 87억9278만 21,646개
# Boram Tube [宝蓝和朋友们] [키즈/어린이] 942만 25억6199만 510개
# 문복희 Eat with Boki [음식/요리/레시피] 940만 27억1898만 787개
# 서은이야기[SeoeunStory] [키즈/어린이] 932만 18억4899만 1,222개
# Serie A [해외] 910만 36억9527만 26,829개
# Mnet TV [음악/댄스/가수] 909만 118억9111만 23,058개
# MBCentertainment [뉴스/정치/사회] 899만 172억3401만 100,592개
# tzuyang쯔양 [음식/요리/레시피] 896만 22억0797만 618개
# iKON [음악/댄스/가수] 878만 26억1978만 685개
# ENHYPEN [음악/댄스/가수] 877만 15억7723만 1,077개
# 이지금 [IU Official] [음악/댄스/가수] 874만 23억4316만 204개
# ITZY [음악/댄스/가수] 872만 24억5633만 1,272개
# KBS Kpop [TV/방송] 837만 80억5717만 42,703개
# The Beatles [미분류] 797만 64억1446만 298개
# 스브스케이팝 X INKIGAYO [TV/방송] 777만 63억1076만 34,446개
# JTBC Entertainment [뉴스/정치/사회] 773만 120억9282만 82,105개
# ONE Championship [미분류] 769만 48억1788만 10,349개
# YG ENTERTAINMENT [음악/댄스/가수] 764만 19억7202만 411개
# MariAndKids [키즈/어린이] 764만 22억5274만 699개
# 야미보이 Yummyboy [음식/요리/레시피] 754만 31억8616만 1,091개
# TREASURE (트레저) [음악/댄스/가수] 734만 24억3194만 984개
# SonicToy소닉토이 [키즈/어린이] 726만 31억6441만 170개
# NLE CHOPPA [해외] 725만 28억1954만 709개
# 미니특공대TV [키즈/어린이] 723만 40억6036만 1,486개
# (G)I-DLE (여자)아이들 (Official YouTube Channel) [음악/댄스/가수] 720만 37억4430만 807개
# 5 분 Tricks [음식/요리/레시피] 719만 30억5514만 4,917개
# Sungha Jung [음악/댄스/가수] 713만 19억7202만 1,403개
# MAMAMOO [음악/댄스/가수] 696만 24억6107만 858개
# ALL THE K-POP [음악/댄스/가수] 689만 46억6289만 29,034개
# SBS Entertainment [TV/방송] 688만 91억3529만 228,945개
# tvN drama [TV/방송] 678만 80억7098만 56,320개
# YouTube Originals [회사/오피셜] 675만 6억4836만 477개
# SBS Drama [TV/방송] 671만 75억8441만 347,223개
# [장난감티비]TOYTV [키즈/어린이] 665만 30억4914만 1,739개
# Rosesarerosie [음악/댄스/가수] 661만 9540만 12개
# With Kids Playground [위드키즈 놀이터] [키즈/어린이] 655만 23억8598만 546개
# NCT DREAM [음악/댄스/가수] 654만 15억3856만 693개
# Samsung [회사/오피셜] 652만 15억7471만 2,077개
# 미니팡TV [키즈/어린이] 624만 40억0816만 968개
# GOT7 [음악/댄스/가수] 624만 9억1634만 579개
# starshipTV [음악/댄스/가수] 618만 44억4344만 2,187개
# NCT [음악/댄스/가수] 616만 10억9154만 839개
# NewJeans [미분류] 614만 24억1476만 399개
# 백종원 PAIK JONG WON [음식/요리/레시피] 602만 10억4071만 588개
# PONY Syndrome [패션/미용] 596만 3억4543만 248개
# 채널십오야 [TV/방송] 594만 17억7832만 998개
# PinkyPopTOY [키즈/어린이] 578만 13억3688만 4,017개
# 영국남자 Korean Englishman [BJ/인물/연예인] 576만 21억1177만 589개
# 팀일루션 노성율 - TEAM1LLUSION [미분류] 574만 61억8822만 820개
# MayTree [미분류] 574만 12억9485만 247개
# 2NE1 [음악/댄스/가수] 568만 23억6405만 321개
# 소맥거핀 [게임] 556만 21억3986만 346개
# 스위트티비 SweetTV [키즈/어린이] 555만 28억8647만 436개
# 푸메Fume [음식/요리/레시피] 550만 12억6307만 749개
# TOY GUMA [키즈/어린이] 546만 18억1828만 396개
# NCT 127 [음악/댄스/가수] 544만 10억8674만 662개
# 베이비버스 -인기 동요・동화 [키즈/어린이] 543만 39억5456만 1,777개
# The Kid LAROI. [미분류] 541만 21억0807만 80개
# SBS NOW / SBS 공식 채널 [뉴스/정치/사회] 541만 61억7899만 26,128개
# Red Velvet [음악/댄스/가수] 538만 14억5535만 335개
# BT21 [음악/댄스/가수] 531만 5억0665만 438개
# KBS Entertain [TV/방송] 528만 95억0476만 122,392개
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[11], line 4
#       2 channel_list = soup.select('tbody > tr')
#       3 for channel in channel_list:
# ----> 4     title = channel.select('h1 > a')[0].text.strip()
#       5     category = channel.select('p.category')[0].text.strip()
#       6     subscriber = channel.select('.subscriber_cnt')[0].text
#
# IndexError: list index out of range

# %%
# 페이지별 URL 만들기
page = 1
url = 'https://youtube-rank.com/board/bbs/board.php?bo_table=youtube&page={}'.format(page)
print(url)
# Out:
# https://youtube-rank.com/board/bbs/board.php?bo_table=youtube&page=1

# %%
#  반복문으로 유튜브 랭킹 화면의 여러 페이지를 크롤링하기
results = []
for page in range(1,11):
    url = f"https://youtube-rank.com/board/bbs/board.php?bo_table=youtube&page={page}" 
    driver.get(url)
    time.sleep(2)
    html = driver.page_source
    soup = BeautifulSoup(html, 'html.parser')
    channel_list = soup.select('form > table > tbody > tr')
    for channel in channel_list:
        title = channel.select('h1 > a')[0].text.strip() 
        category = channel.select('p.category')[0].text.strip()
        subscriber = channel.select('.subscriber_cnt')[0].text 
        view = channel.select('.view_cnt')[0].text
        video = channel.select('.video_cnt')[0].text
        data = [title, category, subscriber, view, video]
        results.append(data)

# %%
# 데이터 칼럼명을 설정하고 엑셀 파일로 저장하기
df = pd.DataFrame(results)
df.columns = ['title', 'category', 'subscriber', 'view', 'video']
df.to_excel('youtube_rank.xlsx', index = False)

# %% [markdown]
# ## 2.1.2 유튜브 랭킹 데이터 시각화하기

# %%
# 라이브러리 추가하기
import pandas as pd
import matplotlib.pyplot as plt

# %%
# 그래프에서 한글을 표기하기 위한 글꼴 변경(윈도우, macOS에 대해 각각 처리)
from matplotlib import font_manager, rc
import platform
if platform.system() == 'Windows':
    path = 'c:/Windows/Fonts/malgun.ttf'
    font_name = font_manager.FontProperties(fname = path).get_name()
    rc('font', family = font_name)
elif platform.system() == 'Darwin':
    rc('font', family = 'AppleGothic')
else:
    print('Check your OS system')

# %%
# 엑셀 파일 불러오기
df = pd.read_excel('youtube_rank.xlsx')
df.head()
# Out:
#           title    category subscriber       view   video
# 0     BLACKPINK  [음악/댄스/가수]      9210만  339억0466만    586개
# 1     BANGTANTV  [음악/댄스/가수]      7690만  217억9572만  2,394개
# 2   HYBE LABELS  [음악/댄스/가수]      7340만  311억8687만  1,555개
# 3  DaFuq!?Boom!       [미분류]      3530만  136억3232만    262개
# 4        SMTOWN  [음악/댄스/가수]      3220만  283억2598만  4,262개

# %%
# 데이터 살펴보기
df.tail()
# Out:
#                title    category subscriber     view   video
# 995  areumsongee아름송이     [패션/미용]        80만    7988만    276개
# 996          가로세로연구소  [뉴스/정치/사회]        80만    3143만    504개
# 997        TOP MEDIA       [미분류]        79만  2억3341만    554개
# 998             핫챌린지     [TV/방송]        79만    5793만     70개
# 999           DKDKTV  [음악/댄스/가수]        79만  2억0924만  1,415개

# %%
# 데이터 살펴보기
df['subscriber'][0:10]
# Out:
# 0    9210만
# 1    7690만
# 2    7340만
# 3    3530만
# 4    3220만
# 5    2830만
# 6    2800만
# 7    2780만
# 8    2650만
# 9    2620만
# Name: subscriber, dtype: object

# %%
# 데이터 살펴보기
df['subscriber'].str.replace('만', '0000')[0:10]
# Out:
# 0    92100000
# 1    76900000
# 2    73400000
# 3    35300000
# 4    32200000
# 5    28300000
# 6    28000000
# 7    27800000
# 8    26500000
# 9    26200000
# Name: subscriber, dtype: object

# %%
# replaced_subscriber 시리즈 문자열 변경하기
df['replaced_subscriber'] = df['subscriber'].str.replace('만', '0000')
df.head()
# Out:
#           title    category subscriber       view   video replaced_subscriber
# 0     BLACKPINK  [음악/댄스/가수]      9210만  339억0466만    586개            92100000
# 1     BANGTANTV  [음악/댄스/가수]      7690만  217억9572만  2,394개            76900000
# 2   HYBE LABELS  [음악/댄스/가수]      7340만  311억8687만  1,555개            73400000
# 3  DaFuq!?Boom!       [미분류]      3530만  136억3232만    262개            35300000
# 4        SMTOWN  [음악/댄스/가수]      3220만  283억2598만  4,262개            32200000

# %%
# 데이터 상세 정보
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 6 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   title                1000 non-null   object
#  1   category             1000 non-null   object
#  2   subscriber           1000 non-null   object
#  3   view                 1000 non-null   object
#  4   video                1000 non-null   object
#  5   replaced_subscriber  1000 non-null   object
# dtypes: object(6)
# memory usage: 47.0+ KB

# %%
# Series 데이터 타입 변환하기
df['replaced_subscriber'] = df['replaced_subscriber'].astype('int')
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 6 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   title                1000 non-null   object
#  1   category             1000 non-null   object
#  2   subscriber           1000 non-null   object
#  3   view                 1000 non-null   object
#  4   video                1000 non-null   object
#  5   replaced_subscriber  1000 non-null   int32
# dtypes: int32(1), object(5)
# memory usage: 43.1+ KB

# %%
# 카테고리별 구독자 수, 채널 수 피봇 테이블 생성하기
pivot_df = df.pivot_table(index = 'category', values = 'replaced_subscriber', aggfunc = ['sum','count'])
pivot_df.head()
# Out:
#                             sum               count
#             replaced_subscriber replaced_subscriber
# category
# [BJ/인물/연예인]           150850000                  59
# [IT/기술/컴퓨터]            10630000                   7
# [TV/방송]               272370000                 114
# [게임]                   71360000                  49
# [교육/강의]                28110000                  18

# %%
# 데이터프레임의 칼럼명 변경하기
pivot_df.columns = ['subscriber_sum', 'category_count']
pivot_df.head()
# Out:
#              subscriber_sum  category_count
# category
# [BJ/인물/연예인]       150850000              59
# [IT/기술/컴퓨터]        10630000               7
# [TV/방송]           272370000             114
# [게임]               71360000              49
# [교육/강의]            28110000              18

# %%
# 데이터프레임의인덱스초기화하기
pivot_df = pivot_df.reset_index()
pivot_df.head()
# Out:
#       category  subscriber_sum  category_count
# 0  [BJ/인물/연예인]       150850000              59
# 1  [IT/기술/컴퓨터]        10630000               7
# 2      [TV/방송]       272370000             114
# 3         [게임]        71360000              49
# 4      [교육/강의]        28110000              18

# %%
# 데이터프레임을내림차순정렬하기
pivot_df = pivot_df.sort_values(by='subscriber_sum', ascending=False)
pivot_df.head()
# Out:
#        category  subscriber_sum  category_count
# 12   [음악/댄스/가수]       846040000             150
# 16     [키즈/어린이]       413110000             130
# 7         [미분류]       384420000             198
# 2       [TV/방송]       272370000             114
# 11  [음식/요리/레시피]       222260000              70

# %%
# 카테고리별구독자수시각화하기
plt.figure(figsize = (30,10))
plt.pie(pivot_df['subscriber_sum'], labels=pivot_df['category'], autopct='%1.1f%%')
plt.show()

# %%
# 카테고리별 채널 수 시각화하기
pivot_df = pivot_df.sort_values(by='category_count', ascending=False)
pivot_df.head()
plt.figure(figsize = (30,10))
plt.pie(pivot_df['category_count'], labels=pivot_df['category'], autopct='%1.1f%%')
plt.show()
