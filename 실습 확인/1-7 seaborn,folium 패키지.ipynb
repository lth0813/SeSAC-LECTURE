# %% [markdown]
# seaborn 패키지: 좀 더 편리한 시각화 도구
# - matplotlib의 기능에 스타일을 확장한 파이썬 시각화 도구
# - 패키지는 설치 해야 함(pip install seaborn) 단, 아나콘다 내부에는 이미 설치되어 있음
# - seaborn을 사용하기 위해서는 matplotlib가 import 되어 있어야 함.
# - 스타일 색상을 지원하기위해서 파렛트를 지원
# - 그래프는 대부분 matplotlib에 있는 그래프를 사용하고, seaborn이 몇개의 그래프를 더 가지고 있음

# %%
import pandas as pd
import numpy as np

# %%
import matplotlib.pyplot as plt #서브 패키지 pyplot 사용
# %matplotlib inline

# %%
# 경고 메시지 무시 설정
import warnings
warnings.filterwarnings(action='ignore')

# %%
# 한글 문제|
# matplotlit의 기본 폰트에서 한글 지원되지 않기 때문에
# matplotlib의 폰트 변경 필요
import platform

from matplotlib import font_manager, rc
plt.rcParams['axes.unicode_minus'] = False

if platform.system() == 'Darwin':  # 맥OS 
    rc('font', family='AppleGothic')
elif platform.system() == 'Windows':  # 윈도우
    path = "c:/Windows/Fonts/H2GTRM.TTF"
    font_name = font_manager.FontProperties(fname=path).get_name()
    rc('font', family=font_name)
else:
    print('Unknown system...  sorry~~~')

# %%
# 그래프 예제
x=np.linspace(1,14,100) #1부터 14까지의 범위에서 동일 간격의 숫자 100개 생성
x
# Out:
# array([ 1.        ,  1.13131313,  1.26262626,  1.39393939,  1.52525253,
#         1.65656566,  1.78787879,  1.91919192,  2.05050505,  2.18181818,
#         2.31313131,  2.44444444,  2.57575758,  2.70707071,  2.83838384,
#         2.96969697,  3.1010101 ,  3.23232323,  3.36363636,  3.49494949,
#         3.62626263,  3.75757576,  3.88888889,  4.02020202,  4.15151515,
#         4.28282828,  4.41414141,  4.54545455,  4.67676768,  4.80808081,
#         4.93939394,  5.07070707,  5.2020202 ,  5.33333333,  5.46464646,
#         5.5959596 ,  5.72727273,  5.85858586,  5.98989899,  6.12121212,
#         6.25252525,  6.38383838,  6.51515152,  6.64646465,  6.77777778,
#         6.90909091,  7.04040404,  7.17171717,  7.3030303 ,  7.43434343,
#         7.56565657,  7.6969697 ,  7.82828283,  7.95959596,  8.09090909,
#         8.22222222,  8.35353535,  8.48484848,  8.61616162,  8.74747475,
#         8.87878788,  9.01010101,  9.14141414,  9.27272727,  9.4040404 ,
#         9.53535354,  9.66666667,  9.7979798 ,  9.92929293, 10.06060606,
#        10.19191919, 10.32323232, 10.45454545, 10.58585859, 10.71717172,
#        10.84848485, 10.97979798, 11.11111111, 11.24242424, 11.37373737,
#        11.50505051, 11.63636364, 11.76767677, 11.8989899 , 12.03030303,
#        12.16161616, 12.29292929, 12.42424242, 12.55555556, 12.68686869,
#        12.81818182, 12.94949495, 13.08080808, 13.21212121, 13.34343434,
#        13.47474747, 13.60606061, 13.73737374, 13.86868687, 14.        ])

# %%
y1=np.sin(x)
y2=2*np.sin(x)
y3=3*np.sin(x)
y4=4*np.sin(x)

plt.figure(figsize=(10,6))
plt.plot(x,y1,x,y2,x,y3,x,y4)
plt.show()

# %%
import seaborn as sns #seaborn 패키지 임포트

# %% [markdown]
# #### seaborn 스타일링
#
# - set_style: background color, grid, spine, tick을 정의하여 그림의 전반적인 모양을 스타일링
# - set_context: 프리젠테이션이나 보고서와 같은 다양한 매체에 활용할 수 있도록 스타일링
#
#
# 1. set_style: 그림의 전반적인 모양 스타일링
#     - Built-in Themes (내장 테마) 활용하기
#
#         - Seaborn에는 5가지 기본 제공 테마가 있음
#         - darkgrid, whitegrid, dark, white, ticks.
#         - 기본값은 darkgrid이지만, 원하는대로 변경이 가능
# 2. sns.despine() 함수
#     - 축선 표시 여부 결정하는 함수(right=T/F,left=T/F,top=T/F,bottom=T/F)
#         - 각 속성값이
#         - True 면 : 표시하지 않는다.
#         - False 면: 표시함
# 3. sns.set_context() 함수
#     - 전체 스케일 조정
#     - paper, notebook, talk, poster. 여기서 기본값은 notebook이다.
#     - 스케일로도 전반적인 사이즈를 조정할 수 있지만 실제 폰트 크기를 조정하는 파라미터는 별도로 있음
#
#     - sns.set_context() 안에 font_scale 사용

# %%
#seaborn이용한 style 설정

x=np.linspace(1,14,100)
y1=np.sin(x)
y2=2*np.sin(x)
y3=3*np.sin(x)
y4=4*np.sin(x)

sns.set_style('whitegrid')
plt.figure(figsize=(10,6))
plt.plot(x,y1,x,y2,x,y3,x,y4)
plt.show()

# %%
#seaborn이용한 style 설정

x=np.linspace(1,14,100)
y1=np.sin(x)
y2=2*np.sin(x)
y3=3*np.sin(x)
y4=4*np.sin(x)

sns.set_style('dark') # 배경 회색
plt.figure(figsize=(10,6))
plt.plot(x,y1,x,y2,x,y3,x,y4)
plt.show()

# %%
#sns.despin() 함수
#축선 표시 여부 결정하는 함수(right=T/F,left=T/F,top=T/F,bottom=T/F)
#각 속성값이 True 면 : 표시하지 않는다.
#            False 면: 표시함
x=np.linspace(1,14,100)
y1=np.sin(x)
y2=2*np.sin(x)
y3=3*np.sin(x)
y4=4*np.sin(x)

sns.set_style('whitegrid')
plt.figure(figsize=(10,6))
plt.plot(x,y1,x,y2,x,y3,x,y4)
# sns.despine(right=True, left=True, top= False, bottom=False)
sns.despine(right=False, left=False) # top = True bottom=False 기본 속성 값
plt.show()

# %%
#seaborn이용한 style 설정

x=np.linspace(1,14,100)
y1=np.sin(x)
y2=2*np.sin(x)
y3=3*np.sin(x)
y4=4*np.sin(x)

sns.set_context('talk') # paper, notebook, talk, poster.
# plt.figure(figsize=(10,6))
plt.plot(x,y1,x,y2,x,y3,x,y4)
plt.show()

# %%
#seaborn이용한 style 설정

x=np.linspace(1,14,100)
y1=np.sin(x)
y2=2*np.sin(x)
y3=3*np.sin(x)
y4=4*np.sin(x)

sns.set_context('talk',font_scale=.5) # paper, notebook, talk, poster.
plt.figure(figsize=(10,6))
plt.plot(x,y1,x,y2,x,y3,x,y4)
plt.show()

# %%
sns.set_context('notebook')

# %% [markdown]
# # sns 의 기본 데이터 셋 : tips 활용
# - 요일별 점심 저녁 식사 금액과 팁을 정리한 데이터 셋
# - 성별, 흡연여부가 구별되어 있음
# - 패키지명.load_dataset(데이터셋명)

# %%
tips = sns.load_dataset('tips')
tips.head(5)
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %% [markdown]
# ###  Distribution Plot
# - Distribution Plot은 데이터의 분포를 시각화하는데 도움이 됨
# - 이 그래프를 사용하여 데이터의 평균(mean), 중위수(median), 범위(range), 분산(variance), 편차(deviation) 등을 이해 할 수 있음

# %% [markdown]
# 1. Hist Plot
# - 변수에 대한 히스토그램을 표시한다.
# - 하나 혹은 두 개의 변수 분포를 나타내는 전형적인 시각화 도구로 범위에 포함되는 관측수를 세어 표시한다.

# %%
sns.histplot(x=tips['total_bill'])
# Out:
# <AxesSubplot:xlabel='total_bill', ylabel='Count'>

# %% [markdown]
# 2. KDE Plot
# - 하나 혹은 두 개의 변수에 대한 분포를 그림
# - histplot은 절대량이라면 kdeplot은 밀도 추정치를 시각화
#     - 결과물로는 연속된 곡선의 그래프를 얻을 수 있음

# %%
sns.kdeplot(x=tips['total_bill'])
# Out:
# <AxesSubplot:xlabel='total_bill', ylabel='Density'>

# %% [markdown]
# 3. Box Plot
# - 최대(maximum), 최소(minimum), mean(평균), 1 사분위수(first quartile), 3 사분위수(third quartile)를 보기 위한 그래프
# - 특이치(outliar)를 발견하기에도 좋다.
# - 단일 연속형 변수에 대해 수치를 표시하거나, 연속형 변수를 기반으로 서로 다른 범주형 변수를 분석할 수 있다.

# %%
#tips 데이터를 이용한 box plot 그리기
#seaborn 패키지의 boxplot() 이용해서 그리기

sns.set_style('whitegrid')

plt.figure(figsize=(10,6))
sns.boxplot(x=tips['total_bill'])
sns.despine()
plt.show()

# %%
#tips 데이터를 이용한 box plot 그리기
#seaborn 패키지의 boxplot() 이용해서 그리기
#요일별 영수증 금액의 분포 확인

sns.set_style('whitegrid')

plt.figure(figsize=(10,6))

sns.boxplot(x=tips['day'], y=tips['total_bill'])
sns.despine(offset=10) # x,y축간의 간격을 설정하는 인수

plt.show()

# %%
#tips 데이터를 이용한 box plot 그리기
#seaborn 패키지의 boxplot() 이용해서 그리기
#요일별 영수증 금액의 분포 확인
#palette 인수 사용 예제 : palette = '파레트명'

sns.set_style('whitegrid')

plt.figure(figsize=(10,6))

# sns.boxplot(x=tips['day'], y=tips['total_bill'], palette='Set2')
sns.boxplot(x='day', y='total_bill',data=tips, palette='Set2')
sns.despine(offset=10) # x,y축간의 간격을 설정하는 인수

plt.show()

# %%
#hue 인수 : 카테고리값을 가지는 변수의 이름 지정하면
#카테고리에 따라 그룹을 만들어서 표시

plt.figure(figsize=(10,6))
sns.boxplot(x='day', y='tip', hue='smoker', data=tips, palette='Set3')
plt.show()

# %%
#hue 인수 : 카테고리값을 가지는 변수의 이름 지정하면
#카테고리에 따라 그룹을 만들어서 표시
#y값을 total_bill 필드로 변경 후 비교

plt.figure(figsize=(10,6))
sns.boxplot(x='day', y='total_bill', hue='sex',data=tips, palette='Set3')

plt.show()

# %%
#요일별 팁의 분포를 비교하는 box plot을 그리시오. 파레트 Set3
sns.boxplot(x='day', y='tip', data=tips, palette='Set3')
# Out:
# <AxesSubplot:xlabel='day', ylabel='tip'>

# %%
#요일별 팁의 분포를 비교하되 성별에 따라 분포를 
#나누어 표시하시오.파레트 세트 3
sns.boxplot(x='day', y='tip', hue='sex', data=tips, palette='Set3')
# Out:
# <AxesSubplot:xlabel='day', ylabel='tip'>

# %%
#위 그래프의 색상값을 파레트 husl 로 변경하시오.
sns.boxplot(x='day', y='tip', hue='sex', data=tips, palette='husl')
# Out:
# <AxesSubplot:xlabel='day', ylabel='tip'>

# %%
#요일별 영수증 금액의 분포를 비교하되 성별에 따라 분포를
#나누어 표시하시오. 파레트는 임의 사용
sns.boxplot(x='day',y='total_bill',hue='sex',data=tips,palette='Set3')
# Out:
# <AxesSubplot:xlabel='day', ylabel='total_bill'>

# %% [markdown]
# 4. Swarm Plot
# - 데이터 포인트 수와 함께 각 데이터의 분포도 제공한다.

# %%
#데이터가 모여 있는 정도를 보여주는 plot : seaborn.swarmplot()
plt.figure(figsize=(10,6))
sns.swarmplot(x='day', y='total_bill', data=tips, palette='husl')
plt.show()

# %%
#box plot과 swarmplot을 같이 사용하는 예제
plt.figure(figsize=(10,6))
sns.boxplot(x='day', y='total_bill', data=tips)
sns.swarmplot(x='day', y='total_bill', data=tips, palette='husl')
plt.show()

# %% [markdown]
# # seaborn.lmplot()
# - 스캐터그래프를 그릴때 회귀선을 기본으로 출력해주는 그래프 함수
# - size 인수 : 그래프 크기
#     - height 인수로 변경해서 사용하라는 메시지가 출력될 수 있음
# - hue 인수 : 카테고리 데이터를 분류하여 그룹화하되 하나의 그래프에 두개의 값을 모두 표현
# - col 인수 : 카테고리 데이터를 분류하여 그룹화하되 그룹의 개수만큼 그래프를 생성해서 표현한다.

# %%
#dataset : tips 사용
sns.set_style('darkgrid')
# plt.scatter(x=tips['total_bill'],y=tips['tip'])
sns.lmplot(x='total_bill',y='tip', data=tips, size=5)
plt.show()

# %%
#dataset : tips 사용
#회귀선 생략 코드 : 인수 :  fit_reg=False
sns.lmplot(x='total_bill',y='tip', data=tips, fit_reg=False, size=5)
plt.show()

# %%
#hue는 그룹을 만듬
sns.lmplot(x='total_bill',y='tip', hue='smoker', data=tips, size=5)
plt.show()

# %%
#영수증 금액과 팁의 관계성을 lmplot()으로 표현하되, 
#성별을 구분해서 표현하시오.
sns.set_style('darkgrid')
sns.lmplot(x='total_bill',y='tip', hue='sex', data=tips, size=5)
plt.show()

# %%
#영수증 금액과 팁의 관계성을 lmplot()으로 표현하되, 
#성별을 구분해서 표현하되 그래프를 각각 그리시오.
#hue 인수 : 카테고리 데이터를 분류하여 그룹화하되 하나의 
#그래프에 두개의 값을 모두 표현
#col 인수 : 카테고리 데이터를 분류하여 그룹화하되 그룹의  
#개수만큼 그래프를 생성해서 표현한다.
sns.lmplot(x='total_bill',y='tip', col='sex', data=tips, size=5)
plt.show()

# %%
#영수증 금액과 팁의 관계성을 lmplot()으로 표현하되, 
#성별을 구분해서 표현하되 그래프를 각각 그리시오.
#hue 인수 : 카테고리 데이터를 분류하여 그룹화하되 하나의 
#그래프에 두개의 값을 모두 표현
#col 인수 : 카테고리 데이터를 분류하여 그룹화하되 그룹의  
#개수만큼 그래프를 생성해서 표현한다.
sns.lmplot(x='total_bill',y='tip', col='smoker', data=tips, size=5)
plt.show()

# %% [markdown]
# ### heatmap 그래프
# - 히트맵 (heat map)
#     - 열분포도
#     - 2차원 수치 데이터를 색으로 표시
# - 두개의 카테고리 값에 대한 값 변화를 한 눈에 알기 쉬움
# - 대용량 데이터 시각화에도 사용성이 높음
#
# sns.heatmap<br>
# (heat, # 전처리한 데이터프레임 <br>
#             annot = True, # 숫자 표시 여부 <br>
#             ax = ax, # 히트맵을 그릴 격자 <br>
#             linewidths = 0.4, # 선의 굵기 <br>
#             linecolor = 'white', # 선의 색깔 <br>
#             fmt = '.1f', # 소수점 포맷팅 형태 <br>
#             cmap = 'YlOrRd') # colormap 형태

# %%
# heatmap 그래프 예제
#예제 데이터 생성
uniform_data = np.random.rand(10,12)
uniform_data
# Out:
# array([[7.57328167e-01, 8.06431309e-02, 9.97510764e-01, 3.35562349e-01,
#         1.80477243e-01, 4.76114785e-01, 5.61845106e-01, 8.84149896e-01,
#         2.59364235e-01, 7.52970081e-01, 3.39996942e-01, 5.38456588e-01],
#        [2.74203246e-01, 9.38953843e-01, 4.77730289e-01, 1.01447679e-01,
#         7.27229566e-01, 8.76508497e-01, 7.93759915e-01, 8.49229795e-02,
#         5.40744572e-01, 5.72576475e-01, 9.69143166e-01, 4.36651867e-01],
#        [6.61228468e-01, 8.03833324e-01, 2.22125945e-01, 8.87527608e-01,
#         1.40793924e-01, 3.50413321e-01, 5.83983145e-01, 2.87166318e-01,
#         6.41986825e-01, 2.64128187e-01, 2.25659222e-01, 3.72211334e-01],
#        [1.16734384e-01, 9.66981015e-01, 7.21125025e-01, 2.99988047e-01,
#         8.79846489e-02, 8.87021127e-01, 3.64036041e-01, 1.10708837e-04,
#         5.51191687e-01, 2.44627016e-01, 2.07173068e-01, 8.06565762e-02],
#        [6.46898189e-01, 5.54913213e-01, 4.55849802e-01, 1.75822547e-01,
#         3.03538961e-01, 5.86483014e-02, 9.96431775e-01, 9.50892102e-01,
#         6.82684241e-01, 1.47409070e-01, 7.10092598e-01, 2.60555214e-01],
#        [7.81257545e-01, 6.09069712e-01, 7.20685248e-01, 6.51243447e-01,
#         8.89855557e-01, 7.83888947e-01, 3.72517750e-01, 6.37264402e-01,
#         4.31705837e-01, 8.57391843e-01, 3.14124801e-01, 3.03277165e-01],
#        [9.47736571e-01, 1.49458506e-01, 4.74548805e-01, 1.54262655e-01,
#         3.83675154e-01, 3.43219265e-01, 1.23261376e-01, 1.50411847e-01,
#         2.54730288e-01, 7.91147911e-01, 4.15040849e-01, 6.87121744e-01],
#        [4.73085476e-01, 7.48739610e-01, 7.28212760e-01, 6.53157144e-01,
#         1.95475810e-01, 9.36545663e-01, 5.94846830e-01, 5.14327146e-01,
#         3.72160205e-01, 5.74115309e-01, 8.57617762e-01, 6.09672523e-01],
#        [8.91751642e-01, 2.70078432e-01, 6.21823370e-01, 7.20500447e-01,
#         8.69066405e-01, 6.91498447e-01, 3.47905566e-01, 1.91177364e-01,
#         1.47056013e-01, 1.35584398e-01, 3.88227111e-02, 8.38837097e-01],
#        [8.80033056e-01, 8.28888295e-01, 3.32129023e-01, 6.77995584e-01,
#         7.54821547e-01, 2.40122240e-01, 6.14704142e-02, 5.50832193e-01,
#         9.54173228e-01, 2.77453068e-01, 6.22492910e-01, 5.53645429e-01]])

# %%
sns.heatmap(uniform_data, vmin=0, vmax=1) # 색상 스케일 최소, 최대값
# Out:
# <AxesSubplot:>

# %% [markdown]
# ### 상관 행렬을 통한 heatmap 활용 예제

# %%
# 상관행렬 생성
tips.corr()
# Out:
#             total_bill       tip      size
# total_bill    1.000000  0.675734  0.598315
# tip           0.675734  1.000000  0.489299
# size          0.598315  0.489299  1.000000

# %%
# 히트맵으로 표현
sns.heatmap(tips.corr(), annot=True, cmap='viridis')
# Out:
# <AxesSubplot:>

# %%
#sns 패키지의 filghts data set 을 이용해서 heatmap 작성
flights=sns.load_dataset('flights')
flights.head()
flights.tail()
# Out:
#      year month  passengers
# 139  1960   Aug         606
# 140  1960   Sep         508
# 141  1960   Oct         461
# 142  1960   Nov         390
# 143  1960   Dec         432

# %%
#pivot 테이블을 이용해서 연도별 각 월 승객수로 구조를 변환
flight_p = pd.pivot_table(flights,
                          index='month',
                          columns = 'year',
                          values='passengers',
                          fill_value=0)

flight_p
# Out:
# year   1949  1950  1951  1952  1953  1954  1955  1956  1957  1958  1959  1960
# month
# Jan     112   115   145   171   196   204   242   284   315   340   360   417
# Feb     118   126   150   180   196   188   233   277   301   318   342   391
# Mar     132   141   178   193   236   235   267   317   356   362   406   419
# Apr     129   135   163   181   235   227   269   313   348   348   396   461
# May     121   125   172   183   229   234   270   318   355   363   420   472
# Jun     135   149   178   218   243   264   315   374   422   435   472   535
# Jul     148   170   199   230   264   302   364   413   465   491   548   622
# Aug     148   170   199   242   272   293   347   405   467   505   559   606
# Sep     136   158   184   209   237   259   312   355   404   404   463   508
# Oct     119   133   162   191   211   229   274   306   347   359   407   461
# Nov     104   114   146   172   180   203   237   271   305   310   362   390
# Dec     118   140   166   194   201   229   278   306   336   337   405   432

# %%
# 한글 문제|
# matplotlit의 기본 폰트에서 한글 지원되지 않기 때문에
# matplotlib의 폰트 변경 필요
import platform

from matplotlib import font_manager, rc
plt.rcParams['axes.unicode_minus'] = False

if platform.system() == 'Darwin':  # 맥OS 
    rc('font', family='AppleGothic')
elif platform.system() == 'Windows':  # 윈도우
    path = "c:/Windows/Fonts/H2GTRM.TTF"
    font_name = font_manager.FontProperties(fname=path).get_name()
    rc('font', family=font_name)
else:
    print('Unknown system...  sorry~~~')

# %%
plt.figure(figsize=(10,6))
sns.heatmap(flight_p)
plt.title('연도/월별 승객수')
plt.show()

# %%
#히트맵 그래프 위에 실제 데이터출력
#사용인수 : annot=True, fmt=d/f - 출력데이터 형태
plt.figure(figsize=(10,6))
sns.heatmap(flight_p,annot=True,fmt='d')
plt.title('연도/월별 승객수')
plt.show()

# %% [markdown]
# # FOLIUM  패키지
# - 지도 이용해 data 시각화 하는 도구
# - 아나콘다 프롬프트에서 설치
#     - pip install folium : 주로 사용
#     - pip install Folium
# - OPEN STREET MAP과 같은 지도 데이터에 leaflet.js 를 이용해서 위치 정보를 시각화 하기 위한 라이브러리
# - 마커형태로 위치정보를 지도상에 표현할 수 있다

# %%
# !pip install folium
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: folium in c:\users\bbobbee\appdata\roaming\python\python39\site-packages (0.12.1.post1)
# Requirement already satisfied: requests in c:\programdata\anaconda3\lib\site-packages (from folium) (2.27.1)
# Requirement already satisfied: numpy in c:\programdata\anaconda3\lib\site-packages (from folium) (1.21.5)
# Requirement already satisfied: branca>=0.3.0 in c:\users\bbobbee\appdata\roaming\python\python39\site-packages (from folium) (0.5.0)
# Requirement already satisfied: jinja2>=2.9 in c:\programdata\anaconda3\lib\site-packages (from folium) (2.11.3)
# Requirement already satisfied: MarkupSafe>=0.23 in c:\programdata\anaconda3\lib\site-packages (from jinja2>=2.9->folium) (2.0.1)
# Requirement already satisfied: charset-normalizer~=2.0.0 in c:\programdata\anaconda3\lib\site-packages (from requests->folium) (2.0.4)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\programdata\anaconda3\lib\site-packages (from requests->folium) (1.26.9)
# Requirement already satisfied: certifi>=2017.4.17 in c:\programdata\anaconda3\lib\site-packages (from requests->folium) (2021.10.8)
# Requirement already satisfied: idna<4,>=2.5 in c:\programdata\anaconda3\lib\site-packages (from requests->folium) (3.3)

# %%
# import folium
import folium

# %%
# %pip install folium

# %% [markdown]
# # 지도 생성 방법
# - Map()메소드에 중심 좌표값을 지정해서 간단하게 생성
# - 위도와 경도를 data로 지도를 그려줌
# - 크롬에서는 출력이 가능하고
# - 익스플로러에서는 저장만 가능(출력되지 않는다.)

# %%
# 초기 map 생성 
#중심좌표 인수 location=[lon,lat]
#확대비율 정의 인수 zoon_start=13

map_osm = folium.Map(location=[45.5236,-122.6750], zoom_start=13)
map_osm
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_72129e8e0abc0f8368eb881e6ee7d06d {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_72129e8e0abc0f8368eb881e6ee7d06d&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#             var map_72129e8e0abc0f8368eb881e6ee7d06d = L.map(
#                 &quot;map_72129e8e0abc0f8368eb881e6ee7d06d&quot;,
#                 {
#                     center: [45.5236, -122.675],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 13,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_0a4ac9c8be3691192805312798872962 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_72129e8e0abc0f8368eb881e6ee7d06d);
#
# &lt;/script&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
#지도 스타일 변경 :
#Open Street  Map을 기반으로 동작하고
#내부적으로 스타일 2개를 지원
#관련인수 tiles= Stamen Toner/ Stamen Terrain

map_osm = folium.Map(location=[45.5236,-122.6750], 
                     zoom_start=13,
                     tiles = 'Stamen Toner')
map_osm
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_deb1ffaf7a82e6c6be6e3c11634ff90a {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_deb1ffaf7a82e6c6be6e3c11634ff90a&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#             var map_deb1ffaf7a82e6c6be6e3c11634ff90a = L.map(
#                 &quot;map_deb1ffaf7a82e6c6be6e3c11634ff90a&quot;,
#                 {
#                     center: [45.5236, -122.675],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 13,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_0ad4a2828b8650dfac219fc229e42527 = L.tileLayer(
#                 &quot;https://stamen-tiles-{s}.a.ssl.fastly.net/toner/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Map tiles by \u003ca href=\&quot;http://stamen.com\&quot;\u003eStamen Design\u003c/a\u003e, under \u003ca href=\&quot;http://creativecommons.org/licenses/by/3.0\&quot;\u003eCC BY 3.0\u003c/a\u003e. Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_deb1ffaf7a82e6c6be6e3c11634ff90a);
#
# &lt;/script&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# - 마커설정(popup 설정도 가능)
#     - 마커(특정 위치를 표시하는 표식)
#     - popup(마커 클릭시에 나타나는 정보) : 환경에 따라 지원안되는 경우도 있음
#
# 1. 마커 생성
#     - folium.Marker():인자값 위,경도 값 리스트, popup 문자
# 2. 마커 생성 후 부착 하는 코드
#     - folium.Marker().add_to(지도객체변수)

# %%
#한글은 깨져서 나오므로 추가 패키지 설치해야 함
#folium 버전 업그레이드시 해결 될 예정
# 한글 제대로 처리 됨
map_1 = folium.Map(location=[45.372,-121.6972],
                   zoom_start=11,
                   tiles='Stamen Terrain')
folium.Marker([45.3288,-121.6625],popup='Hood 산',
              icon=folium.Icon(icon='cloud')).add_to(map_1)
folium.Marker([45.3311,-121.7113],popup='Timberline Lodge',
              icon=folium.Icon(color='red')).add_to(map_1)
folium.Marker([45.3300,-121.6823],popup='Some other location',
              icon=folium.Icon(color='green',icon='info-sign')).add_to(map_1)
map_1
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_e3099d0175351616eea517ce682b4505 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_e3099d0175351616eea517ce682b4505&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#             var map_e3099d0175351616eea517ce682b4505 = L.map(
#                 &quot;map_e3099d0175351616eea517ce682b4505&quot;,
#                 {
#                     center: [45.372, -121.6972],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 11,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_8f675d5ac041d99dede8c2e4005e7d3d = L.tileLayer(
#                 &quot;https://stamen-tiles-{s}.a.ssl.fastly.net/terrain/{z}/{x}/{y}.jpg&quot;,
#                 {&quot;attribution&quot;: &quot;Map tiles by \u003ca href=\&quot;http://stamen.com\&quot;\u003eStamen Design\u003c/a\u003e, under \u003ca href=\&quot;http://creativecommons.org/licenses/by/3.0\&quot;\u003eCC BY 3.0\u003c/a\u003e. Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://creativecommons.org/licenses/by-sa/3.0\&quot;\u003eCC BY SA\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_e3099d0175351616eea517ce682b4505);
#
#
#             var marker_b315ea46f355c0a4a2dde9163dbc7540 = L.marker(
#                 [45.3288, -121.6625],
#                 {}
#             ).addTo(map_e3099d0175351616eea517ce682b4505);
#
#
#             var icon_5d0b399c0a8ca38a58b0d5ced86bf385 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;cloud&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_b315ea46f355c0a4a2dde9163dbc7540.setIcon(icon_5d0b399c0a8ca38a58b0d5ced86bf385);
#
#
#         var popup_2c56763bef982cddc3ef0e69626935d0 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_3c8ce206cfcf867b342815c0570d7e3d = $(`&lt;div id=&quot;html_3c8ce206cfcf867b342815c0570d7e3d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Hood 산&lt;/div&gt;`)[0];
#             popup_2c56763bef982cddc3ef0e69626935d0.setContent(html_3c8ce206cfcf867b342815c0570d7e3d);
#
#
#         marker_b315ea46f355c0a4a2dde9163dbc7540.bindPopup(popup_2c56763bef982cddc3ef0e69626935d0)
#         ;
#
#
#
#
#             var marker_c4fa0fb9626f01f55b318159bc1dd349 = L.marker(
#                 [45.3311, -121.7113],
#                 {}
#             ).addTo(map_e3099d0175351616eea517ce682b4505);
#
#
#             var icon_d88a0c6c4987d32f434514e86f5c0c03 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;red&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_c4fa0fb9626f01f55b318159bc1dd349.setIcon(icon_d88a0c6c4987d32f434514e86f5c0c03);
#
#
#         var popup_29f9276b880bbeb1c5ad0cd8f7a0c35a = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_9b2e5d49fcae089fe66c5240b4b82d6c = $(`&lt;div id=&quot;html_9b2e5d49fcae089fe66c5240b4b82d6c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Timberline Lodge&lt;/div&gt;`)[0];
#             popup_29f9276b880bbeb1c5ad0cd8f7a0c35a.setContent(html_9b2e5d49fcae089fe66c5240b4b82d6c);
#
#
#         marker_c4fa0fb9626f01f55b318159bc1dd349.bindPopup(popup_29f9276b880bbeb1c5ad0cd8f7a0c35a)
#         ;
#
#
#
#
#             var marker_8652b434f8c84d402055b9821c6c81c6 = L.marker(
#                 [45.33, -121.6823],
#                 {}
#             ).addTo(map_e3099d0175351616eea517ce682b4505);
#
#
#             var icon_e12e1af8abfbe2ae7556b8f39c3b275a = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;green&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_8652b434f8c84d402055b9821c6c81c6.setIcon(icon_e12e1af8abfbe2ae7556b8f39c3b275a);
#
#
#         var popup_efab7ffdd800e7d1390a0359e831dbac = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_0e3534f891e4f674785ebf5fd231f44c = $(`&lt;div id=&quot;html_0e3534f891e4f674785ebf5fd231f44c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Some other location&lt;/div&gt;`)[0];
#             popup_efab7ffdd800e7d1390a0359e831dbac.setContent(html_0e3534f891e4f674785ebf5fd231f44c);
#
#
#         marker_8652b434f8c84d402055b9821c6c81c6.bindPopup(popup_efab7ffdd800e7d1390a0359e831dbac)
#         ;
#
#
#
# &lt;/script&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
# @37.579617,126.977041
map_1 = folium.Map(location=[37.579617,126.977041],
                   zoom_start=13,
                   tiles='Stamen Terrain')
folium.Marker([37.579617,126.977041],popup='경복궁',
              icon=folium.Icon(icon='cloud')).add_to(map_1)
map_1
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_115f76dc0ea87dc47eb06fbbcb63b32c {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_115f76dc0ea87dc47eb06fbbcb63b32c&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#             var map_115f76dc0ea87dc47eb06fbbcb63b32c = L.map(
#                 &quot;map_115f76dc0ea87dc47eb06fbbcb63b32c&quot;,
#                 {
#                     center: [37.579617, 126.977041],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 13,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_b25fe297adcc3f89d774f4657c31e390 = L.tileLayer(
#                 &quot;https://stamen-tiles-{s}.a.ssl.fastly.net/terrain/{z}/{x}/{y}.jpg&quot;,
#                 {&quot;attribution&quot;: &quot;Map tiles by \u003ca href=\&quot;http://stamen.com\&quot;\u003eStamen Design\u003c/a\u003e, under \u003ca href=\&quot;http://creativecommons.org/licenses/by/3.0\&quot;\u003eCC BY 3.0\u003c/a\u003e. Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://creativecommons.org/licenses/by-sa/3.0\&quot;\u003eCC BY SA\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_115f76dc0ea87dc47eb06fbbcb63b32c);
#
#
#             var marker_e673d83385d2e7cef4a9c95a730dd9fb = L.marker(
#                 [37.579617, 126.977041],
#                 {}
#             ).addTo(map_115f76dc0ea87dc47eb06fbbcb63b32c);
#
#
#             var icon_10ac009ef38261767ddcf6d97a6634bb = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;cloud&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_e673d83385d2e7cef4a9c95a730dd9fb.setIcon(icon_10ac009ef38261767ddcf6d97a6634bb);
#
#
#         var popup_050c14f055ab55f32b523e3e9e180e40 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_96eeac7655bb5496e2fe17e41e429b6f = $(`&lt;div id=&quot;html_96eeac7655bb5496e2fe17e41e429b6f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;경복궁&lt;/div&gt;`)[0];
#             popup_050c14f055ab55f32b523e3e9e180e40.setContent(html_96eeac7655bb5496e2fe17e41e429b6f);
#
#
#         marker_e673d83385d2e7cef4a9c95a730dd9fb.bindPopup(popup_050c14f055ab55f32b523e3e9e180e40)
#         ;
#
#
#
# &lt;/script&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# # 단계 구분도
# - 데이터를 지도 그림에 반영시켜서 전달하는 그래프
# - 보통 folium 에 layer로 얹게 된다.
# - map 객체의 choropleth() 이용해서 작업
# - 사용 인수
#     - geo_data : 지도 파일 경로와 파일명
#     - data : 지도에 표현되어야 할 값 변수
#     - columns =  [key로 사용할 data, 실제 data의 필드명]
#     - key_on : 지도 경계파일인 json에서 사용할 키 값이며 지도 Data는 표준 형식으로 만들어 져야 함
#         - key_on 지칭 문법 : feature(키워드).json에서 나타나키 필드명
# - folium.LayerControl().add_to(map)  : 단계구분도를 map에 표시하는 함수

# %%
# 미국 각 주별 실업율을 data로 단계 구분도 작성
#지도 경계 data가 있어야 함.json 파일로 작성됨

# %%
#관련 data 가져오기
state_unemployment='./data/02. folium_US_Unemployment_Oct2012.csv'
state_unemp_data=pd.read_csv(state_unemployment)
state_unemp_data.head()
#50개주의 실업율 data
# Out:
#   State  Unemployment
# 0    AL           7.1
# 1    AK           6.8
# 2    AZ           8.1
# 3    AR           7.2
# 4    CA          10.1

# %%
state_geo='./data/02. folium_us-states.json'
state_geo
# Out:
# './data/02. folium_us-states.json'

# %%
map = folium.Map(location=[40,-98], zoom_start=3)
# map
map.choropleth(geo_data=state_geo,
               data=state_unemp_data,
               columns=['State','Unemployment'],
               key_on = 'feature.id',
               fill_color='YlGn',
               legend_name='Unemployment Rate(%)')
folium.LayerControl().add_to(map)
map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_15f31d520be7b2d471b7dbce0b89d257 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/d3/3.5.5/d3.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_15f31d520be7b2d471b7dbce0b89d257&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#             var map_15f31d520be7b2d471b7dbce0b89d257 = L.map(
#                 &quot;map_15f31d520be7b2d471b7dbce0b89d257&quot;,
#                 {
#                     center: [40.0, -98.0],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 3,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_f6ce2400dceb2ac03a6543d3c04c5a9e = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_15f31d520be7b2d471b7dbce0b89d257);
#
#
#             var choropleth_14c7efca48ab88da009c6784c7efc726 = L.featureGroup(
#                 {}
#             ).addTo(map_15f31d520be7b2d471b7dbce0b89d257);
#
#
#         function geo_json_3517be39b4de3770f09ed8f42816a325_styler(feature) {
#             switch(feature.id) {
#                 case &quot;AZ&quot;: case &quot;CT&quot;: case &quot;FL&quot;: case &quot;GA&quot;: case &quot;IL&quot;: case &quot;IN&quot;: case &quot;KY&quot;: case &quot;MI&quot;: case &quot;MS&quot;: case &quot;NY&quot;: case &quot;OR&quot;: case &quot;PA&quot;: case &quot;SC&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#31a354&quot;, &quot;fillOpacity&quot;: 0.6, &quot;opacity&quot;: 1, &quot;weight&quot;: 1};
#                 case &quot;CA&quot;: case &quot;NV&quot;: case &quot;NJ&quot;: case &quot;NC&quot;: case &quot;RI&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#006837&quot;, &quot;fillOpacity&quot;: 0.6, &quot;opacity&quot;: 1, &quot;weight&quot;: 1};
#                 case &quot;HI&quot;: case &quot;IA&quot;: case &quot;OK&quot;: case &quot;SD&quot;: case &quot;UT&quot;: case &quot;VT&quot;: case &quot;WY&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#d9f0a3&quot;, &quot;fillOpacity&quot;: 0.6, &quot;opacity&quot;: 1, &quot;weight&quot;: 1};
#                 case &quot;ID&quot;: case &quot;KS&quot;: case &quot;LA&quot;: case &quot;MA&quot;: case &quot;MN&quot;: case &quot;MO&quot;: case &quot;MT&quot;: case &quot;NH&quot;: case &quot;TX&quot;: case &quot;VA&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#addd8e&quot;, &quot;fillOpacity&quot;: 0.6, &quot;opacity&quot;: 1, &quot;weight&quot;: 1};
#                 case &quot;NE&quot;: case &quot;ND&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#ffffcc&quot;, &quot;fillOpacity&quot;: 0.6, &quot;opacity&quot;: 1, &quot;weight&quot;: 1};
#                 default:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#78c679&quot;, &quot;fillOpacity&quot;: 0.6, &quot;opacity&quot;: 1, &quot;weight&quot;: 1};
#             }
#         }
#
#         function geo_json_3517be39b4de3770f09ed8f42816a325_onEachFeature(feature, layer) {
#             layer.on({
#             });
#         };
#         var geo_json_3517be39b4de3770f09ed8f42816a325 = L.geoJson(null, {
#                 onEachFeature: geo_json_3517be39b4de3770f09ed8f42816a325_onEachFeature,
#
#                 style: geo_json_3517be39b4de3770f09ed8f42816a325_styler,
#         });
#
#         function geo_json_3517be39b4de3770f09ed8f42816a325_add (data) {
#             geo_json_3517be39b4de3770f09ed8f42816a325
#                 .addData(data)
#                 .addTo(choropleth_14c7efca48ab88da009c6784c7efc726);
#         }
#             geo_json_3517be39b4de3770f09ed8f42816a325_add({&quot;features&quot;: [{&quot;geometry&quot;: {&quot;coordinates&quot;: [[[-87.359296, 35.00118], [-85.606675, 34.984749], [-85.431413, 34.124869], [-85.184951, 32.859696], [-85.069935, 32.580372], [-84.960397, 32.421541], [-85.004212, 32.322956], [-84.889196, 32.262709], [-85.058981, 32.13674], [-85.053504, 32.01077], [-85.141136, 31.840985], [-85.042551, 31.539753], [-85.113751, 31.27686], [-85.004212, 31.003013], [-85.497137, 30.997536], [-87.600282, 30.997536], [-87.633143, 30.86609], [-87.408589, 30.674397], [-87.446927, 30.510088], [-87.37025, 30.427934], [-87.518128, 30.280057], [-87.655051, 30.247195], [-87.90699, 30.411504], [-87.934375, 30.657966], [-88.011052, 30.685351], [-88.10416, 30.499135], [-88.137022, 30.318396], [-88.394438, 30.367688], [-88.471115, 31.895754], [-88.241084, 33.796253], [-88.098683, 34.891641], [-88.202745, 34.995703], [-87.359296, 35.00118]]], &quot;type&quot;: &quot;Polygon&quot;}, &quot;id&quot;: &quot;AL&quot;, &quot;properties&quot;: {&quot;name&quot;: &quot;Alabama&quot;}, &quot;type&quot;: &quot;Feature&quot;}, {&quot;geometry&quot;: {&quot;coordina

# %%
#한국 지도 데이터 이용해서 단계 구분도 그리기
import json
#한국지도 경계의 json data 파일 가져오기
#한글이 포함된경우에는 그냥 path만 연결하면 인코딩 문제 발생
#json.load( encoding='utf-8') 이용해서 변수에 data 저장 후 사용하는 것이 일반적

geo_path='./data/02. skorea_municipalities_geo_simple.json'
geo_str = json.load(open(geo_path,encoding='utf-8'))
# geo_str

#서울을 중심으로 기본 지도 출력
#위경도[37.5502,126.982]
map=folium.Map(location=[37.5502,126.982],
               zoom_start=11,
               tiles='Stamen Toner')
map

#단계 구분도 data 읽어오기
#csv 읽어오기 : pd.read_csv(경로포함파일명,encoding=,index_col='지정인덱스 필드명')
f_test=pd.read_csv('./data/cctv_result.csv',encoding='utf-8',index_col='구별')
f_test.head()
# Out:
#        소계       최근증가율       인구수       한국인      외국인      고령자     외국인비율  \
# 구별
# 강남구  3238  150.619195  570500.0  565550.0   4950.0  63167.0  0.867660
# 강동구  1010  166.490765  453233.0  449019.0   4214.0  54622.0  0.929765
# 강북구   831  125.203252  330192.0  326686.0   3506.0  54813.0  1.061806
# 강서구   911  134.793814  603772.0  597248.0   6524.0  72548.0  1.080540
# 관악구  2109  149.290780  525515.0  507203.0  18312.0  68082.0  3.484582
#
#          고령자비율    CCTV비율
# 구별
# 강남구  11.072217  0.567572
# 강동구  12.051638  0.222843
# 강북구  16.600342  0.251672
# 강서구  12.015794  0.150885
# 관악구  12.955291  0.401321

# %%
map.choropleth(geo_data=geo_str,
               data=f_test,
               columns=[f_test.index,'소계'],
               key_on = 'feature.id',
               fill_color='PuRd',
               legend_name='CCTV 현황')
folium.LayerControl().add_to(map)
map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_7cd51e888e5beb434aa758e10361447f {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/d3/3.5.5/d3.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_7cd51e888e5beb434aa758e10361447f&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#             var map_7cd51e888e5beb434aa758e10361447f = L.map(
#                 &quot;map_7cd51e888e5beb434aa758e10361447f&quot;,
#                 {
#                     center: [37.5502, 126.982],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 11,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_0ff5cdeae36afc9de8cfdf444487ab2a = L.tileLayer(
#                 &quot;https://stamen-tiles-{s}.a.ssl.fastly.net/toner/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Map tiles by \u003ca href=\&quot;http://stamen.com\&quot;\u003eStamen Design\u003c/a\u003e, under \u003ca href=\&quot;http://creativecommons.org/licenses/by/3.0\&quot;\u003eCC BY 3.0\u003c/a\u003e. Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_7cd51e888e5beb434aa758e10361447f);
#
#
#             var choropleth_df98cbfad4b686bc6b8bf41989703de4 = L.featureGroup(
#                 {}
#             ).addTo(map_7cd51e888e5beb434aa758e10361447f);
#
#
#         function geo_json_dd1d43fd54d2eaf6de169f1c57e4c588_styler(feature) {
#             switch(feature.id) {
#                 case &quot;\uac15\ub0a8\uad6c&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#980043&quot;, &quot;fillOpacity&quot;: 0.6, &quot;opacity&quot;: 1, &quot;weight&quot;: 1};
#                 case &quot;\uc11c\ucd08\uad6c&quot;: case &quot;\uad00\uc545\uad6c&quot;: case &quot;\uc740\ud3c9\uad6c&quot;: case &quot;\uc6a9\uc0b0\uad6c&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#df65b0&quot;, &quot;fillOpacity&quot;: 0.6, &quot;opacity&quot;: 1, &quot;weight&quot;: 1};
#                 case &quot;\ub3d9\uc791\uad6c&quot;: case &quot;\uc601\ub4f1\ud3ec\uad6c&quot;: case &quot;\uae08\ucc9c\uad6c&quot;: case &quot;\uc11c\ub300\ubb38\uad6c&quot;: case &quot;\ub178\uc6d0\uad6c&quot;: case &quot;\uc131\ub3d9\uad6c&quot;: case &quot;\uc885\ub85c\uad6c&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#d4b9da&quot;, &quot;fillOpacity&quot;: 0.6, &quot;opacity&quot;: 1, &quot;weight&quot;: 1};
#                 case &quot;\uad6c\ub85c\uad6c&quot;: case &quot;\uc131\ubd81\uad6c&quot;: case &quot;\ub3d9\ub300\ubb38\uad6c&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#c994c7&quot;, &quot;fillOpacity&quot;: 0.6, &quot;opacity&quot;: 1, &quot;weight&quot;: 1};
#                 case &quot;\uc591\ucc9c\uad6c&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#dd1c77&quot;, &quot;fillOpacity&quot;: 0.6, &quot;opacity&quot;: 1, &quot;weight&quot;: 1};
#                 default:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#f1eef6&quot;, &quot;fillOpacity&quot;: 0.6, &quot;opacity&quot;: 1, &quot;weight&quot;: 1};
#             }
#         }
#
#         function geo_json_dd1d43fd54d2eaf6de169f1c57e4c588_onEachFeature(feature, layer) {
#             layer.on({
#             });
#         };
#         var geo_json_dd1d43fd54d2eaf6de169f1c57e4c588 = L.geoJson(null, {
#                 onEachFeature: geo_json_dd1d43fd54d2eaf6de169f1c57e4c588_onEachFeature,
#
#                 style: geo_json_dd1d43fd54d2eaf6de169f1c57e4c588_styler,
#         });
#
#         function geo_json_dd1d43fd54d2eaf6de169f1c57e4c588_add (data) {
#             geo_json_dd1d43fd54d2eaf6de169f1c57e4c588
#                 .addData(data)
#                 .addTo(choropleth_df98cbfad4b686bc6b8bf41989703de4);
#         }
#             geo_json_dd1d43fd54d2eaf6de169f1c57e4c588_add({&quot;features&quot;: [{&quot;geometry&quot;: {&quot;coordinates&quot;: [[[127.11519584981606, 37.557533180704915], [127.16683184366129, 37.57672487388627], [127.18408792330152, 37.55814280369575], [127.16530984307447, 37.54221851258693], [127.14672806823502, 37.51415680680291], [127.12123165719615, 37.52528270089], [127.1116764203608, 37.540669955324965], [127.11519584981606, 37.557533180704915]]], &quot;type&quot;: &quot;Polygon&quot;}, &quot;id&quot;: &quot;\uac15\ub3d9\uad6c&quot;, &quot;properties&quot;: {&quot;base_year&quot;: &quot;2013&quot;, &quot;code&quot;: &quot;11250&quot;, &quot;name&quot;: &quot;\uac15\ub3d9\uad6c&quot;, &quot;name_eng&quot;: &quot;Gangdong-gu&quot;}, &quot;type&quot;: &quot;Feature&quot;}, {&quot;geometry&quot;: {&quot;coordinates&quot;: [[[127.0690698130372, 37.522279423505026], [127.10087519791962, 37.524841220167055], [127.1116764203608, 37.540669955324965], [127.12123165719615, 37.52528270089], [127.14672806823502, 37.51415680680291], [127.1634944215765, 37.497445406097484], [127.14206058413274, 37.470898
