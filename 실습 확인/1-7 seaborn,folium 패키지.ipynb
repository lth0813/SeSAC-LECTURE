# %% [markdown]
# seaborn 패키지: 좀 더 편리한 시각화 도구
# - matplotlib의 기능에 스타일을 확장한 파이썬 시각화 도구
# - 패키지는 설치 해야 함(pip install seaborn) 단, 아나콘다 내부에는 이미 설치되어 있음
# - seaborn을 사용하기 위해서는 matplotlib가 import 되어 있어야 함.
# - 스타일 색상을 지원하기위해서 파렛트를 지원
# - 그래프는 대부분 matplotlib에 있는 그래프를 사용하고, seaborn이 몇개의 그래프를 더 가지고 있음

# %%
import pandas as pd
import numpy as np

# %%
import matplotlib.pyplot as plt #서브 패키지 pyplot 사용
# %matplotlib inline

# %%
# 경고 메시지 무시 설정
import warnings
warnings.filterwarnings(action='ignore')

# %%
# 한글 문제|
# matplotlit의 기본 폰트에서 한글 지원되지 않기 때문에
# matplotlib의 폰트 변경 필요
import platform

from matplotlib import font_manager, rc
plt.rcParams['axes.unicode_minus'] = False

if platform.system() == 'Darwin':  # 맥OS 
    rc('font', family='AppleGothic')
elif platform.system() == 'Windows':  # 윈도우
    path = "c:/Windows/Fonts/H2GTRM.TTF"
    font_name = font_manager.FontProperties(fname=path).get_name()
    rc('font', family=font_name)
else:
    print('Unknown system...  sorry~~~')

# %%
# 그래프 예제
x=np.linspace(1,14,100) #1부터 14까지의 범위에서 동일 간격의 숫자 100개 생성
x
# Out:
# array([ 1.        ,  1.13131313,  1.26262626,  1.39393939,  1.52525253,
#         1.65656566,  1.78787879,  1.91919192,  2.05050505,  2.18181818,
#         2.31313131,  2.44444444,  2.57575758,  2.70707071,  2.83838384,
#         2.96969697,  3.1010101 ,  3.23232323,  3.36363636,  3.49494949,
#         3.62626263,  3.75757576,  3.88888889,  4.02020202,  4.15151515,
#         4.28282828,  4.41414141,  4.54545455,  4.67676768,  4.80808081,
#         4.93939394,  5.07070707,  5.2020202 ,  5.33333333,  5.46464646,
#         5.5959596 ,  5.72727273,  5.85858586,  5.98989899,  6.12121212,
#         6.25252525,  6.38383838,  6.51515152,  6.64646465,  6.77777778,
#         6.90909091,  7.04040404,  7.17171717,  7.3030303 ,  7.43434343,
#         7.56565657,  7.6969697 ,  7.82828283,  7.95959596,  8.09090909,
#         8.22222222,  8.35353535,  8.48484848,  8.61616162,  8.74747475,
#         8.87878788,  9.01010101,  9.14141414,  9.27272727,  9.4040404 ,
#         9.53535354,  9.66666667,  9.7979798 ,  9.92929293, 10.06060606,
#        10.19191919, 10.32323232, 10.45454545, 10.58585859, 10.71717172,
#        10.84848485, 10.97979798, 11.11111111, 11.24242424, 11.37373737,
#        11.50505051, 11.63636364, 11.76767677, 11.8989899 , 12.03030303,
#        12.16161616, 12.29292929, 12.42424242, 12.55555556, 12.68686869,
#        12.81818182, 12.94949495, 13.08080808, 13.21212121, 13.34343434,
#        13.47474747, 13.60606061, 13.73737374, 13.86868687, 14.        ])

# %%
y1=np.sin(x)
y2=2*np.sin(x)
y3=3*np.sin(x)
y4=4*np.sin(x)

plt.figure(figsize=(10,6))
plt.plot(x,y1,x,y2,x,y3,x,y4)
plt.show()

# %%
import seaborn as sns #seaborn 패키지 임포트

# %% [markdown]
# #### seaborn 스타일링
#
# - set_style: background color, grid, spine, tick을 정의하여 그림의 전반적인 모양을 스타일링
# - set_context: 프리젠테이션이나 보고서와 같은 다양한 매체에 활용할 수 있도록 스타일링
#
#
# 1. set_style: 그림의 전반적인 모양 스타일링
#     - Built-in Themes (내장 테마) 활용하기
#
#         - Seaborn에는 5가지 기본 제공 테마가 있음
#         - darkgrid, whitegrid, dark, white, ticks.
#         - 기본값은 darkgrid이지만, 원하는대로 변경이 가능
# 2. sns.despine() 함수
#     - 축선 표시 여부 결정하는 함수(right=T/F,left=T/F,top=T/F,bottom=T/F)
#         - 각 속성값이
#         - True 면 : 표시하지 않는다.
#         - False 면: 표시함
# 3. sns.set_context() 함수
#     - 전체 스케일 조정
#     - paper, notebook, talk, poster. 여기서 기본값은 notebook이다.
#     - 스케일로도 전반적인 사이즈를 조정할 수 있지만 실제 폰트 크기를 조정하는 파라미터는 별도로 있음
#
#     - sns.set_context() 안에 font_scale 사용

# %%
#seaborn이용한 style 설정

x=np.linspace(1,14,100)
y1=np.sin(x)
y2=2*np.sin(x)
y3=3*np.sin(x)
y4=4*np.sin(x)

sns.set_style('whitegrid')
plt.figure(figsize=(10,6))
plt.plot(x,y1,x,y2,x,y3,x,y4)
plt.show()

# %%
#seaborn이용한 style 설정

x=np.linspace(1,14,100)
y1=np.sin(x)
y2=2*np.sin(x)
y3=3*np.sin(x)
y4=4*np.sin(x)

sns.set_style('dark') # 배경 회색
plt.figure(figsize=(10,6))
plt.plot(x,y1,x,y2,x,y3,x,y4)
plt.show()

# %%
#sns.despin() 함수
#축선 표시 여부 결정하는 함수(right=T/F,left=T/F,top=T/F,bottom=T/F)
#각 속성값이 True 면 : 표시하지 않는다.
#            False 면: 표시함
x=np.linspace(1,14,100)
y1=np.sin(x)
y2=2*np.sin(x)
y3=3*np.sin(x)
y4=4*np.sin(x)

sns.set_style('whitegrid')
plt.figure(figsize=(10,6))
plt.plot(x,y1,x,y2,x,y3,x,y4)
# sns.despine(right=True, left=True, top= False, bottom=False)
sns.despine(right=False, left=False) # top = True bottom=False 기본 속성 값
plt.show()

# %%
#seaborn이용한 style 설정

x=np.linspace(1,14,100)
y1=np.sin(x)
y2=2*np.sin(x)
y3=3*np.sin(x)
y4=4*np.sin(x)

sns.set_context('talk') # paper, notebook, talk, poster.
# plt.figure(figsize=(10,6))
plt.plot(x,y1,x,y2,x,y3,x,y4)
plt.show()

# %%
#seaborn이용한 style 설정

x=np.linspace(1,14,100)
y1=np.sin(x)
y2=2*np.sin(x)
y3=3*np.sin(x)
y4=4*np.sin(x)

sns.set_context('talk',font_scale=.5) # paper, notebook, talk, poster.
plt.figure(figsize=(10,6))
plt.plot(x,y1,x,y2,x,y3,x,y4)
plt.show()

# %%
sns.set_context('notebook')

# %% [markdown]
# # sns 의 기본 데이터 셋 : tips 활용
# - 요일별 점심 저녁 식사 금액과 팁을 정리한 데이터 셋
# - 성별, 흡연여부가 구별되어 있음
# - 패키지명.load_dataset(데이터셋명)

# %%
tips = sns.load_dataset('tips')
tips.head(5)
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %% [markdown]
# ###  Distribution Plot
# - Distribution Plot은 데이터의 분포를 시각화하는데 도움이 됨
# - 이 그래프를 사용하여 데이터의 평균(mean), 중위수(median), 범위(range), 분산(variance), 편차(deviation) 등을 이해 할 수 있음

# %% [markdown]
# 1. Hist Plot
# - 변수에 대한 히스토그램을 표시한다.
# - 하나 혹은 두 개의 변수 분포를 나타내는 전형적인 시각화 도구로 범위에 포함되는 관측수를 세어 표시한다.

# %%
sns.histplot(x=tips['total_bill'])
# Out:
# <Axes: xlabel='total_bill', ylabel='Count'>

# %% [markdown]
# 2. KDE Plot
# - 하나 혹은 두 개의 변수에 대한 분포를 그림
# - histplot은 절대량이라면 kdeplot은 밀도 추정치를 시각화
#     - 결과물로는 연속된 곡선의 그래프를 얻을 수 있음

# %%
sns.kdeplot(x=tips['total_bill'])
# Out:
# <Axes: xlabel='total_bill', ylabel='Count'>

# %% [markdown]
# 3. Box Plot
# - 최대(maximum), 최소(minimum), mean(평균), 1 사분위수(first quartile), 3 사분위수(third quartile)를 보기 위한 그래프
# - 특이치(outliar)를 발견하기에도 좋다.
# - 단일 연속형 변수에 대해 수치를 표시하거나, 연속형 변수를 기반으로 서로 다른 범주형 변수를 분석할 수 있다.

# %%
#tips 데이터를 이용한 box plot 그리기
#seaborn 패키지의 boxplot() 이용해서 그리기

sns.set_style('whitegrid')

plt.figure(figsize=(10,6))
sns.boxplot(x=tips['total_bill'])
sns.despine()
plt.show()

# %%
#tips 데이터를 이용한 box plot 그리기
#seaborn 패키지의 boxplot() 이용해서 그리기
#요일별 영수증 금액의 분포 확인

sns.set_style('whitegrid')

plt.figure(figsize=(10,6))

sns.boxplot(x=tips['day'], y=tips['total_bill'])
sns.despine(offset=10) # x,y축간의 간격을 설정하는 인수

plt.show()

# %%
#tips 데이터를 이용한 box plot 그리기
#seaborn 패키지의 boxplot() 이용해서 그리기
#요일별 영수증 금액의 분포 확인
#palette 인수 사용 예제 : palette = '파레트명'

sns.set_style('whitegrid')

plt.figure(figsize=(10,6))

# sns.boxplot(x=tips['day'], y=tips['total_bill'], palette='Set2')
sns.boxplot(x='day', y='total_bill',data=tips, palette='Set2')
sns.despine(offset=10) # x,y축간의 간격을 설정하는 인수

plt.show()

# %%
#hue 인수 : 카테고리값을 가지는 변수의 이름 지정하면
#카테고리에 따라 그룹을 만들어서 표시

plt.figure(figsize=(10,6))
sns.boxplot(x='day', y='tip', hue='smoker', data=tips, palette='Set3')
plt.show()

# %%
#hue 인수 : 카테고리값을 가지는 변수의 이름 지정하면
#카테고리에 따라 그룹을 만들어서 표시
#y값을 total_bill 필드로 변경 후 비교

plt.figure(figsize=(10,6))
sns.boxplot(x='day', y='total_bill', hue='sex',data=tips, palette='Set3')

plt.show()

# %%
#요일별 팁의 분포를 비교하는 box plot을 그리시오. 파레트 Set3
sns.boxplot(x='day', y='tip', data=tips, palette='Set3')
# Out:
# <Axes: xlabel='day', ylabel='tip'>

# %%
#요일별 팁의 분포를 비교하되 성별에 따라 분포를 
#나누어 표시하시오.파레트 세트 3
sns.boxplot(x='day', y='tip', hue='sex', data=tips, palette='Set3')
# Out:
# <Axes: xlabel='day', ylabel='tip'>

# %%
#위 그래프의 색상값을 파레트 husl 로 변경하시오.
sns.boxplot(x='day', y='tip', hue='sex', data=tips, palette='husl')
# Out:
# <Axes: xlabel='day', ylabel='tip'>

# %%
#요일별 영수증 금액의 분포를 비교하되 성별에 따라 분포를
#나누어 표시하시오. 파레트는 임의 사용
sns.boxplot(x='day',y='total_bill',hue='sex',data=tips,palette='Set3')
# Out:
# <Axes: xlabel='day', ylabel='tip'>

# %% [markdown]
# 4. Swarm Plot
# - 데이터 포인트 수와 함께 각 데이터의 분포도 제공한다.

# %%
#데이터가 모여 있는 정도를 보여주는 plot : seaborn.swarmplot()
plt.figure(figsize=(10,6))
sns.swarmplot(x='day', y='total_bill', data=tips, palette='husl')
plt.show()

# %%
#box plot과 swarmplot을 같이 사용하는 예제
plt.figure(figsize=(10,6))
sns.boxplot(x='day', y='total_bill', data=tips)
sns.swarmplot(x='day', y='total_bill', data=tips, palette='husl')
plt.show()

# %% [markdown]
# # seaborn.lmplot()
# - 스캐터그래프를 그릴때 회귀선을 기본으로 출력해주는 그래프 함수
# - size 인수 : 그래프 크기
#     - height 인수로 변경해서 사용하라는 메시지가 출력될 수 있음
# - hue 인수 : 카테고리 데이터를 분류하여 그룹화하되 하나의 그래프에 두개의 값을 모두 표현
# - col 인수 : 카테고리 데이터를 분류하여 그룹화하되 그룹의 개수만큼 그래프를 생성해서 표현한다.

# %%
#dataset : tips 사용
sns.set_style('darkgrid')
# plt.scatter(x=tips['total_bill'],y=tips['tip'])
sns.lmplot(x='total_bill',y='tip', data=tips, height=5)
plt.show()

# %%
#dataset : tips 사용
#회귀선 생략 코드 : 인수 :  fit_reg=False
sns.lmplot(x='total_bill',y='tip', data=tips, fit_reg=False, height=5)
plt.show()

# %%
#hue는 그룹을 만듬
sns.lmplot(x='total_bill',y='tip', hue='smoker', data=tips, height=5)
plt.show()

# %%
#영수증 금액과 팁의 관계성을 lmplot()으로 표현하되, 
#성별을 구분해서 표현하시오.
sns.set_style('darkgrid')
sns.lmplot(x='total_bill',y='tip', hue='sex', data=tips, height=5)
plt.show()

# %%
#영수증 금액과 팁의 관계성을 lmplot()으로 표현하되, 
#성별을 구분해서 표현하되 그래프를 각각 그리시오.
#hue 인수 : 카테고리 데이터를 분류하여 그룹화하되 하나의 
#그래프에 두개의 값을 모두 표현
#col 인수 : 카테고리 데이터를 분류하여 그룹화하되 그룹의  
#개수만큼 그래프를 생성해서 표현한다.
sns.lmplot(x='total_bill',y='tip', col='sex', data=tips, height=5)
plt.show()

# %%
#영수증 금액과 팁의 관계성을 lmplot()으로 표현하되, 
#성별을 구분해서 표현하되 그래프를 각각 그리시오.
#hue 인수 : 카테고리 데이터를 분류하여 그룹화하되 하나의 
#그래프에 두개의 값을 모두 표현
#col 인수 : 카테고리 데이터를 분류하여 그룹화하되 그룹의  
#개수만큼 그래프를 생성해서 표현한다.
sns.lmplot(x='total_bill',y='tip', col='smoker', data=tips, height=5)
plt.show()

# %% [markdown]
# ### heatmap 그래프
# - 히트맵 (heat map)
#     - 열분포도
#     - 2차원 수치 데이터를 색으로 표시
# - 두개의 카테고리 값에 대한 값 변화를 한 눈에 알기 쉬움
# - 대용량 데이터 시각화에도 사용성이 높음
#
# sns.heatmap<br>
# (heat, # 전처리한 데이터프레임 <br>
#             annot = True, # 숫자 표시 여부 <br>
#             ax = ax, # 히트맵을 그릴 격자 <br>
#             linewidths = 0.4, # 선의 굵기 <br>
#             linecolor = 'white', # 선의 색깔 <br>
#             fmt = '.1f', # 소수점 포맷팅 형태 <br>
#             cmap = 'YlOrRd') # colormap 형태

# %%
# heatmap 그래프 예제
#예제 데이터 생성
uniform_data = np.random.rand(10,12)
uniform_data
# Out:
# array([[0.82898204, 0.37257326, 0.29928595, 0.09560867, 0.83557444,
#         0.96315714, 0.11485081, 0.26567965, 0.56629564, 0.58841911,
#         0.70535708, 0.36626806],
#        [0.51137172, 0.43133293, 0.99686003, 0.85109819, 0.95472379,
#         0.62459223, 0.81734965, 0.83880803, 0.43906403, 0.75218826,
#         0.79328801, 0.09737796],
#        [0.70071716, 0.65528408, 0.54297572, 0.6906623 , 0.72901052,
#         0.03302559, 0.22436541, 0.03296297, 0.20879089, 0.69074383,
#         0.85096354, 0.91449075],
#        [0.17120428, 0.55143089, 0.48620426, 0.0844888 , 0.55742658,
#         0.6057008 , 0.99662796, 0.84531235, 0.78578032, 0.34959487,
#         0.29897168, 0.21890785],
#        [0.65512833, 0.8359969 , 0.13476494, 0.81090818, 0.09224416,
#         0.70406143, 0.55515471, 0.69552368, 0.56351197, 0.46556608,
#         0.26463483, 0.4440019 ],
#        [0.4033476 , 0.5404553 , 0.57191185, 0.60655116, 0.90214123,
#         0.27108299, 0.92144501, 0.05090927, 0.01724058, 0.67246099,
#         0.60987694, 0.27489574],
#        [0.55123475, 0.36134613, 0.05373192, 0.52645546, 0.96675371,
#         0.38192279, 0.24449319, 0.89244103, 0.50334226, 0.51841313,
#         0.22379919, 0.09315931],
#        [0.6265742 , 0.38583323, 0.77518658, 0.07957564, 0.05695314,
#         0.32450014, 0.13779837, 0.00614147, 0.27033373, 0.67915486,
#         0.17662497, 0.35177841],
#        [0.40980905, 0.23045661, 0.05947852, 0.98524912, 0.29914362,
#         0.64418869, 0.2592318 , 0.80154854, 0.5798457 , 0.79451328,
#         0.52219297, 0.21641739],
#        [0.08694644, 0.70287011, 0.00302344, 0.14015525, 0.13062141,
#         0.17381069, 0.2741489 , 0.21095602, 0.81473211, 0.77487863,
#         0.97690653, 0.65053078]])

# %%
sns.heatmap(uniform_data, vmin=0, vmax=1) # 색상 스케일 최소, 최대값
plt.show()

# %% [markdown]
# ### 상관 행렬을 통한 heatmap 활용 예제

# %%
# 상관행렬 생성
tips_corr = tips.select_dtypes(include='number')
tips_corr.corr()
# Out:
#             total_bill       tip      size
# total_bill    1.000000  0.675734  0.598315
# tip           0.675734  1.000000  0.489299
# size          0.598315  0.489299  1.000000

# %%
# 히트맵으로 표현
sns.heatmap(tips_corr.corr(), annot=True, cmap='viridis')
plt.show()

# %%
#sns 패키지의 filghts data set 을 이용해서 heatmap 작성
flights=sns.load_dataset('flights')
flights.head()
flights.tail()
# Out:
#      year month  passengers
# 139  1960   Aug         606
# 140  1960   Sep         508
# 141  1960   Oct         461
# 142  1960   Nov         390
# 143  1960   Dec         432

# %%
#pivot 테이블을 이용해서 연도별 각 월 승객수로 구조를 변환
flight_p = pd.pivot_table(flights,
                          index='month',
                          columns = 'year',
                          values='passengers',
                          fill_value=0)

flight_p
# Out:
# year    1949   1950   1951   1952   1953   1954   1955   1956   1957   1958  \
# month
# Jan    112.0  115.0  145.0  171.0  196.0  204.0  242.0  284.0  315.0  340.0
# Feb    118.0  126.0  150.0  180.0  196.0  188.0  233.0  277.0  301.0  318.0
# Mar    132.0  141.0  178.0  193.0  236.0  235.0  267.0  317.0  356.0  362.0
# Apr    129.0  135.0  163.0  181.0  235.0  227.0  269.0  313.0  348.0  348.0
# May    121.0  125.0  172.0  183.0  229.0  234.0  270.0  318.0  355.0  363.0
# Jun    135.0  149.0  178.0  218.0  243.0  264.0  315.0  374.0  422.0  435.0
# Jul    148.0  170.0  199.0  230.0  264.0  302.0  364.0  413.0  465.0  491.0
# Aug    148.0  170.0  199.0  242.0  272.0  293.0  347.0  405.0  467.0  505.0
# Sep    136.0  158.0  184.0  209.0  237.0  259.0  312.0  355.0  404.0  404.0
# Oct    119.0  133.0  162.0  191.0  211.0  229.0  274.0  306.0  347.0  359.0
# Nov    104.0  114.0  146.0  172.0  180.0  203.0  237.0  271.0  305.0  310.0
# Dec    118.0  140.0  166.0  194.0  201.0  229.0  278.0  306.0  336.0  337.0
#
# year    1959   1960
# month
# Jan    360.0  417.0
# Feb    342.0  391.0
# Mar    406.0  419.0
# Apr    396.0  461.0
# May    420.0  472.0
# Jun    472.0  535.0
# Jul    548.0  622.0
# Aug    559.0  606.0
# Sep    463.0  508.0
# Oct    407.0  461.0
# Nov    362.0  390.0
# Dec    405.0  432.0

# %%
# 한글 문제|
# matplotlit의 기본 폰트에서 한글 지원되지 않기 때문에
# matplotlib의 폰트 변경 필요
import platform

from matplotlib import font_manager, rc
plt.rcParams['axes.unicode_minus'] = False

if platform.system() == 'Darwin':  # 맥OS 
    rc('font', family='AppleGothic')
elif platform.system() == 'Windows':  # 윈도우
    path = "c:/Windows/Fonts/H2GTRM.TTF"
    font_name = font_manager.FontProperties(fname=path).get_name()
    rc('font', family=font_name)
else:
    print('Unknown system...  sorry~~~')

# %%
plt.figure(figsize=(10,6))
sns.heatmap(flight_p)
plt.title('연도/월별 승객수')
plt.show()

# %%
#히트맵 그래프 위에 실제 데이터출력
#사용인수 : annot=True, fmt=d/f - 출력데이터 형태
plt.figure(figsize=(10,6))
sns.heatmap(flight_p,annot=True,fmt='.1f')
plt.title('연도/월별 승객수')
plt.show()

# %% [markdown]
# # FOLIUM  패키지
# - 지도 이용해 data 시각화 하는 도구
# - 아나콘다 프롬프트에서 설치
#     - pip install folium : 주로 사용
#     - pip install Folium
# - OPEN STREET MAP과 같은 지도 데이터에 leaflet.js 를 이용해서 위치 정보를 시각화 하기 위한 라이브러리
# - 마커형태로 위치정보를 지도상에 표현할 수 있다

# %%
# !pip install folium
# Out:
# Requirement already satisfied: folium in c:\programdata\anaconda3\lib\site-packages (0.19.4)
# Requirement already satisfied: branca>=0.6.0 in c:\programdata\anaconda3\lib\site-packages (from folium) (0.8.1)
# Requirement already satisfied: jinja2>=2.9 in c:\programdata\anaconda3\lib\site-packages (from folium) (3.1.4)
# Requirement already satisfied: numpy in c:\programdata\anaconda3\lib\site-packages (from folium) (1.26.4)
# Requirement already satisfied: requests in c:\programdata\anaconda3\lib\site-packages (from folium) (2.32.3)
# Requirement already satisfied: xyzservices in c:\programdata\anaconda3\lib\site-packages (from folium) (2022.9.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\programdata\anaconda3\lib\site-packages (from jinja2>=2.9->folium) (2.1.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\programdata\anaconda3\lib\site-packages (from requests->folium) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\programdata\anaconda3\lib\site-packages (from requests->folium) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\programdata\anaconda3\lib\site-packages (from requests->folium) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in c:\programdata\anaconda3\lib\site-packages (from requests->folium) (2024.12.14)

# %%
# import folium
import folium

# %%
# %pip install folium

# %% [markdown]
# # 지도 생성 방법
# - Map()메소드에 중심 좌표값을 지정해서 간단하게 생성
# - 위도와 경도를 data로 지도를 그려줌
# - 크롬에서는 출력이 가능하고
# - 익스플로러에서는 저장만 가능(출력되지 않는다.)

# %%
# 초기 map 생성 
#중심좌표 인수 location=[lon,lat]
#확대비율 정의 인수 zoon_start=13

map_osm = folium.Map(location=[45.5236,-122.6750], zoom_start=13)
map_osm
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_732568cc4d78bde45f17f49c19400866 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_732568cc4d78bde45f17f49c19400866&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_732568cc4d78bde45f17f49c19400866 = L.map(
#                 &quot;map_732568cc4d78bde45f17f49c19400866&quot;,
#                 {
#                     center: [45.5236, -122.675],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_cf3fbd015013bf7da68caec849e36b21 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_cf3fbd015013bf7da68caec849e36b21.addTo(map_732568cc4d78bde45f17f49c19400866);
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
#지도 스타일 변경 :
#Open Street  Map을 기반으로 동작하고
#내부적으로 스타일 2개를 지원
#관련인수 tiles= Stamen Toner/ Stamen Terrain

map_osm = folium.Map(location=[45.5236,-122.6750], 
                     zoom_start=13,
                     tiles = 'OpenStreetMap')
map_osm
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_fb513823a4665fa25c1a0aeeef3a619d {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_fb513823a4665fa25c1a0aeeef3a619d&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_fb513823a4665fa25c1a0aeeef3a619d = L.map(
#                 &quot;map_fb513823a4665fa25c1a0aeeef3a619d&quot;,
#                 {
#                     center: [45.5236, -122.675],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_3105899defa39af8f1ebb1f340fae469 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_3105899defa39af8f1ebb1f340fae469.addTo(map_fb513823a4665fa25c1a0aeeef3a619d);
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# - 마커설정(popup 설정도 가능)
#     - 마커(특정 위치를 표시하는 표식)
#     - popup(마커 클릭시에 나타나는 정보) : 환경에 따라 지원안되는 경우도 있음
#
# 1. 마커 생성
#     - folium.Marker():인자값 위,경도 값 리스트, popup 문자
# 2. 마커 생성 후 부착 하는 코드
#     - folium.Marker().add_to(지도객체변수)

# %%
#한글은 깨져서 나오므로 추가 패키지 설치해야 함
#folium 버전 업그레이드시 해결 될 예정
# 한글 제대로 처리 됨
map_1 = folium.Map(location=[45.372,-121.6972],
                   zoom_start=11,
                   tiles='OpenStreetMap')
folium.Marker([45.3288,-121.6625],popup='Hood 산',
              icon=folium.Icon(icon='cloud')).add_to(map_1)
folium.Marker([45.3311,-121.7113],popup='Timberline Lodge',
              icon=folium.Icon(color='red')).add_to(map_1)
folium.Marker([45.3300,-121.6823],popup='Some other location',
              icon=folium.Icon(color='green',icon='info-sign')).add_to(map_1)
map_1
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_7e155b8b7dfb4f464557ca0ef541c921 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_7e155b8b7dfb4f464557ca0ef541c921&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_7e155b8b7dfb4f464557ca0ef541c921 = L.map(
#                 &quot;map_7e155b8b7dfb4f464557ca0ef541c921&quot;,
#                 {
#                     center: [45.372, -121.6972],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 11,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_fb656150644435972690122b41bfb0f9 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_fb656150644435972690122b41bfb0f9.addTo(map_7e155b8b7dfb4f464557ca0ef541c921);
#
#
#             var marker_9da62b1462b4f8cf83efc4c826f536c8 = L.marker(
#                 [45.3288, -121.6625],
#                 {
# }
#             ).addTo(map_7e155b8b7dfb4f464557ca0ef541c921);
#
#
#             var icon_5a73d473640cba6279985cafd443975e = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;blue&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;cloud&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#             marker_9da62b1462b4f8cf83efc4c826f536c8.setIcon(icon_5a73d473640cba6279985cafd443975e);
#
#
#         var popup_fdbf6a3ae4e3b4aadfb3c4aba159d9a5 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_646e6545017ed6877684a5870844fc71 = $(`&lt;div id=&quot;html_646e6545017ed6877684a5870844fc71&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Hood 산&lt;/div&gt;`)[0];
#                 popup_fdbf6a3ae4e3b4aadfb3c4aba159d9a5.setContent(html_646e6545017ed6877684a5870844fc71);
#
#
#
#         marker_9da62b1462b4f8cf83efc4c826f536c8.bindPopup(popup_fdbf6a3ae4e3b4aadfb3c4aba159d9a5)
#         ;
#
#
#
#
#             var marker_fa954aa08918713e9d676faab679e55c = L.marker(
#                 [45.3311, -121.7113],
#                 {
# }
#             ).addTo(map_7e155b8b7dfb4f464557ca0ef541c921);
#
#
#             var icon_36b8f9ffe9c0aa0e8452eaf3e8c1603b = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;red&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;info-sign&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#             marker_fa954aa08918713e9d676faab679e55c.setIcon(icon_36b8f9ffe9c0aa0e8452eaf3e8c1603b);
#
#
#         var popup_49d63506716fb820c865054f4d5a3d8f = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_f2b125687ddfbd3fb9efb1de32b2c4b5 = $(`&lt;div id=&quot;html_f2b125687ddfbd3fb9efb1de32b2c4b5&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Timberline Lodge&lt;/div&gt;`)[0];
#                 popup_49d63506716fb820c865054f4d5a3d8f.setContent(html_f2b125687ddfbd3fb9efb1de32b2c4b5);
#
#
#
#         marker_fa954aa08918713e9d676faab679e55c.bindPopup(popup_49d63506716fb820c865054f4d5a3d8f)
#         ;
#
#
#
#
#             var marker_0b9de56f3f339a0c399d5dc489b612f9 = L.marker(
#                 [45.33, -121.6823],
#                 {
# }
#             ).addTo(map_7e155b8b7dfb4f464557ca0ef541c921);
#
#
#             var icon_69a7f605368627648177ba22adf2ca33 = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;green&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;info-sign&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#             marker_0b9de56f3f339a0c399d5dc489b612f9.setIcon(icon_69a7f605368627648177ba22adf2ca33);
#
#
#         var popup_c1ce35999ae882d1754fd4dd72636675 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_7bbcd104de64b45601f1ed19ceb855d9 = $(`&lt;div id=&quot;html_7bbcd104de64b45601f1ed19ceb855d9&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Some other location&lt;/div&gt;`)[0];
#                 popup_c1ce35999ae882d1754fd4dd72636675.setContent(html_7bbcd104de64b45601f1ed19ceb855d9);
#
#
#
#         marker_0b9de56f3f339a0c399d5dc489b612f9.bindPopup(popup_c1ce35999ae882d1754fd4dd72636675)
#         ;
#
#
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
# @37.579617,126.977041
map_1 = folium.Map(location=[37.579617,126.977041],
                   zoom_start=13,
                   tiles='OpenStreetMap')
folium.Marker([37.579617,126.977041],popup='경복궁',
              icon=folium.Icon(icon='cloud')).add_to(map_1)
map_1
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_a22c4ed6bdeeb7e2f83e3b058e70c841 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_a22c4ed6bdeeb7e2f83e3b058e70c841&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_a22c4ed6bdeeb7e2f83e3b058e70c841 = L.map(
#                 &quot;map_a22c4ed6bdeeb7e2f83e3b058e70c841&quot;,
#                 {
#                     center: [37.579617, 126.977041],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_682c52e8c16ae14b5000230168aba222 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_682c52e8c16ae14b5000230168aba222.addTo(map_a22c4ed6bdeeb7e2f83e3b058e70c841);
#
#
#             var marker_d3176a779dbbc3d9131a2352e9e038aa = L.marker(
#                 [37.579617, 126.977041],
#                 {
# }
#             ).addTo(map_a22c4ed6bdeeb7e2f83e3b058e70c841);
#
#
#             var icon_10aec0061e58fbbb2cfbfa86de062ff4 = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;blue&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;cloud&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#             marker_d3176a779dbbc3d9131a2352e9e038aa.setIcon(icon_10aec0061e58fbbb2cfbfa86de062ff4);
#
#
#         var popup_eaa207869b7ed9197e78f4a15c4951ee = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_12193173f1764a6ce8aa1eba0304da84 = $(`&lt;div id=&quot;html_12193173f1764a6ce8aa1eba0304da84&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;경복궁&lt;/div&gt;`)[0];
#                 popup_eaa207869b7ed9197e78f4a15c4951ee.setContent(html_12193173f1764a6ce8aa1eba0304da84);
#
#
#
#         marker_d3176a779dbbc3d9131a2352e9e038aa.bindPopup(popup_eaa207869b7ed9197e78f4a15c4951ee)
#         ;
#
#
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# # 단계 구분도
# - 데이터를 지도 그림에 반영시켜서 전달하는 그래프
# - 보통 folium 에 layer로 얹게 된다.
# - map 객체의 choropleth() 이용해서 작업
# - 사용 인수
#     - geo_data : 지도 파일 경로와 파일명
#     - data : 지도에 표현되어야 할 값 변수
#     - columns =  [key로 사용할 data, 실제 data의 필드명]
#     - key_on : 지도 경계파일인 json에서 사용할 키 값이며 지도 Data는 표준 형식으로 만들어 져야 함
#         - key_on 지칭 문법 : feature(키워드).json에서 나타나키 필드명
# - folium.LayerControl().add_to(map)  : 단계구분도를 map에 표시하는 함수

# %%
# 미국 각 주별 실업율을 data로 단계 구분도 작성
#지도 경계 data가 있어야 함.json 파일로 작성됨

# %%
#관련 data 가져오기
state_unemployment='./data/02. folium_US_Unemployment_Oct2012.csv'
state_unemp_data=pd.read_csv(state_unemployment)
state_unemp_data.head()
#50개주의 실업율 data
# Out:
#   State  Unemployment
# 0    AL           7.1
# 1    AK           6.8
# 2    AZ           8.1
# 3    AR           7.2
# 4    CA          10.1

# %%
state_geo='./data/02. folium_us-states.json'
state_geo
# Out:
# './data/02. folium_us-states.json'

# %%
map = folium.Map(location=[40,-98], zoom_start=4)
# map
folium.Choropleth(geo_data=state_geo,
               data=state_unemp_data,
               columns=['State','Unemployment'],
               key_on = 'feature.id',
               fill_color='YlGn',
               legend_name='Unemployment Rate(%)').add_to(map)
folium.LayerControl().add_to(map)
map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_acd61ea3f27ae58fa6894c7f4bc6b7e0 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/d3/3.5.5/d3.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_acd61ea3f27ae58fa6894c7f4bc6b7e0&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_acd61ea3f27ae58fa6894c7f4bc6b7e0 = L.map(
#                 &quot;map_acd61ea3f27ae58fa6894c7f4bc6b7e0&quot;,
#                 {
#                     center: [40.0, -98.0],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 4,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_28d50a42923e8dad76237cae1f8be3f3 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_28d50a42923e8dad76237cae1f8be3f3.addTo(map_acd61ea3f27ae58fa6894c7f4bc6b7e0);
#
#
#             var choropleth_8124882337dcc5c8dfa2266f1f5c29fa = L.featureGroup(
#                 {
# }
#             );
#
#
#         function geo_json_517d8949be6e4b0a58c231894c60cfa3_styler(feature) {
#             switch(feature.id) {
#                 case &quot;AL&quot;: case &quot;AK&quot;: case &quot;AR&quot;: case &quot;CO&quot;: case &quot;DE&quot;: case &quot;ME&quot;: case &quot;MD&quot;: case &quot;NM&quot;: case &quot;OH&quot;: case &quot;TN&quot;: case &quot;WA&quot;: case &quot;WV&quot;: case &quot;WI&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#78c679&quot;, &quot;fillOpacity&quot;: 0.6, &quot;opacity&quot;: 1, &quot;weight&quot;: 1};
#                 case &quot;AZ&quot;: case &quot;CT&quot;: case &quot;FL&quot;: case &quot;GA&quot;: case &quot;IL&quot;: case &quot;IN&quot;: case &quot;KY&quot;: case &quot;MI&quot;: case &quot;MS&quot;: case &quot;NY&quot;: case &quot;OR&quot;: case &quot;PA&quot;: case &quot;SC&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#31a354&quot;, &quot;fillOpacity&quot;: 0.6, &quot;opacity&quot;: 1, &quot;weight&quot;: 1};
#                 case &quot;CA&quot;: case &quot;NV&quot;: case &quot;NJ&quot;: case &quot;NC&quot;: case &quot;RI&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#006837&quot;, &quot;fillOpacity&quot;: 0.6, &quot;opacity&quot;: 1, &quot;weight&quot;: 1};
#                 case &quot;HI&quot;: case &quot;IA&quot;: case &quot;OK&quot;: case &quot;SD&quot;: case &quot;UT&quot;: case &quot;VT&quot;: case &quot;WY&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#d9f0a3&quot;, &quot;fillOpacity&quot;: 0.6, &quot;opacity&quot;: 1, &quot;weight&quot;: 1};
#                 case &quot;ID&quot;: case &quot;KS&quot;: case &quot;LA&quot;: case &quot;MA&quot;: case &quot;MN&quot;: case &quot;MO&quot;: case &quot;MT&quot;: case &quot;NH&quot;: case &quot;TX&quot;: case &quot;VA&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#addd8e&quot;, &quot;fillOpacity&quot;: 0.6, &quot;opacity&quot;: 1, &quot;weight&quot;: 1};
#                 default:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#ffffcc&quot;, &quot;fillOpacity&quot;: 0.6, &quot;opacity&quot;: 1, &quot;weight&quot;: 1};
#             }
#         }
#
#         function geo_json_517d8949be6e4b0a58c231894c60cfa3_onEachFeature(feature, layer) {
#             layer.on({
#             });
#         };
#         var geo_json_517d8949be6e4b0a58c231894c60cfa3 = L.geoJson(null, {
#                 onEachFeature: geo_json_517d8949be6e4b0a58c231894c60cfa3_onEachFeature,
#
#                 style: geo_json_517d8949be6e4b0a58c231894c60cfa3_styler,
#             ...{
# }
#         });
#
#         function geo_json_517d8949be6e4b0a58c231894c60cfa3_add (data) {
#             geo_json_517d8949be6e4b0a58c231894c60cfa3
#                 .addData(data);
#         }
#             geo_json_517d8949be6e4b0a58c231894c60cfa3_add({&quot;features&quot;: [{&quot;geometry&quot;: {&quot;coordinates&quot;: [[[-87.359296, 35.00118], [-85.606675, 34.984749], [-85.431413, 34.124869], [-85.184951, 32.859696], [-85.069935, 32.580372], [-84.960397, 32.421541], [-85.004212, 32.322956], [-84.889196, 32.262709], [-85.058981, 32.13674], [-85.053504, 32.01077], [-85.141136, 31.840985], [-85.042551, 31.539753], [-85.113751, 31.27686], [-85.004212, 31.003013], [-85.497137, 30.997536], [-87.600282, 30.997536], [-87.633143, 30.86609], [-87.408589, 30.674397], [-87.446927, 30.510088], [-87.37025, 30.427934], [-87.518128, 30.280057], [-87.655051, 30.247195], [-87.90699, 30.411504], [-87.934375, 30.657966], [-88.011052, 30.685351], [-88.10416, 30.499135], [-88.137022, 30.318396], [-88.394438, 30.367688], [-88.471115, 31.895754], [-88.241084, 33.796253], [-88.098683, 34.891641], [-88.202745, 34.99

# %%
#한국 지도 데이터 이용해서 단계 구분도 그리기
import json
#한국지도 경계의 json data 파일 가져오기
#한글이 포함된경우에는 그냥 path만 연결하면 인코딩 문제 발생
#json.load( encoding='utf-8') 이용해서 변수에 data 저장 후 사용하는 것이 일반적

geo_path='./data/02. skorea_municipalities_geo_simple.json'
geo_str = json.load(open(geo_path,encoding='utf-8'))
# geo_str

#서울을 중심으로 기본 지도 출력
#위경도[37.5502,126.982]
map=folium.Map(location=[37.5502,126.982],
               zoom_start=11,
               tiles='OpenStreetMap')
map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_116b458fc9046348bebf5792d2dbbad4 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_116b458fc9046348bebf5792d2dbbad4&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_116b458fc9046348bebf5792d2dbbad4 = L.map(
#                 &quot;map_116b458fc9046348bebf5792d2dbbad4&quot;,
#                 {
#                     center: [37.5502, 126.982],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 11,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_ad7c3e7ef179b10856e13f47cd6e6076 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_ad7c3e7ef179b10856e13f47cd6e6076.addTo(map_116b458fc9046348bebf5792d2dbbad4);
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
#단계 구분도 data 읽어오기
#csv 읽어오기 : pd.read_csv(경로포함파일명,encoding=,index_col='지정인덱스 필드명')
f_test=pd.read_csv('./data/cctv_result.csv',encoding='utf-8',index_col='구별')
f_test.head()
# Out:
#        소계       최근증가율       인구수       한국인      외국인      고령자     외국인비율  \
# 구별
# 강남구  2780  150.619195  570500.0  565550.0   4950.0  63167.0  0.867660
# 강동구   773  166.490765  453233.0  449019.0   4214.0  54622.0  0.929765
# 강북구   748  125.203252  330192.0  326686.0   3506.0  54813.0  1.061806
# 강서구   884  134.793814  603772.0  597248.0   6524.0  72548.0  1.080540
# 관악구  1496  149.290780  525515.0  507203.0  18312.0  68082.0  3.484582
#
#          고령자비율    CCTV비율           오차
# 구별
# 강남구  11.072217  0.487292  1388.055355
# 강동구  12.051638  0.170552   465.422892
# 강북구  16.600342  0.226535   329.342026
# 강서구  12.015794  0.146413   551.503155
# 관악구  12.955291  0.284673   162.948104

# %%
folium.Choropleth(geo_data=geo_str,
               data=f_test,
               columns=[f_test.index,'소계'],
               key_on = 'feature.id',
               fill_color='GnBu',
               legend_name='CCTV 현황').add_to(map)
folium.LayerControl().add_to(map)
map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_116b458fc9046348bebf5792d2dbbad4 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/d3/3.5.5/d3.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_116b458fc9046348bebf5792d2dbbad4&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_116b458fc9046348bebf5792d2dbbad4 = L.map(
#                 &quot;map_116b458fc9046348bebf5792d2dbbad4&quot;,
#                 {
#                     center: [37.5502, 126.982],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 11,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_ad7c3e7ef179b10856e13f47cd6e6076 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_ad7c3e7ef179b10856e13f47cd6e6076.addTo(map_116b458fc9046348bebf5792d2dbbad4);
#
#
#             tile_layer_ad7c3e7ef179b10856e13f47cd6e6076.addTo(map_116b458fc9046348bebf5792d2dbbad4);
#
#
#             var choropleth_6c79b2c57621e5f5457e845972e02e7c = L.featureGroup(
#                 {
# }
#             );
#
#
#         function geo_json_2f1d57852c3bd54524d24b2f0768fa04_styler(feature) {
#             switch(feature.id) {
#                 case &quot;\uac15\ub3d9\uad6c&quot;: case &quot;\uc1a1\ud30c\uad6c&quot;: case &quot;\ub9c8\ud3ec\uad6c&quot;: case &quot;\ub3c4\ubd09\uad6c&quot;: case &quot;\uac15\ubd81\uad6c&quot;: case &quot;\uc911\ub791\uad6c&quot;: case &quot;\uad11\uc9c4\uad6c&quot;: case &quot;\uc911\uad6c&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#f0f9e8&quot;, &quot;fillOpacity&quot;: 0.6, &quot;opacity&quot;: 1, &quot;weight&quot;: 1};
#                 case &quot;\uac15\ub0a8\uad6c&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#0868ac&quot;, &quot;fillOpacity&quot;: 0.6, &quot;opacity&quot;: 1, &quot;weight&quot;: 1};
#                 case &quot;\uc11c\ucd08\uad6c&quot;: case &quot;\uc740\ud3c9\uad6c&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#7bccc4&quot;, &quot;fillOpacity&quot;: 0.6, &quot;opacity&quot;: 1, &quot;weight&quot;: 1};
#                 case &quot;\uad00\uc545\uad6c&quot;: case &quot;\uad6c\ub85c\uad6c&quot;: case &quot;\ub178\uc6d0\uad6c&quot;: case &quot;\uc131\ubd81\uad6c&quot;: case &quot;\ub3d9\ub300\ubb38\uad6c&quot;: case &quot;\uc6a9\uc0b0\uad6c&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#a8ddb5&quot;, &quot;fillOpacity&quot;: 0.6, &quot;opacity&quot;: 1, &quot;weight&quot;: 1};
#                 case &quot;\ub3d9\uc791\uad6c&quot;: case &quot;\uc601\ub4f1\ud3ec\uad6c&quot;: case &quot;\uae08\ucc9c\uad6c&quot;: case &quot;\uac15\uc11c\uad6c&quot;: case &quot;\uc11c\ub300\ubb38\uad6c&quot;: case &quot;\uc131\ub3d9\uad6c&quot;: case &quot;\uc885\ub85c\uad6c&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#ccebc5&quot;, &quot;fillOpacity&quot;: 0.6, &quot;opacity&quot;: 1, &quot;weight&quot;: 1};
#                 default:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#43a2ca&quot;, &quot;fillOpacity&quot;: 0.6, &quot;opacity&quot;: 1, &quot;weight&quot;: 1};
#             }
#         }
#
#         function geo_json_2f1d57852c3bd54524d24b2f0768fa04_onEachFeature(feature, layer) {
#             layer.on({
#             });
#         };
#         var geo_json_2f1d57852c3bd54524d24b2f0768fa04 = L.geoJson(null, {
#                 onEachFeature: geo_json_2f1d57852c3bd54524d24b2f0768fa04_onEachFeature,
#
#                 style: geo_json_2f1d57852c3bd54524d24b2f0768fa04_styler,
#             ...{
# }
#         });
#
#         function geo_json_2f1d57852c3bd54524d24b2f0768fa04_add (data) {
#             geo_json_2f1d57852c3bd54524d24b2f0768fa04
#                 .addData(data);
#         }
#             geo_json_2f1d57852c3bd54524d24b2f0768fa04_add({&quot;features&quot;: [{&quot;geometry&quot;: {&quot;coordinates&quot;: [[[127.11519584981606, 37.557533180704915], [127.16683184366129, 37.57672487388627], [127.18408792330152, 37.55814280369575], [127.16530984307447, 37.54221851258693], [127.14672806823502, 37.51415680680291], [127.12123165719615, 37.52528270089], [127.1116764203608, 37.540669955324965], [127.11519584981606, 37.557533180704915]]], &quot;type&quot;: &quot;Polygon&quot;}, &quot;id&quot;: &quot;\uac15\ub3d9\uad6c&quot;, &quot;properties&quot;: {&quot;base_year&quot;: &quot;2013&quot;, &quot;code&quot;: &quot;11250&quot;, &quot;name&quot;: &quot;\uac15\ub3d9\uad6c&quot;, &quot;name_eng&quot;: &quot;Gangdong-gu&quot;}, &quot;type&quot;: &quot;Feature&quot;}, {&quot;geometry&quot;: {&quot;coordinates&quot;: [[[127.0690698130372, 37.522279423505026], [127.10087519791962, 3
