# %% [markdown]
# ### 포털사이트 크롤링
# - 소스내에서 특정 문자열(data)을 지칭하는 선택자 얻기
#     - 크롬 개발자도구 사용
# - 전체 코드에서 수집하려고 하는 데이터(태그)의 위치를 찾고
#     - 태그를 파싱한 후 필요데이터 추출

# %%
from urllib.request import urlopen # 서버 요청/응답 패키지
import bs4 # 파싱패키지

# %%
# 네이버 사이트의 기본 메뉴 문구 추출
url = 'https://www.naver.com'

# url로 요청후 응답
html = urlopen(url)

# 파서객체 생성 - bs4 객체로 변환
bs_obj = bs4.BeautifulSoup(html, 'html.parser')

# %%
bs_obj
# Out:
#  <!DOCTYPE html>
#  <html class="fzoom" lang="ko"> <head> <meta charset="utf-8"/> <meta content="origin" name="Referrer"/> <meta content="IE=edge" http-equiv="X-UA-Compatible"/> <meta content="width=1190" name="viewport"/> <title>NAVER</title> <meta content="NAVER" name="apple-mobile-web-app-title"> <meta content="index,nofollow" name="robots"> <meta content="네이버 메인에서 다양한 정보와 유용한 컨텐츠를 만나 보세요" name="description"> <meta content="네이버" property="og:title"/> <meta content="https://www.naver.com/" property="og:url"/> <meta content="https://s.pstatic.net/static/www/mobile/edit/2016/0705/mobile_212852414260.png" property="og:image"/> <meta content="네이버 메인에서 다양한 정보와 유용한 컨텐츠를 만나 보세요" property="og:description"> <meta content="summary" name="twitter:card"/> <meta content="" name="twitter:title"/> <meta content="https://www.naver.com/" name="twitter:url"/> <meta content="https://s.pstatic.net/static/www/mobile/edit/2016/0705/mobile_212852414260.png" name="twitter:image"/> <meta content="네이버 메인에서 다양한 정보와 유용한 컨텐츠를 만나 보세요" name="twitter:description"> <meta content="uru5NJKa1Bfr5nv5AdQ26Qat7UrPU_02l-PIZRLzI-g" name="google-site-verification"> <link href="/favicon.ico?1" rel="shortcut icon" type="image/x-icon"/> <link href="https://s.pstatic.net/static/www/nFavicon96.png" rel="apple-touch-icon-precomposed"> <link href="https://s.pstatic.net/static/www/u/2014/0328/mma_204243574.png" rel="apple-touch-icon" sizes="114x114"/> <link href="https://s.pstatic.net/static/www/u/2014/0328/mma_20432863.png" rel="apple-touch-icon"/> <link href="https://ssl.pstatic.net/sstatic/search/pc/css/sp_autocomplete_241121.css" rel="stylesheet"/> <link href="https://www.naver.com/" rel="canonical"/> <link href="https://m.naver.com/" media="only screen and (max-width: 767px)" rel="alternate"/> <script>window.gladsdk=window.gladsdk||{},window.gladsdk.cmd=window.gladsdk.cmd||[],window.ndpsdk=window.ndpsdk||{},window.ndpsdk.cmd=window.ndpsdk.cmd||[],window.ndpsdk.polyfill=window.ndpsdk.polyfill||{cmd:[]};var g_ssc="navertop.v5";window.nsc=g_ssc,window.nmain=window.nmain||{},window.nmain.jsOrigin="www"</script> <script>window.ntm=window.ntm||[]</script> <script async="" src="https://ssl.pstatic.net/tveta/libs/ndpsdk/prod/ndp-loader.js"></script> <script async="" src="https://ssl.pstatic.net/tveta/libs/glad/prod/gfp-core.js"></script> <script defer="defer" src="https://ssl.pstatic.net/tveta/libs/assets/js/pc/main/min/pc.veta.core.min.js"></script> <script>
# window["EAGER-DATA"] = window["EAGER-DATA"] || {};
# window["EAGER-DATA"]["PC-FEED-WRAPPER"] = {"@type":"BLOCK","blocks":[{"@type":"BLOCK","blocks":[{"@type":"BLOCK","blocks":null,"materials":[{"@type":"MATERIAL-PC-FEED","title":"데일리룩 장인 김나영의 데일리백 추천템!","url":"https://in.naver.com/meandyou_vvvv/topic/781834816417792","image":{"url":"https://s.pstatic.net/dthumb.phinf/?src=%22https%3A%2F%2Finfluencer-phinf.pstatic.net%2FMjAyNTAxMThfMTc5%2FMDAxNzM3MTc4MzQwOTI3.6abMLgB2_U3nV5i8sBQg1LEJNx42q1THv1GijMMV7SAg.dWSlvJhqRGdluionmI4wMqljI1r52plsmxEz3jEJbQQg.PNG%2F735c.png%22&type=ff364_236&service=navermain"},"source":{"name":"키묘링","image":{"url":"https://s.pstatic.net/dthumb.phinf/?src=%22https%3A%2F%2Fblogpfthumb-phinf.pstatic.net%2FMjAyMjA5MjVfMjEz%2FMDAxNjY0MDg0MDY1ODk5.RE_tXVtPilLNoagu326pfDjAkL-BjHKG0Z2LUmCuu54g.32RTIVRsPjqboJh2aHGyTdV4PG7v5VK0iVSEc6KSw3gg.PNG.thdgywjd987%2FprofileImage.png%22&type=nf40_40&service=navermain"}},"showLiveBadge":false,"_id":"654ad80598c6dbca70ba6cce"},{"@type":"MATERIAL-PC-FEED","title":"만원 이하로 챙기는 스킨케어! 다이소 기초템 추천","url":"https://in.naver.com/sisi/topic/782318916218752","image":{"url":"https://s.pstatic.net/dthumb.phinf/?src=%22https%3A%2F%2Finfluencer-phinf.pstatic.net%2FMjAyNTAxMTlfMjYw%2FMDAxNzM3Mjk2NDAwOTM1.rfcSg_ZJmCWvgIWOP1QE1Wzqwrx18MJHp5IyLJN8jm0g.JY46vgzB-8PaU6CAOzUQkvfcIgHGDcNarlbmE7OGVvwg.PNG%2Fafb2.png%22&type=ff364_236&service=navermain"},"source":{"name":"뷰스타 시시","image":{"url":"https://s.pstatic.net/dthumb.phinf/?src=%22https%3A%2F%2Fblogpfthumb-phinf.pstatic.net%2FMjAyNDAyMTZfMTc5%2FMDAxNzA4MDQ4MTcwOTc2.EmOzFA6gqateYuhl_5_G10q7yegvOXmBWj1mpNKpuScg.LDTbjd51J_0hgoa1f96EEOVrSI_FIRQB5xyj3qqOWQEg.JPEG.njuiwwik%2FKakaoTalk_20240215_165857085_01_%25EB%25B3%25B5%25EC%2582%25AC_2.jpg%2FKakaoTalk_20240215_165857085_01%2B%25EB%25B3%25B5%25EC%2582%25AC%2B2.jpg%22&type=nf40_40&service=navermain"}},"showLiveBadge":false,"_id":"654ad80598c6dbca70ba6ccf"},{"@type":"MATERIAL-PC-FEED","title":"겨울철 미스트 종류별 특징 알아보기","url":"https://in.naver.com/masung_xoxo/topic/781927968301024","image":{"url":"https://s.pstatic.net/dthumb.phinf/?src=%22https%3A%2F%2Finfluencer-phinf.pstatic.net%2FMjAyNTAxMTVfMTM5%2FMDAxNzM2ODcwMDY4MzE3.qGdl3K4K_JIXRQnH3lhfUhiXiyL5yg2L_6T9_3V6eMMg.-pJ0DpbjGxKFi0S_CUTMtXelKKbpnqWeVstfu4olg_4g.PNG%2F3abc.png%22&type=ff364_236&service=navermain"},"source":{"name":"마성술키","image":{"url":"https://s.pstatic.net/dthumb.phinf/?src=%22https%3A%2F%2Fblogpfthumb-phinf.pstatic.net%2FMjAyMzAyMjdfNTMg%2FMDAxNjc3NDk5MTkwMTA1.zUAS5zEWOk-BICUvVdoC0uNns-JKWD7wMZH1l3G2Xsgg.ELPIZ_zelZkgTgsMpyYv2t-sAtxXequ8ajUIzsaG8cog.PNG.admaster81%2FprofileImage.png%22&type=nf40_40&service=navermain"}},"showLiveBadge":false,"_id":"654ad80598c6dbca70ba6cd0"},{"@type":"MATERIAL-PC-FEED","title":"인간디올 블핑 지수 pick 디올 가방?","url":"https://in.naver.com/hoho_fashion/topic/782480715182048","image":{"url":"https://s.pstatic.net/dthumb.phinf/?src=%22https%3A%2F%2Finfluencer-phinf.pstatic.net%2FMjAyNTAxMjBfNTAg%2FMDAxNzM3MzM1NjQxMDA3.p9Ie57o-MjXkHUnO4OgeKdgE5g86noOMosZLXs6gbiAg.dWm_lKQvCelcMBV_p3_kLgFXTqWPk_BPGy0hnP8d1Vkg.PNG%2F2093.png%22&type=ff364_236&service=navermain"},"source":{"name":"몸큰남자 호호","image":{"url":"https://s.pstatic.net/dthumb.phinf/?src=%22https%3A%2F%2Fhomebuilder-phinf.pstatic.net%2FMjAyMzAzMjJfNjQg%2FMDAxNjc5NDEzNjM5Nzc1.KL7S-xfZtXXyU_L18OGqMl2UzgsfkG7rPnz1yX6FtuYg.axR-8HHby0skZHN32cW3IEDKfRv0gsh1NFuPZ1FSScsg.JPEG%2F1679413639736_KakaoTalk_20220728_010546701_02.jpg%22&type=nf40_40&service=navermain"}},"showLiveBadge":false,"_id":"654ad80598c6dbca70ba6cd1"},{"@type":"MATERIAL-PC-FEED","title":"갓성비라는 20대 여자 가방 브랜드‼️","url":"https://in.naver.com/redbeom.92/topic/781765255753600","image":{"url":"https://s.pstatic.net/dthumb.phinf/?src=%22https%3A%2F%2Finfluencer-phinf.pstatic.net%2FMjAyNTAxMThfMjc4%2FMDAxNzM3MTYxMzY0NTE2.tch9zsa6jk3x655htH7iwgod_N1OY_Gf0CuG88vYDIwg.MWyoPllGXx1wjliqbkzozLolvy7IZr9XS9AlN6OGkJMg.PNG%2F8113.png%22&type=ff364_236&service=navermain"},"source":{"name":"호랭이","image":{"url":"https://s.pstatic.net/dthumb.phinf/?src=%22https%3A%2F%2Fhomebuilder-phi ...
# window["EAGER-DATA"]["CAS-MINICONTENT-PC-SPECIAL-LOGO"] = {"@type":"MINI-CONTENT-BLOCK","blocks":null,"materials":null,"excludeInPaging":false,"positionForPaging":0,"realtime":false,"items":[],"_id":"6433d8e3a10d3006850274e8","@type":"MINI-CONTENT-BLOCK","@code":"CAS-MINICONTENT-PC-SPECIAL-LOGO","@template":"NONE","@flowId":"CAS-MINICONTENT","@flowExecutionId":"3da482d3-d703-11ef-bb94-ffa748db74b5","@provider":"lambda","@lastModifiedAt":[2025,1,20,7,50,39,122000000]}
# window["EAGER-DATA"]["PC-MEDIA-WRAPPER"] = {"@type":"PC-MEDIA-CONTENTS-BLOCK","blocks":[{"@type":"BLOCK","blocks":[{"@type":"PC-NEWSSTAND-BLOCK","blocks":[{"@type":"PC-NEWSSTAND-PRESS-BLOCK","blocks":null,"materials":null,"excludeInPaging":false,"positionForPaging":0,"realtime":false,"pid":"907","name":"경북매일신문","logoLight":{"url":"https://s.pstatic.net/static/newsstand/2020/logo/light/0604/907.png"},"logoDark":{"url":"https://s.pstatic.net/static/newsstand/2020/logo/dark/0604/907.png"},"showThumbnailView":true,"showListView":true,"regDate":"20250120 16:40:47","_id":null,"@type":"PC-NEWSSTAND-PRESS-BLOCK","@code":null,"@template":"NONE","@flowId":null,"@flowExecutionId":null,"@provider":null,"@lastModifiedAt":null},{"@type":"PC-NEWSSTAND-PRESS-BLOCK","blocks":null,"materials":null,"excludeInPaging":false,"positionForPaging":0,"realtime":false,"pid":"908","name":"국방일보","logoLight":{"url":"https://s.pstatic.net/static/newsstand/2020/logo/light/0604/908.png"},"logoDark":{"url":"https://s.pstatic.net/static/newsstand/2020/logo/dark/0604/908.png"},"showThumbnailView":true,"showListView":true,"regDate":"20250119 15:45:11","_id":null,"@type":"PC-NEWSSTAND-PRESS-BLOCK","@code":null,"@template":"NONE","@flowId":null,"@flowExecutionId":null,"@provider":null,"@lastModifiedAt":null},{"@type":"PC-NEWSSTAND-PRESS-BLOCK","blocks":null,"materials":null,"excludeInPaging":false,"positionForPaging":0,"realtime":false,"pid":"909","name":"기호일보","logoLight":{"url":"https://s.pstatic.net/static/newsstand/2020/logo/light/0604/909.png"},"logoDark":{"url":"https://s.pstatic.net/static/newsstand/2020/logo/dark/0604/909.png"},"showThumbnailView":true,"showListView":true,"regDate":"20250120 11:59:57","_id":null,"@type":"PC-NEWSSTAND-PRESS-BLOCK","@code":null,"@template":"NONE","@flowId":null,"@flowExecutionId":null,"@provider":null,"@lastModifiedAt":null},{"@type":"PC-NEWSSTAND-PRESS-BLOCK","blocks":null,"materials":null,"excludeInPaging":false,"positionForPaging":0,"realtime":false,"pid":"353","name":"중앙SUNDAY","logoLight":{"url":"https://s.pstatic.net/static/newsstand/2020/logo/light/0604/353.png"},"logoDark":{"url":"https://s.pstatic.net/static/newsstand/2020/logo/dark/0604/353.png"},"showThumbnailView":true,"showListView":true,"regDate":"20250120 13:49:23","_id":null,"@type":"PC-NEWSSTAND-PRESS-BLOCK","@code":null,"@template":"NONE","@flowId":null,"@flowExecutionId":null,"@provider":null,"@lastModifiedAt":null},{"@type":"PC-NEWSSTAND-PRESS-BLOCK","blocks":null,"materials":null,"excludeInPaging":false,"positionForPaging":0,"realtime":false,"pid":"354","name":"엘르","logoLight":{"url":"https://s.pstatic.net/static/newsstand/2020/logo/light/0604/354.png"},"logoDark":{"url":"https://s.pstatic.net/static/newsstand/2020/logo/dark/0604/354.png"},"showThumbnailView":true,"showListView":true,"regDate":"20250120 16:45:22","_id":null,"@type":"PC-NEWSSTAND-PRESS-BLOCK","@code":null,"@template":"NONE","@flowId":null,"@flowExecutionId":null,"@provider":null,"@lastModifiedAt":null},{"@type":"PC-NEWSSTAND-PRESS-BLOCK","blocks":null,"materials":null,"excludeInPaging":false,"positionForPaging":0,"realtime":false,"pid":"355","name":"사이언스타임즈","logoLight":{"url":"https://s.pstatic.net/static/newsstand/2020/logo/light/0604/355.png"},"logoDark":{"url":"https://s.pstatic.net/static/newsstand/2020/logo/dark/0604/355.png"},"showThumbnailView":true,"showListView":true,"regDate":"20250117 09:33:25","_id":null,"@type":"PC-NEWSSTAND-PRESS-BLOCK","@code":null,"@template":"NONE","@flowId":null,"@flowExecutionId":null,"@provider":null,"@lastModifiedAt":null},{"@type":"PC-NEWSSTAND-PRESS-BLOCK","blocks":null,"materials":null,"excludeInPaging":false,"positionForPaging":0,"realtime":false,"pid":"356","name":"게임메카","logoLight":{"url":"https://s.pstatic.net/static/newsstand/2020/logo/light/0604/356.png"},"logoDark":{"url":"https://s.pstatic.net/static/newsstand/2020/logo/dark/0604/356.png"},"showThumbnailView":true,"showListView":true,"regDate":"20250120 16:23:54","_id":null,"@type":"PC-NEWS ...
# window["EAGER-DATA"]["PC-NEWSSTAND-YONHAP"] = {"@type":"BLOCK","blocks":[{"@type":"BLOCK","blocks":null,"materials":[],"excludeInPaging":false,"positionForPaging":0,"realtime":false,"_id":null,"@type":"BLOCK","@code":null,"@template":"NONE","@flowId":null,"@flowExecutionId":null,"@provider":null,"@lastModifiedAt":null}],"materials":[{"@type":"MATERIAL-PC-NEWS-ONELINE","gdid":null,"title":"공수처, 尹 강제구인 검토…집행되면 역대 대통령 처음","url":"https://news.naver.com/main/list.naver?mode=LPOD&mid=sec&sid1=001&sid2=140&oid=001&isYeonhapFlash=Y&aid=0015170070","aid":null,"emergency":false,"notCompleted":false,"officeName":"연합뉴스","officeId":"001","officeHomeUrl":null,"officeWeight":0,"officeWeightRate":0.0,"_id":"643543b2caf3d87b7e0a0da6"},{"@type":"MATERIAL-PC-NEWS-ONELINE","gdid":null,"title":"검찰, 공수처에 尹대통령 사건 송부 일정 협의 요청","url":"https://news.naver.com/main/list.naver?mode=LPOD&mid=sec&sid1=001&sid2=140&oid=001&isYeonhapFlash=Y&aid=0015170117","aid":null,"emergency":false,"notCompleted":false,"officeName":"연합뉴스","officeId":"001","officeHomeUrl":null,"officeWeight":0,"officeWeightRate":0.0,"_id":"677344ca0dae05b66ec43489"},{"@type":"MATERIAL-PC-NEWS-ONELINE","gdid":null,"title":"尹 21일 탄핵심판 나올까…\"곧 출석\"·헌재 \"밝힐 단계 아냐\"","url":"https://news.naver.com/main/list.naver?mode=LPOD&mid=sec&sid1=001&sid2=140&oid=001&isYeonhapFlash=Y&aid=0015169885","aid":null,"emergency":false,"notCompleted":false,"officeName":"연합뉴스","officeId":"001","officeHomeUrl":null,"officeWeight":0,"officeWeightRate":0.0,"_id":"677344ca0dae05b66ec4348a"},{"@type":"MATERIAL-PC-NEWS-ONELINE","gdid":null,"title":"경찰, 안가·경호처 압수수색…CCTV·계엄문건 확보 재시도","url":"https://news.naver.com/main/list.naver?mode=LPOD&mid=sec&sid1=001&sid2=140&oid=001&isYeonhapFlash=Y&aid=0015169586","aid":null,"emergency":false,"notCompleted":false,"officeName":"연합뉴스","officeId":"001","officeHomeUrl":null,"officeWeight":0,"officeWeightRate":0.0,"_id":"677344ca0dae05b66ec4348b"},{"@type":"MATERIAL-PC-NEWS-ONELINE","gdid":null,"title":"경찰청장 대행 \"서부지법 난동 체포자들 훈방 약속한 적 없다\"","url":"https://news.naver.com/main/list.naver?mode=LPOD&mid=sec&sid1=001&sid2=140&oid=001&isYeonhapFlash=Y&aid=0015169897","aid":null,"emergency":false,"notCompleted":false,"officeName":"연합뉴스","officeId":"001","officeHomeUrl":null,"officeWeight":0,"officeWeightRate":0.0,"_id":"677344ca0dae05b66ec4348c"},{"@type":"MATERIAL-PC-NEWS-ONELINE","gdid":null,"title":"비트코인, 트럼프 취임 직전 최고가 경신…10만8천943달러","url":"https://news.naver.com/main/list.naver?mode=LPOD&mid=sec&sid1=001&sid2=140&oid=001&isYeonhapFlash=Y&aid=0015170184","aid":null,"emergency":true,"notCompleted":false,"officeName":"연합뉴스","officeId":"001","officeHomeUrl":null,"officeWeight":0,"officeWeightRate":0.0,"_id":"677344ca0dae05b66ec4348d"},{"@type":"MATERIAL-PC-NEWS-ONELINE","gdid":null,"title":"'8인 체제' 헌재 23일 심판 선고…이진숙 탄핵 등 40여건","url":"https://news.naver.com/main/list.naver?mode=LPOD&mid=sec&sid1=001&sid2=140&oid=001&isYeonhapFlash=Y&aid=0015170179","aid":null,"emergency":false,"notCompleted":false,"officeName":"연합뉴스","officeId":"001","officeHomeUrl":null,"officeWeight":0,"officeWeightRate":0.0,"_id":"677344ca0dae05b66ec4348e"},{"@type":"MATERIAL-PC-NEWS-ONELINE","gdid":null,"title":"수능 논·서술 도입 논의…고교학점제·2028대입 엇박자 지적도","url":"https://news.naver.com/main/list.naver?mode=LPOD&mid=sec&sid1=001&sid2=140&oid=001&isYeonhapFlash=Y&aid=0015170168","aid":null,"emergency":false,"notCompleted":false,"officeName":"연합뉴스","officeId":"001","officeHomeUrl":null,"officeWeight":0,"officeWeightRate":0.0,"_id":"677344ca0dae05b66ec4348f"},{"@type":"MATERIAL-PC-NEWS-ONELINE","gdid":null,"title":"커피 가격 줄인상…스타벅스, 아메리카노 톨 4천700원으로 올려","url":"https://news.naver.com/main/list.naver?mode=LPOD&mid=sec&sid1=001&sid2=140&oid=001&isYeonhapFlash=Y&aid=0015169794","aid":null,"emergency":false,"notCompleted":false,"officeName":"연합뉴스","officeId":"001","officeHomeUrl":null,"officeWeight":0,"officeWeightRate":0.0,"_id":"6785b91692afb581c3951648"},{"@type":"MATERIAL-PC-NEWS-ONELINE","gdid":null,"title":"尹 체포 당일 공수처 인근 분신 50대, 사고 엿새째 사망" ...
# window["EAGER-DATA"]["CAS-MINICONTENT-PC-SEARCH-RIGHT"] = {"@type":"MINI-CONTENT-BLOCK","blocks":null,"materials":null,"excludeInPaging":false,"positionForPaging":0,"realtime":false,"items":[],"_id":"6433d8a5a10d300685012682","@type":"MINI-CONTENT-BLOCK","@code":"CAS-MINICONTENT-PC-SEARCH-RIGHT","@template":"NONE","@flowId":"CAS-MINICONTENT","@flowExecutionId":"3c724452-d703-11ef-bb94-65c8e90cf105","@provider":"lambda","@lastModifiedAt":[2025,1,20,7,50,37,116000000]}
# window["EAGER-DATA"]["PC-HEADLINE-AD"] = {"@type":"PC-HEADLINE-AD-BLOCK","blocks":null,"materials":null,"excludeInPaging":false,"positionForPaging":0,"realtime":false,"adResponse":{"type":"N401","adlineId":"2978437","vimp100p0s":"https://siape.veta.naver.com/fxview?eu=EU10044129&calp=-&oj=ZJlEFeSBKmLf40n3ktJ9%2FHMYAo6AWNPD%2FOr5cIjh%2B5X68465N59uqSGNcbrnFmKn&ac=9069840&src=7424333&evtcd=V900&x_ti=1585&tb=&oid=&sid1=&sid2=&rk=gzayq5fzuRiDbc4s9xkHjQ&eltts=gGmMKM%2FMIaD%2FFjSuD6ilUQ%3D%3D&brs=Y&&eid=V900","assets":{"hl_web_img":{"url":"https://ssl.pstatic.net/melona/libs/1518/1518397/e3de1f7b257da2eda1d6_20250103110222016.png","alt":"[광고]선물은 여기서 고르세요 뉴트리원 설 선물 특가","w":488,"h":216},"hl_web_img_dark":{"url":"https://ssl.pstatic.net/melona/libs/1518/1518397/41f061e696a43c9a7b11_20250103110225096.png","alt":"[광고]선물은 여기서 고르세요 뉴트리원 설 선물 특가","w":488,"h":216},"hl_link":{"url":"https://siape.veta.naver.com/fxclick?eu=EU10044129&calp=-&oj=ZJlEFeSBKmLf40n3ktJ9%2FHMYAo6AWNPD%2FOr5cIjh%2B5X68465N59uqSGNcbrnFmKn&ac=9069840&src=7424333&br=4663169&evtcd=P901&x_ti=1585&tb=&oid=&sid1=&sid2=&rk=gzayq5fzuRiDbc4s9xkHjQ&eltts=gGmMKM%2FMIaD%2FFjSuD6ilUQ%3D%3D&brs=Y&&tr=ndp&na=s_380031316681763092&a=2116843A12D422285FF8903A5E8099024A30EFD91EE4B66D372D465D6FD0DAF9E04DF88A1B76CF44EF897866780E66865EF1755EDC3BC17239990D82F42F4987553D2E913354A0DEDEAEDF6CDC3B21784E88028F3BA06B7223DA2FF235FE9E932539603A7D2F4C1E3E36A990FD84190E","clicktracking":"https://ssl.pstatic.net/tveta/libs/1by1.gif"},"bb_web_img":{"url":"https://ssl.pstatic.net/melona/libs/1518/1518397/459db411b2184dfdb5e8_20250103110227360.jpg","alt":"뉴트리원","w":80,"h":80},"bb_web_img_dark":{"url":"https://ssl.pstatic.net/melona/libs/1518/1518397/459db411b2184dfdb5e8_20250103110227360.jpg","alt":"뉴트리원","w":80,"h":80},"bb_link":{"url":"https://siape.veta.naver.com/fxclick?eu=EU10044129&calp=-&oj=ZJlEFeSBKmLf40n3ktJ9%2FHMYAo6AWNPD%2FOr5cIjh%2B5X68465N59uqSGNcbrnFmKn&ac=9069840&src=7424335&br=4663170&evtcd=BUBBLE_CLK_1&x_ti=1585&tb=&oid=&sid1=&sid2=&rk=gzayq5fzuRiDbc4s9xkHjQ&eltts=gGmMKM%2FMIaD%2FFjSuD6ilUQ%3D%3D&brs=Y&&tr=ndp&na=s_380031316681763092&a=8336A461175A15A833C2277A785FE9D89EF1F850F55274611D5102508702BD858C15878407C0E523205065D019185781BFCB095C481BBD233B64EE116E04AEB4996D475E555703949B01401CF55A17E265DBB92BD696F3BB1A52DAC3345CE64F2B12BD68CED07F5E4B71BBCD532C8F5A","clicktracking":"https://ssl.pstatic.net/tveta/libs/1by1.gif"},"bb_web_text":"뉴트리원"}},"_id":null,"@type":null,"@code":"PC-HEADLINE-AD","@template":"PC-HEADLINE-AD","@flowId":null,"@flowExecutionId":null,"@provider":null,"@lastModifiedAt":null}
# window["EAGER-DATA"]["CAS-MINICONTENT-PC-MEDIA-TAB-EVENT"] = {"@type":"MINI-CONTENT-BLOCK","blocks":null,"materials":null,"excludeInPaging":false,"positionForPaging":0,"realtime":false,"items":[],"_id":"643687e1a10d300685630556","@type":"MINI-CONTENT-BLOCK","@code":"CAS-MINICONTENT-PC-MEDIA-TAB-EVENT","@template":"NONE","@flowId":"CAS-MINICONTENT","@flowExecutionId":"43b73ac7-d703-11ef-bb94-b9caa1bc1a36","@provider":"lambda","@lastModifiedAt":[2025,1,20,7,50,49,296000000]}
# window["EAGER-DATA"]["CAS-MINICONTENT-PC-MID-BANNER"] = {"@type":"MINI-CONTENT-BLOCK","blocks":null,"materials":null,"excludeInPaging":false,"positionForPaging":0,"realtime":false,"items":[],"_id":"648ae476a10d300685fbab10","@type":"MINI-CONTENT-BLOCK","@code":"CAS-MINICONTENT-PC-MID-BANNER","@template":"NONE","@flowId":"CAS-MINICONTENT","@flowExecutionId":"3918e10d-d703-11ef-bb94-37fc446196ff","@provider":"lambda","@lastModifiedAt":[2025,1,20,7,50,31,500000000]}
# window["EAGER-DATA"]["CAS-MINICONTENT-PC-TAB-META"] = {"@type":"MINI-CONTENT-BLOCK","blocks":null,"materials":null,"excludeInPaging":false,"positionForPaging":0,"realtime":false,"items":[{"content":{"area":"FEED","tabList":[{"clickCode":"tct.mynr","name":"추천・구독","id":"PC-FEED-RECOMMEND","contingencyEnabled":true,"enabled":true,"useFeedCasEditTemplate":false,"weight":1},{"clickCode":"tct.wtn","name":"자동차","id":"PC-FEED-CARGAME","contingencyEnabled":true,"enabled":true,"useFeedCasEditTemplate":true,"weight":1},{"clickCode":"tct.wtn","name":"웹툰","id":"PC-FEED-WEBTOON","contingencyEnabled":true,"enabled":true,"useFeedCasEditTemplate":true,"weight":1},{"clickCode":"tct.bty","name":"패션뷰티","id":"PC-FEED-BEAUTY","contingencyEnabled":true,"enabled":true,"useFeedCasEditTemplate":false,"weight":1},{"clickCode":"tct.fod","name":"레시피","id":"PC-FEED-RECIPE","contingencyEnabled":true,"enabled":true,"useFeedCasEditTemplate":true,"weight":1},{"clickCode":"tct.lif","name":"리빙","id":"PC-FEED-LIVINGHOME","contingencyEnabled":true,"enabled":true,"useFeedCasEditTemplate":true,"weight":1},{"clickCode":"tct.bok","name":"책방","id":"PC-FEED-CULTURE","contingencyEnabled":true,"enabled":true,"useFeedCasEditTemplate":true,"weight":1},{"clickCode":"tct.lec","name":"지식+","id":"PC-FEED-LECTURE","contingencyEnabled":true,"enabled":true,"useFeedCasEditTemplate":true,"weight":1},{"clickCode":"tct.health","name":"건강","id":"PC-FEED-HEALTH","contingencyEnabled":true,"enabled":true,"useFeedCasEditTemplate":false,"weight":1},{"clickCode":"tct.gameapp","name":"게임","id":"PC-FEED-GAMEAPP","contingencyEnabled":true,"enabled":true,"useFeedCasEditTemplate":false,"weight":1}],"@type":"BLOCK-PC-TAB-META"},"exposure":true,"@miniContentId":"643e64d370a065058f369bac","@miniContentCode":"PC-TAB-META","@startAt":"2023-04-10 00:00","@endAt":"2030-05-30 23:59","@createdAt":"2023-04-18T18:37:23.412","@updatedAt":"2023-11-08T11:34:03.902"},{"content":{"area":"MEDIA","tabList":[{"clickCode":"nst.nsd","name":"뉴스스탠드","id":"PC-MEDIA-NEWSSTAND","contingencyEnabled":true,"enabled":true,"useFeedCasEditTemplate":false,"weight":1},{"clickCode":"nst.nch","name":"언론사편집","id":"PC-MEDIA-NEWS","contingencyEnabled":true,"enabled":true,"useFeedCasEditTemplate":false,"weight":1},{"clickCode":"nst.ent","name":"엔터","id":"PC-MEDIA-ENTER","contingencyEnabled":true,"enabled":true,"useFeedCasEditTemplate":false,"weight":1},{"clickCode":"nst.spo","name":"스포츠","id":"PC-MEDIA-SPORTS","contingencyEnabled":true,"enabled":true,"useFeedCasEditTemplate":false,"weight":1},{"clickCode":"nst.fin","name":"경제","id":"PC-MEDIA-ECONOMIC","contingencyEnabled":true,"enabled":true,"useFeedCasEditTemplate":false,"weight":1},{"clickCode":"nst.shpt","name":"쇼핑투데이","id":"PC-MEDIA-SHOPPING-TODAY","contingencyEnabled":true,"enabled":true,"useFeedCasEditTemplate":false,"weight":1}],"@type":"BLOCK-PC-TAB-META"},"exposure":true,"@miniContentId":"643e642c8793487c84743a38","@miniContentCode":"PC-TAB-META","@startAt":"2023-04-11 00:00","@endAt":"2030-05-31 23:59","@createdAt":"2023-04-18T18:34:36.648","@updatedAt":"2024-04-18T16:13:27.109"}],"_id":"643e6299a10d3006853cc04c","@type":"MINI-CONTENT-BLOCK","@code":"CAS-MINICONTENT-PC-TAB-META","@template":"NONE","@flowId":"CAS-MINICONTENT","@flowExecutionId":"45fbfab0-d703-11ef-bb94-916f1f2a51eb","@provider":"lambda","@lastModifiedAt":[2025,1,20,7,50,53,117000000]}
# </script> <script crossorigin="anonymous" defer="defer" src="https://pm.pstatic.net/resources/js/polyfill.a163af38.js?o=www"></script><script crossorigin="anonymous" defer="defer" src="https://pm.pstatic.net/resources/js/preload.33507660.js?o=www"></script><script crossorigin="anonymous" defer="defer" src="https://pm.pstatic.net/resources/js/search.b23b1e46.js?o=www"></script><script crossorigin="anonymous" defer="defer" src="https://pm.pstatic.net/resources/js/main.dae176f6.js?o=www"></script><link href="https://pm.pstatic.net/resources/css/main.5b2d3fbe.css" rel="stylesheet"/></link></meta></meta></meta></meta></meta></meta></head> <body> <div id="u_skip"> <a href="#topAsideButton"><span>상단영역 바로가기</span></a> <a href="#shortcutArea"><span>서비스 메뉴 바로가기</span></a> <a href="#newsstand"><span>새소식 블록 바로가기</span></a> <a href="#shopping"><span>쇼핑 블록 바로가기</span></a> <a href="#feed"><span>관심사 블록 바로가기</span></a> <a href="#account"><span>MY 영역 바로가기</span></a> <a href="#widgetboard"><span>위젯 보드 바로가기</span></a> <a href="#viewSetting"><span>보기 설정 바로가기</span></a> </div> <script data-gfp-banner-size="830x130" data-gfp-banner-type="full" id="ad-timeboard-response" type="text/plain">{"payload":{"requestId":"5e1e2422506b4c258f75e23e2b4b5703","head":{"version":"0.0.1","description":"Naver SSP Waterfall List"},"eventTracking":{"ackImpressions":[{"url":"https://tivan.naver.com/sc2/1/"}],"activeViewImpressions":[{"url":"https://tivan.naver.com/sc2/2/"}],"clicks":[{"url":"https://tivan.naver.com/sc2/3/"}],"completions":[{"url":"https://tivan.naver.com/sc2/4/"}],"attached":[{"url":"https://tivan.naver.com/sc2/10/"}],"renderedImpressions":[{"url":"https://tivan.naver.com/sc2/11/"}],"viewableImpressions":[{"url":"https://tivan.naver.com/sc2/12/"}],"loadErrors":[{"url":"https://tivan.naver.com/sc2/91/"}],"startErrors":[{"url":"https://tivan.naver.com/sc2/92/"}],"lazyRenderMediaFailed":[{"url":"https://tivan.naver.com/sc2/93/"}],"mute":[{"url":"https://tivan.naver.com/sc2/5/"}],"close":[{"url":"https://tivan.naver.com/sc2/6/"}]},"adUnit":"p_main_timeboard_v1","randomNumber":53,"adDivId":"ad_timeboard","ads":[{"encrypted":"kXxnxyplbxOljTIqlnEeiAHstqA78GMHhKRAPU0I5xGUAaHlhUv1KabN7PESyOceX8Yul71w88Iwjwnge1lP1bSawxzz8RTTlkc-O1zJ-N1r0GSyvlPX-eOXjCmvFNa5avYwMw6SPO6byR4OsI7bc5EMFsGn0SZzbZjJ5uYvSHk1OrjqUhv61OFkSCSp9qt2yukU_LSI58XAvOcG0EsaY40sLD2J_ptskMjd9ZOSP_GlfqEN7fjlpO74JqNGbuLSorIKpDbje7mbsK80ExfjmapbgcKD-TXIth35RdwtJydfOCtSgzy-_NK3At8A5yFrFwlkplWWFRPCqBwlvi2Upo_f_5vxPW1SwXP1CzClZVmbnKS_IzRiUj1B4xuUmuhPqOHnT6jhvDZhspw_QlimwD1_PVCDACQOtYbcbHrTu6v6nM8e9joIoqK7jy6o_q9Eb_osUrNG6f9B6EaVUKLlygASgSuckQWJezsIlzI4GAEAefBA8oewIfs3PC-GVd8GvYdjEdXoJ-kFE4Btm8JQEsVP852cpD1zbfVw6JkFKQQHOi1GGeA3zlIfa1CTb-HC5J_8fS6-hcjo3e7VMOAIz9t6NwLdJlCW3ZspY8uHKLH2v4gPX_FEzndtdvQ2vNVRIHYd7cGBLKUfbb2qfOTu42xgKsDj2hUL-MgwqaxdR3LqKPr27s_5xxN2wiKO2hfvqXMMNLG5WIEN6EOLgqDQeg==","connectionType":"S2S","adProviderType":"IN_NAVER","adProviderName":"NDP_SF","layoutType":"FLUID","creativeType":"BANNER","renderType":"SF","eventTracking":{"ackImpressions":[{"url":"https://siape.veta.naver.com/openrtb/nurl?eu=EU10043565\u0026calp=-\u0026oj=cQgn6aire5N7W6C6AkOTFiahH01PEUMxdF4%2BbU5ohIH1mBCytC%2BO0HEOPE%2FEJyL3JL1qM2Pf%2FalzGAKOgFjTw%2Fzq%2BXCI4fuV%2BvOOuTefbqnIBWexIpibH0plqdgUSG%2BUXrQSw%2B%2FX1bbNCF9%2F110BZDp0hCNKO%2BcHo2M9jEOAPSLbaIdXv9YIFqKzdZWOwZvbdMAtSn%2B9Id4vH4MuGzFJiErLLp1Ox71Vg1K%2FFXnNMQA\u0026ac=9074401\u0026src=7440080\u0026evtcd=BID_WIN\u0026x_ti=1504\u0026rk=qEccxTo2Y5U7-pwv7ZN_Uw\u0026eltts=gGmMKM%2FMIaD%2FFjSuD6ilUQ%3D%3D\u0026brs=Y\u0026"}],"attached":[],"activeViewImpressions":[],"renderedImpressions":[],"viewableImpressions":[],"clicks":[],"vimp1px":[],"vimp100":[],"vimp100p":[],"admute":[],"advmute":[],"like":[],"unlike":[],"close":[],"bounce":[]},"adInfo":{"placeId":"6436232db28a76002ea3f30c","cid":"1522180","crid":"2710906","exp":432,"adm":"%3Cscript%20src%3D%22https%3A%2F%2Fssl.pstatic.net%2Fmelona%2Flibs%2Fglad%2Fbridge%2Fgfp-bridge.js%22%3E%3C%2Fscript%3E%0D%0A%0D%0A%3Ca%20href% ...
# </script> <div id="wrap"> <div id="header" role="banner"> <div class="header_inner" id="topSearchWrap"> <div class="search_special_bg" id="special-logo"></div> <div class="ad_area" id="timeboard-ex" style="min-width:1340px"> </div> <div class="search_area" id="search_area" style="border-color:#fff"> <div class="search_group"> <div class="search_group_inner" id="search"> <h1 class="search_logo" id="special-input-logo"></h1> <form action="https://search.naver.com/search.naver" id="sform" method="get" name="search" role="search"> <fieldset> <legend class="blind">검색</legend> <input name="where" type="hidden" value="nexearch"/> <input id="sm" name="sm" type="hidden" value="top_hty"/> <input id="fbm" name="fbm" type="hidden" value="0"/> <input disabled="disabled" id="acr" name="acr" type="hidden" value=""/> <input disabled="disabled" id="acq" name="acq" type="hidden" value=""/> <input disabled="disabled" id="qdt" name="qdt" type="hidden" value=""/> <input id="ie" name="ie" type="hidden" value="utf8"/> <input disabled="disabled" id="acir" name="acir" type="hidden" value=""/> <input disabled="disabled" id="os" name="os" type="hidden" value=""/> <input disabled="disabled" id="bid" name="bid" type="hidden" value=""/> <input disabled="disabled" id="pkid" name="pkid" type="hidden" value=""/> <input disabled="disabled" id="eid" name="eid" type="hidden" value=""/> <input disabled="disabled" id="mra" name="mra" type="hidden" value=""/> <div class="search_input_box"> <input autocomplete="off" class="search_input" data-atcmp-element="" id="query" maxlength="255" name="query" placeholder="검색어를 입력해 주세요." title="검색어를 입력해 주세요." type="search"/> </div> <button class="btn_search" onclick='window.ntm.push({event:"nclick",el:this,click_area:"sch.action"})' type="submit"> <span class="ico_btn_search_svg"> <svg id="search-btn" viewbox="0 0 50 50" xmlns="http://www.w3.org/2000/svg"> <path d="M22.13.5c11.378 0 20.632 9.256 20.632 20.63 0 4.699-1.566 9.155-4.439 12.782l10.164 10.165a2.41 2.41 0 0 1-1.706 4.115 2.412 2.412 0 0 1-1.706-.705L33.31 35.719a2.41 2.41 0 0 1 0-3.41 15.71 15.71 0 0 0 4.628-11.178c0-8.718-7.09-15.808-15.807-15.808-8.718 0-15.808 7.09-15.808 15.808 0 7.15 4.817 13.43 11.714 15.273a2.41 2.41 0 0 1 1.705 2.954 2.41 2.41 0 0 1-2.95 1.705C7.788 38.658 1.5 30.46 1.5 21.131 1.5 9.756 10.756.5 22.13.5zm4.716 34.746a3.483 3.483 0 1 1 0 6.966 3.483 3.483 0 0 1 0-6.966z"></path> </svg> </span> <span class="blind">검색</span> </button> </fieldset> </form> <div class="search_box"> <button aria-pressed="false" class="btn_keyboard" id="ke_kbd_btn" type="button"> <span class="keybord_text"> <span class="blind">입력도구</span> </span> </button> <div id="_nx_kbd" style="display:none"></div> <button class="btn_arrow" data-atcmp-element="" id="nautocomplete" type="button"> <span class="blind">자동완성/최근검색어펼치기</span> </button> </div> <div class="layer_atcmp" id="autoFrame" style="display:none"></div> </div> </div> </div> <div id="search-right-first"></div> <div id="search-right-second"></div> <div aria-label="주요 서비스" class="shortcut_area" id="shortcutArea" role="navigation"></div> <div class="menu_area" id="topAsideArea"></div> <div class="pay_area" id="topPayArea"></div> <div class="talk_area" id="topTalkArea"></div> <div class="notify_area" id="topNotiArea"></div> <div class="shopping_area" id="topShoppingArea"></div> </div> </div> <div id="container" role="main"> <div id="root"></div> </div> <div id="footer" role="contentinfo"></div> </div> <script> window['EAGER-DATA'] = window['EAGER-DATA'] || {};
#         window['EAGER-DATA']['GV'] = {
#             svt: '20250120165246',  }; </script> <script>!function(){function t(t){var e=document.getElementById("search_area"),n=document.getElementById("search-btn");if(!t)return e&&e.removeAttribute("style"),void(n&&n.setAttribute("style","fill: #03c75a"));e&&e.setAttribute("style","border-color: "+t),n&&n.setAttribute("class","ico_btn_search type_color"),n&&n.setAttribute("style","fill: "+t)}var e=window["EAGER-DATA"]["CAS-MINICONTENT-PC-SPECIAL-LOGO"];if(!e||!e.items||e.items.length>0==!1)return void t();var n=Math.floor(Math.random()*e.items.length),i=e.items[n];e.items=[i],t(i&&i.content&&i.content.input&&i.content.input.color);const l=document.getElementById("search");l&&l.classList.add("type_special_logo_full"),window.addEventListener("header-sticky-state-change",(function(){var t;(t=document.getElementById("header"))&&t.classList.contains("ani_fixed")?l&&l.classList.remove("type_special_logo_full"):l&&l.classList.add("type_special_logo_full")}));var o=i&&i.content&&i.content.input&&i.content.input.placeholder;if(o){var s=document.getElementById("query");s&&o&&s.setAttribute("title",o),s&&o&&s.setAttribute("placeholder",o)}}()</script> </body> </html>

# %%
test_menu = bs_obj.find('div',{'id':'wrap'})
test_menu
# Out:
# <div id="wrap"> <div id="header" role="banner"> <div class="header_inner" id="topSearchWrap"> <div class="search_special_bg" id="special-logo"></div> <div class="ad_area" id="timeboard-ex" style="min-width:1340px"> </div> <div class="search_area" id="search_area" style="border-color:#fff"> <div class="search_group"> <div class="search_group_inner" id="search"> <h1 class="search_logo" id="special-input-logo"></h1> <form action="https://search.naver.com/search.naver" id="sform" method="get" name="search" role="search"> <fieldset> <legend class="blind">검색</legend> <input name="where" type="hidden" value="nexearch"/> <input id="sm" name="sm" type="hidden" value="top_hty"/> <input id="fbm" name="fbm" type="hidden" value="0"/> <input disabled="disabled" id="acr" name="acr" type="hidden" value=""/> <input disabled="disabled" id="acq" name="acq" type="hidden" value=""/> <input disabled="disabled" id="qdt" name="qdt" type="hidden" value=""/> <input id="ie" name="ie" type="hidden" value="utf8"/> <input disabled="disabled" id="acir" name="acir" type="hidden" value=""/> <input disabled="disabled" id="os" name="os" type="hidden" value=""/> <input disabled="disabled" id="bid" name="bid" type="hidden" value=""/> <input disabled="disabled" id="pkid" name="pkid" type="hidden" value=""/> <input disabled="disabled" id="eid" name="eid" type="hidden" value=""/> <input disabled="disabled" id="mra" name="mra" type="hidden" value=""/> <div class="search_input_box"> <input autocomplete="off" class="search_input" data-atcmp-element="" id="query" maxlength="255" name="query" placeholder="검색어를 입력해 주세요." title="검색어를 입력해 주세요." type="search"/> </div> <button class="btn_search" onclick='window.ntm.push({event:"nclick",el:this,click_area:"sch.action"})' type="submit"> <span class="ico_btn_search_svg"> <svg id="search-btn" viewbox="0 0 50 50" xmlns="http://www.w3.org/2000/svg"> <path d="M22.13.5c11.378 0 20.632 9.256 20.632 20.63 0 4.699-1.566 9.155-4.439 12.782l10.164 10.165a2.41 2.41 0 0 1-1.706 4.115 2.412 2.412 0 0 1-1.706-.705L33.31 35.719a2.41 2.41 0 0 1 0-3.41 15.71 15.71 0 0 0 4.628-11.178c0-8.718-7.09-15.808-15.807-15.808-8.718 0-15.808 7.09-15.808 15.808 0 7.15 4.817 13.43 11.714 15.273a2.41 2.41 0 0 1 1.705 2.954 2.41 2.41 0 0 1-2.95 1.705C7.788 38.658 1.5 30.46 1.5 21.131 1.5 9.756 10.756.5 22.13.5zm4.716 34.746a3.483 3.483 0 1 1 0 6.966 3.483 3.483 0 0 1 0-6.966z"></path> </svg> </span> <span class="blind">검색</span> </button> </fieldset> </form> <div class="search_box"> <button aria-pressed="false" class="btn_keyboard" id="ke_kbd_btn" type="button"> <span class="keybord_text"> <span class="blind">입력도구</span> </span> </button> <div id="_nx_kbd" style="display:none"></div> <button class="btn_arrow" data-atcmp-element="" id="nautocomplete" type="button"> <span class="blind">자동완성/최근검색어펼치기</span> </button> </div> <div class="layer_atcmp" id="autoFrame" style="display:none"></div> </div> </div> </div> <div id="search-right-first"></div> <div id="search-right-second"></div> <div aria-label="주요 서비스" class="shortcut_area" id="shortcutArea" role="navigation"></div> <div class="menu_area" id="topAsideArea"></div> <div class="pay_area" id="topPayArea"></div> <div class="talk_area" id="topTalkArea"></div> <div class="notify_area" id="topNotiArea"></div> <div class="shopping_area" id="topShoppingArea"></div> </div> </div> <div id="container" role="main"> <div id="root"></div> </div> <div id="footer" role="contentinfo"></div> </div>

# %% [markdown]
# ### 수집한 데이터를 csv로 저장
# 1. 항목별로 list에 저장
# 2. 항목들을 dict로 구성
# 3. dict를 데이터프레임으로 생성
# 4. 데이터프레임을 csv로 저장

# %% [markdown]
# ## 네이버 뉴스 크롤링
# #### 네이버 뉴스는 네이버 정책에 따라 모든 언론사들의 뉴스가 랜덤하게 배치됨
# - 단, 로그인 후 구독을 추가하면 구독한 언론사들의 뉴스가 나옴
# - 헤드라인 뉴스는 표면적으로는 제공되지 않는다

# %%
# 네이버 뉴스 크롤링
# url은 기본 url 부터 사용
url = 'https://news.naver.com'
html = urlopen(url)

# %%
# html #<http.client.HTTPResponse at 0x1b6fa0cd0d0>
# html_text = html.read() # 바이너리 문자열로 반환
# # html_text

# %%
# bs4 객체 생성
bs_obj = bs4.BeautifulSoup(html, 'html.parser')

# %%
print(bs_obj.prettify())
# Out:
# <!DOCTYPE html>
# <html lang="ko">
#  <head>
#   <title id="browserTitleArea">
#    네이버 뉴스
#   </title>
#   <script>
#    function isMobileDevice() {
# 		return /^.*(iPhone|iPod|iPad|Android).*/.test(navigator.userAgent);
# 	}
#   </script>
#   <script>
#    (function () {
# 		try {
# 			if (isMobileDevice() && isAbleApplyPrefersColorScheme()) {
#
# 				document.querySelector("html").classList.add("DARK_THEME");
# 			}
# 		} catch(e) {}
#
# 		function isAbleApplyPrefersColorScheme() {
#
# 			if (window.matchMedia("(prefers-color-scheme)").matches === false) {
# 				return false;
# 			}
#
# 			var userAgent = navigator.userAgent;
#
# 			if (userAgent.indexOf("NAVER") > -1) {
#
# 				if (/.*NAVER\([a-zA-Z]*;\s[a-zA-Z]*;\s([0-9]*);/.test(userAgent)) {
# 					return Number(RegExp.$1) >= 1000;
# 				}
# 			} else {
#
# 				return document.cookie.indexOf("NSCS=1") > -1;
# 			}
#
# 			return false;
# 		}
# 	})();
#   </script>
#   <script>
#    var g_ssc = 'news.v3_media' || null;
# 		var bSupportedIntersectionObserver = "IntersectionObserver" in window;
#   </script>
#   <meta charset="utf-8"/>
#   <meta content="width=device-width,initial-scale=1.0,maximum-scale=1.0,minimum-scale=1.0,user-scalable=no,target-densitydpi=medium-dpi" name="viewport">
#    <link href="https://ssl.pstatic.net/static.news/mnews/resources/20250117_004017/css/generated/newshome.css" rel="stylesheet" type="text/css"/>
#    <link href="https://mimgnews.pstatic.net/image/news/m/2023/favicon/favicon.ico" rel="shortcut icon" type="image/x-icon"/>
#    <script>
#     (function(){
# 		var userAgent = navigator.userAgent;
# 		var result = [];
#
# 		if(userAgent.indexOf('Android') > -1){
# 			result = [
# 				'<link rel="apple-touch-icon-precomposed" sizes="72x72" href="https://ssl.pstatic.net/static.news/image/news/m/2018/favicon/06/android_legacy_hdpi_72X72.png" />',
# 				'<link rel="apple-touch-icon-precomposed" sizes="96x96" href="https://ssl.pstatic.net/static.news/image/news/m/2018/favicon/06/android_legacy_xhdpi_96x96.png" />',
# 				'<link rel="apple-touch-icon-precomposed" sizes="144x144" href="https://ssl.pstatic.net/static.news/image/news/m/2018/favicon/06/android_legacy_xxhpdi_144x144.png" />',
# 				'<link rel="apple-touch-icon-precomposed" sizes="192x192" href="https://ssl.pstatic.net/static.news/image/news/m/2018/favicon/06/android_legacy_xxxhpdi_192x192.png" />'
# 			];
# 		}else if(userAgent.indexOf('iPhone') > -1){
# 			result = [
# 				'<link rel="apple-touch-icon-precomposed" sizes="120X120" href="https://ssl.pstatic.net/static.news/image/news/m/2018/favicon/06/iOS_iPhone_2x_120X120.png" />',
# 				'<link rel="apple-touch-icon-precomposed" sizes="180x180" href="https://ssl.pstatic.net/static.news/image/news/m/2018/favicon/06/iOS_iPhone_3x_180X180.png" />'
# 			];
# 		}else if(userAgent.indexOf('iPad') > -1){
# 			result = [
# 				'<link rel="apple-touch-icon-precomposed" sizes="167x167" href="https://ssl.pstatic.net/static.news/image/news/m/2018/favicon/06/iOS_iPadPro_2x_167X167.png" />',
# 				'<link rel="apple-touch-icon-precomposed" sizes="152x152" href="https://ssl.pstatic.net/static.news/image/news/m/2018/favicon/06/iOS_iPad_2x_152X152.png" />'
# 			];
# 		}
# 		document.write(result.join('\n'));
# 	})();
#    </script>
#    <script src="https://ssl.pstatic.net/static.news/mnews/resources/20250117_004017/js/generated/statistics_jquery.js" type="text/javascript">
#    </script>
#    <script>
#     document.documentElement.setAttribute('data-useragent',navigator.userAgent);
#    </script>
#    <script>
#     document.documentElement.setAttribute('data-useragent', navigator.userAgent);
#
#
# function showNoImage(elImg, type) {
#     switch (type) {
#
#         case "remove":
#             try {
#                 elImg.parentNode.removeChild(elImg);
#             } catch(e) {}
#             break;
#
#
#         case "removeParent":
#             try {
#                 elImg.parentNode.outerHTML = '';
#             } catch(e) {}
#             break;
#
#
#         case "alt":
#             elImg.outerHTML = ('<span class="noimage_text {imgClassName}">' + (elImg.alt || "") + '</span>')
#
#                 .replace('{imgClassName}', elImg.className);
#             break;
#
#
# 		case "class" :
# 			var outerHTMLSource = Number(elImg.getAttribute("height")) > 0?
#
# 				'<span class="noimage_wrap {imgClassName}" style="height:' + elImg.getAttribute("height") + 'px;"><span class="noimage"></span></span>':
# 				'<span class="noimage_wrap {imgClassName}"><span class="noimage"></span></span>';
# 			elImg.outerHTML = outerHTMLSource.replace('{imgClassName}', elImg.className);
# 			break;
#
#         case "pressname" :
#             var pressname = elImg.getAttribute("data-pressname");
#             elImg.outerHTML = '<span class="cjs_broadcast_noimg"><span class="noimg_text">' + pressname + '</span></span>';
#             break;
#
#         case "noHeight":
#
#             elImg.outerHTML = '<span class="noimage_wrap"><span class="noimage"></span></span>';
#             break;
#
#
#         default:
#
#             elImg.outerHTML = Number(elImg.getAttribute("height")) > 0?
#
#                 '<span class="noimage_wrap" style="height:' + elImg.getAttribute("height") + 'px;"><span class="noimage"></span></span>':
#                 '<span class="noimage_wrap"><span class="noimage"></span></span>';
#     }
# }
#
#
# function doAfterLoadEnd(callback, callbackOnPersisted) {
#     var eventName = "onpageshow" in window ? "pageshow" : "load";
#
#     callback = callback || function(){};
#     callbackOnPersisted = callbackOnPersisted || function(){};
#
#     window.addEventListener(eventName, function(e) {
#         try{
#             if(Boolean(e.persisted)){
#                 callbackOnPersisted();
#                 return;
#             }
#         }catch(e){}
#
#         callback();
#     });
# }
#    </script>
#    <meta content="네이버 뉴스" property="og:title"/>
#    <meta content="website" property="og:type"/>
#    <meta content="https://news.naver.com/main/home.naver" property="og:url"/>
#    <meta content="https://ssl.pstatic.net/static.news/image/news/ogtag/navernews_800x420_20221201.png" property="og:image"/>
#    <meta content="정치, 경제, 사회, 생활/문화, 세계, IT/과학 등 언론사별, 분야별 뉴스 기사 제공" property="og:description"/>
#    <meta content="네이버" property="og:article:author"/>
#    <meta content="summary" name="twitter:card"/>
#    <meta content="네이버 뉴스" name="twitter:title"/>
#    <meta content="네이버 뉴스" name="twitter:site"/>
#    <meta content="네이버 뉴스" name="twitter:creator"/>
#    <meta content="https://ssl.pstatic.net/static.news/image/news/ogtag/navernews_800x420_20221201.png" name="twitter:image"/>
#    <meta content="정치, 경제, 사회, 생활/문화, 세계, IT/과학 등 언론사별, 분야별 뉴스 기사 제공" name="twitter:description"/>
#    <script>
#     (function () {
#         var isUnderIE10 = navigator.appName === "Microsoft Internet Explorer";
#         if (!isUnderIE10) {
#             var script = document.createElement("script");
#             script.async = true;
#             script.src = "https://ssl.pstatic.net/tveta/libs/glad/prod/gfp-core.js";
#             document.head.appendChild(script);
#         }
#     })();
#
#
#     window.gladsdk = window.gladsdk || { cmd: [] };
#     window.gladsdk.cmd.push(function () {
#
#         window.gladsdk.setGlobalConfig({
#             enablePersistAd: true
#         });
#
#
#         var adUnits = [];
#
#         adUnits.push({
#             adUnitId: "p_news_sidebox",
#             adSlotElementId: "glad_ad_sidebox",
#             customParam: {
#                 calp: "home"
#             }
#         });
#
#         for (let i = 0; i < adUnits.length; i++) {
#             window.gladsdk.defineAdSlot(adUnits[i]);
#         }
#
#
#         var htmlClass = document.querySelector("html").getAttribute("class");
#         if (htmlClass && htmlClass.indexOf("DARK_THEME") > -1) {
#             window.gladsdk.setHostMeta("theme", "system");
#         }
#     });
#    </script>
#   </meta>
#  </head>
#  <body class="as_mp_layout body_main">
#   <div class="u_skip">
#    <a href="#ct">
#     본문 바로가기
#    </a>
#   </div>
#   <!-- Menu 구분  -->
#   <section class="news_header">
#    <header class="nh_header" role="banner">
#     <div class="Ngnb">
#      <div class="Ngnb_inner">
#       <div class="Ngnb_both">
#        <div class="Ngnb_left">
#         <span class="Ngnb_logo">
#          <a class="Nlogo_link" href="https://www.naver.com" onclick="nclk(event,'gnb.naver','','');">
#           <span class="Nicon_logo">
#            NAVER
#           </span>
#          </a>
#         </span>
#         <div class="Ngnb_service">
#          <h1 class="Nservice_item">
#           <a href="https://news.naver.com" onclick="nclk(event,'gnb.news','','');">
#            <span class="Nicon_service">
#             뉴스
#            </span>
#           </a>
#          </h1>
#          <span class="Nservice_subitem">
#           <a href="https://entertain.naver.com/home" onclick="nclk(event,'gnb.enter','','');">
#            <span class="Nicon_family Nicon_entertain">
#             엔터
#            </span>
#           </a>
#          </span>
#          <span class="Nservice_subitem">
#           <a href="https://sports.news.naver.com/index" onclick="nclk(event,'gnb.sports','','');">
#            <span class="Nicon_family Nicon_sports">
#             스포츠
#            </span>
#           </a>
#          </span>
#          <span class="Nservice_subitem">
#           <a href="https://weather.naver.com/" onclick="nclk(event,'gnb.weather','','');">
#            <span class="Nicon_family Nicon_weather">
#             날씨
#            </span>
#           </a>
#          </span>
#          <span class="Nservice_subitem">
#           <a href="https://contents.premium.naver.com/" onclick="nclk(event,'gnb.premium','','');">
#            <span class="Nicon_family Nicon_premium">
#             프리미엄
#            </span>
#           </a>
#          </span>
#         </div>
#        </div>
#        <div class="Ngnb_right">
#         <div class="Ngnb_group">
#          <div class="gnb_dark_type2" id="gnb">
#          </div>
#         </div>
#         <div class="Ngnb_search is_hidden _search_content">
#         </div>
#         <div class="Ngnb_tool">
#          <a class="Ntool_button _search_content_toggle_btn" href="javascript:;" onclick="nclk(event,'gnb.sch','','');">
#           <span class="Nicon_search">
#            검색
#           </span>
#          </a>
#         </div>
#        </div>
#       </div>
#      </div>
#     </div>
#     <div class="Nlnb _float_lnb">
#      <div class="Nlnb_inner">
#       <div class="Nlnb_both">
#        <div class="Nlnb_left _lnb_scroll">
#         <div class="Nlnb_menu Ntype_scroll">
#          <div class="Nlnb_menu_inner _scroll">
#           <ul class="Nlnb_menu_list" role="menu">
#            <li class="Nlist_item is_active">
#             <a aria-selected="true" class="Nitem_link" href="https://news.naver.com/?viewType=pc" onclick="nclk(event,'lnb.pcmedia','','');" role="menuitem">
#              <span class="Nitem_link_menu">
#               언론사별
#              </span>
#             </a>
#            </li>
#            <li class="Nlist_item">
#             <a aria-selected="false" class="Nitem_link" href="https://news.naver.com/section/100" onclick="nclk(event,'lnb.pol','','');" role="menuitem">
#              <span class="Nitem_link_menu">
#               정치
#              </span>
#             </a>
#            </li>
#            <li class="Nlist_item">
#             <a aria-selected="false" class="Nitem_link" href="https://news.naver.com/section/101" onclick="nclk(event,'lnb.eco','','');" role="menuitem">
#              <span class="Nitem_link_menu">
#               경제
#              </span>
#             </a>
#            </li>
#            <li class="Nlist_item">
#             <a aria-selected="false" class="Nitem_link" href="https://news.naver.com/section/102" onclick="nclk(event,'lnb.soc','','');" role="menuitem">
#              <span class="Nitem_link_menu">
#               사회
#              </span>
#             </a>
#            </li>
#            <li class="Nlist_item">
#             <a aria-selected="false" class="Nitem_link" href="https://news.naver.com/section/103" onclick="nclk(event,'lnb.lif','','');" role="menuitem">
#              <span class="Nitem_link_menu">
#               생활/문화
#              </span>
#             </a>
#            </li>
#            <li class="Nlist_item">
#             <a aria-selected="false" class="Nitem_link" href="https://news.naver.com/section/105" onclick="nclk(event,'lnb.sci','','');" role="menuitem">
#              <span class="Nitem_link_menu">
#               IT/과학
#              </span>
#             </a>
#            </li>
#            <li class="Nlist_item">
#             <a aria-selected="false" class="Nitem_link" href="https://news.naver.com/section/104" onclick="nclk(event,'lnb.wor','','');" role="menuitem">
#              <span class="Nitem_link_menu">
#               세계
#              </span>
#             </a>
#            </li>
#            <li class="Nlist_item _isNew">
#             <a aria-selected="false" class="Nitem_link" href="https://news.naver.com/main/ranking/popularDay.naver" onclick="nclk(event,'lnb.rank','','');" role="menuitem">
#              <span class="Nitem_link_menu">
#               랭킹
#              </span>
#             </a>
#            </li>
#            <li class="Nlist_item _isNew">
#             <a aria-selected="false" class="Nitem_link" href="https://news.naver.com/newspaper/home?viewType=pc" onclick="nclk(event,'lnb.paper','','');" role="menuitem">
#              <span class="Nitem_link_menu">
#               신문보기
#              </span>
#             </a>
#            </li>
#            <li class="Nlist_item">
#             <a aria-selected="false" class="Nitem_link" href="https://news.naver.com/opinion/home" onclick="nclk(event,'lnb.opi','','');" role="menuitem">
#              <span class="Nitem_link_menu">
#               오피니언
#              </span>
#             </a>
#            </li>
#            <li class="Nlist_item">
#             <a aria-selected="false" class="Nitem_link" href="https://news.naver.com/main/tv/index.naver?mid=tvh" onclick="nclk(event,'lnb.tv','','');" role="menuitem">
#              <span class="Nitem_link_menu">
#               TV
#              </span>
#             </a>
#            </li>
#            <li class="Nlist_item">
#             <a aria-selected="false" class="Nitem_link" href="https://news.naver.com/factcheck/main" onclick="nclk(event,'lnb.fact','','');" role="menuitem">
#              <span class="Nitem_link_menu">
#               팩트체크
#              </span>
#             </a>
#            </li>
#            <li class="Nlist_item">
#             <a aria-selected="false" class="Nitem_link" href="https://media.naver.com/algorithm" onclick="nclk(event,'lnb.algo','','');" role="menuitem">
#              <span class="Nitem_link_menu">
#               알고리즘 안내
#              </span>
#             </a>
#            </li>
#            <li class="Nlist_item _isNew">
#             <a aria-selected="false" class="Nitem_link" href="https://news.naver.com/main/ombudsman/errorArticleList.naver?mid=omb" onclick="nclk(event,'lnb.correct','','');" role="menuitem">
#              <span class="Nitem_link_menu">
#               정정보도 모음
#              </span>
#             </a>
#            </li>
#           </ul>
#          </div>
#         </div>
#        </div>
#       </div>
#      </div>
#     </div>
#    </header>
#   </section>
#   <hr/>
#   <div class="main_wrap" id="ct" role="main">
#    <div class="main_container">
#     <section class="main_content">
#      <h3 class="blind">
#       콘텐츠
#      </h3>
#      <div class="main_sublnb">
#       <div class="main_sublnb_date">
#        <strong>
#         1
#        </strong>
#        .
#        <strong>
#         20
#        </strong>
#        <span>
#         (월)
#        </span>
#       </div>
#       <ul class="main_sublnb_menu">
#        <li class="main_sublnb_item">
#         <a class="main_sublnb_link" href="https://news.naver.com/main/officeList.naver " onclick="nclk(event, 'slb.allmedia', '', '')">
#          전체 언론사
#         </a>
#        </li>
#        <li class="main_sublnb_item">
#         <a class="main_sublnb_link" href="https://newsstand.naver.com/" onclick="nclk(event, 'slb.newsstand', '', '')" target="_blank">
#          뉴스스탠드
#         </a>
#        </li>
#        <li class="main_sublnb_item">
#         <a class="main_sublnb_link" href="https://newslibrary.naver.com/search/searchByDate.naver" onclick="nclk(event, 'slb.library', '', '')" target="_blank">
#          라이브러리
#         </a>
#        </li>
#       </ul>
#      </div>
#      <div class="main_brick">
#       <!-- BRICK HOUSE -->
#       <div class="grid1_wrap brick-house _brick_gid_wrapper">
#        <div class="brick-vowel _brick_column">
#         <div class="main_brick_item _press_main_status_wrapper">
#          <div class="comp_journal_subscribe">
#           <div class="cjs_title_wrap">
#            <h3 class="cjs_edit_title">
#             <span class="cjs_main">
#              언론사편집
#             </span>
#             <a class="cjs_subscribe_a" href="#feedJournalistCard" onclick="nclk(event, 'home.editassetting1', '', '')">
#              <span class="subs_text">
#               기자
#              </span>
#             </a>
#             <a class="cjs_subscribe_a" href="#feedSeriesCard" onclick="nclk(event, 'home.editassetting2', '', '')">
#              <span class="subs_text">
#               연재
#              </span>
#             </a>
#            </h3>
#            <a class="cjs_more_link" href="https://media.naver.com/channel/settings" onclick="nclk(event, 'home.editsetting', '', '')">
#             구독설정
#             <span class="ico_more">
#             </span>
#            </a>
#           </div>
#           <div class="cjs_news_flash_wrap cjs_nf_close _newsflash_wrapper">
#            <div class="cjs_nf_title">
#             <span class="ico_newsflash">
#              속보
#             </span>
#            </div>
#            <div class="cjs_nf_list _item_list">
#             <a class="cjs_nf_a _item _cds_link _newsflash_link" href="https://n.news.naver.com/article/032/0003346543" onclick="nclk(event, 'home.newsflash', '', '')">
#              <div class="cn_title_area">
#               <h4 class="cn_title">
#                경찰 “윤상현, 강남경찰서장에게 전화해 ‘연행자 잘 부탁한다’ 발언”
#               </h4>
#               <div class="cn_snippet">
#                <div class="cn_journal_wrap">
#                 <div class="cn_thumb">
#                  <img alt="" height="10" loading="lazy" onerror="showNoImage(this)" src="https://mimgnews.pstatic.net/image/upload/office_logo/032/2022/12/05/logo_032_56_20221205150153.png?type=nf20_20" width="10"/>
#                 </div>
#                 <div class="cn_name">
#                  경향신문
#                 </div>
#                </div>
#               </div>
#              </div>
#             </a>
#             <a class="cjs_nf_a _item _cds_link _newsflash_link" href="https://n.news.naver.com/article/660/0000077748" onclick="nclk(event, 'home.newsflash', '', '')">
#              <div class="cn_title_area">
#               <h4 class="cn_title">
#                비트코인, 트럼프 취임 앞두고 최고가 갱신
#               </h4>
#               <div class="cn_snippet">
#                <div class="cn_journal_wrap">
#                 <div class="cn_thumb">
#                  <img alt="" height="10" loading="lazy" onerror="showNoImage(this)" src="https://mimgnews.pstatic.net/image/upload/office_logo/660/2022/01/19/logo_660_56_20220119141745.png?type=nf20_20" width="10"/>
#                 </div>
#                 <div class="cn_name">
#                  kbc광주방송
#                 </div>
#                </div>
#               </div>
#              </div>
#             </a>
#             <a class="cjs_nf_a _item _cds_link _newsflash_link" href="https://n.news.naver.com/article/081/0003512371" onclick="nclk(event, 'home.newsflash', '', '')">
#              <div class="cn_title_area">
#               <h4 class="cn_title">
#                공수처 관용차 서울구치소 도착…尹 강제구인 집행 촉각
#               </h4>
#               <div class="cn_snippet">
#                <div class="cn_journal_wrap">
#                 <div class="cn_thumb">
#                  <img alt="" height="10" loading="lazy" onerror="showNoImage(this)" src="https://mimgnews.pstatic.net/image/upload/office_logo/081/2022/01/05/logo_081_56_20220105195830.png?type=nf20_20" width="10"/>
#                 </div>
#                 <div class="cn_name">
#                  서울신문
#                 </div>
#                </div>
#               </div>
#              </div>
#             </a>
#             <a class="cjs_nf_a _item _cds_link _newsflash_link" href="https://n.news.naver.com/article/052/0002143314" onclick="nclk(event, 'home.newsflash', '', '')">
#              <div class="cn_title_area">
#               <h4 class="cn_title">
#                교정본부장 "서울구치소에 공수처 수사팀 도착"
#               </h4>
#               <div class="cn_snippet">
#                <div class="cn_journal_wrap">
#                 <div class="cn_thumb">
#                  <img alt="" height="10" loading="lazy" onerror="showNoImage(this)" src="https://mimgnews.pstatic.net/image/upload/office_logo/052/2021/10/01/logo_052_56_20211001183149.png?type=nf20_20" width="10"/>
#                 </div>
#                 <div class="cn_name">
#                  YTN
#                 </div>
#                </div>
#               </div>
#              </div>
#             </a>
#             <a class="cjs_nf_a _item _cds_link _newsflash_link" href="https://n.news.naver.com/article/417/0001053250" onclick="nclk(event, 'home.newsflash', '', '')">
#              <div class="cn_title_area">
#               <h4 class="cn_title">
#                공수처, 윤 대통령 강제구인 시도… 서울구치소 도착
#               </h4>
#               <div class="cn_snippet">
#                <div class="cn_journal_wrap">
#                 <div class="cn_thumb">
#                  <img alt="" height="10" loading="lazy" onerror="showNoImage(this)" src="https://mimgnews.pstatic.net/image/upload/office_logo/417/2021/01/25/logo_417_56_20210125161624.png?type=nf20_20" width="10"/>
#                 </div>
#                 <div class="cn_name">
#                  머니S
#                 </div>
#                </div>
#                <div class="cn_state">
#                 내용작성전
#                </div>
#               </div>
#              </div>
#             </a>
#             <a class="cjs_nf_a _item _cds_link _newsflash_link" href="https://n.news.naver.com/article/087/0001093687" onclick="nclk(event, 'home.newsflash', '', '')">
#              <div class="cn_title_area">
#               <h4 class="cn_title">
#                尹 체포 당일 공수처 부근서 분신한 50대 男 끝내 사망
#               </h4>
#               <div class="cn_snippet">
#                <div class="cn_journal_wrap">
#                 <div class="cn_thumb">
#                  <img alt="" height="10" loading="lazy" onerror="showNoImage(this)" src="https://mimgnews.pstatic.net/image/upload/office_logo/087/2019/08/22/logo_087_56_20190822110222.png?type=nf20_20" width="10"/>
#                 </div>
#                 <div class="cn_name">
#                  강원일보
#                 </div>
#                </div>
#               </div>
#              </div>
#             </a>
#             <a class="cjs_nf_a _item _cds_link _newsflash_link" href="https://n.news.naver.com/article/469/0000845015" onclick="nclk(event, 'home.newsflash', '', '')">
#              <div class="cn_title_area">
#               <h4 class="cn_title">
#                공수처, 尹 강제구인 시도… 검사·수사관 등 4명 투입
#               </h4>
#               <div class="cn_snippet">
#                <div class="cn_journal_wrap">
#                 <div class="cn_thumb">
#                  <img alt="" height="10" loading="lazy" onerror="showNoImage(this)" src="https://mimgnews.pstatic.net/image/upload/office_logo/469/2023/02/07/logo_469_56_20230207160012.png?type=nf20_20" width="10"/>
#                 </div>
#                 <div class="cn_name">
#                  한국일보
#                 </div>
#                </div>
#               </div>
#              </div>
#             </a>
#             <a class="cjs_nf_a _item _cds_link _newsflash_link" href="https://n.news.naver.com/article/654/0000102421" onclick="nclk(event, 'home.newsflash', '', '')">
#              <div class="cn_title_area">
#               <h4 class="cn_title">
#                비트코인, 트럼프 취임 직전 사상 최고가 경신…10만8943달러
#               </h4>
#               <div class="cn_snippet">
#                <div class="cn_journal_wrap">
#                 <div class="cn_thumb">
#                  <img alt="" height="10" loading="lazy" onerror="showNoImage(this)" src="https://mimgnews.pstatic.net/image/upload/office_logo/654/2022/01/14/logo_654_56_20220114111216.png?type=nf20_20" width="10"/>
#                 </div>
#                 <div class="cn_name">
#                  강원도민일보
#                 </div>
#                </div>
#               </div>
#              </div>
#             </a>
#             <a class="cjs_nf_a _item _cds_link _newsflash_link" href="https://n.news.naver.com/article/448/0000503455" onclick="nclk(event, 'home.newsflash', '', '')">
#              <div class="cn_title_area">
#               <h4 class="cn_title">
#                대법관회의 "법원 공격은 법치주의 부정…매우 중대한 범죄"
#               </h4>
#               <div class="cn_snippet">
#                <div class="cn_journal_wrap">
#                 <div class="cn_thumb">
#                  <img alt="" height="10" loading="lazy" onerror="showNoImage(this)" src="https://mimgnews.pstatic.net/image/upload/office_logo/448/2020/08/11/logo_448_56_20200811154809.png?type=nf20_20" width="10"/>
#                 </div>
#                 <div class="cn_name">
#                  TV조선
#                 </div>
#                </div>
#                <div class="cn_state">
#                 내용작성전
#                </div>
#               </div>
#              </div>
#             </a>
#             <a class="cjs_nf_a _item _cds_link _newsflash_link" href="https://n.news.naver.com/article/056/0011878172" onclick="nclk(event, 'home.newsflash', '', '')">
#              <div class="cn_title_area">
#               <h4 class="cn_title">
#                공수처 관용차 서울구치소 진입…경호처 차량 여러 대 공수처 도착
#               </h4>
#               <div class="cn_snippet">
#                <div class="cn_journal_wrap">
#                 <div class="cn_thumb">
#                  <img alt="" height="10" loading="lazy" onerror="showNoImage(this)" src="https://mimgnews.pstatic.net/image/upload/office_logo/056/2021/10/28/logo_056_56_20211028103053.png?type=nf20_20" width="10"/>
#                 </div>
#                 <div class="cn_name">
#                  KBS
#                 </div>
#                </div>
#                <div class="cn_state">
#                 내용작성전
#                </div>
#               </div>
#              </div>
#             </a>
#             <a class="cjs_nf_a _item _cds_link _newsflash_link" href="https://n.news.naver.com/article/421/0008033020" onclick="nclk(event, 'home.newsflash', '', '')">
#              <div class="cn_title_area">
#               <h4 class="cn_title">
#                트럼프 취임 앞두고 비트코인 4%↑ 10만8943달러…사상 최고치 경신
#               </h4>
#               <div class="cn_snippet">
#                <div class="cn_journal_wrap">
#                 <div class="cn_thumb">
#                  <img alt="" height="10" loading="lazy" onerror="showNoImage(this)" src="https://mimgnews.pstatic.net/image/upload/office_logo/421/2024/03/06/logo_421_56_20240306140514.png?type=nf20_20" width="10"/>
#                 </div>
#                 <div class="cn_name">
#                  뉴스1
#                 </div>
#                </div>
#                <div class="cn_state">
#                 내용작성전
#                </div>
#               </div>
#              </div>
#             </a>
#             <a class="cjs_nf_a _item _cds_link _newsflash_link" href="https://n.news.naver.com/article/277/0005535564" onclick="nclk(event, 'home.newsflash', '', '')">
#              <div class="cn_title_area">
#               <h4 class="cn_title">
#                대법관회의 "법원 공격은 법치주의 부정…중대한 범죄"
#               </h4>
#               <div class="cn_snippet">
#                <div class="cn_journal_wrap">
#                 <div class="cn_thumb">
#                  <img alt="" height="10" loading="lazy" onerror="showNoImage(this)" src="https://mimgnews.pstatic.net/image/upload/office_logo/277/2018/07/18/logo_277_56_20180718153218.png?type=nf20_20" width="10"/>
#                 </div>
#                 <div class="cn_name">
#                  아시아경제
#                 </div>
#                </div>
#                <div class="cn_state">
#                 내용작성전
#                </div>
#               </div>
#              </div>
#             </a>
#             <a class="cjs_nf_a _item _cds_link _newsflash_link" href="https://n.news.naver.com/article/009/0005431867" onclick="nclk(event, 'home.newsflash', '', '')">
#              <div class="cn_title_area">
#               <h4 class="cn_title">
#                대법관회의 “법원 공격은 법치주의 부정…매우 중대한 범죄”
#               </h4>
#               <div class="cn_snippet">
#                <div class="cn_journal_wrap">
#                 <div class="cn_thumb">
#                  <img alt="" height="10" loading="lazy" onerror="showNoImage(this)" src="https://mimgnews.pstatic.net/image/upload/office_logo/009/2024/10/29/logo_009_56_20241029153137.jpg?type=nf20_20" width="10"/>
#                 </div>
#                 <div class="cn_name">
#                  매일경제
#                 </div>
#                </div>
#                <div class="cn_state">
#                 내용작성전
#                </div>
#               </div>
#              </div>
#             </a>
#             <a class="cjs_nf_a _item _cds_link _newsflash_link" href="https://n.news.naver.com/article/025/0003415986" onclick="nclk(event, 'home.newsflash', '', '')">
#              <div class="cn_title_area">
#               <h4 class="cn_title">
#                대법관회의 “법원 공격은 법치주의 부정…매우 중대한 범죄”
#               </h4>
#               <div class="cn_snippet">
#                <div class="cn_journal_wrap">
#                 <div class="cn_thumb">
#                  <img alt="" height="10" loading="lazy" onerror="showNoImage(this)" src="https://mimgnews.pstatic.net/image/upload/office_logo/025/2021/08/20/logo_025_56_20210820165911.png?type=nf20_20" width="10"/>
#                 </div>
#                 <div class="cn_name">
#                  중앙일보
#                 </div>
#                </div>
#                <div class="cn_state">
#                 내용작성전
#                </div>
#               </div>
#              </div>
#             </a>
#             <button class="cjs_nf_btn_open is_close _toggle_btn" type="button">
#              <span class="blind">
#               속보 닫기
#              </span>
#             </button>
#            </div>
#           </div>
#          </div>
#         </div>
#         <div class="main_brick_item _channel_main_news_card_wrapper">
#          <div class="comp_news_feed comp_news_none">
#           <div class="cnf_journal_area">
#            <a class="cnf_journal" href="https://media.naver.com/press/094" onclick="nclk(event, 'home.editnfmedia', '', '')">
#             <div class="cnf_journal_thumb">
#              <img alt="" data-src="https://mimgnews.pstatic.net/image/upload/office_logo/094/2018/09/20/logo_094_56_20180920153620.png?type=nf36_36" height="18" loading="lazy" onerror="showNoImage(this)" width="18">
#              </img>
#             </div>
#             <em class="cnf_journal_name">
#              월간산
#             </em>
#             <span class="cnf_journal_sub">
#              01월 20일 08:11
#             </span>
#            </a>
#            <button class="cnf_btn_subscription _subscribe_btn" data-office_id="094" data-office_name="월간산" onclick="nclk(event, 'home.editnfset', '', '')">
#             <span class="blind">
#              구독
#             </span>
#            </button>
#           </div>
#           <a class="cnf_news_area _cds_link _editn_link" href="https://n.news.naver.com/article/094/0000012385" onclick="nclk(event, 'home.editnfimg', '', '')">
#            <div class="cnf_news_thumb">
#             <img alt="" data-src="https://mimgnews.pstatic.net/image/origin/094/2025/01/20/12385.jpg?type=nf168_108&amp;ut=20250120074510" height="54" loading="lazy" onerror="showNoImage(this)" width="80"/>
#            </div>
#            <strong class="cnf_news_title">
#             지중해 초강력 더위에 물·콜라 4리터, 반나절에 바닥 [지중해 자전거 여행기 中]
#            </strong>
#           </a>
#           <ul class="cnf_news_list">
#            <li class="cnf_news_item">
#             <a class="cnf_news _cds_link _editn_link" href="https://n.news.naver.com/article/094/0000012383" onclick="nclk(event, 'home.editnfimg', '', '')">
#              캐나다 오지에서 실종된 하이커, 50일 만에 생환
#             </a>
#            </li>
#            <li class="cnf_news_item">
#             <a class="cnf_news _cds_link _editn_link" href="https://n.news.naver.com/article/094/0000012384" onclick="nclk(event, 'home.editnfimg', '', '')">
#              변치 않는 꿋꿋함이 그립다 [들꽃을 그리다 홍매화]
#             </a>
#            </li>
#            <li class="cnf_news_item">
#             <a class="cnf_news _cds_link _editn_link" href="https://n.news.naver.com/article/094/0000012382" onclick="nclk(event, 'home.editnfimg', '', '')">
#              [속보] 김영미 대장, 혼자 걸어서 남극 1,700km 횡단 성공
#             </a>
#            </li>
#           </ul>
#          </div>
#         </div>
#         <div class="main_brick_item _channel_main_news_card_wrapper">
#          <div class="comp_news_feed comp_news_none">
#           <div class="cnf_journal_area">
#            <a class="cnf_journal" href="https://media.naver.com/press/656" onclick="nclk(event, 'home.editnfmedia', '', '')">
#             <div class="cnf_journal_thumb">
#              <img alt="" data-src="https://mimgnews.pstatic.net/image/upload/office_logo/656/2022/01/19/logo_656_56_20220119134936.png?type=nf36_36" height="18" loading="lazy" onerror="showNoImage(this)" width="18">
#              </img>
#             </div>
#             <em class="cnf_journal_name">
#              대전일보
#             </em>
#             <span class="cnf_journal_sub">
#              01월 20일 16:21
#             </span>
#            </a>
#            <button class="cnf_btn_subscription _subscribe_btn" data-office_id="656" data-office_name="대전일보" onclick="nclk(event, 'home.editnfset', '', '')">
#             <span class="blind">
#              구독
#             </span>
#            </button>
#           </div>
#           <a class="cnf_news_area _cds_link _editn_link" href="https://n.news.naver.com/article/656/0000118960" onclick="nclk(event, 'home.editnfimg', '', '')">
#            <div class="cnf_news_thumb">
#             <img alt="" data-src="https://mimgnews.pstatic.net/image/origin/656/2025/01/20/118960.jpg?type=nf168_108&amp;ut=20250120162011" height="54" loading="lazy" onerror="showNoImage(this)" width="80"/>
#            </div>
#            <strong class="cnf_news_title">
#             공수처, 尹 강제구인 검토…집행 시 현직 대통령 최초
#            </strong>
#           </a>
#           <ul class="cnf_news_list">
#            <li class="cnf_news_item">
#             <a class="cnf_news _cds_link _editn_link" href="https://n.news.naver.com/article/656/0000118935" onclick="nclk(event, 'home.editnfimg', '', '')">
#              조지호 경찰청장, 尹탄핵심판 증인 불출석…건강 등 사유
#             </a>
#            </li>
#            <li class="cnf_news_item">
#             <a class="cnf_news _cds_link _editn_link" href="https://n.news.naver.com/article/656/0000118900" onclick="nclk(event, 'home.editnfimg', '', '')">
#              경찰, '서부지법 난동' 46명 구속영장…2030 절반 이상
#             </a>
#            </li>
#            <li class="cnf_news_item">
#             <a class="cnf_news _cds_link _editn_link" href="https://n.news.naver.com/article/656/0000118941" onclick="nclk(event, 'home.editnfimg', '', '')">
#              민주, 당내 인권위 출범…'尹방어권' 논란 인권위 견제
#             </a>
#            </li>
#           </ul>
#          </div>
#         </div>
#         <div class="main_brick_item _channel_main_news_card_wrapper">
#          <div class="comp_news_feed comp_news_none">
#           <div class="cnf_journal_area">
#            <a class="cnf_journal" href="https://media.naver.com/press/088" onclick="nclk(event, 'home.editnfmedia', '', '')">
#             <div class="cnf_journal_thumb">
#              <img alt="" data-src="https://mimgnews.pstatic.net/image/upload/office_logo/088/2019/08/22/logo_088_56_20190822111422.png?type=nf36_36" height="18" loading="lazy" onerror="showNoImage(this)" width="18">
#              </img>
#             </div>
#             <em class="cnf_journal_name">
#              매일신문
#             </em>
#             <span class="cnf_journal_sub">
#              01월 20일 16:49
#             </span>
#            </a>
#            <button class="cnf_btn_subscription _subscribe_btn" data-office_id="088" data-office_name="매일신문" onclick="nclk(event, 'home.editnfset', '', '')">
#             <span class="blind">
#              구독
#             </span>
#            </button>
#           </div>
#           <a class="cnf_news_area _cds_link _editn_link" href="https://n.news.naver.com/article/088/0000927089" onclick="nclk(event, 'home.editnfimg', '', '')">
#            <div class="cnf_news_thumb">
#             <img alt="" data-src="https://mimgnews.pstatic.net/image/origin/088/2025/01/20/927089.jpg?type=nf168_108&amp;ut=20250120164909" height="54" loading="lazy" onerror="showNoImage(this)" width="80"/>
#            </div>
#            <strong class="cnf_news_title">
#             [속보] 공수처, 尹 강제구인 시도… 서울구치소 도착
#            </strong>
#           </a>
#           <ul class="cnf_news_list">
#            <li class="cnf_news_item">
#             <a class="cnf_news _cds_link _editn_link" href="https://n.news.naver.com/article/088/0000927038" onclick="nclk(event, 'home.editnfimg', '', '')">
#              검찰 내부망에 "尹 제기한 부정선거 의혹 수사해야" 글 올라와
#             </a>
#            </li>
#            <li class="cnf_news_item">
#             <a class="cnf_news _cds_link _editn_link" href="https://n.news.naver.com/article/088/0000927055" onclick="nclk(event, 'home.editnfimg', '', '')">
#              재판 중 위증하면 큰코다친다…대구지검, 작년 위증사범 41명 적발
#             </a>
#            </li>
#            <li class="cnf_news_item">
#             <a class="cnf_news _cds_link _editn_link" href="https://n.news.naver.com/article/088/0000927071" onclick="nclk(event, 'home.editnfimg', '', '')">
#              "헌재 방화", "민주당 의원 죽이면 게임 끝" 등 테러 글 온라인에 잇달아
#             </a>
#            </li>
#           </ul>
#          </div>
#         </div>
#         <div class="main_brick_item _channel_main_news_card_wrapper">
#          <div class="comp_news_feed comp_news_none">
#           <div class="cnf_journal_area">
#            <a class="cnf_journal" href="https://media.naver.com/press/020" onclick="nclk(event, 'home.editnfmedia', '', '')">
#             <div class="cnf_journal_thumb">
#              <img alt="" data-src="https://mimgnews.pstatic.net/image/upload/office_logo/020/2020/09/17/logo_020_56_20200917112548.jpg?type=nf36_36" height="18" loading="lazy" onerror="showNoImage(this)" width="18">
#              </img>
#             </div>
#             <em class="cnf_journal_name">
#              동아일보
#             </em>
#             <span class="cnf_journal_sub">
#              01월 20일 16:42
#             </span>
#            </a>
#            <button class="cnf_btn_subscription _subscribe_btn" data-office_id="020" data-office_name="동아일보" onclick="nclk(event, 'home.editnfset', '', '')">
#             <span class="blind">
#              구독
#             </span>
#            </button>
#           </div>
#           <a class="cnf_news_area _cds_link _editn_link" href="https://n.news.naver.com/article/020/0003611053" onclick="nclk(event, 'home.editnfimg', '', '')">
#            <div class="cnf_news_thumb">
#             <img alt="" data-src="https://mimgnews.pstatic.net/image/origin/020/2025/01/20/3611053.jpg?type=nf168_108&amp;ut=20250120162910" height="54" loading="lazy" onerror="showNoImage(this)" width="80"/>
#            </div>
#            <strong class="cnf_news_title">
#             “트럼프 취임식 행사 중 ‘행정명령 서명 쇼’ 벌일수도”
#            </strong>
#           </a>
#           <ul class="cnf_news_list">
#            <li class="cnf_news_item">
#             <a class="cnf_news _cds_link _editn_link" href="https://n.news.naver.com/article/020/0003611013" onclick="nclk(event, 'home.editnfimg', '', '')">
#              [단독]현직검사 “부정선거 의혹 수사해야…음모론으로만 치부 안돼” 檢내부망에 글
#             </a>
#            </li>
#            <li class="cnf_news_item">
#             <a class="cnf_news _cds_link _editn_link" href="https://n.news.naver.com/article/020/0003611003" onclick="nclk(event, 'home.editnfimg', '', '')">
#              “7층 판사실 중 영장판사 방만 의도적 파손…알고 온 듯”
#             </a>
#            </li>
#            <li class="cnf_news_item">
#             <a class="cnf_news _cds_link _editn_link" href="https://n.news.naver.com/article/020/0003611043" onclick="nclk(event, 'home.editnfimg', '', '')">
#              옥수수·콩·포도씨…‘씨앗 기름’ 정말 건강에 나쁠까?
#             </a>
#            </li>
#           </ul>
#          </div>
#         </div>
#         <div class="main_brick_item _channel_main_news_card_wrapper">
#          <div class="comp_news_feed comp_news_none">
#           <div class="cnf_journal_area">
#            <a class="cnf_journal" href="https://media.naver.com/press/310" onclick="nclk(event, 'home.editnfmedia', '', '')">
#             <div class="cnf_journal_thumb">
#              <img alt="" data-src="https://mimgnews.pstatic.net/image/upload/office_logo/310/2020/08/11/logo_310_56_20200811154942.png?type=nf36_36" height="18" loading="lazy" onerror="showNoImage(this)" width="18">
#              </img>
#             </div>
#             <em class="cnf_journal_name">
#              여성신문
#             </em>
#             <span class="cnf_journal_sub">
#              01월 20일 13:56
#             </span>
#            </a>
#            <button class="cnf_btn_subscription _subscribe_btn" data-office_id="310" data-office_name="여성신문" onclick="nclk(event, 'home.editnfset', '', '')">
#             <span class="blind">
#              구독
#             </span>
#            </button>
#           </div>
#           <a class="cnf_news_area _cds_link _editn_link" href="https://n.news.naver.com/article/310/0000122323" onclick="nclk(event, 'home.editnfimg', '', '')">
#            <div class="cnf_news_thumb">
#             <img alt="" data-src="https://mimgnews.pstatic.net/image/origin/310/2025/01/19/122323.jpg?type=nf168_108&amp;ut=20250119132814" height="54" loading="lazy" onerror="showNoImage(this)" width="80"/>
#            </div>
#            <strong class="cnf_news_title">
#             설 연휴 건강하게 보내려면…독감 백신부터
#            </strong>
#           </a>
#           <ul class="cnf_news_list">
#            <li class="cnf_news_item">
#             <a class="cnf_news _cds_link _editn_link" href="https://n.news.naver.com/article/310/0000122340" onclick="nclk(event, 'home.editnfimg', '', '')">
#              [정보라의 월간데모] 한겨울 옥상서 맞은 1년...박정혜·소현숙 힘내라
#             </a>
#            </li>
#            <li class="cnf_news_item">
#             <a class="cnf_news _cds_link _editn_link" href="https://n.news.naver.com/article/310/0000122331" onclick="nclk(event, 'home.editnfimg', '', '')">
#              공수처, 윤 대통령 오늘 출석통보...불응시 강제구인 검토
#             </a>
#            </li>
#            <li class="cnf_news_item">
#             <a class="cnf_news _cds_link _editn_link" href="https://n.news.naver.com/article/310/0000122277" onclick="nclk(event, 'home.editnfimg', '', '')">
#              [인터뷰] 김수정 변호사 “ ‘56년 만의 미투’ 최말자 선생님은 모든 여성의 영웅”
#             </a>
#            </li>
#           </ul>
#          </div>
#         </div>
#         <div class="main_brick_item _channel_main_news_card_wrapper">
#          <div class="comp_news_feed comp_news_none">
#           <div class="cnf_journal_area">
#            <a class="cnf_journal" href="https://media.naver.com/press/655" onclick="nclk(event, 'home.editnfmedia', '', '')">
#             <div class="cnf_journal_thumb">
#              <img alt="" data-src="https://mimgnews.pstatic.net/image/upload/office_logo/655/2022/01/20/logo_655_56_20220120164501.png?type=nf36_36" height="18" loading="lazy" onerror="showNoImage(this)" width="18">
#              </img>
#             </div>
#             <em class="cnf_journal_name">
#              CJB청주방송
#             </em>
#             <span class="cnf_journal_sub">
#              01월 20일 16:02
#             </span>
#            </a>
#            <button class="cnf_btn_subscription _subscribe_btn" data-office_id="655" data-office_name="CJB청주방송" onclick="nclk(event, 'home.editnfset', '', '')">
#             <span class="blind">
#              구독
#             </span>
#            </button>
#           </div>
#           <a class="cnf_news_area _cds_link _editn_link" href="https://n.news.naver.com/article/655/0000023099" onclick="nclk(event, 'home.editnfimg', '', '')">
#            <div class="cnf_news_thumb">
#             <img alt="" data-src="https://mimgnews.pstatic.net/image/origin/655/2025/01/20/23099.jpg?type=nf168_108&amp;ut=20250120094710" height="54" loading="lazy" onerror="showNoImage(this)" width="80"/>
#            </div>
#            <strong class="cnf_news_title">
#             권영세 “민노총이면 진작 훈방으로 풀어줬을 것”
#            </strong>
#           </a>
#           <ul class="cnf_news_list">
#            <li class="cnf_news_item">
#             <a class="cnf_news _cds_link _editn_link" href="https://n.news.naver.com/article/655/0000023102" onclick="nclk(event, 'home.editnfimg', '', '')">
#              [속보] 경호차장·본부장·부장, 미리 짠 듯 “휴대전화 두고 와”
#             </a>
#            </li>
#            <li class="cnf_news_item">
#             <a class="cnf_news _cds_link _editn_link" href="https://n.news.naver.com/article/655/0000023100" onclick="nclk(event, 'home.editnfimg', '', '')">
#              尹측 “외부인 접견 금지, 현직 대통령 눈·귀 막는 것”
#             </a>
#            </li>
#            <li class="cnf_news_item">
#             <a class="cnf_news _cds_link _editn_link" href="https://n.news.naver.com/article/655/0000023097" onclick="nclk(event, 'home.editnfimg', '', '')">
#              호모 사피엔스에게 세상은 결코 안전하지 않습니다..낙상 조심 또 조심 &lt;일상이 뉴스다!&gt;
#             </a>
#            </li>
#           </ul>
#          </div>
#         </div>
#         <div class="main_brick_item _channel_main_news_card_wrapper">
#          <div class="comp_news_feed comp_news_none">
#           <div class="cnf_journal_area">
#            <a class="cnf_journal" href="https://media.naver.com/press/002" onclick="nclk(event, 'home.editnfmedia', '', '')">
#             <div class="cnf_journal_thumb">
#              <img alt="" data-src="https://mimgnews.pstatic.net/image/upload/office_logo/002/2018/07/18/logo_002_56_20180718152018.png?type=nf36_36" height="18" loading="lazy" onerror="showNoImage(this)" width="18">
#              </img>
#             </div>
#             <em class="cnf_journal_name">
#              프레시안
#             </em>
#             <span class="cnf_journal_sub">
#              01월 20일 16:30
#             </span>
#            </a>
#            <button class="cnf_btn_subscription _subscribe_btn" data-office_id="002" data-office_name="프레시안" onclick="nclk(event, 'home.editnfset', '', '')">
#             <span class="blind">
#              구독
#             </span>
#            </button>
#           </div>
#           <a class="cnf_news_area _cds_link _editn_link" href="https://n.news.naver.com/article/002/0002369533" onclick="nclk(event, 'home.editnfimg', '', '')">
#            <div class="cnf_news_thumb">
#             <img alt="" data-src="https://mimgnews.pstatic.net/image/origin/002/2025/01/20/2369533.jpg?type=nf168_108&amp;ut=20250120094416" height="54" loading="lazy" onerror="showNoImage(this)" width="80"/>
#            </div>
#            <strong class="cnf_news_title">
#             [리얼미터] 정권연장론 48.6% vs 교체론 46.2%
#            </strong>
#           </a>
#           <ul class="cnf_news_list">
#            <li class="cnf_news_item">
#             <a class="cnf_news _cds_link _editn_link" href="https://n.news.naver.com/article/002/0002369631" onclick="nclk(event, 'home.editnfimg', '', '')">
#              경찰, '법원·헌재 폭력 사태' 현행범 66명 구속영장 청구
#             </a>
#            </li>
#            <li class="cnf_news_item">
#             <a class="cnf_news _cds_link _editn_link" href="https://n.news.naver.com/article/002/0002369552" onclick="nclk(event, 'home.editnfimg', '', '')">
#              판사 출신 변호사 "1.19 법원 폭도, 소요죄는 물론 내란죄 적용 여부도 조사해야"
#             </a>
#            </li>
#            <li class="cnf_news_item">
#             <a class="cnf_news _cds_link _editn_link" href="https://n.news.naver.com/article/002/0002369617" onclick="nclk(event, 'home.editnfimg', '', '')">
#              다보스 간 김동연…트럼프 취임식 갔다 '낙동강 오리알' 된 정치권
#             </a>
#            </li>
#           </ul>
#          </div>
#         </div>
#         <div class="main_brick_item _channel_main_news_card_wrapper">
#          <div class="comp_news_feed comp_news_none">
#           <div class="cnf_journal_area">
#            <a class="cnf_journal" href="https://media.naver.com/press/024" onclick="nclk(event, 'home.editnfmedia', '', '')">
#             <div class="cnf_journal_thumb">
# ...
#          <div class="comp_correction_banner">
#           <div class="ccb_banner_wrap">
#            <a class="ccb_link_banner" href="/main/ombudsman/errorArticleList.naver?mid=omb" onclick="nclk(event, 'home.editmodbanner', '', '')" target="_blank">
#             <picture>
#              <source media="(max-width: 320px)" srcset="https://ssl.pstatic.net/static.news/image/news/m/2024/07/29/ccb_correction_banner_320.png"/>
#              <img alt="고침, 정정, 반론 추후 보도 모음. 언론사의 정정 반론 추후 보도 기사를 모았습니다." class="light_type" loading="lazy" src="https://ssl.pstatic.net/static.news/image/news/m/2024/07/29/ccb_correction_banner.png" width="100%"/>
#             </picture>
#             <picture>
#              <source media="(max-width: 320px)" srcset="https://ssl.pstatic.net/static.news/image/news/m/2024/07/29/ccb_correction_banner_320_dark.png"/>
#              <img alt="고침, 정정, 반론 추후 보도 모음. 언론사의 정정 반론 추후 보도 기사를 모았습니다." class="dark_type" loading="lazy" src="https://ssl.pstatic.net/static.news/image/news/m/2024/07/29/ccb_correction_banner_dark.png" width="100%"/>
#             </picture>
#            </a>
#           </div>
#          </div>
#         </div>
#        </div>
#        <div class="brick-vowel _brick_column">
#        </div>
#        <div class="brick-vowel _brick_column">
#        </div>
#       </div>
#      </div>
#     </section>
#     <section class="main_aside _aside_wrapper">
#      <div class="main_aside_inner _aside_content">
#       <h3 class="blind">
#        구독
#       </h3>
#       <div class="_aside">
#       </div>
#       <script>
#        doAfterLoadEnd(loadAside);
#
#
# function loadAside() {
#     var forcePcVersion = "";
#
#     if (isMobileDevice() && !forcePcVersion) {
#         return;
#     }
#     var iframe = append();
#     var asideFixed;
#
#     window.addEventListener('message', function(event) {
#         var data = event.data;
#
#         if (event.origin !== "https://news.naver.com") {
#             return;
#         }
#
#         if (data.type === "setIframeSize" && data.height) {
#             iframe.style.height = data.height + 'px';
#             iframe.style.visibility = "";
#
#             try {
#                 asideFixed.deactivate(); // event 중복 적용되지 않게
#             } catch(e) {}
#
#             asideFixed = AsideFixed({
#                 "wrapper" : document.querySelector("._aside_wrapper")
#
#             });
#         }
#     });
#
#
#     function append() {
#         var iframe = document.createElement('iframe');
#
#         iframe.title = "구독 및 추천 채널";
#         iframe.width = "100%";
#         iframe.height = "0";
#         iframe.style.visibility = "hidden";
#         iframe.setAttribute("frameborder", "no");
#         iframe.setAttribute("scrolling", "no");
#         iframe.src = "https://news.naver.com/aside?oid=";
#
#         document.querySelector("._aside").appendChild(iframe);
#
#         return iframe;
#     }
# }
#       </script>
#      </div>
#     </section>
#     <div class="layer_toast" style="display: none">
#     </div>
#     <div class="layer_toast_journal_subscribe _subscribe_toast_layer" style="display: none">
#      <button class="lt_btn_set _subscribe_toast_btn" onclick="nclk(event, 'home.edittallchk', '', '')" type="button">
#      </button>
#     </div>
#    </div>
#   </div>
#   <!-- //ct -->
#   <hr/>
#   <div class="mp_footer">
#    <div class="f_maininfo">
#     <div class="f_maininfoinner">
#      <a class="r_pg_top _go_top" href="javascript:topPage();" id="goTop" onclick="nclk(event, 'fot.pctop', '', '');">
#       맨위로
#      </a>
#      <footer role="contentinfo">
#       <p class="u_cr">
#        <span class="u_ftm _footer_login">
#         <span class="u_cri u_cri_v1">
#          <a class="u_cra" data-mpurl='{"m":"https://m.naver.com/services.html","p":"https://www.naver.com/more.html"}' href="https://m.naver.com/services.html" onclick="nclk(event,'fot.serviceall','','');">
#           전체서비스
#          </a>
#         </span>
#        </span>
#        <span class="u_ftm">
#         <span class="u_cri u_cri_v1">
#          <a class="u_cra" data-mpurl='{"m":"https://m.news.naver.com/ombudsman/index","p":"https://news.naver.com/main/ombudsman/index.naver"}' href="https://m.news.naver.com/ombudsman/index" onclick="nclk(event,'fot.guide','','');">
#           서비스안내
#          </a>
#         </span>
#         <span class="u_cri u_cri_v1">
#          <a class="u_cra" data-mpurl='{"m":"https://help.naver.com/alias/news/news_001.naver","p":"https://help.naver.com/alias/news/news_001.naver"}' href="https://help.naver.com/alias/news/news_001.naver" onclick="nclk(event,'fot.report','','');">
#           오류신고
#          </a>
#         </span>
#         <span class="u_cri u_cri_v1">
#          <a class="u_cra" data-mpurl='{"m":"https://help.naver.com/alias/news/news_007.naver","p":"https://help.naver.com/alias/news/news_007.naver"}' href="https://help.naver.com/alias/news/news_007.naver" onclick="nclk(event,'fot.help','','');">
#           고객센터
#          </a>
#         </span>
#        </span>
#        <span class="cr_rule">
#         <span class="cr_rulea">
#          청소년 보호 책임자 : 이정규
#         </span>
#        </span>
#        <span class="u_presscopy">
#         각 언론사가 직접 콘텐츠를 편집합니다.
#        </span>
#        <span class="u_copyright">
#         이 콘텐츠의 저작권은 저작권자 또는 제공처에 있으며, 이를 무단 이용하는 경우 저작권법 등에 따라 법적 책임을 질 수 있습니다.
#        </span>
#        <span class="u_naverlogo">
#         <a class="u_naverlogo_a" data-mpurl='{"m":"https://www.navercorp.com/","p":"https://www.navercorp.com/"}' href="https://www.navercorp.com/" id="nhnLink" onclick="nclk(event,'fot.navercorp','','');">
#          NAVER
#         </a>
#        </span>
#       </p>
#      </footer>
#     </div>
#    </div>
#   </div>
#   <script src="https://ssl.pstatic.net/static.news/mnews/resources/20250117_004017/js/generated/news.mobile.js" type="text/javascript">
#   </script>
#   <script src="https://ssl.pstatic.net/static.news/mnews/resources/20250117_004017/js/generated/pressmain.dependency.js" type="text/javascript">
#   </script>
#   <script type="text/javascript">
#    var config = {
#         "neloCollectorUrl": "https://kr-col-ext.nelo.navercorp.com/_store",
#         "projectName": "P638fcb_news-mobile-front",
#         "host": "real"
#     }
#
#     try{
#         neloSender.init(config);
#     }catch(e){}
#   </script>
#   <script type="text/javascript">
#    /**
#  * 이 파일은 모바일 뉴스 서비스 전체 페이지에 적용되는 스크립트로써,
#  * 코드 추가 시 Front-End 성능 관점에서 주의를 요합니다.
#  */
# jQuery(window).on('load', function(){
#     setTimeout(onload, 10);
#
#     function onload(){
#         var oLnb = new news.Lnb('._lnb_scroll');
#         new news.ImageLazyLoader().load("img[data-src]");
#         new news.MoveTopButton("._go_top");
#
#
#         new news.HistoryManager().init("naver_mobile_news_history", "");
#
#         // iframe lazy-loading
#         (function(){
#             try {
#                 Array.prototype.slice.apply(document.querySelectorAll('iframe[data-src]'))
#                     .forEach(function(iframeEl) {
#                         var originSrc = iframeEl.getAttribute('data-src');
#                         if(originSrc) {
#                             iframeEl.setAttribute('src', originSrc);
#                         }
#                     });
#             }catch(e) {}
#         })();
#
#         if(typeof init === "function"){
#             init();
#         }
#
#         var cookie = news.Cookie.getInstance();
#         var isShownNewLnb = cookie.getItem("isShownNewLnb");
#         if(isShownNewLnb == null) {
#             isShownNewLnb = "Y";
#             cookie.setItem("isShownNewLnb", isShownNewLnb, 3650, "", "/");
#             $("._isNew").addClass("is_new");
#         }
#
#         {
#             var footerLogin = jQuery(document).find('._footer_login');
#             if(footerLogin <= 0) {
#                 return;
#             }
#
#             // 디바이스에 따라 로그인, 로그아웃 URL 분기
#             var loginUrl = "https://nid.naver.com/nidlogin.login";
#             var logoutUrl = "https://nid.naver.com/nidlogin.logout?";
#             if (news.Util.getAgentInfo().bMobileOrTablet) {
#                 loginUrl = "https://nid.naver.com/nidlogin.login?svctype=262144";
#                 logoutUrl = "https://nid.naver.com/nidlogin.logout?svctype=262144&";
#             }
#
#             if(news.LoginAssistor.isLoginUser()) {
#                 footerLogin.prepend('<span class="u_cri u_cri_v1"><a href="javascript:news.Util.logout(\''+logoutUrl+'url=\'+encodeURIComponent(location.href));" class="u_cra" id="news_logout" onclick="nclk(event,\'fot.logout\',\'\',\'\');" >로그아웃</a></span>')
#             }else {
#                 footerLogin.prepend('<span class="u_cri u_cri_v1"><a href="'+loginUrl+'" class="u_cra" id="news_login" onclick="nclk(event,\'fot.login\',\'\',\'\');" >로그인</a></span>')
#             }
#         }
#     }
# });
#   </script>
#   <script id="feedRefreshButtonTemplate" type="text/x-handlebars-template">
#    {{buttonText}}
#     <span class="paging">
#         <span class="blind">현재</span>{{currentPage}}
#         <em class="total"> / <span class="blind">전체</span>{{totalPage}}</em>
#     </span>
#   </script>
#   <script type="text/javascript">
#    try {
#         FeedCard($('._journalist_feed_card_wrapper'), 'journalist', 'https://m.news.naver.com');
#         FeedCard($('._series_feed_card_wrapper'), 'series', 'https://m.news.naver.com');
#     } catch (e) {
#         neloSender.sendErrorToNelo("[PC 언론사별] FeedCard 스크립트 오류 " + e);
#     }
#
#     try {
#         BrickGridForEditByPress($("._brick_gid_wrapper"));
#     } catch (e) {
#         neloSender.sendErrorToNelo("[PC 언론사별] BrickGridForEditByPress 스크립트 오류 " + e);
#     }
#
#     try {
#         PressMainStatusCard($('._press_main_status_wrapper'));
#     } catch (e) {
#         neloSender.sendErrorToNelo("[PC 언론사별] PressMainStatusCard 스크립트 오류 " + e);
#     }
#
#     try {
#         NewsFlashCard($('._newsflash_wrapper'));
#     } catch (e) {
#         neloSender.sendErrorToNelo("[PC 언론사별] NewsFlashCard 스크립트 오류 " + e);
#     }
#
#     try {
#
#
#         window.gladsdk.cmd.push(function () {
#             var adSlot = window.gladsdk.findAdSlot("glad_ad_sidebox");
#             adSlot.setCustomParam("calp", 'home');
#             window.gladsdk.displayAd(adSlot);
#
#
#             window.gladsdk.addEventListener(window.gladsdk.event.ERROR, function (ad, error) {
#                 $("._card_ad").hide();
#             });
#         });
#     } catch (e) {
#         neloSender.sendErrorToNelo("[PC 언론사별] 광고 호출 스크립트 오류 " + e);
#     }
#
#     try {
#         $('._channel_news_card_wrapper').each(function () {
#             var wrapper = $(this);
#             ChannelNewsCard(wrapper, 'https://m.news.naver.com');
#         });
#     } catch (e) {
#         neloSender.sendErrorToNelo("[PC 언론사별] ChannelNewsCard 스크립트 오류" + e);
#     }
#
#     try {
#         ChannelMainNewsCard($('._channel_main_news_card_wrapper'), 'https://m.news.naver.com');
#     } catch (e) {
#         neloSender.sendErrorToNelo("[PC 언론사별] ChannelMainNewsCard 스크립트 오류 " + e);
#     }
#
#     try {
#         SubscribeBannerShortCard($('._short_subscribe_banner_card_wrapper'), 'https://m.news.naver.com');
#         SubscribeBannerLongCard($('._long_subscribe_banner_card_wrapper'), 'https://m.news.naver.com');
#     } catch (e) {
#         neloSender.sendErrorToNelo("[PC 언론사별] SubscribeBannerCard 스크립트 오류 " + e);
#     }
#
#     try {
#         WeeklySpecialReportCard($('._weekly_special_report_card_wrapper'));
#     } catch (e) {
#         neloSender.sendErrorToNelo("[PC 언론사별] WeeklySpecialReportCard 스크립트 오류 " + e);
#     }
#
#     try {
#         $('._horizontal_card_wrapper').each(function () {
#             var wrapper = $(this);
#             HorizontalTypeCard(wrapper, 'https://m.news.naver.com');
#         });
#     } catch (e) {
#         neloSender.sendErrorToNelo("[PC 언론사별] HorizontalTypeCard 스크립트 오류 " + e);
#     }
#
#     try {
#         SpecialReportCard($('._special_report_card_wrapper'), 'https://m.news.naver.com');
#     } catch (e) {
#         neloSender.sendErrorToNelo("[PC 언론사별] SpecialReportCard 스크립트 오류 " + e);
#     }
#
#     ArticleLinkParamsAppender('news_media_pc');
#
#     // Impression
#     try {
#         news.Impression.getInstance().init();
#     } catch (e) {
#         neloSender.sendErrorToNelo("[PC 언론사별] Impression init 스크립트 오류 " + e);
#     }
#
#     new news.ImageLazyLoader().load("img[data-src]");
#   </script>
#   <script>
#    var gnb_service = 'news';
#     var gnb_logout = encodeURIComponent(location.href);
#     var gnb_template = 'gnb_utf8';
#     var gnb_brightness = 3;
#     var gnb_item_hide_option= 128;
#
#     doAfterLoadEnd(function () {
#         try {
#             GlobalMPUrlManager.init();
#         } catch (e) {}
#     });
#
#     doAfterLoadEnd(function() {
#         if (!document.querySelector('#gnb') || isMobileDevice() === true) {
#             return;
#         }
#
#         var gnb_src = "https://ssl.pstatic.net/static.gn/templates/gnb_utf8?2025012016";
#
#         // GnbHelper를 이용하여 GNB Layer를 닫을 수 있도록 지원한다.
#         if (window.jindo) {
#             jindo.LazyLoading.load(
#                 gnb_src,
#                 function() {
#                     try {
#                         getGNB();
#                     } catch(e) {}
#                 },
#                 'utf-8'
#             );
#
#             jindo.$Fn(function (oEvent) {
#
#                 GnbHelper.attachClick(oEvent.$value().target);
#             }).attach(document, 'click');
#         } else if (window.jQuery) {
#             new news.JsLoader().
#                 load(
#                     [gnb_src],
#                     function() {
#                         try {
#                             getGNB();
#                         } catch(e) {}
#                     }
#                 );
#
#             $(document).on("click", function(event) {
#                 GnbHelper.attachClick(event.target);
#             });
#         }
#     });
#   </script>
#   <script>
#    doAfterLoadEnd(function() {
#         if (!document.querySelector('.news_header')){
#             return;
#         }
#
#         try {
#             GnbFloatingManager.init();
#         } catch (e) { }
#     });
#   </script>
#   <script>
#    doAfterLoadEnd(function() {
#     try {
#         new SearchAutoComplete({
#             content: document.querySelector("._search_content"),
#             contentToggleBtn: document.querySelector("._search_content_toggle_btn"),
#             isMobile: isMobileDevice(),
#             nClickType: "newsM"
#         });
#     } catch(e) {}
# });
#   </script>
#   <!-- LCS -->
#   <script type="text/javascript">
#    function initMa(){
#     var data = {
#         "service": "news",
#         "baseInfo": {
#             "category": (function(){
#
#                 var result = "언론사별(신규)";
#
#                 if(result !== ""){
#                     return result;
#                 }
#                 try{
#
#                     return document.querySelector('meta[property="og:title"]')
#                         .getAttribute('content')
#                         .replace(/[\s]*:+[\s]*네이버[\s]*뉴스/, '');
#                 }catch(e){
#                     return "";
#                 }
#             })()
#         },
#         "extraInfo": {}
#     };
#
#
#
#     try{
#         ma.init({
#             api: "https://ma.news.naver.com/l",
#             data: data
#         });
#     }catch(e){}
# }
#   </script>
#   <script type="text/javascript">
#    window.ntm_news = window.ntm_news || [];
#
#     doAfterLoadEnd(function () {
#         var ntmUrl = "https://ntm.pstatic.net/scripts/ntm_b7032129a433.js";
#
#
#
#
#
#         ntmInit(ntmUrl);
#     });
#   </script>
#   <script type="text/javascript">
#    // NLog pageview 전송
#     var eventType = "onpageshow" in window ? "pageshow" : "load";
#     jQuery(window).on(eventType, function() {
#         var sti = "";
#         var gdid = "";
#
#
#
#
#
#
#                 if (isMobileDevice()) {
#                     // mobile
#
#                         sti = "m_news";
#
#                 } else {
#                     // pc
#
#                 }
#
#
#
#         // ma 전송
#         try {
#             initMa();
#         } catch (e) {
#         }
#
#         ntmCustomPageViewSend({
#             sti: sti,
#             gdid: gdid
#         });
#     });
#   </script>
#   <!-- //LCS -->
#   <div id="videoWrap">
#   </div>
#  </body>
# </html>

# %%
news_title = bs_obj.findAll('div',{'class':'cjs_t'})

# %%
len(news_title)
# Out:
# 0

# %%
news_title
# Out:
# []

# %%
for title in news_title : 
    print(title.text)

# %%
news_dec = bs_obj.findAll('p',{'class':'cjs_d'})

# %%
len(news_dec)
# Out:
# 0

# %%
for dec in news_dec : 
    print(dec.text)

# %% [markdown]
# ### 네이버 뉴스섹션메뉴와 섹션별 url 추출

# %%
from urllib.request import urlopen
import bs4
import pandas as pd

# %%
url = 'https://news.naver.com'

html = urlopen(url)

bs_obj = bs4.BeautifulSoup(html, 'html.parser')

# %%
# 네이버 뉴스 섹션메뉴 태그 확인(개발자도구)
# body > section > header > div.Nlnb._float_lnb > div > div > div.Nlnb_left._lnb_scroll > div > div > ul
# selector가 너무 길어서 유용하지 않아 보임
# 직접 확인한 태그와 클래스 속성 사용
# ul 태그의 class : Nlnb_menu_list
uls = bs_obj.findAll("ul",{"class":"Nlnb_menu_list"})
len(uls) # 원소가 1개이므로
ul = bs_obj.find("ul",{"class":"Nlnb_menu_list"})
ul
# Out:
# <ul class="Nlnb_menu_list" role="menu">
# <li class="Nlist_item is_active"><a aria-selected="true" class="Nitem_link" href="https://news.naver.com/?viewType=pc" onclick="nclk(event,'lnb.pcmedia','','');" role="menuitem"><span class="Nitem_link_menu">언론사별</span></a></li>
# <li class="Nlist_item"><a aria-selected="false" class="Nitem_link" href="https://news.naver.com/section/100" onclick="nclk(event,'lnb.pol','','');" role="menuitem"><span class="Nitem_link_menu">정치</span></a></li>
# <li class="Nlist_item"><a aria-selected="false" class="Nitem_link" href="https://news.naver.com/section/101" onclick="nclk(event,'lnb.eco','','');" role="menuitem"><span class="Nitem_link_menu">경제</span></a></li>
# <li class="Nlist_item"><a aria-selected="false" class="Nitem_link" href="https://news.naver.com/section/102" onclick="nclk(event,'lnb.soc','','');" role="menuitem"><span class="Nitem_link_menu">사회</span></a></li>
# <li class="Nlist_item"><a aria-selected="false" class="Nitem_link" href="https://news.naver.com/section/103" onclick="nclk(event,'lnb.lif','','');" role="menuitem"><span class="Nitem_link_menu">생활/문화</span></a></li>
# <li class="Nlist_item"><a aria-selected="false" class="Nitem_link" href="https://news.naver.com/section/105" onclick="nclk(event,'lnb.sci','','');" role="menuitem"><span class="Nitem_link_menu">IT/과학</span></a></li>
# <li class="Nlist_item"><a aria-selected="false" class="Nitem_link" href="https://news.naver.com/section/104" onclick="nclk(event,'lnb.wor','','');" role="menuitem"><span class="Nitem_link_menu">세계</span></a></li>
# <li class="Nlist_item _isNew"><a aria-selected="false" class="Nitem_link" href="https://news.naver.com/main/ranking/popularDay.naver" onclick="nclk(event,'lnb.rank','','');" role="menuitem"><span class="Nitem_link_menu">랭킹</span></a></li>
# <li class="Nlist_item _isNew"><a aria-selected="false" class="Nitem_link" href="https://news.naver.com/newspaper/home?viewType=pc" onclick="nclk(event,'lnb.paper','','');" role="menuitem"><span class="Nitem_link_menu">신문보기</span></a></li>
# <li class="Nlist_item"><a aria-selected="false" class="Nitem_link" href="https://news.naver.com/opinion/home" onclick="nclk(event,'lnb.opi','','');" role="menuitem"><span class="Nitem_link_menu">오피니언</span></a></li>
# <li class="Nlist_item"><a aria-selected="false" class="Nitem_link" href="https://news.naver.com/main/tv/index.naver?mid=tvh" onclick="nclk(event,'lnb.tv','','');" role="menuitem"><span class="Nitem_link_menu">TV</span></a></li>
# <li class="Nlist_item"><a aria-selected="false" class="Nitem_link" href="https://news.naver.com/factcheck/main" onclick="nclk(event,'lnb.fact','','');" role="menuitem"><span class="Nitem_link_menu">팩트체크</span></a></li>
# <li class="Nlist_item"><a aria-selected="false" class="Nitem_link" href="https://media.naver.com/algorithm" onclick="nclk(event,'lnb.algo','','');" role="menuitem"><span class="Nitem_link_menu">알고리즘 안내</span></a></li>
# <li class="Nlist_item _isNew"><a aria-selected="false" class="Nitem_link" href="https://news.naver.com/main/ombudsman/errorArticleList.naver?mid=omb" onclick="nclk(event,'lnb.correct','','');" role="menuitem"><span class="Nitem_link_menu">정정보도 모음</span></a></li>
# </ul>

# %%
lis = ul.findAll('li')
len(lis)
# Out:
# 14

# %%
for li in lis :
    a_tag = li.find('a')
    print(a_tag.text," : ",a_tag['href'])
# Out:
# 언론사별  :  https://news.naver.com/?viewType=pc
# 정치  :  https://news.naver.com/section/100
# 경제  :  https://news.naver.com/section/101
# 사회  :  https://news.naver.com/section/102
# 생활/문화  :  https://news.naver.com/section/103
# IT/과학  :  https://news.naver.com/section/105
# 세계  :  https://news.naver.com/section/104
# 랭킹  :  https://news.naver.com/main/ranking/popularDay.naver
# 신문보기  :  https://news.naver.com/newspaper/home?viewType=pc
# 오피니언  :  https://news.naver.com/opinion/home
# TV  :  https://news.naver.com/main/tv/index.naver?mid=tvh
# 팩트체크  :  https://news.naver.com/factcheck/main
# 알고리즘 안내  :  https://media.naver.com/algorithm
# 정정보도 모음  :  https://news.naver.com/main/ombudsman/errorArticleList.naver?mid=omb

# %%
# li태그를 이용해서 추출
lis = bs_obj.findAll("li",{"class" : "Nlist_item"})
len(lis)
# Out:
# 14

# %%
for li in lis :
    a_tag = li.find('a')
    print(a_tag.text)
    print(a_tag['href'])
# Out:
# 언론사별
# https://news.naver.com/?viewType=pc
# 정치
# https://news.naver.com/section/100
# 경제
# https://news.naver.com/section/101
# 사회
# https://news.naver.com/section/102
# 생활/문화
# https://news.naver.com/section/103
# IT/과학
# https://news.naver.com/section/105
# 세계
# https://news.naver.com/section/104
# 랭킹
# https://news.naver.com/main/ranking/popularDay.naver
# 신문보기
# https://news.naver.com/newspaper/home?viewType=pc
# 오피니언
# https://news.naver.com/opinion/home
# TV
# https://news.naver.com/main/tv/index.naver?mid=tvh
# 팩트체크
# https://news.naver.com/factcheck/main
# 알고리즘 안내
# https://media.naver.com/algorithm
# 정정보도 모음
# https://news.naver.com/main/ombudsman/errorArticleList.naver?mid=omb

# %%
# 수집 데이터 df로 구성 후 저장
section = []
link = []

# %%
for li in lis :
    a_tag = li.find('a')
    section.append(a_tag.text)
    link.append(a_tag['href'])

# %%
col_dict = {'section':section, "link":link}
news_section_df = pd.DataFrame(col_dict)
news_section_df
# Out:
#     section                                               link
# 0      언론사별                https://news.naver.com/?viewType=pc
# 1        정치                 https://news.naver.com/section/100
# 2        경제                 https://news.naver.com/section/101
# 3        사회                 https://news.naver.com/section/102
# 4     생활/문화                 https://news.naver.com/section/103
# 5     IT/과학                 https://news.naver.com/section/105
# 6        세계                 https://news.naver.com/section/104
# 7        랭킹  https://news.naver.com/main/ranking/popularDay...
# 8      신문보기  https://news.naver.com/newspaper/home?viewType=pc
# 9      오피니언                https://news.naver.com/opinion/home
# 10       TV  https://news.naver.com/main/tv/index.naver?mid...
# 11     팩트체크              https://news.naver.com/factcheck/main
# 12  알고리즘 안내                  https://media.naver.com/algorithm
# 13  정정보도 모음  https://news.naver.com/main/ombudsman/errorArt...

# %%
# news_section_df.to_csv('./navew_news_section.csv', encoding='euc-kr')
news_section_df.to_csv('c:\\Myexam\\navew_news_section.csv', encoding='euc-kr')
